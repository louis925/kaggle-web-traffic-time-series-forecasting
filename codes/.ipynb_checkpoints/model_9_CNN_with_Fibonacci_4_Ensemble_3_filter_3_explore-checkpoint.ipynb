# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# ### Kaggle - Web Traffic Time Series Forecasting
#
# ## Model 09 - CNN with Fibonacci
#
# ### v4 Ensemble
#
# by Louis Yang
#
# Use Fibonacci series median instead of median. The Fib. median are now compute on both training and CV set separately.
#
# Split into groups based on the scale of visit number and train individual model in each group
#
# The first 2 groups use original Fibonacci median as prediction. The rest groups use the trained CNN as prediction.
#
# Test on stage 2 data.
#
# Original model: 'model_9_CNN_with_Fibonacci_4_Ensemble'
#
# Ensemble: automatically evaluate the same model 4 times

# %%
model_name = 'model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3_explore'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import gc  # Python garbage collect
from tools import *

# %% [markdown]
# ## Input

# %%
train_file = 'train_2.csv'

# %%
print('%%% Reading data '+ train_file + ' ... ', end = '', flush = True)
input_df = pd.read_csv('../data/' + train_file)
print('done!')
# Out:
# %%% Reading data train_2.csv ... done!

# %% [markdown]
# input_df.head()

# %% [markdown]
# input_df.info()

# %%
input_df_dates = input_df.columns[1:]; #input_df_dates

# %% [markdown]
# ## Processing Data
# Generate training set and test (predict) set

# %% [markdown]
# ### Day of week alignment

# %%
from datetime import datetime
def weekday(datestr):
    return datetime.strptime(datestr,'%Y-%m-%d').weekday()
def daydiff(dstr1,dstr2):
    return datetime.strptime(dstr1,'%Y-%m-%d') - datetime.strptime(dstr2,'%Y-%m-%d')

# %% [markdown]
# We need to predict output (Y_output_pred) start from Sunday (6) for data set 1. (0: Monday, 6: Sunday)

# %%
# We take the x_length + y_length days of data only
# This part then split into x_length as input X and y_length as output Y
x_length = 63  # input period
y_length = 63  # predict period

# %%
#test_length = 0  # for predicting
test_length = y_length  # for self testing

# %% [markdown]
# Shift everything forward by y_length = 63 days to allows self testing without Kaggle

# %% [markdown]
# #### X

# %%
X_input_dates = input_df_dates[-x_length-test_length-364:-test_length-364]; #X_input_dates

# %%
X_input_first_day = X_input_dates[0]
X_input_final_day = X_input_dates[-1]
X_input_first_day, X_input_final_day
# Out:
# ('2016-04-29', '2016-06-30')

# %% [markdown]
# daydiff(X_input_first_day, X_input_final_day)  # should be 1 - y_length

# %%
# X for output set
if test_length:
    X_output_dates = input_df_dates[-x_length-test_length:-test_length]
else:
    X_output_dates = input_df_dates[-x_length:]
#X_output_dates

# %%
X_output_first_day = X_output_dates[0]
X_output_final_day = X_output_dates[-1]
X_output_first_day, X_output_final_day
# Out:
# ('2017-04-28', '2017-06-29')

# %% [markdown]
# daydiff(X_output_first_day, X_output_final_day)  # should be 1 - y_length

# %% [markdown]
# weekday(X_input_first_day), weekday(X_output_first_day)

# %% [markdown]
# Both are Wednesday (2).

# %% [markdown]
# #### Y

# %%
Y_input_dates = input_df_dates[-test_length-364:-test_length-364+y_length]; #Y_input_dates

# %%
Y_input_first_day = Y_input_dates[0]
Y_input_final_day = Y_input_dates[-1]
Y_input_first_day, Y_input_final_day
# Out:
# ('2016-07-01', '2016-09-01')

# %% [markdown]
# daydiff(Y_input_first_day, Y_input_final_day)

# %%
# Y for output set
if test_length:
    Y_output_dates = input_df_dates[-test_length:]
else:
    Y_output_first_day = '2017-09-12'  ## Make sure it is correct when predicting !!!!!!!
    Y_output_dates = pd.Index(np.arange(np.datetime64(Y_output_first_day), 
                                        np.datetime64(Y_output_first_day)
                                        + np.timedelta64(y_length, 'D')).astype('str'))
#Y_output_dates

# %%
Y_output_first_day = Y_output_dates[0]
Y_output_final_day = Y_output_dates[-1]
Y_output_first_day, Y_output_final_day
# Out:
# ('2017-06-30', '2017-08-31')

# %% [markdown]
# daydiff(Y_output_first_day, Y_output_final_day)  # should be 1 - y_length

# %% [markdown]
# weekday(Y_input_first_day), weekday(Y_output_first_day)

# %% [markdown]
# Both are Sunday (6).

# %% [markdown]
# ## Fibonacci

# %% [markdown]
# #### Window Sizes

# %% [markdown]
# The window sizes are given by Ehsan https://www.kaggle.com/safavieh

# %%
windows = [11, 18, 30, 48, 78, 126, 203, 329]
fib_length = max(windows)#; fib_length

# %% [markdown]
# #### Data selection

# %% [markdown]
# In this testing code, we did not include the last y_length days since in the real predicting stage, we don't know their visits.

# %%
if test_length:
    fib_output_dates = input_df_dates[-fib_length-test_length:-test_length]
else:
    fib_output_dates = input_df_dates[-fib_length:]
fib_input_dates = input_df_dates[-fib_length-test_length-364:-test_length-364]
fib_input_dates, fib_output_dates
# Out:
# (Index(['2015-08-07', '2015-08-08', '2015-08-09', '2015-08-10', '2015-08-11',
#         '2015-08-12', '2015-08-13', '2015-08-14', '2015-08-15', '2015-08-16',
#         ...
#         '2016-06-21', '2016-06-22', '2016-06-23', '2016-06-24', '2016-06-25',
#         '2016-06-26', '2016-06-27', '2016-06-28', '2016-06-29', '2016-06-30'],
#        dtype='object', length=329),
#  Index(['2016-08-05', '2016-08-06', '2016-08-07', '2016-08-08', '2016-08-09',
#         '2016-08-10', '2016-08-11', '2016-08-12', '2016-08-13', '2016-08-14',
#         ...
#         '2017-06-20', '2017-06-21', '2017-06-22', '2017-06-23', '2017-06-24',
#         '2017-06-25', '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29'],
#        dtype='object', length=329))

# %%
weekday(fib_input_dates[0]), weekday(fib_output_dates[0])
# Out:
# (4, 4)

# %%
fib_output_data = input_df[fib_output_dates].values; fib_output_data
# Out:
# array([[  49.,   10.,   19., ...,   32.,   34.,   21.],
#        [  30.,   16.,   54., ...,  127.,  104.,   20.],
#        [   7.,    2.,    1., ...,    5.,    5.,    0.],
#        ...,
#        [  nan,   nan,   nan, ...,   35.,   46.,   43.],
#        [  nan,   nan,   nan, ...,    6.,    6.,    7.],
#        [  nan,   nan,   nan, ...,   21.,   20.,   14.]])

# %%
fib_input_data = input_df[fib_input_dates].values; fib_input_data
# Out:
# array([[  4.,  11.,  10., ...,  18.,  23.,  12.],
#        [  2.,  23.,  12., ...,  24.,  16.,  15.],
#        [  5.,   1.,   4., ...,   5.,   1.,   4.],
#        ...,
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan]])

# %% [markdown]
# #### Fibonacci median in each window

# %%
fib_input_median_list = np.array([np.nanmedian(fib_input_data[:, -w:] , axis=-1) 
                            for w in windows])
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
fib_output_median_list = np.array([np.nanmedian(fib_output_data[:, -w:] , axis=-1) 
                            for w in windows])
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
del fib_input_data
del fib_output_data
gc.collect()

# %% [markdown]
# fib_input_median_list.T.shape

# %% [markdown]
# fib_output_median_na = np.nanmedian(fib_output_median_list.T, axis=-1)

# %% [markdown]
# fib_output_median_na

# %%
fib_input_median = np.nan_to_num(np.nanmedian(fib_input_median_list.T, axis=-1)); fib_input_median.shape
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# (145063,)

# %%
fib_output_median = np.nan_to_num(np.nanmedian(fib_output_median_list.T, axis=-1)); fib_output_median.shape
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# (145063,)

# %%
fib_input_median
# Out:
# array([ 16.5 ,  15.25,   4.  , ...,   0.  ,   0.  ,   0.  ])

# %%
fib_output_median
# Out:
# array([ 24.  ,  22.5 ,   4.  , ...,  34.  ,   7.75,  11.25])

# %% [markdown]
# We will use this as the center and part of the result

# %%
Y_input_fib = fib_input_median.reshape(-1,1)
Y_output_fib = fib_output_median.reshape(-1,1)

# %% [markdown]
# ## Data Selection
# Select x_length + y_length days of data as input or ouput set.

# %% [markdown]
# ### Input data

# %% [markdown]
# input_data contains X_input and Y_input array

# %%
input_dates = pd.Index(np.concatenate((X_input_dates, Y_input_dates)))
input_dates, X_input_first_day, Y_input_final_day
# Out:
# (Index(['2016-04-29', '2016-04-30', '2016-05-01', '2016-05-02', '2016-05-03',
#         '2016-05-04', '2016-05-05', '2016-05-06', '2016-05-07', '2016-05-08',
#         ...
#         '2016-08-23', '2016-08-24', '2016-08-25', '2016-08-26', '2016-08-27',
#         '2016-08-28', '2016-08-29', '2016-08-30', '2016-08-31', '2016-09-01'],
#        dtype='object', length=126), '2016-04-29', '2016-09-01')

# %%
input_data = input_df[input_dates].values; #input_data  # input_data with nan

# %% [markdown]
# ##### Convert nan to number 0.

# %%
input_data_num = np.nan_to_num(input_data); #input_data_num  # intput_data with nan -> 0.

# %% [markdown]
# input_data_num.shape

# %% [markdown]
# ### Output Data

# %% [markdown]
# output_data for this self-testing script contains both X_output and Y_output

# %%
if test_length:
    output_dates = pd.Index(np.concatenate((X_output_dates, Y_output_dates)))
else:
    output_dates = X_output_dates
output_dates, X_output_first_day, X_output_final_day, Y_output_final_day
# Out:
# (Index(['2017-04-28', '2017-04-29', '2017-04-30', '2017-05-01', '2017-05-02',
#         '2017-05-03', '2017-05-04', '2017-05-05', '2017-05-06', '2017-05-07',
#         ...
#         '2017-08-22', '2017-08-23', '2017-08-24', '2017-08-25', '2017-08-26',
#         '2017-08-27', '2017-08-28', '2017-08-29', '2017-08-30', '2017-08-31'],
#        dtype='object', length=126), '2017-04-28', '2017-06-29', '2017-08-31')

# %%
output_dates.shape
# Out:
# (126,)

# %%
output_data = input_df[output_dates].values; #output_data

# %% [markdown]
# ##### Convert nan to number 0.

# %%
output_data_num = np.nan_to_num(output_data); output_data_num
# Out:
# array([[ 24.,  20.,  36., ...,  26.,  24.,  21.],
#        [ 19.,  18.,  12., ...,  29.,  34.,  25.],
#        [  2.,   0.,   3., ...,   8.,  12.,   9.],
#        ...,
#        [ 27.,  84.,  14., ...,  21.,  11.,   9.],
#        [  7.,  10.,  13., ...,   3.,   9.,   2.],
#        [ 34.,  16.,  16., ...,   9.,   6.,   5.]])

# %%
output_data_num.shape
# Out:
# (145063, 126)

# %% [markdown]
# ### View

# %% [markdown]
# def view(x, xlim=None, ylim=None, yscale='linear', title=None, show=True):
#     plt.yscale(yscale)
#     plt.plot(x)
#     if ylim: plt.ylim(ylim)
#     if xlim: plt.xlim(xlim)
#     if title: plt.title(title)
#     if show: plt.show()
#
# def viewi(X, i, xlim=None, ylim=None, yscale='linear', show=True):
#     view(X[i], xlim=xlim, ylim=ylim, yscale=yscale, title='i = ' + str(i), show=show)
#
# def examine(X, n=5, xlim=None, ylim=None):
#     '''randomly show some example in feature and label'''
#     n_X = len(X)
#     view_list = np.random.choice(n_X, min(n, n_X), replace=False)
#     for i in view_list:
#         viewi(X, i, xlim=xlim, ylim=ylim)
#     return view_list

# %% [markdown]
# examine(input_data)

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Log

# %%
def log(X):
    return np.log10(X + 1.0)
def unlog(X):
    return np.clip(np.power(10., X) - 1.0, 0.0, None)

# %%
input_data_log = log(input_data_num)
output_data_log = log(output_data_num)

# %% [markdown]
# ##### Check Log transformation

# %%
input_data_log.shape, input_data.shape, output_data_log.shape, output_data.shape
# Out:
# ((145063, 126), (145063, 126), (145063, 126), (145063, 126))

# %% [markdown]
# input_data_log

# %% [markdown]
# output_data_log

# %% [markdown]
# #Check inverse log transformation
# input_data_log_tt = unlog(input_data_log)
# input_data_log_tt_dif = input_data_log_tt - input_data_num
# input_data_log_tt_dif.min(), input_data_log_tt_dif.max()

# %% [markdown]
# #Check inverse log transformation
# output_data_log_tt = unlog(output_data_log)
# output_data_log_tt_dif = output_data_log_tt - output_data_num
# output_data_log_tt_dif.min(), output_data_log_tt_dif.max()

# %% [markdown]
# del input_data_log_tt
# del input_data_log_tt_dif
# del output_data_log_tt
# del output_data_log_tt_dif

# %%
gc.collect()
# Out:
# 283

# %% [markdown]
# ### Normalization (Shift and Scale)

# %% [markdown]
# #### Use Fib Median as the Center

# %%
#input_center = log(fib_input_median).reshape(-1,1)
output_center = log(fib_output_median).reshape(-1,1)
input_center = output_center  # using output_center instead

# %%
input_center, output_center
# Out:
# (array([[ 1.39794001],
#         [ 1.37106786],
#         [ 0.69897   ],
#         ...,
#         [ 1.54406804],
#         [ 0.94200805],
#         [ 1.08813609]]), array([[ 1.39794001],
#         [ 1.37106786],
#         [ 0.69897   ],
#         ...,
#         [ 1.54406804],
#         [ 0.94200805],
#         [ 1.08813609]]))

# %% [markdown]
# #### Choice of default scale

# %%
input_raw_log = log(input_data)  # log of input_data with nan
output_raw_log = log(output_data)  # log of output_data with nan

# %% [markdown]
# np.median(np.nanstd(input_data_log[:,:x_length], axis=-1))

# %% [markdown]
# np.mean(np.nanstd(input_data_log[:,:x_length], axis=-1))

# %%
default_input_scale = np.nanmedian(np.nanstd(input_raw_log[:,:x_length], axis=-1))
default_input_scale
# Out:
# c:\python3\lib\site-packages\numpy\lib\nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# 0.17974041809557845

# %%
default_output_scale = np.nanmedian(np.nanstd(output_raw_log[:,:x_length], axis=-1))
default_output_scale
# Out:
# c:\python3\lib\site-packages\numpy\lib\nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# 0.16425448559207598

# %% [markdown]
# #### Compute Median and Stdev

# %% [markdown]
# Here we are not using this median as center

# %% [markdown]
# input_center = np.nanmedian(input_data_log[:,:x_length], axis=-1).reshape(-1,1)
# input_center  # remember sample-wised center

# %%
input_scale = np.nanstd(input_data_log[:,:x_length], axis=-1).reshape(-1,1)
input_scale[input_scale == 0.0] = default_input_scale  # Prevent divid by zero 
# non-zero value is choose based on the median of other page with non-zero stdev)
input_scale  # remember sample-wised scale
# Out:
# array([[ 0.22042467],
#        [ 0.1944303 ],
#        [ 0.23390395],
#        ...,
#        [ 0.17974042],
#        [ 0.17974042],
#        [ 0.17974042]])

# %% [markdown]
# output_center = np.nanmedian(output_data_log[:,:x_length], axis=-1).reshape(-1,1)
# output_center  # remember sample-wised center

# %%
output_scale = np.nanstd(output_data_log[:,:x_length], axis=-1).reshape(-1,1)
output_scale[output_scale == 0.0] = default_output_scale  # Prevent divid by zero
output_scale  # remember sample-wised scale
# Out:
# array([[ 0.15715761],
#        [ 0.23019142],
#        [ 0.29932548],
#        ...,
#        [ 0.30635028],
#        [ 0.308769  ],
#        [ 0.41433723]])

# %% [markdown]
# ##### Check zero in scale

# %% [markdown]
# #Check if there is any 0. in input_scale
# input_scale[input_scale == 0.]

# %% [markdown]
# #Check if there is any 0. in output_scale
# output_scale[output_scale == 0.]

# %% [markdown]
# #### Shift by Center and Scale by Scale

# %%
def transform(data_ori, center, scale):
    return (data_ori - center) / scale
def untransform(data, center, scale):
    return data * scale + center

# %%
# Normalize the input_data and output_data
input_data_norm = transform(input_data_log, input_center, input_scale)
output_data_norm = transform(output_data_log, output_center, output_scale)

# %% [markdown]
# ##### Check median and stdev transformations

# %%
def check_nan(X):
    return [x for x in X if np.isnan(x).any()]

# %% [markdown]
# check_nan(input_data_norm), check_nan(output_data_norm)  # Check if there is any nan in the input_data

# %% [markdown]
# #Check inverse scale transformation
# input_data_norm_it = untransform(input_data_norm, input_center, input_scale)
# input_data_norm_it_dif = input_data_norm_it - input_data_log
# input_data_norm_it_dif.min(), input_data_norm_it_dif.max()

# %% [markdown]
# #Check inverse scale transformation
# output_data_norm_it = untransform(output_data_norm, output_center, output_scale)
# output_data_norm_it_dif = output_data_norm_it - output_data_log
# output_data_norm_it_dif.min(), output_data_norm_it_dif.max()

# %% [markdown]
# del input_data_norm_it
# del input_data_norm_it_dif
# del output_data_norm_it
# del output_data_norm_it_dif
# gc.collect()

# %% [markdown]
# ## Center (Median) and Scale (Stdev) Investigation

# %% [markdown]
# ### Center

# %% [markdown]
# plt.hist(input_center, bins=40, alpha=0.7, label='input')
# plt.hist(output_center, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(input_center, bins=40, alpha=0.7, label='input')
# plt.hist(output_center, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.yscale('log')
# plt.show()

# %% [markdown]
# ### Scale

# %% [markdown]
# plt.hist(input_scale, bins=40, alpha=0.7, label='input')
# plt.hist(output_scale, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(input_scale, bins=40, alpha=0.7, label='input')
# plt.hist(output_scale, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.yscale('log')
# plt.show()

# %% [markdown]
# ### Group index based on scale of median (center)

# %%
def group_index(logx):
    if logx == 0.: return 0
    elif logx < 1.0: return 1
    elif logx < 2.0: return 2
    elif logx < 4.0: return 3
    elif logx < 5.0: return 4
    else: return 5
group_index_v = np.vectorize(group_index)
gp_list = list(range(6)); gp_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
input_gp = group_index_v(input_center).reshape(-1)
output_gp = group_index_v(output_center).reshape(-1)
#input_gp, output_gp

# %%
# group counts
gp_input_counts = [0] * len(gp_list)
for x in input_gp: gp_input_counts[x] += 1
#gp_input_counts

# %%
# group counts
gp_output_counts = [0] * len(gp_list)
for x in output_gp: gp_output_counts[x] += 1
#gp_output_counts

# %% [markdown]
# plt.hist(input_gp, alpha=0.8, label='input')
# plt.hist(output_gp, alpha=0.3, label='output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(input_gp, alpha=0.8, label='input')
# plt.hist(output_gp, alpha=0.3, label='output')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# ## Make (X,Y) pairs data from data set

# %%
X_input = input_data_norm[:, :x_length]
Y_input = input_data_norm[:, -y_length:]
X_input.shape, Y_input.shape
# Out:
# ((145063, 63), (145063, 63))

# %%
X_output = output_data_norm[:, :x_length]
if test_length:
    Y_output = output_data_norm[:, -y_length:]
    print(X_output.shape, Y_output.shape)
else:
    print(X_output.shape, 'No Y_output')
# Out:
# (145063, 63) (145063, 63)

# %% [markdown]
# #### Original data

# %%
X_input_ori = input_data_num[:, :x_length]
Y_input_ori = input_data_num[:, -y_length:]
X_output_ori = output_data_num[:, :x_length]
if test_length: 
    Y_output_ori = output_data_num[:, -y_length:]

# %% [markdown]
# #### Raw data (with nan)

# %%
X_input_raw = input_data[:, :x_length]
Y_input_raw = input_data[:, -y_length:]
X_output_raw = output_data[:, :x_length]
if test_length:
    Y_output_raw = output_data[:, -y_length:]

# %% [markdown]
# #### Backward compatible

# %% [markdown]
# X_input = X_input
# Y_input = Y_input
# X_val = X_output
# if test_length:
#     Y_val = Y_output

# %% [markdown]
# X_input_ori = X_input_ori
# Y_input_ori = Y_input_ori
# X_val_ori = X_output_ori
# if test_length:
#     Y_val_ori = Y_output_ori

# %% [markdown]
# train_scale = input_scale
# train_center = input_center
# val_scale = output_scale
# val_center = output_center

# %% [markdown]
# #### Check

# %% [markdown]
# X_input, input_data_norm[:,:x_length]

# %% [markdown]
# Y_input, input_data_norm[:,-y_length:]

# %% [markdown]
# X_output, output_data_norm[:,:x_length]

# %% [markdown]
# if test_length:
#     print(Y_output)
#     print(output_data_norm[:,-y_length:])

# %% [markdown]
# X_input_ori, input_data_num

# %% [markdown]
# Y_input_ori, input_data_num

# %% [markdown]
# X_output_ori, output_data_num

# %% [markdown]
# if test_length:
#     print(Y_output_ori)
#     print(output_data_num)

# %%
if test_length:
    arr_info((X_input, Y_input, X_output, Y_output, 
              X_input_ori, Y_input_ori, X_output_ori, Y_output_ori))
else:
    arr_info((X_input, Y_input, X_output, 
              X_input_ori, Y_input_ori, X_output_ori))
# Out:
# shape, min, max, median, stdev
# (145063, 63) -104.945597725 182.183688699 0.0250217121081 3.34816141728
# (145063, 63) -104.945597725 181.969627538 -0.0156385758122 3.42135990909
# (145063, 63) -57.3465699314 8.00100800101 0.0 1.27077605981
# (145063, 63) -1627.7382547 51.3918797946 -0.214767758227 6.0365527548
# (145063, 63) 0.0 23209383.0 126.0 63765.8619057
# (145063, 63) 0.0 67264258.0 128.0 155483.953622
# (145063, 63) 0.0 24630674.0 123.0 65785.6552263
# (145063, 63) 0.0 18670230.0 113.0 57469.0537846

# %% [markdown]
# #### Min and max cases examination

# %% [markdown]
# np.argmin(Y_output, axis=0)

# %% [markdown]
# Y_output[8604]

# %% [markdown]
# Y_output_ori[8604]

# %% [markdown]
# fib_output_median[8604]

# %% [markdown]
# log(Y_output_ori[8604])

# %% [markdown]
# log(fib_output_median[8604])

# %% [markdown]
# np.std(log(Y_output_ori[8604]))

# %% [markdown]
# np.std(log(X_output_ori[8604]))

# %% [markdown]
# output_scale[8604]

# %% [markdown]
# #### Check if the inverse transformation is correct

# %% [markdown]
# #Undo transformation
# X_input_tt = unlog(untransform(X_input, train_center, train_scale))

# %% [markdown]
# X_input_tt_diff = X_input_tt - X_input_ori
# X_input_tt_diff.min(), X_input_tt_diff.max()

# %% [markdown]
# ## Split X,Y data into groups

# %% [markdown]
# X_input[input_gp == 1].shape

# %%
X_input_list = [X_input[input_gp == gp] for gp in gp_list]
Y_input_list = [Y_input[input_gp == gp] for gp in gp_list]
X_output_list = [X_output[output_gp == gp] for gp in gp_list]
if test_length:
    Y_output_list = [Y_output[output_gp == gp] for gp in gp_list]

# %% [markdown]
# ## Neural Network?

# %%
from keras.models import Sequential
#from keras.layers import Conv1D
from keras.layers import Dense, Dropout, Flatten
from keras.losses import mean_squared_error
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### SMAPE
# Symmetric mean absolute percentage error
#
# https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error

# %%
import keras.backend as K

def k_smape(y_true, y_pred):
    '''Symmetric mean absolute percentage error for keras metric'''
    diff = K.abs((y_true - y_pred) / K.clip(K.abs(y_true) + K.abs(y_pred),
                                            K.epsilon(), None))
    return 200. * K.mean(diff, axis=-1)

# %%
def smape(y_true, y_pred, axis=None):
    '''Symmetric mean absolute percentage error'''
    diff = np.abs((y_true - y_pred) / 
                  np.clip(np.abs(y_true) + np.abs(y_pred), 1e-07, None))
    return 200. * np.nanmean(diff, axis=axis)

# %% [markdown]
# smape(np.array([0,1]),np.array([np.nan, 0])), smape(np.array([0]),np.array([0]))

# %%
# Benchmark SMAPE on the transformed data
smape(Y_input,X_input), smape(Y_input, X_output), smape(Y_input,Y_input)
# Out:
# (118.39849931396679, 148.1903381452849, 0.0)

# %%
# Benchmark SMAPE on the original data
smape(Y_input_raw,X_input_ori), smape(Y_input_ori,X_input_ori)
# Out:
# (60.417294139521594, 58.828327132034431)

# %%
if test_length: print(smape(Y_output_raw, X_output_ori), smape(Y_output, X_output))
# Out:
# 50.9386336667 142.088333627

# %%
print(smape(Y_input_raw, Y_input_fib))
if test_length: print(smape(Y_output_raw, Y_output_fib))
# Out:
# 48.3250071896
# 40.4041165988

# %% [markdown]
# Doing better than the first two scores are better than simply copy and past the previous result.

# %% [markdown]
# ### Neural Network Model
# With the flavor of convolutional neural network

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv1D
from keras.layers import Flatten
from keras.layers import Reshape
from keras.layers import MaxPooling1D
from keras.layers import AveragePooling1D

# %%
n_ens = 5
ens_list = list(range(n_ens))

# %%
#runbelow
models_ens = []
for run in ens_list:
    print('Run', run, end=': ')
    models = []
    for gp in gp_list:
        print('Group-', gp, sep='', end=' ')
        layer_0 = Input(shape=(x_length,))
        layer_t = Reshape((-1, 1))(layer_0)
        layer_t = Conv1D(120, kernel_size=3, activation='relu')(layer_t)
        layer_t = AveragePooling1D(pool_size=2)(layer_t)
        layer_t = Flatten()(layer_t)
        layer_t = Dense(120, activation='relu')(layer_t)
        layer_t = Dropout(0.25)(layer_t)
        layer_t = Dense(120, activation='relu')(layer_t)
        layer_t = Dropout(0.5)(layer_t)
        layer_f = Dense(y_length)(layer_t)
        model = Model(inputs=layer_0, outputs=layer_f)
        model.compile(optimizer='adam',
                      loss='mean_absolute_error', metrics=[k_smape])
        #model.summary()
        models.append(model)
    models_ens.append(models)
    print('')
# Out:
# Run 0: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 1: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 2: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 3: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 4: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5

# %%
models_ens[0][0].summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 63)                0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 63, 1)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 61, 120)           480
# _________________________________________________________________
# average_pooling1d_1 (Average (None, 30, 120)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3600)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               432120
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 120)               14520
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 120)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 63)                7623
# =================================================================
# Total params: 454,743
# Trainable params: 454,743
# Non-trainable params: 0
# _________________________________________________________________

# %%
np.array(models_ens).shape
# Out:
# (5, 6)

# %%
len(gp_list)
# Out:
# 6

# %%
epochs_list = [1,1,40,40,60,80]  # change to smaller epochs later (1,1,20,40,60,80)

# %%
# %%time
hists_ens = []
for run, models in zip(ens_list, models_ens):
    print('=== Run:', run, '/', len(ens_list), '===')
    hists = []
    for (gp, model, X_in, Y_in, epochs) in zip(gp_list, models,
                                       X_input_list, Y_input_list, 
                                       epochs_list):
        print('-- Group:', gp, '/', len(gp_list), '--')
        hist = model.fit(X_in, Y_in, batch_size=128, 
                         epochs=epochs, 
                         validation_split=0.1, verbose=2)
        #validation_data=(X_val, Y_val))
        hists.append(hist)
    hists_ens.append(hists)
# Out:
# === Run: 0 / 5 ===
# -- Group: 0 / 6 --
# Train on 1691 samples, validate on 188 samples
# Epoch 1/1
# 4s - loss: 0.9466 - k_smape: 195.5492 - val_loss: 0.9748 - val_k_smape: 199.5131
# -- Group: 1 / 6 --
# Train on 20776 samples, validate on 2309 samples
# Epoch 1/1
# 4s - loss: 1.1418 - k_smape: 144.4336 - val_loss: 0.9691 - val_k_smape: 133.6552
# -- Group: 2 / 6 --
# Train on 39321 samples, validate on 4370 samples
# Epoch 1/40
# 8s - loss: 1.3229 - k_smape: 127.4059 - val_loss: 1.0241 - val_k_smape: 116.9170
# Epoch 2/40
# 8s - loss: 1.2507 - k_smape: 118.5815 - val_loss: 1.0289 - val_k_smape: 116.5002
# Epoch 3/40
# 8s - loss: 1.2292 - k_smape: 116.4567 - val_loss: 1.0428 - val_k_smape: 119.2288
# Epoch 4/40
# 8s - loss: 1.2198 - k_smape: 115.6573 - val_loss: 1.0113 - val_k_smape: 115.2895
# Epoch 5/40
# 8s - loss: 1.2114 - k_smape: 114.9996 - val_loss: 1.0345 - val_k_smape: 116.7708
# Epoch 6/40
# 8s - loss: 1.2122 - k_smape: 114.9777 - val_loss: 1.0161 - val_k_smape: 117.5994
# Epoch 7/40
# 8s - loss: 1.2091 - k_smape: 114.7130 - val_loss: 1.0518 - val_k_smape: 115.0238
# Epoch 8/40
# 8s - loss: 1.2096 - k_smape: 114.3624 - val_loss: 1.0249 - val_k_smape: 120.1302
# Epoch 9/40
# 8s - loss: 1.2078 - k_smape: 114.2281 - val_loss: 1.0533 - val_k_smape: 122.3717
# Epoch 10/40
# 8s - loss: 1.1996 - k_smape: 113.9107 - val_loss: 1.0417 - val_k_smape: 116.8878
# Epoch 11/40
# 8s - loss: 1.1979 - k_smape: 113.8026 - val_loss: 1.0341 - val_k_smape: 113.6575
# Epoch 12/40
# 8s - loss: 1.1963 - k_smape: 113.4862 - val_loss: 1.0133 - val_k_smape: 117.0441
# Epoch 13/40
# 8s - loss: 1.1976 - k_smape: 113.6090 - val_loss: 1.0244 - val_k_smape: 115.6730
# Epoch 14/40
# 8s - loss: 1.1986 - k_smape: 113.3212 - val_loss: 1.0252 - val_k_smape: 115.2837
# Epoch 15/40
# 8s - loss: 1.1884 - k_smape: 113.0342 - val_loss: 1.0237 - val_k_smape: 116.3141
# Epoch 16/40
# 8s - loss: 1.1905 - k_smape: 113.3171 - val_loss: 1.0312 - val_k_smape: 116.1035
# Epoch 17/40
# 8s - loss: 1.1893 - k_smape: 112.8741 - val_loss: 1.0333 - val_k_smape: 117.3926
# Epoch 18/40
# 8s - loss: 1.1851 - k_smape: 112.5497 - val_loss: 1.0323 - val_k_smape: 121.3161
# Epoch 19/40
# 8s - loss: 1.1819 - k_smape: 112.4886 - val_loss: 1.0518 - val_k_smape: 120.5448
# Epoch 20/40
# 8s - loss: 1.1873 - k_smape: 112.4335 - val_loss: 1.0559 - val_k_smape: 119.1888
# Epoch 21/40
# 8s - loss: 1.1832 - k_smape: 112.3736 - val_loss: 1.0208 - val_k_smape: 115.3995
# Epoch 22/40
# 8s - loss: 1.1827 - k_smape: 112.0338 - val_loss: 1.0287 - val_k_smape: 116.6372
# Epoch 23/40
# 8s - loss: 1.1717 - k_smape: 111.8495 - val_loss: 1.0395 - val_k_smape: 118.7314
# Epoch 24/40
# 8s - loss: 1.1741 - k_smape: 111.8293 - val_loss: 1.0459 - val_k_smape: 116.3022
# Epoch 25/40
# 8s - loss: 1.1770 - k_smape: 111.7856 - val_loss: 1.0164 - val_k_smape: 114.3648
# Epoch 26/40
# 8s - loss: 1.1765 - k_smape: 111.8547 - val_loss: 1.0239 - val_k_smape: 115.4770
# Epoch 27/40
# 8s - loss: 1.1763 - k_smape: 111.5339 - val_loss: 1.0192 - val_k_smape: 115.0971
# Epoch 28/40
# 8s - loss: 1.1728 - k_smape: 111.3796 - val_loss: 1.0502 - val_k_smape: 117.4051
# Epoch 29/40
# 8s - loss: 1.1768 - k_smape: 111.6431 - val_loss: 1.0297 - val_k_smape: 116.2352
# Epoch 30/40
# 8s - loss: 1.1740 - k_smape: 111.5954 - val_loss: 1.0166 - val_k_smape: 115.4175
# Epoch 31/40
# 8s - loss: 1.1678 - k_smape: 111.0784 - val_loss: 1.0187 - val_k_smape: 115.9347
# Epoch 32/40
# 8s - loss: 1.1727 - k_smape: 111.1750 - val_loss: 1.0193 - val_k_smape: 114.7932
# Epoch 33/40
# 8s - loss: 1.1675 - k_smape: 111.0398 - val_loss: 1.0357 - val_k_smape: 116.1637
# Epoch 34/40
# 8s - loss: 1.1637 - k_smape: 110.9275 - val_loss: 1.0500 - val_k_smape: 117.9454
# Epoch 35/40
# 8s - loss: 1.1662 - k_smape: 110.9298 - val_loss: 1.0200 - val_k_smape: 114.4352
# Epoch 36/40
# 8s - loss: 1.1608 - k_smape: 110.8015 - val_loss: 1.0312 - val_k_smape: 115.8657
# Epoch 37/40
# 8s - loss: 1.1599 - k_smape: 110.7450 - val_loss: 1.0169 - val_k_smape: 113.4692
# Epoch 38/40
# 8s - loss: 1.1589 - k_smape: 110.6258 - val_loss: 1.0260 - val_k_smape: 116.2867
# Epoch 39/40
# 8s - loss: 1.1567 - k_smape: 110.4749 - val_loss: 1.0195 - val_k_smape: 115.9078
# Epoch 40/40
# 8s - loss: 1.1566 - k_smape: 110.4507 - val_loss: 1.0371 - val_k_smape: 115.9688
# -- Group: 3 / 6 --
# Train on 68055 samples, validate on 7562 samples
# Epoch 1/40
# 15s - loss: 1.3368 - k_smape: 108.8796 - val_loss: 1.1924 - val_k_smape: 112.8199
# Epoch 2/40
# 15s - loss: 1.2483 - k_smape: 101.3740 - val_loss: 1.1145 - val_k_smape: 107.6159
# Epoch 3/40
# 14s - loss: 1.2233 - k_smape: 99.7256 - val_loss: 1.0921 - val_k_smape: 104.8895
# Epoch 4/40
# 14s - loss: 1.2133 - k_smape: 98.9396 - val_loss: 1.1153 - val_k_smape: 106.1717
# Epoch 5/40
# 14s - loss: 1.2036 - k_smape: 98.3566 - val_loss: 1.1067 - val_k_smape: 106.4358
# Epoch 6/40
# 14s - loss: 1.2021 - k_smape: 98.1280 - val_loss: 1.0879 - val_k_smape: 106.8104
# Epoch 7/40
# 14s - loss: 1.1935 - k_smape: 97.6560 - val_loss: 1.1681 - val_k_smape: 107.9440
# Epoch 8/40
# 14s - loss: 1.1904 - k_smape: 97.4989 - val_loss: 1.0788 - val_k_smape: 105.1771
# Epoch 9/40
# 14s - loss: 1.1953 - k_smape: 97.4107 - val_loss: 1.0679 - val_k_smape: 104.8953
# Epoch 10/40
# 14s - loss: 1.1873 - k_smape: 97.1379 - val_loss: 1.0762 - val_k_smape: 104.9610
# Epoch 11/40
# 14s - loss: 1.1883 - k_smape: 97.1011 - val_loss: 1.0757 - val_k_smape: 106.2038
# Epoch 12/40
# 14s - loss: 1.1835 - k_smape: 96.8044 - val_loss: 1.1049 - val_k_smape: 108.3859
# Epoch 13/40
# 14s - loss: 1.1812 - k_smape: 96.8118 - val_loss: 1.0636 - val_k_smape: 104.8512
# Epoch 14/40
# 14s - loss: 1.1787 - k_smape: 96.5659 - val_loss: 1.0844 - val_k_smape: 105.1579
# Epoch 15/40
# 14s - loss: 1.1806 - k_smape: 96.7113 - val_loss: 1.0695 - val_k_smape: 105.7068
# Epoch 16/40
# 14s - loss: 1.1766 - k_smape: 96.6081 - val_loss: 1.0736 - val_k_smape: 104.5241
# Epoch 17/40
# 14s - loss: 1.1753 - k_smape: 96.2840 - val_loss: 1.0918 - val_k_smape: 106.3427
# Epoch 18/40
# 14s - loss: 1.1727 - k_smape: 95.9857 - val_loss: 1.0793 - val_k_smape: 105.0025
# Epoch 19/40
# 14s - loss: 1.1710 - k_smape: 96.1280 - val_loss: 1.0638 - val_k_smape: 104.7636
# Epoch 20/40
# 14s - loss: 1.1683 - k_smape: 96.0220 - val_loss: 1.0954 - val_k_smape: 106.9527
# Epoch 21/40
# 14s - loss: 1.1645 - k_smape: 95.9520 - val_loss: 1.0646 - val_k_smape: 104.7369
# Epoch 22/40
# 14s - loss: 1.1656 - k_smape: 95.8863 - val_loss: 1.0897 - val_k_smape: 105.2458
# Epoch 23/40
# 14s - loss: 1.1617 - k_smape: 95.7720 - val_loss: 1.1055 - val_k_smape: 106.4468
# Epoch 24/40
# 14s - loss: 1.1605 - k_smape: 95.6648 - val_loss: 1.1011 - val_k_smape: 107.4243
# Epoch 25/40
# 14s - loss: 1.1615 - k_smape: 95.8390 - val_loss: 1.0967 - val_k_smape: 106.6668
# Epoch 26/40
# 14s - loss: 1.1601 - k_smape: 95.6373 - val_loss: 1.0783 - val_k_smape: 104.9515
# Epoch 27/40
# 14s - loss: 1.1596 - k_smape: 95.6192 - val_loss: 1.0906 - val_k_smape: 106.1251
# Epoch 28/40
# 14s - loss: 1.1567 - k_smape: 95.4238 - val_loss: 1.0669 - val_k_smape: 103.7850
# Epoch 29/40
# 14s - loss: 1.1552 - k_smape: 95.3652 - val_loss: 1.1107 - val_k_smape: 106.0871
# Epoch 30/40
# 14s - loss: 1.1501 - k_smape: 95.1175 - val_loss: 1.0555 - val_k_smape: 104.1680
# Epoch 31/40
# 14s - loss: 1.1516 - k_smape: 95.0885 - val_loss: 1.0582 - val_k_smape: 105.9372
# Epoch 32/40
# 14s - loss: 1.1506 - k_smape: 95.1501 - val_loss: 1.0564 - val_k_smape: 105.7904
# Epoch 33/40
# 14s - loss: 1.1478 - k_smape: 95.0281 - val_loss: 1.0633 - val_k_smape: 106.1624
# Epoch 34/40
# 14s - loss: 1.1456 - k_smape: 95.0039 - val_loss: 1.0699 - val_k_smape: 104.8658
# Epoch 35/40
# 17s - loss: 1.1478 - k_smape: 94.9800 - val_loss: 1.0887 - val_k_smape: 105.4212
# Epoch 36/40
# 18s - loss: 1.1439 - k_smape: 94.8969 - val_loss: 1.0806 - val_k_smape: 106.0323
# Epoch 37/40
# 18s - loss: 1.1422 - k_smape: 94.7604 - val_loss: 1.0747 - val_k_smape: 106.8511
# Epoch 38/40
# 15s - loss: 1.1473 - k_smape: 94.7960 - val_loss: 1.0669 - val_k_smape: 105.7120
# Epoch 39/40
# 17s - loss: 1.1414 - k_smape: 94.7474 - val_loss: 1.0537 - val_k_smape: 103.2260
# Epoch 40/40
# 18s - loss: 1.1416 - k_smape: 94.6036 - val_loss: 1.0770 - val_k_smape: 105.5863
# -- Group: 4 / 6 --
# Train on 666 samples, validate on 74 samples
# Epoch 1/60
# 0s - loss: 2.9765 - k_smape: 159.7615 - val_loss: 3.0218 - val_k_smape: 140.8029
# Epoch 2/60
# 0s - loss: 2.5786 - k_smape: 136.1456 - val_loss: 2.8279 - val_k_smape: 136.9038
# Epoch 3/60
# 0s - loss: 2.3763 - k_smape: 131.2015 - val_loss: 2.4332 - val_k_smape: 125.8104
# Epoch 4/60
# 0s - loss: 2.2006 - k_smape: 124.7308 - val_loss: 2.2773 - val_k_smape: 122.2666
# Epoch 5/60
# 0s - loss: 2.0875 - k_smape: 119.1173 - val_loss: 2.0497 - val_k_smape: 115.2836
# Epoch 6/60
# 0s - loss: 2.0216 - k_smape: 114.4963 - val_loss: 1.9782 - val_k_smape: 113.8397
# Epoch 7/60
# 0s - loss: 1.9222 - k_smape: 111.4395 - val_loss: 1.7861 - val_k_smape: 111.2630
# Epoch 8/60
# 0s - loss: 1.9107 - k_smape: 108.9421 - val_loss: 1.7892 - val_k_smape: 108.9661
# Epoch 9/60
# 0s - loss: 1.7932 - k_smape: 106.1468 - val_loss: 1.8636 - val_k_smape: 106.9088
# Epoch 10/60
# 0s - loss: 1.7883 - k_smape: 103.4321 - val_loss: 1.6432 - val_k_smape: 103.3664
# Epoch 11/60
# 0s - loss: 1.7405 - k_smape: 101.4902 - val_loss: 1.6455 - val_k_smape: 102.3173
# Epoch 12/60
# 0s - loss: 1.6953 - k_smape: 98.1116 - val_loss: 1.9725 - val_k_smape: 108.4010
# Epoch 13/60
# 0s - loss: 1.7387 - k_smape: 101.0031 - val_loss: 1.4383 - val_k_smape: 97.8856
# Epoch 14/60
# 0s - loss: 1.7026 - k_smape: 96.8528 - val_loss: 1.9283 - val_k_smape: 106.1743
# Epoch 15/60
# 0s - loss: 1.6765 - k_smape: 98.4639 - val_loss: 1.4238 - val_k_smape: 96.7777
# Epoch 16/60
# 0s - loss: 1.6334 - k_smape: 95.5853 - val_loss: 2.0050 - val_k_smape: 104.1831
# Epoch 17/60
# 0s - loss: 1.6806 - k_smape: 95.3897 - val_loss: 1.5059 - val_k_smape: 94.8837
# Epoch 18/60
# 0s - loss: 1.6449 - k_smape: 93.1210 - val_loss: 1.9585 - val_k_smape: 103.1236
# Epoch 19/60
# 0s - loss: 1.6187 - k_smape: 93.8807 - val_loss: 1.3897 - val_k_smape: 97.2152
# Epoch 20/60
# 0s - loss: 1.5594 - k_smape: 93.1271 - val_loss: 1.6939 - val_k_smape: 99.4280
# Epoch 21/60
# 0s - loss: 1.5351 - k_smape: 92.2830 - val_loss: 1.3571 - val_k_smape: 92.1230
# Epoch 22/60
# 0s - loss: 1.5487 - k_smape: 89.4564 - val_loss: 1.6156 - val_k_smape: 96.2255
# Epoch 23/60
# 0s - loss: 1.4985 - k_smape: 90.3009 - val_loss: 1.3545 - val_k_smape: 92.0095
# Epoch 24/60
# 0s - loss: 1.5370 - k_smape: 88.5264 - val_loss: 1.7942 - val_k_smape: 97.2267
# Epoch 25/60
# 0s - loss: 1.5370 - k_smape: 88.8571 - val_loss: 1.3326 - val_k_smape: 92.5298
# Epoch 26/60
# 0s - loss: 1.4830 - k_smape: 89.6274 - val_loss: 1.7198 - val_k_smape: 97.6913
# Epoch 27/60
# 0s - loss: 1.5033 - k_smape: 89.8133 - val_loss: 1.3174 - val_k_smape: 89.5015
# Epoch 28/60
# 0s - loss: 1.4751 - k_smape: 87.7308 - val_loss: 1.5760 - val_k_smape: 92.8659
# Epoch 29/60
# 0s - loss: 1.4628 - k_smape: 86.8607 - val_loss: 1.4680 - val_k_smape: 91.8582
# Epoch 30/60
# 0s - loss: 1.4328 - k_smape: 87.6939 - val_loss: 1.5792 - val_k_smape: 93.4371
# Epoch 31/60
# 0s - loss: 1.4551 - k_smape: 85.4341 - val_loss: 1.3144 - val_k_smape: 88.7377
# Epoch 32/60
# 0s - loss: 1.4155 - k_smape: 86.6306 - val_loss: 1.3653 - val_k_smape: 90.3787
# Epoch 33/60
# 0s - loss: 1.4657 - k_smape: 84.7055 - val_loss: 1.3988 - val_k_smape: 87.3322
# Epoch 34/60
# 0s - loss: 1.3836 - k_smape: 84.5126 - val_loss: 1.2883 - val_k_smape: 87.8383
# Epoch 35/60
# 0s - loss: 1.4161 - k_smape: 83.4760 - val_loss: 1.4498 - val_k_smape: 91.0201
# Epoch 36/60
# 0s - loss: 1.3928 - k_smape: 85.0282 - val_loss: 1.4930 - val_k_smape: 89.0219
# Epoch 37/60
# 0s - loss: 1.3872 - k_smape: 83.8507 - val_loss: 1.3272 - val_k_smape: 87.4003
# Epoch 38/60
# 0s - loss: 1.3955 - k_smape: 83.3924 - val_loss: 1.3185 - val_k_smape: 86.1514
# Epoch 39/60
# 0s - loss: 1.3735 - k_smape: 82.9545 - val_loss: 1.5674 - val_k_smape: 90.0455
# Epoch 40/60
# 0s - loss: 1.3924 - k_smape: 82.9158 - val_loss: 1.2882 - val_k_smape: 85.0805
# Epoch 41/60
# 0s - loss: 1.4133 - k_smape: 83.3072 - val_loss: 1.3334 - val_k_smape: 88.7092
# Epoch 42/60
# 0s - loss: 1.4095 - k_smape: 82.6893 - val_loss: 1.6531 - val_k_smape: 89.9293
# Epoch 43/60
# 0s - loss: 1.4510 - k_smape: 83.7946 - val_loss: 1.5013 - val_k_smape: 86.1869
# Epoch 44/60
# 0s - loss: 1.4085 - k_smape: 81.6014 - val_loss: 1.7497 - val_k_smape: 93.3767
# Epoch 45/60
# 0s - loss: 1.4309 - k_smape: 86.4640 - val_loss: 1.4619 - val_k_smape: 87.2200
# Epoch 46/60
# 0s - loss: 1.4199 - k_smape: 84.3765 - val_loss: 1.7104 - val_k_smape: 91.5729
# Epoch 47/60
# 0s - loss: 1.4131 - k_smape: 83.7950 - val_loss: 1.2740 - val_k_smape: 86.4805
# Epoch 48/60
# 0s - loss: 1.3816 - k_smape: 83.3855 - val_loss: 1.6315 - val_k_smape: 89.3073
# Epoch 49/60
# 0s - loss: 1.3660 - k_smape: 80.8303 - val_loss: 1.2625 - val_k_smape: 85.3445
# Epoch 50/60
# 0s - loss: 1.3080 - k_smape: 81.4822 - val_loss: 1.3321 - val_k_smape: 87.2022
# Epoch 51/60
# 0s - loss: 1.2846 - k_smape: 81.7515 - val_loss: 1.3277 - val_k_smape: 87.6718
# Epoch 52/60
# 0s - loss: 1.2916 - k_smape: 80.1199 - val_loss: 1.3051 - val_k_smape: 86.2062
# Epoch 53/60
# 0s - loss: 1.2937 - k_smape: 80.6572 - val_loss: 1.2609 - val_k_smape: 85.4300
# Epoch 54/60
# 0s - loss: 1.2879 - k_smape: 79.1763 - val_loss: 1.4770 - val_k_smape: 87.6362
# Epoch 55/60
# 0s - loss: 1.2852 - k_smape: 79.3707 - val_loss: 1.2454 - val_k_smape: 82.8651
# Epoch 56/60
# 0s - loss: 1.3759 - k_smape: 78.7463 - val_loss: 1.4721 - val_k_smape: 88.2616
# Epoch 57/60
# 0s - loss: 1.3322 - k_smape: 80.9568 - val_loss: 1.2589 - val_k_smape: 85.3817
# Epoch 58/60
# 0s - loss: 1.3080 - k_smape: 79.2194 - val_loss: 1.2405 - val_k_smape: 83.7632
# Epoch 59/60
# 0s - loss: 1.2902 - k_smape: 77.2193 - val_loss: 1.2454 - val_k_smape: 84.3705
# Epoch 60/60
# 0s - loss: 1.2983 - k_smape: 79.8734 - val_loss: 1.3974 - val_k_smape: 85.8659
# -- Group: 5 / 6 --
# Train on 45 samples, validate on 6 samples
# Epoch 1/80
# 0s - loss: 6.9261 - k_smape: 178.9039 - val_loss: 4.6819 - val_k_smape: 172.4293
# Epoch 2/80
# 0s - loss: 6.5986 - k_smape: 168.8366 - val_loss: 4.4365 - val_k_smape: 158.7180
# Epoch 3/80
# 0s - loss: 6.4255 - k_smape: 160.9076 - val_loss: 4.1793 - val_k_smape: 147.3423
# Epoch 4/80
# 0s - loss: 6.1462 - k_smape: 150.7508 - val_loss: 3.9116 - val_k_smape: 138.0396
# Epoch 5/80
# 0s - loss: 6.0662 - k_smape: 143.9708 - val_loss: 3.6482 - val_k_smape: 132.9644
# Epoch 6/80
# 0s - loss: 5.8274 - k_smape: 138.3593 - val_loss: 3.4510 - val_k_smape: 129.6395
# Epoch 7/80
# 0s - loss: 5.6964 - k_smape: 133.3283 - val_loss: 3.2716 - val_k_smape: 125.3674
# Epoch 8/80
# 0s - loss: 5.6164 - k_smape: 129.1357 - val_loss: 3.1277 - val_k_smape: 123.3743
# Epoch 9/80
# 0s - loss: 5.5820 - k_smape: 128.6094 - val_loss: 3.0289 - val_k_smape: 121.6125
# Epoch 10/80
# 0s - loss: 5.6464 - k_smape: 127.5948 - val_loss: 2.9854 - val_k_smape: 120.9089
# Epoch 11/80
# 0s - loss: 5.3030 - k_smape: 126.2295 - val_loss: 2.9921 - val_k_smape: 121.7889
# Epoch 12/80
# 0s - loss: 5.2170 - k_smape: 127.2479 - val_loss: 3.0220 - val_k_smape: 122.8310
# Epoch 13/80
# 0s - loss: 5.0687 - k_smape: 128.1962 - val_loss: 3.0651 - val_k_smape: 122.5362
# Epoch 14/80
# 0s - loss: 4.7521 - k_smape: 122.8504 - val_loss: 3.0583 - val_k_smape: 122.2757
# Epoch 15/80
# 0s - loss: 5.0071 - k_smape: 127.7760 - val_loss: 3.0039 - val_k_smape: 120.2811
# Epoch 16/80
# 0s - loss: 5.0188 - k_smape: 126.2687 - val_loss: 2.9343 - val_k_smape: 117.9341
# Epoch 17/80
# 0s - loss: 4.7555 - k_smape: 120.7950 - val_loss: 2.8296 - val_k_smape: 115.5082
# Epoch 18/80
# 0s - loss: 4.8864 - k_smape: 121.8018 - val_loss: 2.6913 - val_k_smape: 112.6796
# Epoch 19/80
# 0s - loss: 4.6878 - k_smape: 123.5911 - val_loss: 2.5190 - val_k_smape: 110.0262
# Epoch 20/80
# 0s - loss: 4.4848 - k_smape: 116.3798 - val_loss: 2.3889 - val_k_smape: 108.1454
# Epoch 21/80
# 0s - loss: 4.5437 - k_smape: 117.2772 - val_loss: 2.2632 - val_k_smape: 106.6975
# Epoch 22/80
# 0s - loss: 4.4566 - k_smape: 114.6181 - val_loss: 2.1927 - val_k_smape: 105.8447
# Epoch 23/80
# 0s - loss: 4.2822 - k_smape: 112.4622 - val_loss: 2.1468 - val_k_smape: 105.3705
# Epoch 24/80
# 0s - loss: 4.2946 - k_smape: 109.2791 - val_loss: 2.1169 - val_k_smape: 105.1518
# Epoch 25/80
# 0s - loss: 4.1266 - k_smape: 108.7630 - val_loss: 2.1319 - val_k_smape: 105.1818
# Epoch 26/80
# 0s - loss: 4.1745 - k_smape: 110.3103 - val_loss: 2.1281 - val_k_smape: 104.8473
# Epoch 27/80
# 0s - loss: 4.3049 - k_smape: 110.8246 - val_loss: 2.0899 - val_k_smape: 104.1105
# Epoch 28/80
# 0s - loss: 4.2135 - k_smape: 109.1499 - val_loss: 2.0342 - val_k_smape: 103.3556
# Epoch 29/80
# 0s - loss: 4.0766 - k_smape: 108.3432 - val_loss: 1.9292 - val_k_smape: 101.6309
# Epoch 30/80
# 0s - loss: 4.0362 - k_smape: 104.0669 - val_loss: 1.7926 - val_k_smape: 100.2326
# Epoch 31/80
# 0s - loss: 3.9743 - k_smape: 106.9525 - val_loss: 1.6061 - val_k_smape: 99.0049
# Epoch 32/80
# 0s - loss: 3.8343 - k_smape: 103.6716 - val_loss: 1.5179 - val_k_smape: 98.6194
# Epoch 33/80
# 0s - loss: 3.9321 - k_smape: 105.2028 - val_loss: 1.4827 - val_k_smape: 98.2469
# Epoch 34/80
# 0s - loss: 3.8928 - k_smape: 102.9908 - val_loss: 1.5228 - val_k_smape: 98.4222
# Epoch 35/80
# 0s - loss: 3.7981 - k_smape: 100.3770 - val_loss: 1.6484 - val_k_smape: 99.1362
# Epoch 36/80
# 0s - loss: 3.5757 - k_smape: 100.5999 - val_loss: 1.8439 - val_k_smape: 101.1043
# Epoch 37/80
# 0s - loss: 3.7406 - k_smape: 103.1576 - val_loss: 1.9244 - val_k_smape: 102.2487
# Epoch 38/80
# 0s - loss: 3.8001 - k_smape: 101.4661 - val_loss: 1.9330 - val_k_smape: 102.4198
# Epoch 39/80
# 0s - loss: 3.6321 - k_smape: 97.5965 - val_loss: 1.8060 - val_k_smape: 101.2012
# Epoch 40/80
# 0s - loss: 3.4819 - k_smape: 96.4275 - val_loss: 1.6320 - val_k_smape: 99.4220
# Epoch 41/80
# 0s - loss: 3.6092 - k_smape: 93.8166 - val_loss: 1.4984 - val_k_smape: 98.8921
# Epoch 42/80
# 0s - loss: 3.6542 - k_smape: 96.2550 - val_loss: 1.3756 - val_k_smape: 97.7129
# Epoch 43/80
# 0s - loss: 3.5562 - k_smape: 92.0854 - val_loss: 1.3254 - val_k_smape: 96.3354
# Epoch 44/80
# 0s - loss: 3.4145 - k_smape: 92.1273 - val_loss: 1.2693 - val_k_smape: 95.3343
# Epoch 45/80
# 0s - loss: 3.3235 - k_smape: 93.0212 - val_loss: 1.2298 - val_k_smape: 94.4965
# Epoch 46/80
# 0s - loss: 3.3836 - k_smape: 91.4408 - val_loss: 1.2261 - val_k_smape: 94.2881
# Epoch 47/80
# 0s - loss: 3.3198 - k_smape: 87.7879 - val_loss: 1.3038 - val_k_smape: 93.9112
# Epoch 48/80
# 0s - loss: 3.4472 - k_smape: 91.2176 - val_loss: 1.3095 - val_k_smape: 92.6956
# Epoch 49/80
# 0s - loss: 3.4445 - k_smape: 88.8111 - val_loss: 1.3314 - val_k_smape: 91.5356
# Epoch 50/80
# 0s - loss: 3.2873 - k_smape: 85.5232 - val_loss: 1.3400 - val_k_smape: 90.7499
# Epoch 51/80
# 0s - loss: 3.2247 - k_smape: 86.9466 - val_loss: 1.3406 - val_k_smape: 90.3671
# Epoch 52/80
# 0s - loss: 3.1878 - k_smape: 83.6197 - val_loss: 1.4231 - val_k_smape: 90.9161
# Epoch 53/80
# 0s - loss: 3.1183 - k_smape: 87.1233 - val_loss: 1.4162 - val_k_smape: 92.1230
# Epoch 54/80
# 0s - loss: 3.4143 - k_smape: 84.6997 - val_loss: 1.4827 - val_k_smape: 92.7702
# Epoch 55/80
# 0s - loss: 3.1078 - k_smape: 84.2578 - val_loss: 1.5668 - val_k_smape: 93.8706
# Epoch 56/80
# 0s - loss: 3.2091 - k_smape: 86.2292 - val_loss: 1.4896 - val_k_smape: 94.4168
# Epoch 57/80
# 0s - loss: 3.1640 - k_smape: 85.6208 - val_loss: 1.2946 - val_k_smape: 93.9961
# Epoch 58/80
# 0s - loss: 3.0305 - k_smape: 82.4264 - val_loss: 1.1515 - val_k_smape: 92.4218
# Epoch 59/80
# 0s - loss: 3.2137 - k_smape: 88.2183 - val_loss: 1.1126 - val_k_smape: 90.4208
# Epoch 60/80
# 0s - loss: 3.0923 - k_smape: 83.0196 - val_loss: 1.1548 - val_k_smape: 87.7993
# Epoch 61/80
# 0s - loss: 3.0135 - k_smape: 79.8910 - val_loss: 1.2747 - val_k_smape: 86.9145
# Epoch 62/80
# 0s - loss: 3.1135 - k_smape: 80.8973 - val_loss: 1.4384 - val_k_smape: 88.5132
# Epoch 63/80
# 0s - loss: 3.2724 - k_smape: 81.9148 - val_loss: 1.4447 - val_k_smape: 88.0463
# Epoch 64/80
# 0s - loss: 3.2076 - k_smape: 80.0530 - val_loss: 1.3680 - val_k_smape: 86.9492
# Epoch 65/80
# 0s - loss: 3.0721 - k_smape: 81.9909 - val_loss: 1.2496 - val_k_smape: 86.2692
# Epoch 66/80
# 0s - loss: 3.3214 - k_smape: 83.0315 - val_loss: 1.0512 - val_k_smape: 85.1884
# Epoch 67/80
# 0s - loss: 3.1671 - k_smape: 79.9782 - val_loss: 1.0376 - val_k_smape: 84.8805
# Epoch 68/80
# 0s - loss: 2.9155 - k_smape: 76.9380 - val_loss: 1.0539 - val_k_smape: 84.7176
# Epoch 69/80
# 0s - loss: 3.0941 - k_smape: 78.2547 - val_loss: 1.1999 - val_k_smape: 85.3674
# Epoch 70/80
# 0s - loss: 3.0205 - k_smape: 77.8120 - val_loss: 1.4083 - val_k_smape: 86.5604
# Epoch 71/80
# 0s - loss: 2.9101 - k_smape: 75.5771 - val_loss: 1.6735 - val_k_smape: 89.3565
# Epoch 72/80
# 0s - loss: 3.0116 - k_smape: 77.2595 - val_loss: 1.7081 - val_k_smape: 89.5768
# Epoch 73/80
# 0s - loss: 3.0921 - k_smape: 81.7339 - val_loss: 1.4311 - val_k_smape: 87.2134
# Epoch 74/80
# 0s - loss: 3.0960 - k_smape: 77.4817 - val_loss: 1.1926 - val_k_smape: 87.3279
# Epoch 75/80
# 0s - loss: 3.0689 - k_smape: 78.0079 - val_loss: 1.0258 - val_k_smape: 86.7221
# Epoch 76/80
# 0s - loss: 3.2396 - k_smape: 80.9429 - val_loss: 0.9510 - val_k_smape: 85.7466
# Epoch 77/80
# 0s - loss: 2.9186 - k_smape: 76.2633 - val_loss: 0.9279 - val_k_smape: 84.8595
# Epoch 78/80
# 0s - loss: 2.9673 - k_smape: 74.8875 - val_loss: 0.8868 - val_k_smape: 84.2679
# Epoch 79/80
# 0s - loss: 2.9037 - k_smape: 74.5116 - val_loss: 0.8636 - val_k_smape: 83.6710
# Epoch 80/80
# 0s - loss: 2.8704 - k_smape: 74.2842 - val_loss: 0.8495 - val_k_smape: 83.3095
# === Run: 1 / 5 ===
# -- Group: 0 / 6 --
# Train on 1691 samples, validate on 188 samples
# Epoch 1/1
# 1s - loss: 0.9426 - k_smape: 195.6447 - val_loss: 0.9761 - val_k_smape: 199.6064
# -- Group: 1 / 6 --
# Train on 20776 samples, validate on 2309 samples
# Epoch 1/1
# 6s - loss: 1.1310 - k_smape: 143.0863 - val_loss: 1.0285 - val_k_smape: 140.3324
# -- Group: 2 / 6 --
# Train on 39321 samples, validate on 4370 samples
# Epoch 1/40
# 11s - loss: 1.3300 - k_smape: 127.5097 - val_loss: 1.0353 - val_k_smape: 118.0580
# Epoch 2/40
# 10s - loss: 1.2517 - k_smape: 118.7825 - val_loss: 1.0582 - val_k_smape: 120.8307
# Epoch 3/40
# 9s - loss: 1.2284 - k_smape: 116.3184 - val_loss: 1.0207 - val_k_smape: 116.7904
# Epoch 4/40
# 8s - loss: 1.2236 - k_smape: 115.7103 - val_loss: 1.0441 - val_k_smape: 124.5061
# Epoch 5/40
# 8s - loss: 1.2121 - k_smape: 115.1321 - val_loss: 1.0466 - val_k_smape: 122.1892
# Epoch 6/40
# 8s - loss: 1.2073 - k_smape: 114.5553 - val_loss: 1.0200 - val_k_smape: 117.9968
# Epoch 7/40
# 8s - loss: 1.2066 - k_smape: 114.5159 - val_loss: 1.0450 - val_k_smape: 123.1164
# Epoch 8/40
# 8s - loss: 1.2021 - k_smape: 114.4545 - val_loss: 1.0148 - val_k_smape: 118.4783
# Epoch 9/40
# 8s - loss: 1.2021 - k_smape: 114.1702 - val_loss: 1.0286 - val_k_smape: 118.6517
# Epoch 10/40
# 8s - loss: 1.1927 - k_smape: 113.7090 - val_loss: 1.0329 - val_k_smape: 115.7561
# Epoch 11/40
# 8s - loss: 1.1965 - k_smape: 113.7700 - val_loss: 1.0566 - val_k_smape: 123.0900
# Epoch 12/40
# 8s - loss: 1.1963 - k_smape: 113.5024 - val_loss: 1.0141 - val_k_smape: 113.3784
# Epoch 13/40
# 8s - loss: 1.1891 - k_smape: 113.4670 - val_loss: 1.0613 - val_k_smape: 119.1695
# Epoch 14/40
# 8s - loss: 1.1957 - k_smape: 113.5126 - val_loss: 1.0480 - val_k_smape: 121.1433
# Epoch 15/40
# 8s - loss: 1.1867 - k_smape: 113.0400 - val_loss: 1.0406 - val_k_smape: 117.7396
# Epoch 16/40
# 8s - loss: 1.1869 - k_smape: 112.9996 - val_loss: 1.0211 - val_k_smape: 115.9916
# Epoch 17/40
# 8s - loss: 1.1859 - k_smape: 112.9693 - val_loss: 1.0187 - val_k_smape: 118.9736
# Epoch 18/40
# 8s - loss: 1.1843 - k_smape: 112.8239 - val_loss: 1.0457 - val_k_smape: 119.6237
# Epoch 19/40
# 8s - loss: 1.1809 - k_smape: 112.7184 - val_loss: 1.0440 - val_k_smape: 116.8996
# Epoch 20/40
# 8s - loss: 1.1801 - k_smape: 112.7000 - val_loss: 1.0520 - val_k_smape: 120.0955
# Epoch 21/40
# 8s - loss: 1.1764 - k_smape: 112.4190 - val_loss: 1.0388 - val_k_smape: 117.8029
# Epoch 22/40
# 8s - loss: 1.1733 - k_smape: 112.4210 - val_loss: 1.0454 - val_k_smape: 117.9152
# Epoch 23/40
# 8s - loss: 1.1806 - k_smape: 112.4036 - val_loss: 1.0298 - val_k_smape: 118.0796
# Epoch 24/40
# 8s - loss: 1.1729 - k_smape: 111.9718 - val_loss: 1.0290 - val_k_smape: 119.0880
# Epoch 25/40
# 8s - loss: 1.1718 - k_smape: 112.0072 - val_loss: 1.0385 - val_k_smape: 118.9238
# Epoch 26/40
# 8s - loss: 1.1706 - k_smape: 112.0458 - val_loss: 1.0447 - val_k_smape: 119.1416
# Epoch 27/40
# 8s - loss: 1.1700 - k_smape: 111.7411 - val_loss: 1.0160 - val_k_smape: 114.9348
# Epoch 28/40
# 8s - loss: 1.1619 - k_smape: 111.5893 - val_loss: 1.0087 - val_k_smape: 116.4720
# Epoch 29/40
# 8s - loss: 1.1629 - k_smape: 111.6243 - val_loss: 1.0316 - val_k_smape: 120.0180
# Epoch 30/40
# 8s - loss: 1.1651 - k_smape: 111.7213 - val_loss: 1.0158 - val_k_smape: 117.6474
# Epoch 31/40
# 8s - loss: 1.1659 - k_smape: 111.5671 - val_loss: 1.0329 - val_k_smape: 117.7448
# Epoch 32/40
# 8s - loss: 1.1642 - k_smape: 111.3860 - val_loss: 1.0263 - val_k_smape: 115.2343
# Epoch 33/40
# 8s - loss: 1.1584 - k_smape: 111.2364 - val_loss: 1.0196 - val_k_smape: 116.5397
# Epoch 34/40
# 8s - loss: 1.1549 - k_smape: 111.1467 - val_loss: 1.0171 - val_k_smape: 118.4804
# Epoch 35/40
# 8s - loss: 1.1572 - k_smape: 111.2888 - val_loss: 1.0364 - val_k_smape: 120.0544
# Epoch 36/40
# 8s - loss: 1.1579 - k_smape: 111.2883 - val_loss: 1.0501 - val_k_smape: 118.9161
# Epoch 37/40
# 8s - loss: 1.1540 - k_smape: 110.9863 - val_loss: 1.0217 - val_k_smape: 115.7089
# Epoch 38/40
# 8s - loss: 1.1512 - k_smape: 110.9136 - val_loss: 1.0288 - val_k_smape: 118.0714
# Epoch 39/40
# 8s - loss: 1.1461 - k_smape: 110.8811 - val_loss: 1.0509 - val_k_smape: 119.1222
# Epoch 40/40
# 8s - loss: 1.1505 - k_smape: 110.6892 - val_loss: 1.0413 - val_k_smape: 118.1467
# -- Group: 3 / 6 --
# Train on 68055 samples, validate on 7562 samples
# Epoch 1/40
# 14s - loss: 1.3342 - k_smape: 108.7139 - val_loss: 1.1174 - val_k_smape: 109.3322
# Epoch 2/40
# 14s - loss: 1.2393 - k_smape: 101.0283 - val_loss: 1.1376 - val_k_smape: 110.0670
# Epoch 3/40
# 14s - loss: 1.2268 - k_smape: 99.9804 - val_loss: 1.1059 - val_k_smape: 106.8930
# Epoch 4/40
# 14s - loss: 1.2112 - k_smape: 99.0039 - val_loss: 1.1409 - val_k_smape: 109.0356
# Epoch 5/40
# 14s - loss: 1.2050 - k_smape: 98.6667 - val_loss: 1.1024 - val_k_smape: 106.7811
# Epoch 6/40
# 14s - loss: 1.2021 - k_smape: 98.2184 - val_loss: 1.0807 - val_k_smape: 106.3647
# Epoch 7/40
# 14s - loss: 1.1960 - k_smape: 97.9344 - val_loss: 1.0792 - val_k_smape: 105.4692
# Epoch 8/40
# 14s - loss: 1.1998 - k_smape: 97.9206 - val_loss: 1.1280 - val_k_smape: 108.1791
# Epoch 9/40
# 14s - loss: 1.1891 - k_smape: 97.4881 - val_loss: 1.0988 - val_k_smape: 107.5313
# Epoch 10/40
# 14s - loss: 1.1914 - k_smape: 97.4562 - val_loss: 1.1042 - val_k_smape: 105.3434
# Epoch 11/40
# 14s - loss: 1.1886 - k_smape: 97.1726 - val_loss: 1.0889 - val_k_smape: 105.9328
# Epoch 12/40
# 14s - loss: 1.1840 - k_smape: 96.9808 - val_loss: 1.0898 - val_k_smape: 105.0713
# Epoch 13/40
# 14s - loss: 1.1842 - k_smape: 96.8744 - val_loss: 1.0721 - val_k_smape: 105.8687
# Epoch 14/40
# 14s - loss: 1.1798 - k_smape: 96.6548 - val_loss: 1.0815 - val_k_smape: 104.3745
# Epoch 15/40
# 15s - loss: 1.1755 - k_smape: 96.6083 - val_loss: 1.0917 - val_k_smape: 106.8105
# Epoch 16/40
# 14s - loss: 1.1758 - k_smape: 96.4532 - val_loss: 1.0971 - val_k_smape: 105.7057
# Epoch 17/40
# 14s - loss: 1.1731 - k_smape: 96.4686 - val_loss: 1.0899 - val_k_smape: 105.2950
# Epoch 18/40
# 14s - loss: 1.1707 - k_smape: 96.3372 - val_loss: 1.0866 - val_k_smape: 105.5262
# Epoch 19/40
# 14s - loss: 1.1691 - k_smape: 96.2404 - val_loss: 1.1188 - val_k_smape: 107.1596
# Epoch 20/40
# 14s - loss: 1.1692 - k_smape: 96.1300 - val_loss: 1.0631 - val_k_smape: 106.3454
# Epoch 21/40
# 14s - loss: 1.1674 - k_smape: 96.0978 - val_loss: 1.1173 - val_k_smape: 107.3446
# Epoch 22/40
# 14s - loss: 1.1625 - k_smape: 95.8032 - val_loss: 1.0818 - val_k_smape: 105.1681
# Epoch 23/40
# 14s - loss: 1.1612 - k_smape: 95.8530 - val_loss: 1.0681 - val_k_smape: 103.9425
# Epoch 24/40
# 14s - loss: 1.1638 - k_smape: 95.8722 - val_loss: 1.0653 - val_k_smape: 104.6483
# Epoch 25/40
# 14s - loss: 1.1593 - k_smape: 95.8425 - val_loss: 1.0774 - val_k_smape: 106.0353
# Epoch 26/40
# 14s - loss: 1.1570 - k_smape: 95.7631 - val_loss: 1.0770 - val_k_smape: 105.5219
# Epoch 27/40
# 14s - loss: 1.1528 - k_smape: 95.5830 - val_loss: 1.0774 - val_k_smape: 104.4115
# Epoch 28/40
# 15s - loss: 1.1508 - k_smape: 95.6259 - val_loss: 1.0641 - val_k_smape: 105.9647
# Epoch 29/40
# 15s - loss: 1.1524 - k_smape: 95.5114 - val_loss: 1.0800 - val_k_smape: 105.6513
# Epoch 30/40
# 18s - loss: 1.1509 - k_smape: 95.3495 - val_loss: 1.0701 - val_k_smape: 104.8763
# Epoch 31/40
# 15s - loss: 1.1491 - k_smape: 95.5509 - val_loss: 1.0963 - val_k_smape: 107.4761
# Epoch 32/40
# 15s - loss: 1.1483 - k_smape: 95.2300 - val_loss: 1.1150 - val_k_smape: 107.7081
# Epoch 33/40
# 14s - loss: 1.1435 - k_smape: 95.2175 - val_loss: 1.0956 - val_k_smape: 105.2702
# Epoch 34/40
# 15s - loss: 1.1431 - k_smape: 95.0680 - val_loss: 1.1049 - val_k_smape: 105.7729
# Epoch 35/40
# 15s - loss: 1.1396 - k_smape: 95.2277 - val_loss: 1.0778 - val_k_smape: 105.6725
# Epoch 36/40
# 15s - loss: 1.1408 - k_smape: 95.0018 - val_loss: 1.0942 - val_k_smape: 105.7996
# Epoch 37/40
# 15s - loss: 1.1418 - k_smape: 95.1427 - val_loss: 1.0977 - val_k_smape: 107.0565
# Epoch 38/40
# 15s - loss: 1.1375 - k_smape: 94.9915 - val_loss: 1.0872 - val_k_smape: 105.9907
# Epoch 39/40
# 15s - loss: 1.1365 - k_smape: 94.8718 - val_loss: 1.0726 - val_k_smape: 105.6341
# Epoch 40/40
# 15s - loss: 1.1379 - k_smape: 94.9139 - val_loss: 1.0853 - val_k_smape: 105.0450
# -- Group: 4 / 6 --
# Train on 666 samples, validate on 74 samples
# Epoch 1/60
# 0s - loss: 2.9814 - k_smape: 158.7517 - val_loss: 3.0829 - val_k_smape: 147.9785
# Epoch 2/60
# 0s - loss: 2.6068 - k_smape: 140.7705 - val_loss: 2.9239 - val_k_smape: 140.9100
# Epoch 3/60
# 0s - loss: 2.3850 - k_smape: 133.3072 - val_loss: 2.2089 - val_k_smape: 122.4626
# Epoch 4/60
# 0s - loss: 2.2226 - k_smape: 123.1493 - val_loss: 2.3492 - val_k_smape: 124.1202
# Epoch 5/60
# 0s - loss: 2.0861 - k_smape: 121.6721 - val_loss: 2.0312 - val_k_smape: 116.3949
# Epoch 6/60
# 0s - loss: 1.9985 - k_smape: 115.1271 - val_loss: 2.0457 - val_k_smape: 114.8906
# Epoch 7/60
# 0s - loss: 1.9697 - k_smape: 112.6519 - val_loss: 1.8334 - val_k_smape: 111.0805
# Epoch 8/60
# 0s - loss: 1.8750 - k_smape: 108.5017 - val_loss: 2.2272 - val_k_smape: 117.4302
# Epoch 9/60
# 0s - loss: 1.9193 - k_smape: 112.3929 - val_loss: 1.5550 - val_k_smape: 103.7515
# Epoch 10/60
# 0s - loss: 1.9750 - k_smape: 102.8380 - val_loss: 2.0245 - val_k_smape: 114.4681
# Epoch 11/60
# 0s - loss: 1.8305 - k_smape: 107.9404 - val_loss: 1.6448 - val_k_smape: 104.6229
# Epoch 12/60
# 0s - loss: 1.7738 - k_smape: 99.5563 - val_loss: 1.6986 - val_k_smape: 107.1626
# Epoch 13/60
# 0s - loss: 1.7054 - k_smape: 102.5378 - val_loss: 1.8003 - val_k_smape: 104.8816
# Epoch 14/60
# 0s - loss: 1.6697 - k_smape: 97.3145 - val_loss: 1.6145 - val_k_smape: 103.2955
# Epoch 15/60
# 0s - loss: 1.6517 - k_smape: 97.3301 - val_loss: 1.6262 - val_k_smape: 104.7716
# Epoch 16/60
# 0s - loss: 1.6320 - k_smape: 97.4669 - val_loss: 1.5799 - val_k_smape: 102.3151
# Epoch 17/60
# 0s - loss: 1.5949 - k_smape: 95.9149 - val_loss: 1.7108 - val_k_smape: 102.5918
# Epoch 18/60
# 0s - loss: 1.5938 - k_smape: 93.8393 - val_loss: 1.6089 - val_k_smape: 99.1181
# Epoch 19/60
# 0s - loss: 1.5514 - k_smape: 95.1419 - val_loss: 1.5391 - val_k_smape: 97.1234
# Epoch 20/60
# 0s - loss: 1.5754 - k_smape: 92.0095 - val_loss: 1.7049 - val_k_smape: 101.4620
# Epoch 21/60
# 0s - loss: 1.5803 - k_smape: 94.6644 - val_loss: 1.3670 - val_k_smape: 94.3493
# Epoch 22/60
# 0s - loss: 1.5537 - k_smape: 91.3569 - val_loss: 1.6716 - val_k_smape: 98.4591
# Epoch 23/60
# 0s - loss: 1.5393 - k_smape: 89.5029 - val_loss: 1.5989 - val_k_smape: 95.8732
# Epoch 24/60
# 0s - loss: 1.4809 - k_smape: 90.0528 - val_loss: 1.3771 - val_k_smape: 94.1896
# Epoch 25/60
# 0s - loss: 1.5936 - k_smape: 89.5792 - val_loss: 1.8573 - val_k_smape: 101.0991
# Epoch 26/60
# 0s - loss: 1.5299 - k_smape: 89.9010 - val_loss: 1.4072 - val_k_smape: 91.2611
# Epoch 27/60
# 0s - loss: 1.5338 - k_smape: 88.5995 - val_loss: 1.8910 - val_k_smape: 99.1840
# Epoch 28/60
# 0s - loss: 1.5217 - k_smape: 88.0515 - val_loss: 1.3403 - val_k_smape: 92.7095
# Epoch 29/60
# 0s - loss: 1.5034 - k_smape: 88.9213 - val_loss: 1.7148 - val_k_smape: 96.2337
# Epoch 30/60
# 0s - loss: 1.5107 - k_smape: 88.3813 - val_loss: 1.3986 - val_k_smape: 90.0023
# Epoch 31/60
# 0s - loss: 1.5120 - k_smape: 86.9410 - val_loss: 1.8518 - val_k_smape: 96.4787
# Epoch 32/60
# 0s - loss: 1.5119 - k_smape: 86.3736 - val_loss: 1.3701 - val_k_smape: 88.6858
# Epoch 33/60
# 0s - loss: 1.4911 - k_smape: 88.4818 - val_loss: 1.5996 - val_k_smape: 93.8275
# Epoch 34/60
# 0s - loss: 1.4324 - k_smape: 85.1734 - val_loss: 1.3259 - val_k_smape: 89.4254
# Epoch 35/60
# 0s - loss: 1.4214 - k_smape: 85.6224 - val_loss: 1.5348 - val_k_smape: 93.6545
# Epoch 36/60
# 0s - loss: 1.4259 - k_smape: 84.4531 - val_loss: 1.3561 - val_k_smape: 87.9611
# Epoch 37/60
# 0s - loss: 1.3955 - k_smape: 84.9389 - val_loss: 1.4492 - val_k_smape: 88.4985
# Epoch 38/60
# 0s - loss: 1.3461 - k_smape: 82.0767 - val_loss: 1.5231 - val_k_smape: 88.1954
# Epoch 39/60
# 0s - loss: 1.4046 - k_smape: 82.3159 - val_loss: 1.2959 - val_k_smape: 86.7014
# Epoch 40/60
# 0s - loss: 1.4099 - k_smape: 83.1179 - val_loss: 1.4988 - val_k_smape: 95.0956
# Epoch 41/60
# 0s - loss: 1.3717 - k_smape: 85.4248 - val_loss: 1.2860 - val_k_smape: 86.2281
# Epoch 42/60
# 0s - loss: 1.3508 - k_smape: 80.1880 - val_loss: 1.5249 - val_k_smape: 89.1422
# Epoch 43/60
# 0s - loss: 1.4104 - k_smape: 82.9483 - val_loss: 1.3608 - val_k_smape: 90.1236
# Epoch 44/60
# 0s - loss: 1.3452 - k_smape: 82.8725 - val_loss: 1.3467 - val_k_smape: 87.8640
# Epoch 45/60
# 0s - loss: 1.3635 - k_smape: 81.0121 - val_loss: 1.3810 - val_k_smape: 89.1156
# Epoch 46/60
# 0s - loss: 1.3263 - k_smape: 81.7752 - val_loss: 1.3374 - val_k_smape: 86.1981
# Epoch 47/60
# 0s - loss: 1.3637 - k_smape: 79.6369 - val_loss: 1.3642 - val_k_smape: 87.8046
# Epoch 48/60
# 0s - loss: 1.3213 - k_smape: 81.8576 - val_loss: 1.2743 - val_k_smape: 84.3418
# Epoch 49/60
# 0s - loss: 1.3349 - k_smape: 80.1404 - val_loss: 1.4716 - val_k_smape: 88.4441
# Epoch 50/60
# 0s - loss: 1.3457 - k_smape: 79.1188 - val_loss: 1.2538 - val_k_smape: 86.6486
# Epoch 51/60
# 0s - loss: 1.3412 - k_smape: 82.1544 - val_loss: 1.2662 - val_k_smape: 86.7061
# Epoch 52/60
# 0s - loss: 1.4377 - k_smape: 80.4462 - val_loss: 1.5093 - val_k_smape: 90.4576
# Epoch 53/60
# 0s - loss: 1.3183 - k_smape: 81.5665 - val_loss: 1.3051 - val_k_smape: 85.1465
# Epoch 54/60
# 0s - loss: 1.3498 - k_smape: 79.0332 - val_loss: 1.4093 - val_k_smape: 88.1009
# Epoch 55/60
# 0s - loss: 1.3233 - k_smape: 80.6348 - val_loss: 1.3254 - val_k_smape: 85.2357
# Epoch 56/60
# 0s - loss: 1.3000 - k_smape: 79.4921 - val_loss: 1.2780 - val_k_smape: 84.5780
# Epoch 57/60
# 0s - loss: 1.2997 - k_smape: 78.8826 - val_loss: 1.4708 - val_k_smape: 87.7053
# Epoch 58/60
# 0s - loss: 1.3045 - k_smape: 78.6725 - val_loss: 1.2419 - val_k_smape: 83.8388
# Epoch 59/60
# 0s - loss: 1.2551 - k_smape: 77.6815 - val_loss: 1.4233 - val_k_smape: 85.8028
# Epoch 60/60
# 0s - loss: 1.3373 - k_smape: 79.1471 - val_loss: 1.2882 - val_k_smape: 83.0556
# -- Group: 5 / 6 --
# Train on 45 samples, validate on 6 samples
# Epoch 1/80
# 0s - loss: 6.8579 - k_smape: 175.7581 - val_loss: 4.8022 - val_k_smape: 172.4522
# Epoch 2/80
# 0s - loss: 6.6755 - k_smape: 167.6727 - val_loss: 4.6589 - val_k_smape: 160.4958
# Epoch 3/80
# 0s - loss: 6.4179 - k_smape: 155.6474 - val_loss: 4.5171 - val_k_smape: 151.3573
# Epoch 4/80
# 0s - loss: 6.0904 - k_smape: 147.1856 - val_loss: 4.3246 - val_k_smape: 142.3014
# Epoch 5/80
# 0s - loss: 5.9167 - k_smape: 140.8051 - val_loss: 4.1299 - val_k_smape: 135.8272
# Epoch 6/80
# 0s - loss: 5.9491 - k_smape: 134.6048 - val_loss: 4.0007 - val_k_smape: 133.5863
# Epoch 7/80
# 0s - loss: 5.9368 - k_smape: 135.2879 - val_loss: 3.9302 - val_k_smape: 132.1912
# Epoch 8/80
# 0s - loss: 5.6890 - k_smape: 131.9574 - val_loss: 3.8932 - val_k_smape: 131.7279
# Epoch 9/80
# 0s - loss: 5.6725 - k_smape: 131.5372 - val_loss: 3.8627 - val_k_smape: 131.3019
# Epoch 10/80
# 0s - loss: 5.4678 - k_smape: 131.0605 - val_loss: 3.8061 - val_k_smape: 131.5359
# Epoch 11/80
# 0s - loss: 5.1833 - k_smape: 130.2718 - val_loss: 3.7409 - val_k_smape: 130.6504
# Epoch 12/80
# 0s - loss: 5.2534 - k_smape: 128.9592 - val_loss: 3.6758 - val_k_smape: 129.3631
# Epoch 13/80
# 0s - loss: 5.0761 - k_smape: 127.8956 - val_loss: 3.5739 - val_k_smape: 127.0718
# Epoch 14/80
# 0s - loss: 4.9878 - k_smape: 126.6381 - val_loss: 3.4464 - val_k_smape: 124.5121
# Epoch 15/80
# 0s - loss: 4.9906 - k_smape: 124.2817 - val_loss: 3.2894 - val_k_smape: 120.9573
# Epoch 16/80
# 0s - loss: 5.0619 - k_smape: 127.2590 - val_loss: 3.0958 - val_k_smape: 116.9919
# Epoch 17/80
# 0s - loss: 4.8076 - k_smape: 119.6010 - val_loss: 2.9404 - val_k_smape: 113.5564
# Epoch 18/80
# 0s - loss: 4.7379 - k_smape: 119.1072 - val_loss: 2.7848 - val_k_smape: 110.8379
# Epoch 19/80
# 0s - loss: 4.5730 - k_smape: 113.5548 - val_loss: 2.6496 - val_k_smape: 108.4573
# Epoch 20/80
# 0s - loss: 4.4688 - k_smape: 112.0437 - val_loss: 2.5391 - val_k_smape: 107.0920
# Epoch 21/80
# 0s - loss: 4.4483 - k_smape: 110.9729 - val_loss: 2.4351 - val_k_smape: 106.6210
# Epoch 22/80
# 0s - loss: 4.3634 - k_smape: 111.1997 - val_loss: 2.3324 - val_k_smape: 105.7827
# Epoch 23/80
# 0s - loss: 4.4147 - k_smape: 111.0694 - val_loss: 2.2270 - val_k_smape: 104.4402
# Epoch 24/80
# 0s - loss: 4.2680 - k_smape: 108.1982 - val_loss: 2.1953 - val_k_smape: 104.2105
# Epoch 25/80
# 0s - loss: 4.1504 - k_smape: 107.5304 - val_loss: 2.2335 - val_k_smape: 104.9431
# Epoch 26/80
# 0s - loss: 4.0752 - k_smape: 106.4994 - val_loss: 2.2680 - val_k_smape: 105.9252
# Epoch 27/80
# 0s - loss: 4.2106 - k_smape: 107.3434 - val_loss: 2.3576 - val_k_smape: 107.6823
# Epoch 28/80
# 0s - loss: 4.1380 - k_smape: 108.7692 - val_loss: 2.4333 - val_k_smape: 109.0925
# Epoch 29/80
# 0s - loss: 3.9640 - k_smape: 107.1455 - val_loss: 2.4225 - val_k_smape: 109.8445
# Epoch 30/80
# 0s - loss: 3.7141 - k_smape: 103.1993 - val_loss: 2.3946 - val_k_smape: 110.6091
# Epoch 31/80
# 0s - loss: 4.0182 - k_smape: 105.3353 - val_loss: 2.3258 - val_k_smape: 110.0847
# Epoch 32/80
# 0s - loss: 3.7493 - k_smape: 102.1191 - val_loss: 2.1840 - val_k_smape: 107.7507
# Epoch 33/80
# 0s - loss: 3.7204 - k_smape: 101.0171 - val_loss: 1.9694 - val_k_smape: 104.5382
# Epoch 34/80
# 0s - loss: 3.5066 - k_smape: 96.2666 - val_loss: 1.8182 - val_k_smape: 102.2689
# Epoch 35/80
# 0s - loss: 3.6543 - k_smape: 99.9112 - val_loss: 1.6936 - val_k_smape: 99.4359
# Epoch 36/80
# 0s - loss: 3.5463 - k_smape: 95.8729 - val_loss: 1.5663 - val_k_smape: 97.0676
# Epoch 37/80
# 0s - loss: 3.5515 - k_smape: 94.4199 - val_loss: 1.4829 - val_k_smape: 95.6851
# Epoch 38/80
# 0s - loss: 3.4248 - k_smape: 92.6939 - val_loss: 1.4458 - val_k_smape: 95.3452
# Epoch 39/80
# 0s - loss: 3.4137 - k_smape: 92.8890 - val_loss: 1.4674 - val_k_smape: 95.1666
# Epoch 40/80
# 0s - loss: 3.7053 - k_smape: 94.9384 - val_loss: 1.6207 - val_k_smape: 96.2393
# Epoch 41/80
# 0s - loss: 3.6733 - k_smape: 92.3129 - val_loss: 1.7412 - val_k_smape: 97.0294
# Epoch 42/80
# 0s - loss: 3.2957 - k_smape: 91.2040 - val_loss: 1.8174 - val_k_smape: 96.8886
# Epoch 43/80
# 0s - loss: 3.4371 - k_smape: 89.3351 - val_loss: 1.7452 - val_k_smape: 95.2602
# Epoch 44/80
# 0s - loss: 3.3564 - k_smape: 87.7123 - val_loss: 1.6244 - val_k_smape: 94.2611
# Epoch 45/80
# 0s - loss: 3.4188 - k_smape: 88.4604 - val_loss: 1.4443 - val_k_smape: 94.0422
# Epoch 46/80
# 0s - loss: 3.2896 - k_smape: 87.4445 - val_loss: 1.3020 - val_k_smape: 95.7497
# Epoch 47/80
# 0s - loss: 3.2333 - k_smape: 86.2013 - val_loss: 1.2317 - val_k_smape: 95.7730
# Epoch 48/80
# 0s - loss: 3.1809 - k_smape: 82.9724 - val_loss: 1.2486 - val_k_smape: 95.0115
# Epoch 49/80
# 0s - loss: 3.1783 - k_smape: 83.1820 - val_loss: 1.2646 - val_k_smape: 94.0454
# Epoch 50/80
# 0s - loss: 3.1220 - k_smape: 86.1946 - val_loss: 1.3366 - val_k_smape: 92.4700
# Epoch 51/80
# 0s - loss: 3.1727 - k_smape: 84.3741 - val_loss: 1.4464 - val_k_smape: 90.1687
# Epoch 52/80
# 0s - loss: 3.0516 - k_smape: 86.3079 - val_loss: 1.5537 - val_k_smape: 89.3672
# Epoch 53/80
# 0s - loss: 3.0962 - k_smape: 81.7892 - val_loss: 1.6422 - val_k_smape: 90.5933
# Epoch 54/80
# 0s - loss: 3.0877 - k_smape: 82.0949 - val_loss: 1.6731 - val_k_smape: 90.6331
# Epoch 55/80
# 0s - loss: 3.1097 - k_smape: 79.6859 - val_loss: 1.6008 - val_k_smape: 89.4401
# Epoch 56/80
# 0s - loss: 3.0735 - k_smape: 81.9603 - val_loss: 1.3604 - val_k_smape: 87.1604
# Epoch 57/80
# 0s - loss: 3.1078 - k_smape: 80.1227 - val_loss: 1.1666 - val_k_smape: 87.5324
# Epoch 58/80
# 0s - loss: 3.0680 - k_smape: 77.8868 - val_loss: 1.1388 - val_k_smape: 88.9073
# Epoch 59/80
# 0s - loss: 2.9584 - k_smape: 80.7170 - val_loss: 1.1132 - val_k_smape: 89.3048
# Epoch 60/80
# 0s - loss: 3.2378 - k_smape: 81.7263 - val_loss: 1.0808 - val_k_smape: 88.6575
# Epoch 61/80
# 0s - loss: 3.1917 - k_smape: 83.5293 - val_loss: 1.0334 - val_k_smape: 85.9001
# Epoch 62/80
# 0s - loss: 2.9471 - k_smape: 76.5406 - val_loss: 1.1056 - val_k_smape: 84.6067
# Epoch 63/80
# 0s - loss: 2.9994 - k_smape: 78.5137 - val_loss: 1.1281 - val_k_smape: 85.0871
# Epoch 64/80
# 0s - loss: 2.9695 - k_smape: 76.8640 - val_loss: 1.2432 - val_k_smape: 86.7366
# Epoch 65/80
# 0s - loss: 3.0305 - k_smape: 76.6850 - val_loss: 1.2468 - val_k_smape: 86.0804
# Epoch 66/80
# 0s - loss: 2.7574 - k_smape: 74.1786 - val_loss: 1.2337 - val_k_smape: 84.9266
# Epoch 67/80
# 0s - loss: 2.8923 - k_smape: 79.2561 - val_loss: 1.1279 - val_k_smape: 85.1660
# Epoch 68/80
# 0s - loss: 2.9039 - k_smape: 76.1111 - val_loss: 1.0607 - val_k_smape: 85.9176
# Epoch 69/80
# 0s - loss: 2.7904 - k_smape: 74.2666 - val_loss: 1.1936 - val_k_smape: 86.7623
# Epoch 70/80
# 0s - loss: 2.9239 - k_smape: 75.6543 - val_loss: 1.3325 - val_k_smape: 87.6061
# Epoch 71/80
# 0s - loss: 2.6192 - k_smape: 73.8802 - val_loss: 1.5224 - val_k_smape: 88.0274
# Epoch 72/80
# 0s - loss: 2.9732 - k_smape: 77.0961 - val_loss: 1.5110 - val_k_smape: 86.8974
# Epoch 73/80
# 0s - loss: 2.7996 - k_smape: 75.6668 - val_loss: 1.2736 - val_k_smape: 84.9028
# Epoch 74/80
# 0s - loss: 2.9335 - k_smape: 78.8378 - val_loss: 0.9720 - val_k_smape: 83.9068
# Epoch 75/80
# 0s - loss: 2.6778 - k_smape: 69.6561 - val_loss: 0.9452 - val_k_smape: 84.3488
# Epoch 76/80
# 0s - loss: 2.9089 - k_smape: 73.8775 - val_loss: 0.9729 - val_k_smape: 84.6558
# Epoch 77/80
# 0s - loss: 2.8351 - k_smape: 72.8605 - val_loss: 0.9522 - val_k_smape: 84.6590
# Epoch 78/80
# 0s - loss: 2.9297 - k_smape: 72.8708 - val_loss: 1.1258 - val_k_smape: 85.7401
# Epoch 79/80
# 0s - loss: 2.6543 - k_smape: 71.1851 - val_loss: 1.5379 - val_k_smape: 87.8028
# Epoch 80/80
# 0s - loss: 2.5948 - k_smape: 71.1304 - val_loss: 1.7543 - val_k_smape: 89.8619
# === Run: 2 / 5 ===
# -- Group: 0 / 6 --
# Train on 1691 samples, validate on 188 samples
# Epoch 1/1
# 1s - loss: 0.9371 - k_smape: 196.7148 - val_loss: 0.9781 - val_k_smape: 199.9757
# -- Group: 1 / 6 --
# Train on 20776 samples, validate on 2309 samples
# Epoch 1/1
# 5s - loss: 1.1351 - k_smape: 144.9449 - val_loss: 0.9837 - val_k_smape: 136.5117
# -- Group: 2 / 6 --
# Train on 39321 samples, validate on 4370 samples
# Epoch 1/40
# 9s - loss: 1.3181 - k_smape: 126.2303 - val_loss: 1.0465 - val_k_smape: 116.2936
# Epoch 2/40
# 8s - loss: 1.2446 - k_smape: 117.9347 - val_loss: 1.0241 - val_k_smape: 118.9796
# Epoch 3/40
# 8s - loss: 1.2205 - k_smape: 116.2279 - val_loss: 1.0543 - val_k_smape: 124.2439
# Epoch 4/40
# 8s - loss: 1.2185 - k_smape: 115.5611 - val_loss: 1.0167 - val_k_smape: 121.3731
# Epoch 5/40
# 8s - loss: 1.2071 - k_smape: 115.1552 - val_loss: 1.0106 - val_k_smape: 118.2475
# Epoch 6/40
# 8s - loss: 1.2086 - k_smape: 114.9456 - val_loss: 1.0264 - val_k_smape: 119.4200
# Epoch 7/40
# 8s - loss: 1.2143 - k_smape: 114.7067 - val_loss: 1.0042 - val_k_smape: 117.2141
# Epoch 8/40
# 8s - loss: 1.1967 - k_smape: 114.0011 - val_loss: 1.0279 - val_k_smape: 118.9062
# Epoch 9/40
# 8s - loss: 1.1935 - k_smape: 113.6499 - val_loss: 1.0223 - val_k_smape: 120.3133
# Epoch 10/40
# 8s - loss: 1.1923 - k_smape: 113.5374 - val_loss: 1.0039 - val_k_smape: 114.4555
# Epoch 11/40
# 8s - loss: 1.1882 - k_smape: 113.3007 - val_loss: 1.0041 - val_k_smape: 116.3013
# Epoch 12/40
# 8s - loss: 1.1882 - k_smape: 113.0896 - val_loss: 1.0505 - val_k_smape: 122.0156
# Epoch 13/40
# 8s - loss: 1.1884 - k_smape: 113.4654 - val_loss: 1.0217 - val_k_smape: 116.4152
# Epoch 14/40
# 8s - loss: 1.2034 - k_smape: 113.3947 - val_loss: 1.0325 - val_k_smape: 119.0763
# Epoch 15/40
# 8s - loss: 1.1926 - k_smape: 113.0732 - val_loss: 1.0148 - val_k_smape: 117.0274
# Epoch 16/40
# 8s - loss: 1.1905 - k_smape: 112.6747 - val_loss: 1.0149 - val_k_smape: 117.3222
# Epoch 17/40
# 8s - loss: 1.1837 - k_smape: 112.4699 - val_loss: 1.0429 - val_k_smape: 119.9624
# Epoch 18/40
# 9s - loss: 1.1848 - k_smape: 112.4301 - val_loss: 1.0291 - val_k_smape: 118.1998
# Epoch 19/40
# 10s - loss: 1.1782 - k_smape: 112.1277 - val_loss: 1.0488 - val_k_smape: 120.0312
# Epoch 20/40
# 9s - loss: 1.1737 - k_smape: 111.9329 - val_loss: 1.0261 - val_k_smape: 119.7720
# Epoch 21/40
# 9s - loss: 1.1801 - k_smape: 112.3676 - val_loss: 1.0374 - val_k_smape: 119.5453
# Epoch 22/40
# 9s - loss: 1.1720 - k_smape: 111.7862 - val_loss: 1.0120 - val_k_smape: 115.4568
# Epoch 23/40
# 9s - loss: 1.1734 - k_smape: 111.8565 - val_loss: 1.0872 - val_k_smape: 120.7064
# Epoch 24/40
# 8s - loss: 1.1707 - k_smape: 111.6778 - val_loss: 1.0233 - val_k_smape: 116.1143
# Epoch 25/40
# 8s - loss: 1.1679 - k_smape: 111.6131 - val_loss: 0.9989 - val_k_smape: 116.5796
# Epoch 26/40
# 8s - loss: 1.1643 - k_smape: 111.5799 - val_loss: 1.0353 - val_k_smape: 119.1644
# Epoch 27/40
# 8s - loss: 1.1728 - k_smape: 111.6947 - val_loss: 0.9991 - val_k_smape: 114.1366
# Epoch 28/40
# 8s - loss: 1.1658 - k_smape: 111.5804 - val_loss: 1.0187 - val_k_smape: 118.9409
# Epoch 29/40
# 8s - loss: 1.1614 - k_smape: 111.0989 - val_loss: 1.0277 - val_k_smape: 117.5604
# Epoch 30/40
# 8s - loss: 1.1574 - k_smape: 111.1315 - val_loss: 1.0349 - val_k_smape: 118.1952
# Epoch 31/40
# 8s - loss: 1.1580 - k_smape: 110.9669 - val_loss: 1.0167 - val_k_smape: 116.9448
# Epoch 32/40
# 8s - loss: 1.1564 - k_smape: 110.9801 - val_loss: 1.0209 - val_k_smape: 116.9483
# Epoch 33/40
# 8s - loss: 1.1523 - k_smape: 110.7251 - val_loss: 1.0397 - val_k_smape: 119.5433
# Epoch 34/40
# 8s - loss: 1.1521 - k_smape: 110.7323 - val_loss: 1.0211 - val_k_smape: 114.3698
# Epoch 35/40
# 8s - loss: 1.1481 - k_smape: 110.5055 - val_loss: 1.0338 - val_k_smape: 118.2773
# Epoch 36/40
# 8s - loss: 1.1588 - k_smape: 110.7492 - val_loss: 1.0124 - val_k_smape: 115.7196
# Epoch 37/40
# 8s - loss: 1.1514 - k_smape: 110.7884 - val_loss: 1.0147 - val_k_smape: 116.5487
# Epoch 38/40
# 8s - loss: 1.1472 - k_smape: 110.4030 - val_loss: 1.0302 - val_k_smape: 117.9201
# Epoch 39/40
# 8s - loss: 1.1440 - k_smape: 110.4499 - val_loss: 1.0002 - val_k_smape: 117.3172
# Epoch 40/40
# 8s - loss: 1.1402 - k_smape: 110.5628 - val_loss: 1.0535 - val_k_smape: 120.8100
# -- Group: 3 / 6 --
# Train on 68055 samples, validate on 7562 samples
# Epoch 1/40
# 16s - loss: 1.3534 - k_smape: 109.3170 - val_loss: 1.1264 - val_k_smape: 108.2650
# Epoch 2/40
# 15s - loss: 1.2468 - k_smape: 100.8885 - val_loss: 1.0992 - val_k_smape: 105.8453
# Epoch 3/40
# 15s - loss: 1.2246 - k_smape: 99.5883 - val_loss: 1.1280 - val_k_smape: 107.7752
# Epoch 4/40
# 15s - loss: 1.2157 - k_smape: 98.9006 - val_loss: 1.1250 - val_k_smape: 107.3923
# Epoch 5/40
# 15s - loss: 1.2107 - k_smape: 98.4496 - val_loss: 1.1048 - val_k_smape: 107.5068
# Epoch 6/40
# 15s - loss: 1.2056 - k_smape: 98.0809 - val_loss: 1.0963 - val_k_smape: 104.5251
# Epoch 7/40
# 15s - loss: 1.1989 - k_smape: 97.7009 - val_loss: 1.1353 - val_k_smape: 106.6583
# Epoch 8/40
# 15s - loss: 1.1955 - k_smape: 97.4193 - val_loss: 1.0750 - val_k_smape: 105.5354
# Epoch 9/40
# 15s - loss: 1.1936 - k_smape: 97.3059 - val_loss: 1.0925 - val_k_smape: 105.5705
# Epoch 10/40
# 15s - loss: 1.1929 - k_smape: 97.1424 - val_loss: 1.0984 - val_k_smape: 106.4506
# Epoch 11/40
# 15s - loss: 1.1865 - k_smape: 96.8257 - val_loss: 1.1022 - val_k_smape: 104.3144
# Epoch 12/40
# 15s - loss: 1.1868 - k_smape: 96.8769 - val_loss: 1.1234 - val_k_smape: 105.5268
# Epoch 13/40
# 15s - loss: 1.1825 - k_smape: 96.7505 - val_loss: 1.0887 - val_k_smape: 105.4436
# Epoch 14/40
# 15s - loss: 1.1804 - k_smape: 96.4844 - val_loss: 1.1171 - val_k_smape: 105.9423
# Epoch 15/40
# 15s - loss: 1.1779 - k_smape: 96.3206 - val_loss: 1.1243 - val_k_smape: 106.5021
# Epoch 16/40
# 15s - loss: 1.1788 - k_smape: 96.2969 - val_loss: 1.1554 - val_k_smape: 107.9788
# Epoch 17/40
# 15s - loss: 1.1735 - k_smape: 96.0104 - val_loss: 1.1441 - val_k_smape: 107.0990
# Epoch 18/40
# 15s - loss: 1.1706 - k_smape: 95.9709 - val_loss: 1.1437 - val_k_smape: 105.1054
# Epoch 19/40
# 15s - loss: 1.1697 - k_smape: 95.9170 - val_loss: 1.0957 - val_k_smape: 105.1360
# Epoch 20/40
# 15s - loss: 1.1688 - k_smape: 95.7827 - val_loss: 1.1231 - val_k_smape: 105.7077
# Epoch 21/40
# 15s - loss: 1.1681 - k_smape: 95.6811 - val_loss: 1.1121 - val_k_smape: 105.3290
# Epoch 22/40
# 15s - loss: 1.1617 - k_smape: 95.5340 - val_loss: 1.1103 - val_k_smape: 106.1172
# Epoch 23/40
# 15s - loss: 1.1607 - k_smape: 95.3906 - val_loss: 1.1240 - val_k_smape: 104.0025
# ...
# Epoch 9/40
# 15s - loss: 1.1931 - k_smape: 97.3885 - val_loss: 1.0845 - val_k_smape: 105.3930
# Epoch 10/40
# 15s - loss: 1.1896 - k_smape: 97.0961 - val_loss: 1.1079 - val_k_smape: 107.0901
# Epoch 11/40
# 15s - loss: 1.1880 - k_smape: 96.9705 - val_loss: 1.0874 - val_k_smape: 105.3407
# Epoch 12/40
# 15s - loss: 1.1850 - k_smape: 96.8231 - val_loss: 1.0841 - val_k_smape: 104.8798
# Epoch 13/40
# 15s - loss: 1.1827 - k_smape: 96.6849 - val_loss: 1.1058 - val_k_smape: 106.3983
# Epoch 14/40
# 15s - loss: 1.1806 - k_smape: 96.5112 - val_loss: 1.1109 - val_k_smape: 105.9153
# Epoch 15/40
# 15s - loss: 1.1775 - k_smape: 96.4487 - val_loss: 1.1130 - val_k_smape: 104.7525
# Epoch 16/40
# 15s - loss: 1.1724 - k_smape: 96.3117 - val_loss: 1.1387 - val_k_smape: 106.8890
# Epoch 17/40
# 15s - loss: 1.1745 - k_smape: 96.2202 - val_loss: 1.0657 - val_k_smape: 105.3107
# Epoch 18/40
# 15s - loss: 1.1714 - k_smape: 96.0927 - val_loss: 1.0701 - val_k_smape: 104.3264
# Epoch 19/40
# 15s - loss: 1.1677 - k_smape: 95.8445 - val_loss: 1.1302 - val_k_smape: 106.7298
# Epoch 20/40
# 15s - loss: 1.1645 - k_smape: 95.7278 - val_loss: 1.1277 - val_k_smape: 107.6102
# Epoch 21/40
# 15s - loss: 1.1641 - k_smape: 95.7088 - val_loss: 1.1092 - val_k_smape: 105.4538
# Epoch 22/40
# 15s - loss: 1.1599 - k_smape: 95.5809 - val_loss: 1.1050 - val_k_smape: 106.5187
# Epoch 23/40
# 15s - loss: 1.1636 - k_smape: 95.5067 - val_loss: 1.1165 - val_k_smape: 106.6713
# Epoch 24/40
# 15s - loss: 1.1559 - k_smape: 95.3957 - val_loss: 1.1011 - val_k_smape: 105.8290
# Epoch 25/40
# 15s - loss: 1.1543 - k_smape: 95.4002 - val_loss: 1.1071 - val_k_smape: 106.9657
# Epoch 26/40
# 15s - loss: 1.1543 - k_smape: 95.3385 - val_loss: 1.0925 - val_k_smape: 104.0876
# Epoch 27/40
# 15s - loss: 1.1563 - k_smape: 95.3959 - val_loss: 1.1253 - val_k_smape: 107.1137
# Epoch 28/40
# 15s - loss: 1.1520 - k_smape: 95.1714 - val_loss: 1.1177 - val_k_smape: 106.0009
# Epoch 29/40
# 15s - loss: 1.1484 - k_smape: 95.1656 - val_loss: 1.0966 - val_k_smape: 105.4673
# Epoch 30/40
# 15s - loss: 1.1503 - k_smape: 95.1483 - val_loss: 1.0641 - val_k_smape: 104.6899
# Epoch 31/40
# 15s - loss: 1.1502 - k_smape: 94.9721 - val_loss: 1.0916 - val_k_smape: 104.1479
# Epoch 32/40
# 15s - loss: 1.1432 - k_smape: 94.8740 - val_loss: 1.0840 - val_k_smape: 105.2226
# Epoch 33/40
# 15s - loss: 1.1423 - k_smape: 94.9679 - val_loss: 1.0842 - val_k_smape: 104.9278
# Epoch 34/40
# 15s - loss: 1.1441 - k_smape: 94.9520 - val_loss: 1.0925 - val_k_smape: 104.7300
# Epoch 35/40
# 15s - loss: 1.1428 - k_smape: 94.8182 - val_loss: 1.1074 - val_k_smape: 105.4881
# Epoch 36/40
# 15s - loss: 1.1409 - k_smape: 94.7262 - val_loss: 1.1188 - val_k_smape: 105.1757
# Epoch 37/40
# 15s - loss: 1.1386 - k_smape: 94.6156 - val_loss: 1.0967 - val_k_smape: 105.2950
# Epoch 38/40
# 15s - loss: 1.1367 - k_smape: 94.4236 - val_loss: 1.1011 - val_k_smape: 107.3010
# Epoch 39/40
# 15s - loss: 1.1352 - k_smape: 94.3827 - val_loss: 1.0769 - val_k_smape: 105.1810
# Epoch 40/40
# 15s - loss: 1.1336 - k_smape: 94.4201 - val_loss: 1.0759 - val_k_smape: 105.0560
# -- Group: 4 / 6 --
# Train on 666 samples, validate on 74 samples
# Epoch 1/60
# 1s - loss: 2.9501 - k_smape: 161.0334 - val_loss: 3.0349 - val_k_smape: 146.4138
# Epoch 2/60
# 0s - loss: 2.5968 - k_smape: 139.6592 - val_loss: 2.7917 - val_k_smape: 139.9365
# Epoch 3/60
# 0s - loss: 2.3586 - k_smape: 134.3545 - val_loss: 2.3101 - val_k_smape: 125.6132
# Epoch 4/60
# 0s - loss: 2.2146 - k_smape: 124.4120 - val_loss: 2.2735 - val_k_smape: 122.1381
# Epoch 5/60
# 0s - loss: 2.0890 - k_smape: 121.0291 - val_loss: 1.9820 - val_k_smape: 116.1250
# Epoch 6/60
# 0s - loss: 1.9799 - k_smape: 114.9811 - val_loss: 2.1854 - val_k_smape: 119.0942
# Epoch 7/60
# 0s - loss: 1.9044 - k_smape: 113.2116 - val_loss: 1.7708 - val_k_smape: 109.1636
# Epoch 8/60
# 0s - loss: 1.8374 - k_smape: 107.5852 - val_loss: 2.0615 - val_k_smape: 112.8986
# Epoch 9/60
# 0s - loss: 1.8285 - k_smape: 106.3507 - val_loss: 1.6321 - val_k_smape: 104.3799
# Epoch 10/60
# 0s - loss: 1.8244 - k_smape: 104.3398 - val_loss: 1.7827 - val_k_smape: 107.1204
# Epoch 11/60
# 0s - loss: 1.7267 - k_smape: 101.1769 - val_loss: 1.5336 - val_k_smape: 102.4899
# Epoch 12/60
# 0s - loss: 1.7269 - k_smape: 99.8463 - val_loss: 1.9356 - val_k_smape: 108.3400
# Epoch 13/60
# 0s - loss: 1.6919 - k_smape: 100.4643 - val_loss: 1.6608 - val_k_smape: 103.0399
# Epoch 14/60
# 0s - loss: 1.6313 - k_smape: 99.9999 - val_loss: 1.4659 - val_k_smape: 99.5587
# Epoch 15/60
# 0s - loss: 1.6533 - k_smape: 96.9665 - val_loss: 1.8900 - val_k_smape: 104.9459
# Epoch 16/60
# 0s - loss: 1.6356 - k_smape: 95.6328 - val_loss: 1.4710 - val_k_smape: 97.6842
# Epoch 17/60
# 0s - loss: 1.6260 - k_smape: 93.5451 - val_loss: 1.7196 - val_k_smape: 100.4899
# Epoch 18/60
# 0s - loss: 1.5462 - k_smape: 93.8736 - val_loss: 1.4652 - val_k_smape: 97.0062
# Epoch 19/60
# 0s - loss: 1.5884 - k_smape: 92.8452 - val_loss: 1.4506 - val_k_smape: 96.6269
# Epoch 20/60
# 0s - loss: 1.5061 - k_smape: 91.1806 - val_loss: 1.6053 - val_k_smape: 98.6410
# Epoch 21/60
# 0s - loss: 1.5372 - k_smape: 91.9336 - val_loss: 1.8221 - val_k_smape: 99.3688
# Epoch 22/60
# 0s - loss: 1.6938 - k_smape: 94.1058 - val_loss: 1.5741 - val_k_smape: 94.9855
# Epoch 23/60
# 0s - loss: 1.6549 - k_smape: 91.7022 - val_loss: 1.7373 - val_k_smape: 100.8560
# Epoch 24/60
# 0s - loss: 1.5285 - k_smape: 90.9465 - val_loss: 1.3879 - val_k_smape: 93.0153
# Epoch 25/60
# 0s - loss: 1.5291 - k_smape: 90.3447 - val_loss: 1.5687 - val_k_smape: 93.6125
# Epoch 26/60
# 0s - loss: 1.5043 - k_smape: 88.0074 - val_loss: 1.5658 - val_k_smape: 94.9575
# Epoch 27/60
# 0s - loss: 1.4714 - k_smape: 88.4906 - val_loss: 1.3447 - val_k_smape: 92.9351
# Epoch 28/60
# 0s - loss: 1.5138 - k_smape: 87.3386 - val_loss: 1.4736 - val_k_smape: 93.8172
# Epoch 29/60
# 0s - loss: 1.4825 - k_smape: 87.1308 - val_loss: 1.6566 - val_k_smape: 93.3621
# Epoch 30/60
# 0s - loss: 1.4391 - k_smape: 86.1515 - val_loss: 1.3399 - val_k_smape: 92.0977
# Epoch 31/60
# 0s - loss: 1.4327 - k_smape: 88.2819 - val_loss: 1.7382 - val_k_smape: 94.2253
# Epoch 32/60
# 0s - loss: 1.4712 - k_smape: 85.5647 - val_loss: 1.3061 - val_k_smape: 88.7478
# Epoch 33/60
# 0s - loss: 1.4531 - k_smape: 86.0297 - val_loss: 1.5645 - val_k_smape: 92.9032
# Epoch 34/60
# 0s - loss: 1.4210 - k_smape: 84.6181 - val_loss: 1.3815 - val_k_smape: 90.4768
# Epoch 35/60
# 0s - loss: 1.3885 - k_smape: 84.5003 - val_loss: 1.4019 - val_k_smape: 89.1658
# Epoch 36/60
# 0s - loss: 1.4208 - k_smape: 83.7111 - val_loss: 1.7168 - val_k_smape: 94.5132
# Epoch 37/60
# 0s - loss: 1.4506 - k_smape: 87.2064 - val_loss: 1.4687 - val_k_smape: 89.9616
# Epoch 38/60
# 0s - loss: 1.4059 - k_smape: 84.9634 - val_loss: 1.3885 - val_k_smape: 87.8926
# Epoch 39/60
# 0s - loss: 1.3715 - k_smape: 82.2690 - val_loss: 1.5093 - val_k_smape: 90.8897
# Epoch 40/60
# 0s - loss: 1.3543 - k_smape: 87.3258 - val_loss: 1.3445 - val_k_smape: 87.4548
# Epoch 41/60
# 0s - loss: 1.3932 - k_smape: 82.4794 - val_loss: 1.5317 - val_k_smape: 87.3312
# Epoch 42/60
# 0s - loss: 1.3473 - k_smape: 80.7658 - val_loss: 1.3120 - val_k_smape: 87.4607
# Epoch 43/60
# 0s - loss: 1.3646 - k_smape: 82.6711 - val_loss: 1.4692 - val_k_smape: 89.5068
# Epoch 44/60
# 0s - loss: 1.3374 - k_smape: 83.3097 - val_loss: 1.2848 - val_k_smape: 84.4882
# Epoch 45/60
# 0s - loss: 1.3214 - k_smape: 81.1919 - val_loss: 1.3932 - val_k_smape: 86.4807
# Epoch 46/60
# 0s - loss: 1.3617 - k_smape: 81.8425 - val_loss: 1.4537 - val_k_smape: 86.7915
# Epoch 47/60
# 0s - loss: 1.3654 - k_smape: 81.5279 - val_loss: 1.3746 - val_k_smape: 86.2654
# Epoch 48/60
# 0s - loss: 1.3392 - k_smape: 82.6266 - val_loss: 1.3170 - val_k_smape: 86.7372
# Epoch 49/60
# 0s - loss: 1.3663 - k_smape: 83.2336 - val_loss: 1.3275 - val_k_smape: 84.9274
# Epoch 50/60
# 0s - loss: 1.3466 - k_smape: 80.9864 - val_loss: 1.4915 - val_k_smape: 86.4706
# Epoch 51/60
# 0s - loss: 1.3583 - k_smape: 81.1840 - val_loss: 1.2713 - val_k_smape: 84.5689
# Epoch 52/60
# 0s - loss: 1.3439 - k_smape: 80.5176 - val_loss: 1.3100 - val_k_smape: 84.6662
# Epoch 53/60
# 0s - loss: 1.3198 - k_smape: 79.8299 - val_loss: 1.6157 - val_k_smape: 85.1672
# Epoch 54/60
# 0s - loss: 1.4061 - k_smape: 82.5232 - val_loss: 1.4554 - val_k_smape: 82.5062
# Epoch 55/60
# 0s - loss: 1.3669 - k_smape: 80.5671 - val_loss: 1.6265 - val_k_smape: 87.4239
# Epoch 56/60
# 0s - loss: 1.3582 - k_smape: 80.6656 - val_loss: 1.3879 - val_k_smape: 83.6407
# Epoch 57/60
# 0s - loss: 1.3468 - k_smape: 79.2062 - val_loss: 1.6242 - val_k_smape: 86.9723
# Epoch 58/60
# 0s - loss: 1.2827 - k_smape: 80.8403 - val_loss: 1.2550 - val_k_smape: 83.7896
# Epoch 59/60
# 0s - loss: 1.3218 - k_smape: 79.2898 - val_loss: 1.6055 - val_k_smape: 86.5153
# Epoch 60/60
# 0s - loss: 1.3679 - k_smape: 80.5761 - val_loss: 1.2622 - val_k_smape: 83.2600
# -- Group: 5 / 6 --
# Train on 45 samples, validate on 6 samples
# Epoch 1/80
# 0s - loss: 6.8917 - k_smape: 176.1700 - val_loss: 4.6263 - val_k_smape: 164.8630
# Epoch 2/80
# 0s - loss: 6.5920 - k_smape: 166.1368 - val_loss: 4.3630 - val_k_smape: 153.7650
# Epoch 3/80
# 0s - loss: 6.2384 - k_smape: 155.8663 - val_loss: 4.0637 - val_k_smape: 142.9747
# Epoch 4/80
# 0s - loss: 6.0097 - k_smape: 142.4146 - val_loss: 3.8424 - val_k_smape: 136.0873
# Epoch 5/80
# 0s - loss: 6.0460 - k_smape: 139.6857 - val_loss: 3.6446 - val_k_smape: 131.3360
# Epoch 6/80
# 0s - loss: 5.8136 - k_smape: 134.5531 - val_loss: 3.4996 - val_k_smape: 129.4624
# Epoch 7/80
# 0s - loss: 5.7625 - k_smape: 131.9593 - val_loss: 3.3788 - val_k_smape: 127.8455
# Epoch 8/80
# 0s - loss: 5.6953 - k_smape: 130.4080 - val_loss: 3.3160 - val_k_smape: 128.0216
# Epoch 9/80
# 0s - loss: 5.6188 - k_smape: 130.6037 - val_loss: 3.3024 - val_k_smape: 128.1394
# Epoch 10/80
# 0s - loss: 5.3637 - k_smape: 130.4828 - val_loss: 3.2805 - val_k_smape: 128.4733
# Epoch 11/80
# 0s - loss: 5.3054 - k_smape: 129.5842 - val_loss: 3.2735 - val_k_smape: 128.6317
# Epoch 12/80
# 0s - loss: 5.2582 - k_smape: 132.8359 - val_loss: 3.2434 - val_k_smape: 127.2652
# Epoch 13/80
# 0s - loss: 5.1238 - k_smape: 131.3167 - val_loss: 3.1567 - val_k_smape: 125.6075
# Epoch 14/80
# 0s - loss: 5.1568 - k_smape: 130.5893 - val_loss: 3.0254 - val_k_smape: 123.3796
# Epoch 15/80
# 0s - loss: 4.8223 - k_smape: 127.5697 - val_loss: 2.8736 - val_k_smape: 120.2450
# Epoch 16/80
# 0s - loss: 5.0151 - k_smape: 126.4589 - val_loss: 2.6917 - val_k_smape: 116.9405
# Epoch 17/80
# 0s - loss: 4.7916 - k_smape: 124.3842 - val_loss: 2.5435 - val_k_smape: 113.7839
# Epoch 18/80
# 0s - loss: 4.6701 - k_smape: 120.0914 - val_loss: 2.3987 - val_k_smape: 111.2175
# Epoch 19/80
# 0s - loss: 4.6325 - k_smape: 118.8584 - val_loss: 2.3072 - val_k_smape: 108.8958
# Epoch 20/80
# 0s - loss: 4.4630 - k_smape: 117.9122 - val_loss: 2.2527 - val_k_smape: 107.0394
# Epoch 21/80
# 0s - loss: 4.5253 - k_smape: 116.4270 - val_loss: 2.2154 - val_k_smape: 106.3292
# Epoch 22/80
# 0s - loss: 4.5380 - k_smape: 114.9080 - val_loss: 2.1650 - val_k_smape: 104.9518
# Epoch 23/80
# 0s - loss: 4.5040 - k_smape: 111.4978 - val_loss: 2.1146 - val_k_smape: 103.5759
# Epoch 24/80
# 0s - loss: 4.2066 - k_smape: 110.0400 - val_loss: 2.1301 - val_k_smape: 103.6244
# Epoch 25/80
# 0s - loss: 4.2795 - k_smape: 113.1530 - val_loss: 2.1545 - val_k_smape: 103.9956
# Epoch 26/80
# 0s - loss: 4.2701 - k_smape: 112.2567 - val_loss: 2.1834 - val_k_smape: 104.4719
# Epoch 27/80
# 0s - loss: 4.0426 - k_smape: 107.6066 - val_loss: 2.2037 - val_k_smape: 105.3089
# Epoch 28/80
# 0s - loss: 4.2085 - k_smape: 109.2770 - val_loss: 2.2128 - val_k_smape: 105.4668
# Epoch 29/80
# 0s - loss: 4.1347 - k_smape: 111.3181 - val_loss: 2.1585 - val_k_smape: 104.8177
# Epoch 30/80
# 0s - loss: 3.9227 - k_smape: 107.4795 - val_loss: 2.1006 - val_k_smape: 104.6049
# Epoch 31/80
# 0s - loss: 4.0029 - k_smape: 106.4010 - val_loss: 1.9825 - val_k_smape: 102.7933
# Epoch 32/80
# 0s - loss: 3.8809 - k_smape: 106.5518 - val_loss: 1.9193 - val_k_smape: 101.1056
# Epoch 33/80
# 0s - loss: 3.9290 - k_smape: 102.5188 - val_loss: 1.9170 - val_k_smape: 99.8771
# Epoch 34/80
# 0s - loss: 3.8503 - k_smape: 102.5669 - val_loss: 1.9986 - val_k_smape: 99.8749
# Epoch 35/80
# 0s - loss: 3.6940 - k_smape: 99.5344 - val_loss: 2.0603 - val_k_smape: 100.6216
# Epoch 36/80
# 0s - loss: 3.6896 - k_smape: 97.0793 - val_loss: 2.0776 - val_k_smape: 101.9371
# Epoch 37/80
# 0s - loss: 3.7330 - k_smape: 98.1148 - val_loss: 2.0057 - val_k_smape: 102.2238
# Epoch 38/80
# 0s - loss: 3.4809 - k_smape: 99.7614 - val_loss: 1.8815 - val_k_smape: 101.4589
# Epoch 39/80
# 0s - loss: 3.6709 - k_smape: 99.7158 - val_loss: 1.6826 - val_k_smape: 99.2496
# Epoch 40/80
# 0s - loss: 3.5286 - k_smape: 95.6499 - val_loss: 1.4914 - val_k_smape: 97.1206
# Epoch 41/80
# 0s - loss: 3.5910 - k_smape: 95.9608 - val_loss: 1.3185 - val_k_smape: 95.3213
# Epoch 42/80
# 0s - loss: 3.4593 - k_smape: 95.7838 - val_loss: 1.2605 - val_k_smape: 94.2155
# Epoch 43/80
# 0s - loss: 3.3176 - k_smape: 89.9911 - val_loss: 1.2483 - val_k_smape: 93.3122
# Epoch 44/80
# 0s - loss: 3.4523 - k_smape: 93.9338 - val_loss: 1.2368 - val_k_smape: 92.9372
# Epoch 45/80
# 0s - loss: 3.5756 - k_smape: 93.5690 - val_loss: 1.2447 - val_k_smape: 92.4712
# Epoch 46/80
# 0s - loss: 3.3544 - k_smape: 87.2266 - val_loss: 1.3290 - val_k_smape: 93.2533
# Epoch 47/80
# 0s - loss: 3.3293 - k_smape: 88.5253 - val_loss: 1.4794 - val_k_smape: 94.9088
# Epoch 48/80
# 0s - loss: 3.3045 - k_smape: 87.7101 - val_loss: 1.6016 - val_k_smape: 96.6655
# Epoch 49/80
# 0s - loss: 3.2830 - k_smape: 90.2389 - val_loss: 1.6194 - val_k_smape: 97.0312
# Epoch 50/80
# 0s - loss: 3.4686 - k_smape: 90.6916 - val_loss: 1.5338 - val_k_smape: 96.4548
# Epoch 51/80
# 0s - loss: 3.1270 - k_smape: 85.9421 - val_loss: 1.4192 - val_k_smape: 96.1698
# Epoch 52/80
# 0s - loss: 3.3538 - k_smape: 88.6709 - val_loss: 1.3025 - val_k_smape: 95.4819
# Epoch 53/80
# 0s - loss: 3.2545 - k_smape: 84.3750 - val_loss: 1.2428 - val_k_smape: 94.6314
# Epoch 54/80
# 0s - loss: 3.2236 - k_smape: 87.6007 - val_loss: 1.2173 - val_k_smape: 93.8873
# Epoch 55/80
# 0s - loss: 3.1578 - k_smape: 86.7022 - val_loss: 1.1782 - val_k_smape: 92.8708
# Epoch 56/80
# 0s - loss: 3.4371 - k_smape: 86.1624 - val_loss: 1.1950 - val_k_smape: 92.1845
# Epoch 57/80
# 0s - loss: 3.4168 - k_smape: 86.0231 - val_loss: 1.1331 - val_k_smape: 90.6380
# Epoch 58/80
# 0s - loss: 3.3351 - k_smape: 88.2582 - val_loss: 1.2224 - val_k_smape: 89.9319
# Epoch 59/80
# 0s - loss: 3.1194 - k_smape: 82.8712 - val_loss: 1.3725 - val_k_smape: 89.8641
# Epoch 60/80
# 0s - loss: 3.1336 - k_smape: 84.0498 - val_loss: 1.4814 - val_k_smape: 90.0903
# Epoch 61/80
# 0s - loss: 2.9076 - k_smape: 81.9944 - val_loss: 1.6175 - val_k_smape: 91.1350
# Epoch 62/80
# 0s - loss: 3.0839 - k_smape: 82.3814 - val_loss: 1.5714 - val_k_smape: 90.9297
# Epoch 63/80
# 0s - loss: 2.9919 - k_smape: 81.8850 - val_loss: 1.5293 - val_k_smape: 90.9545
# Epoch 64/80
# 0s - loss: 3.2159 - k_smape: 86.2596 - val_loss: 1.4284 - val_k_smape: 90.1895
# Epoch 65/80
# 0s - loss: 2.8134 - k_smape: 76.4154 - val_loss: 1.3626 - val_k_smape: 90.1646
# Epoch 66/80
# 0s - loss: 2.9693 - k_smape: 78.8329 - val_loss: 1.1990 - val_k_smape: 88.3446
# Epoch 67/80
# 0s - loss: 2.9580 - k_smape: 79.6460 - val_loss: 1.1084 - val_k_smape: 88.2553
# Epoch 68/80
# 0s - loss: 2.9739 - k_smape: 78.6207 - val_loss: 1.0795 - val_k_smape: 87.6874
# Epoch 69/80
# 0s - loss: 2.9338 - k_smape: 78.6711 - val_loss: 1.2276 - val_k_smape: 87.7671
# Epoch 70/80
# 0s - loss: 3.0684 - k_smape: 77.7453 - val_loss: 1.2911 - val_k_smape: 88.1417
# Epoch 71/80
# 0s - loss: 2.9044 - k_smape: 75.7055 - val_loss: 1.3547 - val_k_smape: 88.8440
# Epoch 72/80
# 0s - loss: 3.1141 - k_smape: 79.5147 - val_loss: 1.3383 - val_k_smape: 88.6620
# Epoch 73/80
# 0s - loss: 2.8115 - k_smape: 77.3063 - val_loss: 1.2993 - val_k_smape: 88.5213
# Epoch 74/80
# 0s - loss: 3.0340 - k_smape: 77.1019 - val_loss: 1.2178 - val_k_smape: 87.9579
# Epoch 75/80
# 0s - loss: 2.8274 - k_smape: 74.6221 - val_loss: 1.0797 - val_k_smape: 86.4830
# Epoch 76/80
# 0s - loss: 2.9809 - k_smape: 77.4321 - val_loss: 1.0403 - val_k_smape: 87.1514
# Epoch 77/80
# 0s - loss: 3.0940 - k_smape: 79.8826 - val_loss: 0.9918 - val_k_smape: 87.3799
# Epoch 78/80
# 0s - loss: 2.9340 - k_smape: 76.5207 - val_loss: 0.9967 - val_k_smape: 86.6429
# Epoch 79/80
# 0s - loss: 2.8576 - k_smape: 78.9255 - val_loss: 0.9621 - val_k_smape: 86.0890
# Epoch 80/80
# 0s - loss: 3.0946 - k_smape: 75.0126 - val_loss: 1.1681 - val_k_smape: 87.3738
# Wall time: 1h 22min 20s

# %% [markdown]
# ### Training History

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['loss'], label=str(run))
        plt.title('Mean Squared Error (Train) - Group' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['val_loss'], label=str(run))
        plt.title('Mean Squared Error (Validation) - Group' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['k_smape'], label=str(run))
        plt.title('SMAPE (Train) - Group' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['val_k_smape'], label=str(run))
        plt.title('SMAPE (Validation) - Group' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep:
        plt.plot(hist.history['loss'], label='train')
        plt.plot(hist.history['val_loss'], label='validation')
        plt.title('Mean Squared Error - ' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep:
        plt.plot(hist.history['k_smape'], label='train')
        plt.plot(hist.history['val_k_smape'], label='validation')
        plt.title('SMAPE - ' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['loss'], label=gp)
plt.title('Mean Squared Error - train')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['val_loss'], label=gp)
plt.title('Mean Squared Error - validation')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['k_smape'], label=gp)
plt.title('SMAPE - train')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['val_k_smape'], label=gp)
plt.title('SMAPE - validation')
plt.legend(); plt.show()

# %% [markdown]
# ### More Training

# %% [markdown]
# epochs_list2 = [0,10,0,0,10]

# %% [markdown]
# hists2 = []
# for (gp, model, X_in, Y_in, epochs) in zip(gp_list, models,
#                                    X_input_list, Y_input_list,
#                                    epochs_list2):
#     hist = model.fit(X_in, Y_in, batch_size=128,
#                      epochs=epochs,
#                      validation_split=0.05)
#     #validation_data=(X_val, Y_val))
#     hists2.append(hist)

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['loss'], label='train')
#         plt.plot(hist.history['val_loss'], label='validation')
#         plt.title('Mean Squared Error - ' + str(gp))
#         plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['k_smape'], label='train')
#         plt.plot(hist.history['val_k_smape'], label='validation')
#         plt.title('SMAPE - ' + str(gp))
#         plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['loss'], label=gp)
# plt.title('Mean Squared Error - train')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['val_loss'], label=gp)
# plt.title('Mean Squared Error - validation')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['k_smape'], label=gp)
# plt.title('SMAPE - train')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['val_k_smape'], label=gp)
# plt.title('SMAPE - validation')
# plt.legend(); plt.show()

# %% [markdown]
# ### Predict for Validation set

# %% [markdown]
# Y_val_pred = model.predict(X_val)

# %% [markdown]
# examine(Y_val_pred)

# %% [markdown]
# Y_val_pred_ori = unlog(untransform(Y_val_pred, val_center, val_scale))

# %% [markdown]
# #SMAPE of the validation set
# smape(Y_val_ori, Y_val_pred_ori)

# %% [markdown]
# def view_val(i):
#     plt.plot(Y_val_pred_ori[i])
#     plt.plot(Y_val_ori[i])
#     plt.plot(X_val_ori[i])
#     plt.show()

# %% [markdown]
# view_val(10)

# %% [markdown]
# ### Evaluation using Output Set

# %% [markdown]
# if test_length:
#     for (gp, model, X, Y) in zip(gp_list, models,
#                                  X_output_list, Y_output_list):
#         print()
#         print(model.evaluate(X,Y))

# %% [markdown]
# ### Predict for Output Set

# %%
Y_output_pred_list_ens = []
for models, run in zip(models_ens, ens_list):
    print('Run', run, end=': ')
    Y_output_pred_list = []
    for (gp, model, X) in zip(gp_list, models, X_output_list):
        print(gp, end=' ')
        Y_output_pred_list.append(model.predict(X))
    Y_output_pred_list_ens.append(Y_output_pred_list)
    print('')
# Out:
# Run 0: 0 1 2 3 4 5
# Run 1: 0 1 2 3 4 5
# Run 2: 0 1 2 3 4 5
# Run 3: 0 1 2 3 4 5
# Run 4: 0 1 2 3 4 5

# %% [markdown]
# Find the original index

# %%
output_index_range = np.arange(len(output_gp)); #output_index_range

# %%
# list for original index
output_index_list = [output_index_range[output_gp == gp] 
                     for gp in gp_list]

# %%
for o in output_index_list:
    print(o.shape)
# Out:
# (1879,)
# (23085,)
# (43691,)
# (75617,)
# (740,)
# (51,)

# %%
output_index_list_comb = np.concatenate(output_index_list)
output_index_list_comb
# Out:
# array([  1475,   3412,   3467, ..., 123025, 139119, 140151])

# %%
Y_output_pred_ens = []
for Y_output_pred_list in Y_output_pred_list_ens:
    Y_output_pred_comb = np.concatenate(Y_output_pred_list)
    Y_output_pred_temp = [0]*len(output_index_list_comb)

    for index, y in zip(output_index_list_comb, Y_output_pred_comb):
        Y_output_pred_temp[index] = y

    Y_output_pred = np.array(Y_output_pred_temp)  # make it an numpy array (which will also make a copy)
    Y_output_pred_ens.append(Y_output_pred)

del Y_output_pred_temp

# %%
# Inverse transform Y of output

Y_output_pred_ori_ens = []
for Y_output_pred in Y_output_pred_ens:
    Y_output_pred_ori = unlog(untransform(Y_output_pred, 
                                          output_center, output_scale))
    Y_output_pred_ori_ens.append(Y_output_pred_ori)

# %% [markdown]
# #### Check predict output

# %% [markdown]
# Y_output_pred

# %% [markdown]
# Y_output_pred_ori

# %% [markdown]
# examine(Y_output_pred)

# %% [markdown]
# examine(Y_output_pred_ori)

# %% [markdown]
# view(X_output_ori[126420])

# %% [markdown]
# ### Model Score

# %%
# SMAPE scores for the model
if test_length:
    model_smape_ens = []
    model_smape_0_ens = []
    for Y_output_pred_ori in Y_output_pred_ori_ens:
        model_smape = smape(Y_output_raw, Y_output_pred_ori) # SMAPE score excluding nan (Correct one)
        model_smape_0 = smape(Y_output_ori, Y_output_pred_ori) # SMAPE assuming nan == 0
        print(model_smape, model_smape_0)
        
        model_smape_ens.append(model_smape)
        model_smape_0_ens.append(model_smape_0)
    model_smape_ens_mean = np.mean(model_smape_ens)
    model_smape_0_ens_mean = np.mean(model_smape_0_ens)
    print('-----------')
    print(model_smape_ens_mean, model_smape_0_ens_mean)
# Out:
# 39.1819546501 42.8629254387
# 38.736580155 42.5527060592
# 38.7578603091 42.2688547221
# 38.7676177917 42.4931526044
# 38.9144441607 42.7921900415
# -----------
# 38.8716914133 42.5939657732

# %%
# SMAPE score for Fibonacci median
if test_length:
    fib_smape = smape(Y_output_raw, Y_output_fib)
    print(fib_smape)
# Out:
# 40.4041165988

# %% [markdown]
# ### Group Scores
# For self-testing stage only

# %%
# Prediction Y_output in group
Y_output_pred_ori_list_ens = [[Y_output_pred_ori[output_gp == gp] for gp in gp_list]
                              for Y_output_pred_ori in Y_output_pred_ori_ens]
#Y_output_pred_ori_list = [Y_output_pred_ori[output_gp == gp] for gp in gp_list]
Y_output_pred_ori_list = Y_output_pred_ori_list_ens[-1]  # in case you want to see one of them

# %%
# True Y_output in group
if test_length:
    # untransformed Y_output with nan replaced by 0
    Y_output_ori_list = [Y_output_ori[output_gp == gp] for gp in gp_list]
    
    # untransformed Y_output_ori with nan (for SMAPE estimation)
    Y_output_raw_list = [Y_output_raw[output_gp == gp] for gp in gp_list]

# %%
tot_n = len(output_gp); tot_n  # total number of pages in output set
# Out:
# 145063

# %%
def count_not_nan(data):
    return np.count_nonzero(~np.isnan(data))

# %% [markdown]
# if test_length: print(count_not_nan(Y_output_raw))

# %%
# Group SMAPE scores
if test_length:
    gp_n = [len(Y) for Y in Y_output_raw_list]
    # SMAPE assuming nan == 0
    #gp_smape_0 = [smape(Y, Y_p) for Y, Y_p 
    #              in zip(Y_output_ori_list, Y_output_pred_ori_list)]
    
    # SMAPE with nan values ignored (used by Kaggle)
    gp_smape_ens = [[smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_list)]
                    for Y_output_pred_ori_list in Y_output_pred_ori_list_ens]
    gp_smape = gp_smape_ens[-1]
    #gp_smape = [smape(Y, Y_p) for Y, Y_p 
    #            in zip(Y_output_raw_list, Y_output_pred_ori_list)]
    
    n_not_nan = count_not_nan(Y_output_raw)
    n_not_nan_gp = [count_not_nan(Y) for Y in Y_output_raw_list]
    n_not_nan_ratio_gp = [n / (len(Y) * len(Y[0])) for Y,n 
                          in zip(Y_output_raw_list, n_not_nan_gp)]
    
    # SMAPE contribution
    #gp_smape_sum = [s * n for n, s in zip(gp_smape, n_not_nan_gp)]
    #gp_smape_cont = [s / n_not_nan for s in gp_smape_sum]

# %% [markdown]
# if test_length:
#     print('[Group SMAPE]')
#     print('W/ Nan, Nan=0, Contribution, Pages, Non-nan Ratio')
#     for score, score_0, c, n, nr in zip(gp_smape, gp_smape_0,
#                                     gp_smape_cont, gp_n,
#                                     n_not_nan_ratio_gp):
#         print('%6.2f' % score, '%6.2f' % score_0, '       %6.2f' % c, '%6d' % n,
#               '        %6.3f' % nr)
#     print('-------------------------------------------------')
#     print('%6.2f' % model_smape, '%6.2f' % model_smape_0)

# %% [markdown]
# n_not_nan_gp

# %% [markdown]
# ### Individual Page Scores

# %%
if test_length:
    smape_Y_pred_ens = []
    #smape_Y_pred_na = np.array([smape(yp, y) for yp, y 
    #                            in zip(Y_output_pred_ori, Y_output_raw)])
    for Y_output_pred_ori in Y_output_pred_ori_ens:
        smape_Y_pred = np.nan_to_num(np.array([smape(yp, y) for yp, y 
                                               in zip(Y_output_pred_ori, Y_output_raw)]))
        smape_Y_pred_ens.append(smape_Y_pred)
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice
#   """

# %%
if test_length:
    for smape_Y_pred in smape_Y_pred_ens:
        plt.hist(smape_Y_pred, bins=40, alpha=0.4)
        #plt.yscale('log')
    plt.show()

# %% [markdown]
# ### SMAPE for the Model

# %%
if test_length:
    smape_Y_pred_list_ens = []
    for smape_Y_pred in smape_Y_pred_ens:
        smape_Y_pred_list = [smape_Y_pred[output_gp == gp] for gp in gp_list]
        smape_Y_pred_list_ens.append(smape_Y_pred_list)

# %%
if test_length:
    for i,s in zip(range(len(smape_Y_pred_list)),smape_Y_pred_list):
        plt.hist(s, bins=40, normed=True, alpha=0.6, label=str(i))
    #plt.yscale('log')
    plt.legend()
    plt.show()

# %% [markdown]
# if test_length:
#     for i,s in zip(range(len(smape_Y_pred_list)),smape_Y_pred_list):
#         plt.hist(s, bins=40, normed=True, alpha=0.6, label=str(i))
#     #plt.yscale('log')
#     plt.ylim([0,0.05])
#     plt.legend()
#     plt.show()

# %%
if test_length:
    for i,s in zip(range(len(smape_Y_pred_list[1:])),smape_Y_pred_list[1:]):
        plt.hist(s, bins=40, alpha=0.6, label=str(i+1))
    #plt.yscale('log')
    #plt.ylim([0,0.05])
    plt.legend()
    plt.show()

# %%
if test_length:
    for i,s in zip(range(len(smape_Y_pred_list)),smape_Y_pred_list):
        plt.hist(s, bins=40, alpha=0.6)
        plt.title('gp = '+str(i))
        plt.show()
    #plt.yscale('log')
    #plt.ylim([0,0.05])

# %% [markdown]
# ### SMAPE for Fibonacci median

# %%
Y_output_fib_list = [Y_output_fib[output_gp == gp] for gp in gp_list]

# %%
# Group SMAPE for Fib.
if test_length:
    gp_smape_fib = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_fib_list)]

# %%
# Individual SMAPE for Fib.
if test_length:
    #smape_Y_fib_na = np.array([smape(yp, y) for yp, y 
    #                           in zip(Y_output_fib, Y_output_raw)])
    smape_Y_fib = np.nan_to_num(np.array([smape(yp, y) for yp, y 
                                          in zip(Y_output_fib, Y_output_raw)]))

    smape_Y_fib_list = [smape_Y_fib[output_gp == gp] for gp in gp_list]
# The above two cells can be combined.
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice
#   """

# %% [markdown]
# #### SMAPE distribution for Fib

# %%
if test_length:
    plt.hist(smape_Y_fib, bins=40, alpha=0.6)
    plt.hist(smape_Y_pred, bins=40, alpha=0.6)
    #plt.yscale('log')
    plt.show()

# %%
if test_length:
    for i,s in zip(range(len(smape_Y_fib_list)),smape_Y_fib_list):
        plt.hist(s, bins=40, normed=True, alpha=0.6, label=str(i))
    #plt.yscale('log')
    #plt.ylim([0,0.05])
    plt.legend()
    plt.show()

# %%
if test_length:
    for i,s in zip(range(len(smape_Y_fib_list[1:])),smape_Y_fib_list[1:]):
        plt.hist(s, bins=40, alpha=0.6, label=str(i+1))
    #plt.yscale('log')
    #plt.ylim([0,0.05])
    plt.legend()
    plt.show()

# %% [markdown]
# if test_length:
#     for i in range(len(smape_Y_fib_list)):
#         plt.hist(smape_Y_pred_list[i], bins=40, alpha=0.7, label='Model')
#         plt.hist(smape_Y_fib_list[i], bins=40, alpha=0.5, label='Fib')
#         plt.title('gp = '+str(i))
#         plt.legend()
#         plt.show()
#     #plt.yscale('log')
#     #plt.ylim([0,0.05])

# %% [markdown]
# ### Models vs Fibonacci Median

# %% [markdown]
# if test_length:  # gp_score
#     print('#### ' + model_name)
#     print('', end='|')
#     print('N_pages ', 'Fibonacci', sep='|', end='|')
#     for run in ens_list: print(' Model', run, end=' |')
#     print('')
#     print('', end='|')
#     print('--------', '---------', sep='|', end='|')
#     for run in ens_list: print('---------', end='|')
#     print('')
#     for gp in gp_list:
#         print('', end='|')
#         print(' %6d ' % gp_n[gp], end='|')
#         print(' %7.3f ' % gp_smape_fib[gp], end='|')
#         for run in ens_list:
#             print(' %7.3f ' % gp_smape_ens[run][gp], end='|')
#         print('')

# %% [markdown]
# #### model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3
# |N_pages |Fibonacci| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 161.230 | 166.806 | 139.008 | 152.935 | 170.833 |
# |  23085 |  61.354 |  64.048 |  63.281 |  63.966 |  63.664 |  63.569 |
# |  43691 |  40.612 |  40.004 |  39.860 |  40.201 |  39.817 |  40.143 |
# |  75617 |  34.284 |  30.201 |  29.582 |  29.611 |  29.744 |  29.618 |
# |    740 |  35.621 |  33.801 |  34.143 |  34.101 |  34.290 |  34.145 |
# |     51 |  20.224 |  16.933 |  17.094 |  16.930 |  17.424 |  16.985 |
#
# #### model_9_CNN_with_Fibonacci_4_Ensemble
# |N_pages |Fibonacci| Model 0 |
# |--------|---------|---------|
# |   1879 |  57.385 | 146.145 |
# |  23085 |  61.354 |  64.128 |
# |  43691 |  40.612 |  40.052 |
# |  75617 |  34.284 |  29.862 |
# |    740 |  35.621 |  34.607 |
# |     51 |  20.224 |  16.023 |

# %% [markdown]
# ## Prediction Combine
# Combine group 0, 1 from Fib and rest from the model

# %%
Y_output_fib.shape
# Out:
# (145063, 1)

# %%
Y_output_fib_ori = np.repeat(Y_output_fib, y_length, axis=1); Y_output_fib_ori.shape
# Out:
# (145063, 63)

# %%
# Select group 0, 1
fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape
# Out:
# (145063, 1)

# %%
# The combined result
Y_output_fmc_ori_ens = []
for Y_output_pred_ori in Y_output_pred_ori_ens:
    
    Y_output_fmc_ori = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori
    
    Y_output_fmc_ori_ens.append(Y_output_fmc_ori)

# %%
Y_output_fmc_ori
# Out:
# array([[ 29.15142878,  29.33763909,  29.59186018, ...,  27.06294787,
#          26.39459764,  27.34669276],
#        [ 33.94780421,  34.74909034,  35.19060587, ...,  26.2467805 ,
#          25.61644178,  26.5564052 ],
#        [  4.        ,   4.        ,   4.        , ...,   4.        ,
#           4.        ,   4.        ],
#        ...,
#        [ 36.62038029,  41.15289949,  43.03553504, ...,  34.66043448,
#          32.83952229,  34.16213255],
#        [  7.75      ,   7.75      ,   7.75      , ...,   7.75      ,
#           7.75      ,   7.75      ],
#        [  7.79408836,   6.20970613,   6.61380074, ...,   9.48690618,
#           9.22428161,  10.30025771]])

# %%
model_smape_ens
# Out:
# [39.181954650137229,
#  38.73658015502685,
#  38.757860309092187,
#  38.767617791707082,
#  38.91444416069421]

# %%
if test_length: 
    fmc_smape_ens = []
    for Y_output_fmc_ori in Y_output_fmc_ori_ens:
        fmc_smape = smape(Y_output_fmc_ori, Y_output_raw)
        fmc_smape_ens.append(fmc_smape)        
    fmc_smape_ens_mean = np.mean(fmc_smape_ens)

# %%
if test_length: 
    for run, fmc_smape, model_smape in zip(ens_list, fmc_smape_ens, model_smape_ens):
        print('%6.3f' % fmc_smape, '(%6.3f)' % model_smape, '-', model_name, run)
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
# Out:
# 38.036 (39.182) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 0
# 37.664 (38.737) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 1
# 37.784 (38.758) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 2
# 37.738 (38.768) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 3
# 37.770 (38.914) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 4
# 37.798 (38.872) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 Average

# %% [markdown]
# #### Combined Scores:
# 38.777 (39.377) - Model 9.1.0 - model_9_CNN_with_Fibonacci_1_no_group 2
#
# 38.734 (39.415) - Model 9.1.0 - model_9_CNN_with_Fibonacci_1_no_group 1
#
# 38.227 (39.321) - Model 9.0.0 - model_9_CNN_with_Fibonacci_0_separate_Fib_median 1
#
# 43.174 (44.159) - Model 7.8.0 - model_7_CNN_with_Fibonacci_8_mean_absolute_error 3
#
# 43.009 (44.180) - Model 7.8.0 - model_7_CNN_with_Fibonacci_8_mean_absolute_error 2
#
# 43.038 (43.990) - Model 7.8.0 - model_7_CNN_with_Fibonacci_8_mean_absolute_error 1
#
# 43.479 (44.659) - Model 7.6.3 - model_7_CNN_with_Fibonacci_6_Wider_3_conv_120_Averagepool 3
#
# 43.804 (45.033) - Model 7.6.3 - model_7_CNN_with_Fibonacci_6_Wider_3_conv_120_Averagepool 2
#
# 44.070 (45.335) - Model 7.6.3 - model_7_CNN_with_Fibonacci_6_Wider_3_conv_120_Averagepool 1
#
# 44.948 (46.090) - Model 7.6.1 - model_7_CNN_with_Fibonacci_6_Wider_1_conv_120_Maxpool 4
#
# 43.762 (44.885) - Model 7.6.1 - model_7_CNN_with_Fibonacci_6_Wider_1_conv_120_Maxpool 3
#
# 43.805 (44.996) - Model 7.6.1 - model_7_CNN_with_Fibonacci_6_Wider_1_conv_120_Maxpool 2
#
# 44.473 (45.652) - Model 7.6.1 - model_7_CNN_with_Fibonacci_6_Wider_1_conv_120_Maxpool 1
#
# 44.433 - Model 7.5.0 - model_7_CNN_with_Fibonacci_5_Deeper_0_Initial
#
# 44.168 - Model 7.2.0

# %% [markdown]
# ## Ensemble Learning

# %%
Y_output_pred_ori_ens
# Out:
# [array([[ 26.8508807 ,  26.71662753,  27.48681733, ...,  27.12926284,
#           26.46024003,  26.96639756],
#         [ 26.47664839,  27.03990221,  27.45344654, ...,  23.77360097,
#           23.25008892,  23.71254751],
#         [  3.47251719,   3.81874388,   3.57713862, ...,   3.43968057,
#            3.46520979,   3.66991882],
#         ...,
#         [ 26.90466733,  29.27509313,  30.69858318, ...,  27.52948291,
#           26.46709875,  27.79739865],
#         [  6.63866009,   7.19283116,   6.70166868, ...,   6.49128104,
#            6.58293471,   6.80369668],
#         [  9.46124696,   7.98451467,   8.55764147, ...,  10.59714302,
#           10.71936343,  12.3247522 ]]),
#  array([[ 24.96884114,  24.78041664,  25.37022512, ...,  25.36493826,
#           24.95339753,  25.52786153],
#         [ 28.27702619,  28.0091421 ,  28.89433931, ...,  26.68539756,
#           26.15320091,  26.64681074],
#         [  3.71103405,   3.85939909,   3.47483726, ...,   3.60480445,
#            3.52169178,   3.7538964 ],
#         ...,
#         [ 29.52307556,  31.40935186,  32.62575388, ...,  29.73923443,
#           28.85074967,  30.87802803],
#         [  7.07395454,   7.50936339,   7.05464349, ...,   6.92422167,
#            6.56491179,   7.03628381],
#         [  7.86447721,   7.03756123,   7.41727573, ...,   9.04958095,
#            8.74243995,   9.45747473]]),
#  array([[ 23.40930531,  23.92746594,  24.38218322, ...,  23.59053432,
#           23.20809712,  23.66121439],
#         [ 23.03400719,  22.9950481 ,  23.48569726, ...,  22.59972924,
#           22.09212459,  22.566643  ],
#         [  3.45727445,   3.54308151,   3.32073461, ...,   3.35971083,
#            3.32395192,   3.6382194 ],
#         ...,
#         [ 28.62063917,  29.27693446,  29.82671824, ...,  28.72188871,
#           28.30199931,  29.95431583],
#         [  6.08524559,   6.60423344,   5.7312479 , ...,   5.96920883,
#            6.01171432,   6.69304046],
#         [ 10.86614627,   9.23211416,   9.66202714, ...,  12.49388071,
#           11.95067268,  12.5632509 ]]),
#  array([[ 21.18241696,  21.25173123,  21.50110253, ...,  21.67301837,
#           21.25369671,  22.06039987],
#         [ 23.64488811,  23.81587157,  24.34188634, ...,  23.17466266,
#           22.45437869,  23.43983376],
#         [  3.41048359,   3.64440256,   3.4079641 , ...,   3.56578957,
#            3.42016494,   3.70826245],
#         ...,
#         [ 27.85239717,  29.10878377,  29.58111687, ...,  27.14171547,
#           26.15737179,  27.71890825],
#         [  7.02623302,   7.44253241,   6.91874719, ...,   7.0282538 ,
#            6.94697108,   7.35690532],
#         [  8.6767623 ,   7.2572085 ,   7.54048899, ...,   9.85801916,
#            9.46770941,  10.56209196]]),
#  array([[ 29.15142878,  29.33763909,  29.59186018, ...,  27.06294787,
#           26.39459764,  27.34669276],
#         [ 33.94780421,  34.74909034,  35.19060587, ...,  26.2467805 ,
#           25.61644178,  26.5564052 ],
#         [  3.58335474,   3.94969188,   3.64236218, ...,   3.4293092 ,
#            3.5187656 ,   3.74597699],
#         ...,
#         [ 36.62038029,  41.15289949,  43.03553504, ...,  34.66043448,
#           32.83952229,  34.16213255],
#         [  6.75647494,   7.3769492 ,   6.73931639, ...,   6.37888674,
#            6.63009761,   6.9827933 ],
#         [  7.79408836,   6.20970613,   6.61380074, ...,   9.48690618,
#            9.22428161,  10.30025771]])]

# %% [markdown]
# ### Method 1 - Mean

# %%
Y_output_pred_ori_ens_mean = np.mean(Y_output_pred_ori_ens, axis=0)

# %%
Y_output_pred_ori_ens_mean.shape
# Out:
# (145063, 63)

# %% [markdown]
# Y_output_pred_ori_ens_mean

# %%
smape(Y_output_pred_ori_ens_mean, Y_output_raw)
# Out:
# 38.901209535622087

# %% [markdown]
# ### Method 2 - Median

# %%
Y_output_pred_ori_ens_med = np.median(Y_output_pred_ori_ens, axis=0)

# %%
Y_output_pred_ori_ens_med.shape
# Out:
# (145063, 63)

# %% [markdown]
# Y_output_pred_ori_ens_med

# %%
smape(Y_output_pred_ori_ens_med, Y_output_raw)
# Out:
# 38.655728954601052

# %% [markdown]
# ### Method 3 - Mean before inverse transform and log

# %%
Y_output_pred_ens_mean = np.mean(Y_output_pred_ens, axis=0)
Y_output_pred_ens_mean_ori = unlog(untransform(Y_output_pred_ens_mean, output_center, output_scale))

# %%
smape(Y_output_pred_ens_mean_ori, Y_output_raw)
# Out:
# 38.775814140430789

# %% [markdown]
# ### Method 4 - Median before inverse transform and log

# %%
Y_output_pred_ens_med = np.median(Y_output_pred_ens, axis=0)
Y_output_pred_ens_med_ori = unlog(untransform(Y_output_pred_ens_med, output_center, output_scale))

# %%
smape(Y_output_pred_ens_med_ori, Y_output_raw)
# Out:
# 38.655728954601052

# %% [markdown]
# Best ways seem to be taking median either before or after transformation.

# %% [markdown]
# ### Ensemble Combine with Fibonacci Median

# %%
# Select group 0, 1
fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape
# Out:
# (145063, 1)

# %%
# The combined result

Y_output_fmc_ori = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori
Y_output_pred_ens_med_ori
# Out:
# array([[ 24.96884114,  24.78041664,  25.37022512, ...,  25.36493826,
#          24.95339753,  25.52786153],
#        [ 26.47664839,  27.03990221,  27.45344654, ...,  23.77360097,
#          23.25008892,  23.71254751],
#        [  3.47251719,   3.81874388,   3.47483726, ...,   3.43968057,
#           3.46520979,   3.70826245],
#        ...,
#        [ 28.62063917,  29.27693446,  30.69858318, ...,  28.72188871,
#          28.30199931,  29.95431583],
#        [  6.75647494,   7.3769492 ,   6.73931639, ...,   6.49128104,
#           6.58293471,   6.9827933 ],
#        [  8.6767623 ,   7.2572085 ,   7.54048899, ...,   9.85801916,
#           9.46770941,  10.56209196]])

# %%
Y_output_f_omean = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori_ens_mean
Y_output_f_omed  = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori_ens_med
Y_output_f_meano = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ens_mean_ori
Y_output_f_medo  = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ens_med_ori

# %%
if test_length:
    f_omean_smape = smape(Y_output_raw, Y_output_f_omean)
    f_omed_smape = smape(Y_output_raw, Y_output_f_omed)
    f_meano_smape = smape(Y_output_raw, Y_output_f_meano)
    f_medo_smape = smape(Y_output_raw, Y_output_f_medo)

# %%
if test_length: # The_score
    print('%6.3f         ' % f_omean_smape, '-', model_name, 'ori_ens_mean')
    print('%6.3f         ' % f_omed_smape, '-', model_name, 'ori_ens_med')
    print('%6.3f         ' % f_meano_smape, '-', model_name, 'ens_mean_ori')
    print('%6.3f         ' % f_medo_smape, '-', model_name, 'ens_med_ori')
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
# Out:
# 37.537          - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 ori_ens_mean
# 37.478          - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 ori_ens_med
# 37.487          - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 ens_mean_ori
# 37.478          - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 ens_med_ori
# 37.798 (38.872) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 Average

# %%
if test_length: 
    for run, fmc_smape, model_smape in zip(ens_list, fmc_smape_ens, model_smape_ens):
        print('%6.3f' % fmc_smape, '(%6.3f)' % model_smape, '-', model_name, run)
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
# Out:
# 38.036 (39.182) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 0
# 37.664 (38.737) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 1
# 37.784 (38.758) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 2
# 37.738 (38.768) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 3
# 37.770 (38.914) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 4
# 37.798 (38.872) - model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3 Average

# %% [markdown]
# Ensemble of model are all better than the individual model.

# %%
fmc_smape_ens
# Out:
# [38.035690229632323,
#  37.663626203064318,
#  37.783717824830404,
#  37.737774285034661,
#  37.769756005764634]

# %%
fmc_smape_ens_mean
# Out:
# 37.798112909665271

# %% [markdown]
#  Y_output_ori_list = [Y_output_ori[output_gp == gp] for gp in gp_list]

# %% [markdown]
# ### All Group Scores

# %%
# ensemble result Y_output in each group
Y_output_pred_ori_ens_mean_list = [Y_output_pred_ori_ens_mean[output_gp == gp] for gp in gp_list]
Y_output_pred_ori_ens_med_list = [Y_output_pred_ori_ens_med[output_gp == gp] for gp in gp_list]
Y_output_pred_ens_mean_ori_list = [Y_output_pred_ens_mean_ori[output_gp == gp] for gp in gp_list]
Y_output_pred_ens_med_ori_list = [Y_output_pred_ens_med_ori[output_gp == gp] for gp in gp_list]

# %%
# Group SMAPE scores
if test_length:
    # SMAPE with nan values ignored (used by Kaggle)
    gp_omean_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_ens_mean_list)]
    gp_omed_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_ens_med_list)]
    gp_meano_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ens_mean_ori_list)]
    gp_medo_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ens_med_ori_list)]
    
    # SMAPE contribution
    #gp_smape_sum = [s * n for n, s in zip(gp_smape, n_not_nan_gp)]
    #gp_smape_cont = [s / n_not_nan for s in gp_smape_sum]

# %%
if test_length:  # The_gp_score
    print('#### ' + model_name)
    print('', end='|')
    print(' N_pages', 'Fibonacci', ' ori mean', 'ori media', ' mean ori', 'media ori', sep='|', end='|')
    for run in ens_list: print(' Model', run, end=' |')
    print('')
    print('', end='|')
    print('--------', '---------', '---------', '---------', '---------', '---------', sep='|', end='|')
    for run in ens_list: print('---------', end='|')
    print('')
    for gp in gp_list:
        print('', end='|')
        print(' %6d ' % gp_n[gp], end='|')
        print(' %7.3f ' % gp_smape_fib[gp], end='|')
        print(' %7.3f ' % gp_omean_smape[gp], end='|')
        print(' %7.3f ' % gp_omed_smape[gp], end='|')
        print(' %7.3f ' % gp_meano_smape[gp], end='|')
        print(' %7.3f ' % gp_medo_smape[gp], end='|')
        for run in ens_list:
            print(' %7.3f ' % gp_smape_ens[run][gp], end='|')
        print('')
# Out:
# #### model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3
# | N_pages|Fibonacci| ori mean|ori media| mean ori|media ori| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 199.921 | 173.799 | 189.346 | 173.799 | 161.230 | 166.806 | 139.008 | 152.935 | 170.833 |
# |  23085 |  61.354 |  63.635 |  63.651 |  63.644 |  63.651 |  64.048 |  63.281 |  63.966 |  63.664 |  63.569 |
# |  43691 |  40.612 |  39.693 |  39.628 |  39.637 |  39.628 |  40.004 |  39.860 |  40.201 |  39.817 |  40.143 |
# |  75617 |  34.284 |  29.444 |  29.368 |  29.381 |  29.368 |  30.201 |  29.582 |  29.611 |  29.744 |  29.618 |
# |    740 |  35.621 |  33.858 |  33.893 |  33.837 |  33.893 |  33.801 |  34.143 |  34.101 |  34.290 |  34.145 |
# |     51 |  20.224 |  16.861 |  16.948 |  16.856 |  16.948 |  16.933 |  17.094 |  16.930 |  17.424 |  16.985 |

# %% [markdown]
# #### model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3
# | N_pages|Fibonacci| ori mean|ori media| mean ori|media ori| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 199.921 | 173.799 | 189.346 | 173.799 | 161.230 | 166.806 | 139.008 | 152.935 | 170.833 |
# |  23085 |  61.354 |  63.635 |  63.651 |  63.644 |  63.651 |  64.048 |  63.281 |  63.966 |  63.664 |  63.569 |
# |  43691 |  40.612 |  39.693 |  39.628 |  39.637 |  39.628 |  40.004 |  39.860 |  40.201 |  39.817 |  40.143 |
# |  75617 |  34.284 |  29.444 |  29.368 |  29.381 |  29.368 |  30.201 |  29.582 |  29.611 |  29.744 |  29.618 |
# |    740 |  35.621 |  33.858 |  33.893 |  33.837 |  33.893 |  33.801 |  34.143 |  34.101 |  34.290 |  34.145 |
# |     51 |  20.224 |  16.861 |  16.948 |  16.856 |  16.948 |  16.933 |  17.094 |  16.930 |  17.424 |  16.985 |

# %% [markdown]
# ## More Explore

# %% [markdown]
# ### Group in other group

# %%
run = 1
models = models_ens[run]

# %%
Y_output_all_ori_list = unlog(np.array([untransform(model.predict(X_output), output_center, output_scale) 
                                        for model in models]))

# %%
Y_output_all_ori_list.shape
# Out:
# (6, 145063, 63)

# %%
smape_Y_all = np.array([smape(Y_output_raw, Y_output_all, axis=-1) for Y_output_all in Y_output_all_ori_list])
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice
#   """

# %% [markdown]
# #### Group model in each group scores

# %%
smape_gpm_gp_ens = []

# %%
# %%time
for run in ens_list:
    print('Run', run)
    models = models_ens[run]
    Y_output_all_ori_list = unlog(np.array([untransform(model.predict(X_output), output_center, output_scale) 
                                            for model in models]))
    # row: model of the group; column: group of Y
    smape_gpm_gp = [[smape(Y, Y_p[output_gp == gp]) for gp, Y in zip(gp_list, Y_output_raw_list)] 
                    for Y_p in Y_output_all_ori_list]
    smape_gpm_gp_ens.append(smape_gpm_gp)
# Out:
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4

# %%
smape_gpm_gp_ens = np.array(smape_gpm_gp_ens)

# %%
smape_gpm_gp_ens.shape  # (ensemble, group model, group)
# Out:
# (5, 6, 6)

# %%
smape_gpm_gp_mean = np.mean(smape_gpm_gp_ens, axis=0)

# %%
print('Ensemble avg  ', end='|')
for j in range(len(smape_gpm_gp_mean[0])): print(' group', j, end='|')
print('')
print('--------------', end='|')
for j in range(len(smape_gpm_gp_mean[0])): print('--------', end='|')
print('')
for i in range(len(smape_gpm_gp_mean)):
    print('group model', i, end=' |')
    for j in range(len(smape_gpm_gp_mean[0])):
        print(' %6.2f ' % smape_gpm_gp_mean[i][j], end='|')
    print('')
# Out:
# Ensemble avg  | group 0| group 1| group 2| group 3| group 4| group 5|
# --------------|--------|--------|--------|--------|--------|--------|
# group model 0 | 158.16 |  61.38 |  40.62 |  34.29 |  35.64 |  20.23 |
# group model 1 | 168.66 |  63.71 |  40.55 |  33.53 |  35.34 |  18.81 |
# group model 2 | 147.31 |  64.69 |  40.00 |  31.03 |  34.26 |  14.39 |
# group model 3 | 136.14 |  65.90 |  40.38 |  29.75 |  31.89 |  15.78 |
# group model 4 | 113.26 |  70.65 |  43.09 |  33.34 |  34.10 |  20.32 |
# group model 5 | 168.62 |  68.89 |  47.00 |  38.40 |  42.57 |  17.07 |

# %% [markdown]
# Ensemble avg  | group 0| group 1| group 2| group 3| group 4| group 5|
# --------------|--------|--------|--------|--------|--------|--------|
# group model 0 | 158.16 |  61.38 |  40.62 |  34.29 |  35.64 |  20.23 |
# group model 1 | 168.66 |  63.71 |  40.55 |  33.53 |  35.34 |  18.81 |
# group model 2 | 147.31 |  64.69 |  40.00 |  31.03 |  34.26 |  14.39 |
# group model 3 | 136.14 |  65.90 |  40.38 |  29.75 |  31.89 |  15.78 |
# group model 4 | 113.26 |  70.65 |  43.09 |  33.34 |  34.10 |  20.32 |
# group model 5 | 168.62 |  68.89 |  47.00 |  38.40 |  42.57 |  17.07 |
#
# Run 1         | group 0| group 1| group 2| group 3| group 4| group 5|
# --------------|--------|--------|--------|--------|--------|--------|
# group model 0 | 166.81 |  61.37 |  40.62 |  34.30 |  35.64 |  20.23 |
# group model 1 | 170.26 |  63.28 |  40.53 |  33.42 |  35.18 |  18.81 |
# group model 2 | 150.58 |  64.46 |  39.86 |  30.99 |  34.56 |  14.48 |
# group model 3 | 136.05 |  66.20 |  40.27 |  29.58 |  31.52 |  15.55 |
# group model 4 | 110.66 |  74.48 |  44.13 |  33.77 |  34.14 |  20.71 |
# group model 5 | 169.66 |  68.87 |  46.58 |  37.67 |  41.70 |  17.09 |
#
# group model\gp| group 0| group 1| group 2| group 3| group 4| group 5|
# --------------|--------|--------|--------|--------|--------|--------|
# group model 0 | 170.83 |  61.43 |  40.62 |  34.30 |  35.65 |  20.23 |
# group model 1 | 169.22 |  63.57 |  40.70 |  33.74 |  35.65 |  18.99 |
# group model 2 | 163.42 |  64.56 |  40.14 |  31.30 |  34.21 |  14.89 |
# group model 3 | 137.23 |  65.54 |  40.30 |  29.62 |  31.53 |  14.51 |
# group model 4 | 112.67 |  71.44 |  43.30 |  33.40 |  34.14 |  19.36 |
# group model 5 | 170.97 |  66.06 |  44.39 |  36.45 |  40.09 |  16.98 |

# %% [markdown]
# ## Plots

# %%
view_list=[93175, 13986, 5464, 89589, 119659, 64392, 73856, 140331, 19234, 25591]

# %%
view_list = examine_list_gp((Y_output_ori,
                             Y_output_pred_ori_ens_mean, 
                             Y_output_pred_ori_ens_med,
                             Y_output_pred_ori_ens[-1], 
                             ), output_gp, view_list=view_list)

# %%
i = 93175
plt.plot(Y_output_ori[i], label='true')
plt.plot(Y_output_pred_ori_ens_mean[i], label='ens mean')
plt.plot(Y_output_pred_ori_ens_med[i], label='ens median')
plt.plot(Y_output_pred_ens_mean_ori[i], label='ens mean before transf')
plt.plot(Y_output_pred_ens_med_ori[i], label='ens median before transf')
plt.plot(Y_output_pred_ori_ens[-1][i], label='run: 4')
plt.title('i = ' + str(i) + ' gp = ' + str(output_gp[i]))
plt.legend()
plt.show()

# %%
i = 93175
plt.plot(Y_output_ori[i], label='true')
for run in ens_list:
    plt.plot(Y_output_pred_ori_ens[run][i], label='run' + str(run))
plt.plot(Y_output_pred_ens_mean_ori[i], label='ens mean before transf')
plt.title('i = ' + str(i) + ' gp = ' + str(output_gp[i]))
plt.legend()
plt.show()

# %%
view_list = examine_list_gp((Y_output_pred_ori_ens_mean, 
                             Y_output_pred_ori_ens_med,
                             Y_output_pred_ori_ens[-1], 
                             Y_output_ori), output_gp, view_list=view_list)

# %% [markdown]
# ## Case Study

# %% [markdown]
# view_list = comp_examine(X_output, Y_output_pred, view_list=view_list)

# %%
view_list
# Out:
# [93175, 13986, 5464, 89589, 119659, 64392, 73856, 140331, 19234, 25591]

# %% [markdown]
# view_list = comp_examine(X_output_ori, Y_output_pred_ori, view_list=view_list)

# %%
view_list = examine_list_gp((Y_output_pred_ori, X_output_ori, Y_input_ori), output_gp, view_list=view_list)

# %%
view_list = examine_list_gp((Y_output_pred, X_output, Y_input), output_gp, view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list((Y_output_pred, Y_output, X_output), view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list((Y_output_pred_ori, Y_output_ori, X_output_ori), view_list=view_list)

# %%
if test_length:
    view_list = examine_list_gp((Y_output_pred, Y_output, X_output), output_gp,
                             view_list=view_list)

# %%
if test_length:
    view_list = examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori), output_gp,
                             view_list=view_list)

# %%
view_list_smape = [smape(Y_output_pred_ori[i], Y_output_raw[i]) for i in view_list]; view_list_smape
# Out:
# [22.89083420578531,
#  78.214970142013428,
#  22.015235430769543,
#  41.254228254546931,
#  27.005253907671527,
#  24.355680145170666,
#  14.69350371968757,
#  37.399129412430831,
#  30.131323395475729,
#  15.743403101719197]

# %%
view_list_review = [score < model_smape for score in view_list_smape]; view_list_review
# Out:
# [True, False, True, False, True, True, True, True, True, True]

# %%
view_list_good = list(np.array(view_list)[view_list_review]); view_list_good
# Out:
# [93175, 5464, 119659, 64392, 73856, 140331, 19234, 25591]

# %%
view_list_bad = list(np.array(view_list)[~np.array(view_list_review)]); view_list_bad
# Out:
# [13986, 89589]

# %% [markdown]
# #### Good cases

# %%
examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori), output_gp,
             view_list=view_list_good)
# Out:
# [93175, 5464, 119659, 64392, 73856, 140331, 19234, 25591]

# %% [markdown]
# #### Bad cases

# %%
examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori),output_gp,
             view_list=view_list_bad)
# Out:
# [13986, 89589]

# %%
print(output_center[view_list_good].reshape(-1))
print(output_center[view_list_bad].reshape(-1))
# Out:
# [ 2.61225391  1.78532984  2.56555268  2.07280115  3.41796964  2.14921911
#   2.61489722  1.85125835]
# [ 0.30103     1.46612587]

# %%
print(output_scale[view_list_good].reshape(-1))
print(output_scale[view_list_bad].reshape(-1))
# Out:
# [ 0.45758495  0.13744919  0.17725717  0.12048413  0.09144428  0.29619523
#   0.18993217  0.07964336]
# [ 0.20849044  0.50503777]

# %%
output_gp[view_list_good]
# Out:
# array([3, 2, 3, 3, 3, 3, 3, 2])

# %%
output_gp[view_list_bad]
# Out:
# array([1, 2])

# %%
gp_smape
# Out:
# [170.83323326991254,
#  63.569390033800147,
#  40.142651919142097,
#  29.61769103677905,
#  34.144841962136368,
#  16.984698161058848]

# %%
gp_n
# Out:
# [1879, 23085, 43691, 75617, 740, 51]

# %% [markdown]
# #### Case 93175

# %%
i = 93175

# %% [markdown]
# multi_view((Y_output_pred_ori[i], Y_output_ori[i], X_output_ori[i]), yscale='log')
# multi_view((Y_output_pred_ori[i], Y_output_ori[i], X_output_ori[i]))

# %%
smape(Y_output_pred_ori[i], Y_output_raw[i])
# Out:
# 22.89083420578531

# %%
input_center[i], output_center[i], input_scale[i], output_scale[i]
# Out:
# (array([ 2.61225391]),
#  array([ 2.61225391]),
#  array([ 0.4493528]),
#  array([ 0.45758495]))

# %% [markdown]
# #### Case 41896

# %% [markdown]
# i = 41896

# %% [markdown]
# multi_view((X_input[i], Y_input[i]))

# %% [markdown]
# comp_view(X_input_ori[i], Y_input_ori[i])

# %% [markdown]
# comp_view(X_output_ori[i], Y_output_pred_ori[i])

# %% [markdown]
# comp_view(X_input_ori[i], Y_input_ori[i])

# %% [markdown]
# ### Good and bad cases

# %%
review_Y = np.array([score < model_smape for score in smape_Y_pred])

# %%
np.arange(len(Y_output_pred))
# Out:
# array([     0,      1,      2, ..., 145060, 145061, 145062])

# %%
good_Y_index = np.arange(len(Y_output_pred))[review_Y]; good_Y_index
# Out:
# array([     0,      3,      8, ..., 144962, 145021, 145042])

# %%
bad_Y_index = np.arange(len(Y_output_pred))[~review_Y]; bad_Y_index
# Out:
# array([     1,      2,      4, ..., 145060, 145061, 145062])

# %%
good_input_scale = input_scale[good_Y_index]
good_output_scale = output_scale[good_Y_index]
bad_input_scale = input_scale[bad_Y_index]
bad_output_scale = output_scale[bad_Y_index]

# %%
good_input_center = input_center[good_Y_index]
good_output_center = output_center[good_Y_index]
bad_input_center = input_center[bad_Y_index]
bad_output_center = output_center[bad_Y_index]

# %% [markdown]
# examine_list_gp((Y_output_pred_ori[good_Y_index], Y_output_ori[good_Y_index], X_output_ori[good_Y_index]), output_gp[good_Y_index])

# %% [markdown]
# examine_list_gp((Y_output_pred_ori[bad_Y_index], Y_output_ori[bad_Y_index], X_output_ori[bad_Y_index]), output_gp[bad_Y_index])

# %%
good_output_scale.min(), good_output_scale.max()
# Out:
# (0.0053654329977268714, 1.2782208038162026)

# %%
bad_output_scale.min(), bad_output_scale.max()
# Out:
# (0.0016980961003407436, 2.0382773961171501)

# %% [markdown]
# plt.hist(good_input_scale, bins=40, alpha=0.6, label='good input')
# plt.hist(bad_input_scale, bins=40, alpha=0.6, label='bad input')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_output_scale, bins=40, alpha=0.6, label='good output')
# plt.hist(bad_output_scale, bins=40, alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_input_scale, bins=40, alpha=0.6, label='good input')
# plt.hist(bad_input_scale, bins=40, alpha=0.6, label='bad input')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_output_scale, bins=40, alpha=0.6, label='good output')
# plt.hist(bad_output_scale, bins=40, alpha=0.6, label='bad output')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(good_input_scale, bins=100, range=(0,0.8), alpha=0.6, label='good input')
# plt.hist(good_output_scale, bins=100, range=(0,0.8), alpha=0.6, label='good output')
# plt.hist(bad_input_scale, bins=100, range=(0,0.8), alpha=0.6, label='bad input')
# plt.hist(bad_output_scale, bins=100, range=(0,0.8), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# Should we split the data into std > and < 1.7 ?

# %%
np.mean(good_output_scale), np.mean(good_input_scale)
# Out:
# (0.14773945715815218, 0.18703146737650495)

# %%
np.mean(bad_output_scale), np.mean(bad_input_scale)
# Out:
# (0.23067874556733933, 0.25848952643383755)

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(bad_input_scale, bins=60, range=(0,0.8), alpha=0.6, label='bad input')
# plt.hist(bad_output_scale, bins=60, range=(0,0.8), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(output_scale, bins=40, alpha=0.6, label='output')
# plt.hist(input_scale, bins=40, alpha=0.6, label='input')
# plt.legend()
# plt.show()

# %% [markdown]
# np.histogram(output_scale, bins=np.arange(0,1,0.05))

# %% [markdown]
# #### Median

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(good_input_center, bins=100, range=(0,5), alpha=0.6, label='good input')
# plt.hist(good_output_center, bins=100, range=(0,5), alpha=0.6, label='good output')
# plt.hist(bad_input_center, bins=100, range=(0,5), alpha=0.6, label='bad input')
# plt.hist(bad_output_center, bins=100, range=(0,5), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# ### stdev/median

# %% [markdown]
# output_factor_1 = (output_center / output_scale).reshape(-1); output_factor_1

# %% [markdown]
# output_factor_1.min(), output_factor_1.max()

# %% [markdown]
# plt.hist(output_factor_1, bins=40, range=[0,50], alpha=0.6)
# plt.show()

# %% [markdown]
# plt.scatter(smape_Y_pred, output_scale, alpha=0.1, marker='.')
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_center, alpha=0.1, marker='.')
# plt.ylim([-0.1,5])
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_scale, alpha=0.1, marker='.')
# plt.ylim([0,0.5])
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(output_scale, output_center, alpha=0.1, marker='.')
# plt.ylim([0,4.5])
# plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_2 = (output_scale / output_center).reshape(-1); output_factor_2

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_2, alpha=0.1, marker='.')
# plt.ylim([0,0.8])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_3 = (output_scale / (output_center + 0.01)).reshape(-1); output_factor_3

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_3, alpha=0.1, marker='.')
# plt.ylim([0,4])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_4 = output_scale - input_scale

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_4, alpha=0.1, marker='.')
# plt.ylim([-1.5,0.5])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# ## Output Prediction
# For predicting stage only

# %% [markdown]
# ### Result DataFrame

# %% [markdown]
# predict_dates_index=pd.date_range(Y_output_first_day,
#                                   periods=np.timedelta64(y_length,'D'),
#                                   freq = 'D', unit = 'D')
# predict_dates_index

# %%
Y_output_dates
# Out:
# Index(['2017-06-30', '2017-07-01', '2017-07-02', '2017-07-03', '2017-07-04',
#        '2017-07-05', '2017-07-06', '2017-07-07', '2017-07-08', '2017-07-09',
#        '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13', '2017-07-14',
#        '2017-07-15', '2017-07-16', '2017-07-17', '2017-07-18', '2017-07-19',
#        '2017-07-20', '2017-07-21', '2017-07-22', '2017-07-23', '2017-07-24',
#        '2017-07-25', '2017-07-26', '2017-07-27', '2017-07-28', '2017-07-29',
#        '2017-07-30', '2017-07-31', '2017-08-01', '2017-08-02', '2017-08-03',
#        '2017-08-04', '2017-08-05', '2017-08-06', '2017-08-07', '2017-08-08',
#        '2017-08-09', '2017-08-10', '2017-08-11', '2017-08-12', '2017-08-13',
#        '2017-08-14', '2017-08-15', '2017-08-16', '2017-08-17', '2017-08-18',
#        '2017-08-19', '2017-08-20', '2017-08-21', '2017-08-22', '2017-08-23',
#        '2017-08-24', '2017-08-25', '2017-08-26', '2017-08-27', '2017-08-28',
#        '2017-08-29', '2017-08-30', '2017-08-31'],
#       dtype='object')

# %%
if test_length == 0:
    result_df = pd.DataFrame(Y_output_fmc_ori, columns = Y_output_dates)  # using combined result
result_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-189-712ee547f657> in <module>()
#       1 if test_length == 0:
#       2     result_df = pd.DataFrame(Y_output_fmc_ori, columns = Y_output_dates)  # using combined result
# ----> 3 result_df
#
# NameError: name 'result_df' is not defined

# %%
result_df['Page'] = input_df['Page']  # Append 'Page' column from input_df
result_df

# %%
result_flat_df = pd.melt(result_df, id_vars='Page', var_name='date',
                         value_name='Visits')
result_flat_df

# %% [markdown]
# ### Output DataFrame

# %%
if test_length == 0:
    print('%%% Reading data key_1.csv ...', end = '', flush = True)
    output_df = pd.read_csv("../data/key_1.csv")
    print('done!')

# %%
output_df['date'] = output_df.Page.apply(lambda a: a[-10:])  # take the last 10 characters from 'Page' as date
output_df['Page'] = output_df.Page.apply(lambda a: a[:-11])  # remove the last 10 caharacters from 'Page'
#output_df['date'] = output_df['date'].astype('datetime64[ns]')  # convert 'date' string to numpy datetime format
#test['weekday'] = test.date.dt.dayofweek  # find the day of week using the 'date' column
output_df.head()

# %%
output_df.info()

# %%
output_df['date'].values[0:62]  # Make sure the range is 60 days (see if the dates resume after 60)

# %%
Y_output_dates

# %%
output_df = output_df.merge(result_flat_df, how='left')  # fill the 'Visits" from result
output_df

# %%
del result_flat_df

# %%
gc.collect()

# %%
#Check if there is null value
output_df.loc[output_df.Visits.isnull(), 'Visits']

# %%
#output_df.loc[output_df.Visits.isnull(), 'Visits'] = 0.0  # Uncommend this line to Replace NaN with 0.0

# %%
print('%%% Writing result for ' + model_name + ' ...', 
      end = '', flush = True)
#Write only the 'Id' and 'Visits' to the result file
output_df[['Id','Visits']].to_csv('../results/submit_1_' + model_name
                                  + '.csv', index = False, 
                                  float_format='%.3f')
print('done!')

# %% [markdown]
# Kaggle LB Score:
#
# [6.0.0] 46.3 [Model 6.0.0 CNN - Conv(60, 7)-FC(120)-Drop(0.25)-FC(120)-Drop(0.5)-Linear, 20 epoches]
#
# [6.1.0] 46.7 [Model 6.1.0 CNN - Conv(30, 7)-Conv(60, 7)-FC(120)-Drop(0.25)-FC(120)-Drop(0.5)-Linear, 20 epoches]
#
# [7.1.2] 47.3 [Model 7.1.2 CNN Fibonacci - range corrected :-y_length - score corrected]
#
# [7.2.0] 46.5 [Model 7.2.0 CNN Fibonacci and original combined]
