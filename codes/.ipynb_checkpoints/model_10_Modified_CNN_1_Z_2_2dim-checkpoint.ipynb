# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# ### Kaggle - Web Traffic Time Series Forecasting
#
# ## Model 10 - Modified CNN with Fibonacci
#
# ### v1 adding last year data as input Z
#
# by Louis Yang
#
# Use Fibonacci series median instead of median. The Fib. median are now compute on both training and CV set separately.
#
# Split into groups based on the scale of visit number and train individual model in each group
#
# The first 2 groups use original Fibonacci median as prediction. The rest groups use the trained CNN as prediction.
#
# v0 Feed second input (median and stdev) to the neural network after the CNN part.
#
# v0.3 Merge the original 0 and 1 groups and 4, 5 groups. Original 2,3 groups split into 2 based on stdev(> 1.7). Total number of groups is 6.
#
# Test on stage 2 data.
#
# Original model: 'model_10_Modified_CNN_0_median_stdev'
#
# Ensemble: automatically evaluate the same model 4 times

# %%
model_name = 'model_10_Modified_CNN_1_Z_2_2dim'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import gc  # Python garbage collect
from tools import *

# %% [markdown]
# ## Input

# %%
train_file = 'train_2.csv'

# %%
input_df = pd.read_csv('../data/' + train_file, nrows=1)

# %%
input_df_dates = input_df.columns[1:]; #input_df_dates

# %%
visits_dtype = {d: np.float32 for d in input_df_dates}

# %%
print('%%% Reading data '+ train_file + ' ... ', end = '', flush = True)
input_df = pd.read_csv('../data/' + train_file, engine='c', dtype=visits_dtype)
print('done!')
# Out:
# %%% Reading data train_2.csv ... done!

# %% [markdown]
# input_df.head()

# %% [markdown]
# input_df.info()

# %%
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145063 entries, 0 to 145062
# Columns: 794 entries, Page to 2017-08-31
# dtypes: float32(793), object(1)
# memory usage: 439.9+ MB

# %% [markdown]
# ## Processing Data
# Generate training set and test (predict) set

# %% [markdown]
# ### Day of week alignment

# %%
from datetime import datetime
def weekday(datestr):
    return datetime.strptime(datestr,'%Y-%m-%d').weekday()
def daydiff(dstr1,dstr2):
    return datetime.strptime(dstr1,'%Y-%m-%d') - datetime.strptime(dstr2,'%Y-%m-%d')

# %% [markdown]
# We need to predict output (Y_output_pred) start from Sunday (6) for data set 1. (0: Monday, 6: Sunday)

# %%
# We take the x_length + y_length days of data only
# This part then split into x_length as input X and y_length as output Y
x_length = 63  # input period
y_length = 63  # predict period

# %%
#test_length = 0  # for predicting
test_length = y_length  # for self testing

# %% [markdown]
# Shift everything forward by y_length = 63 days to allows self testing without Kaggle

# %% [markdown]
# #### X

# %%
X_input_dates = input_df_dates[-x_length-test_length-364:-test_length-364]; #X_input_dates

# %%
X_input_first_day = X_input_dates[0]
X_input_final_day = X_input_dates[-1]
X_input_first_day, X_input_final_day
# Out:
# ('2016-04-29', '2016-06-30')

# %%
daydiff(X_input_first_day, X_input_final_day)  # should be 1 - y_length
# Out:
# datetime.timedelta(-62)

# %%
# X for output set
if test_length:
    X_output_dates = input_df_dates[-x_length-test_length:-test_length]
else:
    X_output_dates = input_df_dates[-x_length:]
#X_output_dates

# %%
X_output_first_day = X_output_dates[0]
X_output_final_day = X_output_dates[-1]
X_output_first_day, X_output_final_day
# Out:
# ('2017-04-28', '2017-06-29')

# %%
daydiff(X_output_first_day, X_output_final_day)  # should be 1 - y_length
# Out:
# datetime.timedelta(-62)

# %%
weekday(X_input_first_day), weekday(X_output_first_day)
# Out:
# (4, 4)

# %% [markdown]
# Should be the same

# %% [markdown]
# #### Y

# %%
Y_input_dates = input_df_dates[-test_length-364:-test_length-364+y_length]; #Y_input_dates

# %%
Y_input_first_day = Y_input_dates[0]
Y_input_final_day = Y_input_dates[-1]
Y_input_first_day, Y_input_final_day
# Out:
# ('2016-07-01', '2016-09-01')

# %%
daydiff(Y_input_first_day, Y_input_final_day)
# Out:
# datetime.timedelta(-62)

# %%
# Y for output set
if test_length:
    Y_output_dates = input_df_dates[-test_length:]
else:
    Y_output_first_day = '2017-09-12'  ## Make sure it is correct when predicting !!!!!!!
    Y_output_dates = pd.Index(np.arange(np.datetime64(Y_output_first_day), 
                                        np.datetime64(Y_output_first_day)
                                        + np.timedelta64(y_length, 'D')).astype('str'))
#Y_output_dates

# %%
Y_output_first_day = Y_output_dates[0]
Y_output_final_day = Y_output_dates[-1]
Y_output_first_day, Y_output_final_day
# Out:
# ('2017-06-30', '2017-08-31')

# %%
daydiff(Y_output_first_day, Y_output_final_day)  # should be 1 - y_length
# Out:
# datetime.timedelta(-62)

# %%
weekday(Y_input_first_day), weekday(Y_output_first_day)
# Out:
# (4, 4)

# %% [markdown]
# Should be the same

# %% [markdown]
# #### Z

# %%
Z_input_dates = input_df_dates[-test_length-364*2:y_length-test_length-364*2]; Z_input_dates
# Out:
# Index(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#        '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11', '2015-07-12',
#        '2015-07-13', '2015-07-14', '2015-07-15', '2015-07-16', '2015-07-17',
#        '2015-07-18', '2015-07-19', '2015-07-20', '2015-07-21', '2015-07-22',
#        '2015-07-23', '2015-07-24', '2015-07-25', '2015-07-26', '2015-07-27',
#        '2015-07-28', '2015-07-29', '2015-07-30', '2015-07-31', '2015-08-01',
#        '2015-08-02', '2015-08-03', '2015-08-04', '2015-08-05', '2015-08-06',
#        '2015-08-07', '2015-08-08', '2015-08-09', '2015-08-10', '2015-08-11',
#        '2015-08-12', '2015-08-13', '2015-08-14', '2015-08-15', '2015-08-16',
#        '2015-08-17', '2015-08-18', '2015-08-19', '2015-08-20', '2015-08-21',
#        '2015-08-22', '2015-08-23', '2015-08-24', '2015-08-25', '2015-08-26',
#        '2015-08-27', '2015-08-28', '2015-08-29', '2015-08-30', '2015-08-31',
#        '2015-09-01', '2015-09-02', '2015-09-03'],
#       dtype='object')

# %%
Z_input_first_day = Z_input_dates[0]
Z_input_final_day = Z_input_dates[-1]
Z_input_first_day, Z_input_final_day
# Out:
# ('2015-07-03', '2015-09-03')

# %%
daydiff(Z_input_first_day, Z_input_final_day)  # should be 1 - y_length
# Out:
# datetime.timedelta(-62)

# %%
# Z for output set
Z_output_dates = Y_input_dates
Z_output_dates
# Out:
# Index(['2016-07-01', '2016-07-02', '2016-07-03', '2016-07-04', '2016-07-05',
#        '2016-07-06', '2016-07-07', '2016-07-08', '2016-07-09', '2016-07-10',
#        '2016-07-11', '2016-07-12', '2016-07-13', '2016-07-14', '2016-07-15',
#        '2016-07-16', '2016-07-17', '2016-07-18', '2016-07-19', '2016-07-20',
#        '2016-07-21', '2016-07-22', '2016-07-23', '2016-07-24', '2016-07-25',
#        '2016-07-26', '2016-07-27', '2016-07-28', '2016-07-29', '2016-07-30',
#        '2016-07-31', '2016-08-01', '2016-08-02', '2016-08-03', '2016-08-04',
#        '2016-08-05', '2016-08-06', '2016-08-07', '2016-08-08', '2016-08-09',
#        '2016-08-10', '2016-08-11', '2016-08-12', '2016-08-13', '2016-08-14',
#        '2016-08-15', '2016-08-16', '2016-08-17', '2016-08-18', '2016-08-19',
#        '2016-08-20', '2016-08-21', '2016-08-22', '2016-08-23', '2016-08-24',
#        '2016-08-25', '2016-08-26', '2016-08-27', '2016-08-28', '2016-08-29',
#        '2016-08-30', '2016-08-31', '2016-09-01'],
#       dtype='object')

# %%
Z_output_first_day = Z_output_dates[0]
Z_output_final_day = Z_output_dates[-1]
Z_output_first_day, Z_output_final_day
# Out:
# ('2016-07-01', '2016-09-01')

# %%
daydiff(Z_output_first_day, Z_output_final_day)  # should be 1 - y_length
# Out:
# datetime.timedelta(-62)

# %%
weekday(Z_input_first_day), weekday(Z_output_first_day)
# Out:
# (4, 4)

# %% [markdown]
# ## Fibonacci

# %% [markdown]
# #### Window Sizes

# %% [markdown]
# The window sizes are given by Ehsan https://www.kaggle.com/safavieh

# %%
windows = [11, 18, 30, 48, 78, 126, 203, 329]
fib_length = max(windows)#; fib_length

# %% [markdown]
# #### Data selection

# %% [markdown]
# In this testing code, we did not include the last y_length days since in the real predicting stage, we don't know their visits.

# %%
if test_length:
    fib_output_dates = input_df_dates[-fib_length-test_length:-test_length]
else:
    fib_output_dates = input_df_dates[-fib_length:]
fib_input_dates = input_df_dates[-fib_length-test_length-364:-test_length-364]
fib_input_dates, fib_output_dates
# Out:
# (Index(['2015-08-07', '2015-08-08', '2015-08-09', '2015-08-10', '2015-08-11',
#         '2015-08-12', '2015-08-13', '2015-08-14', '2015-08-15', '2015-08-16',
#         ...
#         '2016-06-21', '2016-06-22', '2016-06-23', '2016-06-24', '2016-06-25',
#         '2016-06-26', '2016-06-27', '2016-06-28', '2016-06-29', '2016-06-30'],
#        dtype='object', length=329),
#  Index(['2016-08-05', '2016-08-06', '2016-08-07', '2016-08-08', '2016-08-09',
#         '2016-08-10', '2016-08-11', '2016-08-12', '2016-08-13', '2016-08-14',
#         ...
#         '2017-06-20', '2017-06-21', '2017-06-22', '2017-06-23', '2017-06-24',
#         '2017-06-25', '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29'],
#        dtype='object', length=329))

# %%
weekday(fib_input_dates[0]), weekday(fib_output_dates[0])
# Out:
# (4, 4)

# %%
fib_output_data = input_df[fib_output_dates].values; #fib_output_data

# %%
fib_input_data = input_df[fib_input_dates].values; #fib_input_data

# %% [markdown]
# #### Fibonacci median in each window

# %%
fib_input_median_list = np.array([np.nanmedian(fib_input_data[:, -w:] , axis=-1) 
                            for w in windows])
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
fib_output_median_list = np.array([np.nanmedian(fib_output_data[:, -w:] , axis=-1) 
                            for w in windows])
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %% [markdown]
# fib_input_median_list.T.shape

# %% [markdown]
# fib_output_median_na = np.nanmedian(fib_output_median_list.T, axis=-1)

# %% [markdown]
# fib_output_median_na

# %%
fib_input_median = np.nan_to_num(np.nanmedian(fib_input_median_list.T, axis=-1)); fib_input_median.shape
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# (145063,)

# %%
fib_output_median = np.nan_to_num(np.nanmedian(fib_output_median_list.T, axis=-1)); fib_output_median.shape
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# (145063,)

# %% [markdown]
# fib_input_median

# %% [markdown]
# fib_output_median

# %% [markdown]
# We will use this as the center and part of the result

# %%
Y_input_fib = fib_input_median.reshape(-1,1)
Y_output_fib = fib_output_median.reshape(-1,1)

# %% [markdown]
# ## Data Selection
# Select x_length + y_length days of data as input or ouput set.

# %% [markdown]
# ### Input data

# %% [markdown]
# input_data contains X_input and Y_input array

# %%
input_dates = pd.Index(np.concatenate((X_input_dates, Y_input_dates)))
input_dates, X_input_first_day, Y_input_final_day
# Out:
# (Index(['2016-04-29', '2016-04-30', '2016-05-01', '2016-05-02', '2016-05-03',
#         '2016-05-04', '2016-05-05', '2016-05-06', '2016-05-07', '2016-05-08',
#         ...
#         '2016-08-23', '2016-08-24', '2016-08-25', '2016-08-26', '2016-08-27',
#         '2016-08-28', '2016-08-29', '2016-08-30', '2016-08-31', '2016-09-01'],
#        dtype='object', length=126), '2016-04-29', '2016-09-01')

# %%
input_data = input_df[input_dates].values; #input_data  # input_data with nan

# %% [markdown]
# ##### Convert nan to number 0.

# %%
input_data_num = np.nan_to_num(input_data); #input_data_num  # intput_data with nan -> 0.

# %% [markdown]
# input_data_num.shape

# %% [markdown]
# #### Z_input

# %%
Z_input_data_num = np.nan_to_num(input_df[Z_input_dates].values)

# %%
Z_input_data_num.shape
# Out:
# (145063, 63)

# %% [markdown]
# ### Output Data

# %% [markdown]
# output_data for this self-testing script contains both X_output and Y_output

# %%
if test_length:
    output_dates = pd.Index(np.concatenate((X_output_dates, Y_output_dates)))
else:
    output_dates = X_output_dates
output_dates, X_output_first_day, X_output_final_day, Y_output_final_day
# Out:
# (Index(['2017-04-28', '2017-04-29', '2017-04-30', '2017-05-01', '2017-05-02',
#         '2017-05-03', '2017-05-04', '2017-05-05', '2017-05-06', '2017-05-07',
#         ...
#         '2017-08-22', '2017-08-23', '2017-08-24', '2017-08-25', '2017-08-26',
#         '2017-08-27', '2017-08-28', '2017-08-29', '2017-08-30', '2017-08-31'],
#        dtype='object', length=126), '2017-04-28', '2017-06-29', '2017-08-31')

# %%
output_dates.shape
# Out:
# (126,)

# %%
output_data = input_df[output_dates].values; #output_data

# %% [markdown]
# ##### Convert nan to number 0.

# %%
output_data_num = np.nan_to_num(output_data); output_data_num
# Out:
# array([[ 24.,  20.,  36., ...,  26.,  24.,  21.],
#        [ 19.,  18.,  12., ...,  29.,  34.,  25.],
#        [  2.,   0.,   3., ...,   8.,  12.,   9.],
#        ...,
#        [ 27.,  84.,  14., ...,  21.,  11.,   9.],
#        [  7.,  10.,  13., ...,   3.,   9.,   2.],
#        [ 34.,  16.,  16., ...,   9.,   6.,   5.]], dtype=float32)

# %%
output_data_num.shape
# Out:
# (145063, 126)

# %% [markdown]
# ### View

# %% [markdown]
# def view(x, xlim=None, ylim=None, yscale='linear', title=None, show=True):
#     plt.yscale(yscale)
#     plt.plot(x)
#     if ylim: plt.ylim(ylim)
#     if xlim: plt.xlim(xlim)
#     if title: plt.title(title)
#     if show: plt.show()
#
# def viewi(X, i, xlim=None, ylim=None, yscale='linear', show=True):
#     view(X[i], xlim=xlim, ylim=ylim, yscale=yscale, title='i = ' + str(i), show=show)
#
# def examine(X, n=5, xlim=None, ylim=None):
#     '''randomly show some example in feature and label'''
#     n_X = len(X)
#     view_list = np.random.choice(n_X, min(n, n_X), replace=False)
#     for i in view_list:
#         viewi(X, i, xlim=xlim, ylim=ylim)
#     return view_list

# %% [markdown]
# examine(input_data)

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Log

# %%
def log(X):
    return np.log10(X + 1.0)
def unlog(X):
    return np.clip(np.power(10., X) - 1.0, 0.0, None)

# %%
input_data_log = log(input_data_num)
output_data_log = log(output_data_num)

# %%
Z_input_data_log = log(Z_input_data_num)

# %% [markdown]
# ##### Check Log transformation

# %%
input_data_log.shape, input_data.shape, output_data_log.shape, output_data.shape
# Out:
# ((145063, 126), (145063, 126), (145063, 126), (145063, 126))

# %%
Z_input_data_log.shape
# Out:
# (145063, 63)

# %% [markdown]
# input_data_log

# %% [markdown]
# output_data_log

# %% [markdown]
# #Check inverse log transformation
# input_data_log_tt = unlog(input_data_log)
# input_data_log_tt_dif = input_data_log_tt - input_data_num
# input_data_log_tt_dif.min(), input_data_log_tt_dif.max()

# %% [markdown]
# #Check inverse log transformation
# output_data_log_tt = unlog(output_data_log)
# output_data_log_tt_dif = output_data_log_tt - output_data_num
# output_data_log_tt_dif.min(), output_data_log_tt_dif.max()

# %% [markdown]
# del input_data_log_tt
# del input_data_log_tt_dif
# del output_data_log_tt
# del output_data_log_tt_dif

# %% [markdown]
# ### Normalization (Shift and Scale)

# %% [markdown]
# #### Use Fib Median as the Center

# %%
#input_center = log(fib_input_median).reshape(-1,1)
output_center = log(fib_output_median).reshape(-1,1)
input_center = output_center  # using output_center instead

# %% [markdown]
# input_center, output_center

# %%
Z_input_center = np.median(Z_input_data_log, axis=-1).reshape(-1,1)

# %%
Z_input_center.shape
# Out:
# (145063, 1)

# %% [markdown]
# #### Choice of default scale

# %%
input_raw_log = log(input_data)  # log of input_data with nan
output_raw_log = log(output_data)  # log of output_data with nan

# %% [markdown]
# np.median(np.nanstd(input_data_log[:,:x_length], axis=-1))

# %% [markdown]
# np.mean(np.nanstd(input_data_log[:,:x_length], axis=-1))

# %%
default_input_scale = np.nanmedian(np.nanstd(input_raw_log[:,:x_length], axis=-1))
default_input_scale
# Out:
# c:\python3\lib\site-packages\numpy\lib\nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# 0.17974041

# %%
default_output_scale = np.nanmedian(np.nanstd(output_raw_log[:,:x_length], axis=-1))
default_output_scale
# Out:
# c:\python3\lib\site-packages\numpy\lib\nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# 0.16425449

# %% [markdown]
# #### Compute Median and Stdev

# %% [markdown]
# Here we are not using this median as center

# %% [markdown]
# input_center = np.nanmedian(input_data_log[:,:x_length], axis=-1).reshape(-1,1)
# input_center  # remember sample-wised center

# %%
input_scale = np.nanstd(input_data_log[:,:x_length], axis=-1).reshape(-1,1)
input_scale[input_scale == 0.0] = default_input_scale  # Prevent divid by zero 
# non-zero value is choose based on the median of other page with non-zero stdev)
input_scale  # remember sample-wised scale
# Out:
# array([[ 0.22042467],
#        [ 0.19443031],
#        [ 0.23390391],
#        ...,
#        [ 0.17974041],
#        [ 0.17974041],
#        [ 0.17974041]], dtype=float32)

# %% [markdown]
# output_center = np.nanmedian(output_data_log[:,:x_length], axis=-1).reshape(-1,1)
# output_center  # remember sample-wised center

# %%
output_scale = np.nanstd(output_data_log[:,:x_length], axis=-1).reshape(-1,1)
output_scale[output_scale == 0.0] = default_output_scale  # Prevent divid by zero
output_scale  # remember sample-wised scale
# Out:
# array([[ 0.15715757],
#        [ 0.23019141],
#        [ 0.29932547],
#        ...,
#        [ 0.30635026],
#        [ 0.30876896],
#        [ 0.41433722]], dtype=float32)

# %%
Z_input_scale = np.std(Z_input_data_log, axis=-1).reshape(-1,1)
Z_input_scale[Z_input_scale == 0.0] = default_input_scale  # Prevent divid by zero
Z_input_scale  # remember sample-wised scale
# Out:
# array([[ 0.22026443],
#        [ 0.34693086],
#        [ 0.26398173],
#        ...,
#        [ 0.17974041],
#        [ 0.17974041],
#        [ 0.17974041]], dtype=float32)

# %% [markdown]
# ##### Check zero in scale

# %% [markdown]
# #Check if there is any 0. in input_scale
# input_scale[input_scale == 0.]

# %% [markdown]
# #Check if there is any 0. in output_scale
# output_scale[output_scale == 0.]

# %% [markdown]
# #### Shift by Center and Scale by Scale

# %%
def transform(data_ori, center, scale):
    return (data_ori - center) / scale
def untransform(data, center, scale):
    return data * scale + center

# %%
# Normalize the input_data and output_data
input_data_norm = transform(input_data_log, input_center, input_scale)
output_data_norm = transform(output_data_log, output_center, output_scale)

# %%
Z_input = transform(Z_input_data_log, Z_input_center, Z_input_scale)

# %% [markdown]
# ##### Check median and stdev transformations

# %%
def check_nan(X):
    return [x for x in X if np.isnan(x).any()]

# %% [markdown]
# check_nan(input_data_norm), check_nan(output_data_norm)  # Check if there is any nan in the input_data

# %% [markdown]
# #Check inverse scale transformation
# input_data_norm_it = untransform(input_data_norm, input_center, input_scale)
# input_data_norm_it_dif = input_data_norm_it - input_data_log
# input_data_norm_it_dif.min(), input_data_norm_it_dif.max()

# %% [markdown]
# #Check inverse scale transformation
# output_data_norm_it = untransform(output_data_norm, output_center, output_scale)
# output_data_norm_it_dif = output_data_norm_it - output_data_log
# output_data_norm_it_dif.min(), output_data_norm_it_dif.max()

# %% [markdown]
# del input_data_norm_it
# del input_data_norm_it_dif
# del output_data_norm_it
# del output_data_norm_it_dif
# gc.collect()

# %% [markdown]
# ## Center (Median) and Scale (Stdev) Investigation

# %% [markdown]
# ### Center

# %%
plt.hist(input_center, bins=40, alpha=0.7, label='input')
plt.hist(output_center, bins=40, alpha=0.7, label='output')
plt.hist(Z_input_center, bins=40, alpha=0.7, label='Z_input')
plt.legend()
plt.show()

# %% [markdown]
# plt.hist(input_center, bins=40, alpha=0.7, label='input')
# plt.hist(output_center, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.yscale('log')
# plt.show()

# %% [markdown]
# ### Scale

# %%
plt.hist(input_scale, bins=40, alpha=0.7, label='input')
plt.hist(output_scale, bins=40, alpha=0.7, label='output')
plt.hist(Z_input_scale, bins=40, alpha=0.7, label='Z_input')
plt.legend()
plt.show()

# %% [markdown]
# plt.hist(input_scale, bins=40, alpha=0.7, label='input')
# plt.hist(output_scale, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.yscale('log')
# plt.show()

# %% [markdown]
# ### Group index based on scale of median (center)

# %% [markdown]
# def group_index(median, stdev):
#     if median < 1.0: return 0
#     elif median < 2.0:
#         if stdev < 1.7: return 1
#         else: return 2
#     elif median < 4.0:
#         if stdev < 1.7: return 3
#         else: return 4
#     else: return 5
# #group_index_v = np.vectorize(group_index)
# gp_list = list(range(6)); gp_list

# %%
def group_index(logx):
    if logx == 0.: return 0
    elif logx < 1.0: return 1
    elif logx < 2.0: return 2
    elif logx < 4.0: return 3
    elif logx < 5.0: return 4
    else: return 5
group_index_v = np.vectorize(group_index)
gp_list = list(range(6)); gp_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %% [markdown]
# input_gp = np.array([group_index(center, scale) for center, scale in zip(input_center, input_scale)]).reshape(-1)
# output_gp = np.array([group_index(center, scale) for center, scale in zip(output_center, output_scale)]).reshape(-1)

# %%
input_gp = group_index_v(input_center).reshape(-1)
output_gp = group_index_v(output_center).reshape(-1)

# %%
input_gp, output_gp
# Out:
# (array([2, 2, 1, ..., 2, 1, 2]), array([2, 2, 1, ..., 2, 1, 2]))

# %%
# group counts
gp_input_counts = [0] * len(gp_list)
for x in input_gp: gp_input_counts[x] += 1
gp_input_counts
# Out:
# [1879, 23085, 43691, 75617, 740, 51]

# %%
# group counts
gp_output_counts = [0] * len(gp_list)
for x in output_gp: gp_output_counts[x] += 1
gp_output_counts
# Out:
# [1879, 23085, 43691, 75617, 740, 51]

# %% [markdown]
# plt.hist(input_gp, alpha=0.8, label='input')
# plt.hist(output_gp, alpha=0.3, label='output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(input_gp, alpha=0.8, label='input')
# plt.hist(output_gp, alpha=0.3, label='output')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# ## Make (X,Y) pairs data from data set

# %%
X_input = input_data_norm[:, :x_length]
Y_input = input_data_norm[:, -y_length:]
X_input.shape, Y_input.shape
# Out:
# ((145063, 63), (145063, 63))

# %%
X_output = output_data_norm[:, :x_length]
if test_length:
    Y_output = output_data_norm[:, -y_length:]
    print(X_output.shape, Y_output.shape)
else:
    print(X_output.shape, 'No Y_output')
# Out:
# (145063, 63) (145063, 63)

# %%
Z_output = Y_input

# %%
Z_input.shape, Z_output.shape
# Out:
# ((145063, 63), (145063, 63))

# %% [markdown]
# #### Original data

# %%
X_input_ori = input_data_num[:, :x_length]
Y_input_ori = input_data_num[:, -y_length:]
X_output_ori = output_data_num[:, :x_length]
if test_length: 
    Y_output_ori = output_data_num[:, -y_length:]

# %% [markdown]
# #### Raw data (with nan)

# %%
X_input_raw = input_data[:, :x_length]
Y_input_raw = input_data[:, -y_length:]
X_output_raw = output_data[:, :x_length]
if test_length:
    Y_output_raw = output_data[:, -y_length:]

# %% [markdown]
# #### Backward compatible

# %% [markdown]
# X_input = X_input
# Y_input = Y_input
# X_val = X_output
# if test_length:
#     Y_val = Y_output

# %% [markdown]
# X_input_ori = X_input_ori
# Y_input_ori = Y_input_ori
# X_val_ori = X_output_ori
# if test_length:
#     Y_val_ori = Y_output_ori

# %% [markdown]
# train_scale = input_scale
# train_center = input_center
# val_scale = output_scale
# val_center = output_center

# %% [markdown]
# #### Check

# %% [markdown]
# X_input, input_data_norm[:,:x_length]

# %% [markdown]
# Y_input, input_data_norm[:,-y_length:]

# %% [markdown]
# X_output, output_data_norm[:,:x_length]

# %% [markdown]
# if test_length:
#     print(Y_output)
#     print(output_data_norm[:,-y_length:])

# %% [markdown]
# X_input_ori, input_data_num

# %% [markdown]
# Y_input_ori, input_data_num

# %% [markdown]
# X_output_ori, output_data_num

# %% [markdown]
# if test_length:
#     print(Y_output_ori)
#     print(output_data_num)

# %%
if test_length:
    arr_info((X_input, Y_input, X_output, Y_output, 
              X_input_ori, Y_input_ori, X_output_ori, Y_output_ori))
else:
    arr_info((X_input, Y_input, X_output, 
              X_input_ori, Y_input_ori, X_output_ori))
# Out:
# shape, min, max, median, stdev
# (145063, 63) -104.946 182.184 0.0250222 3.34816
# (145063, 63) -104.946 181.97 -0.0156384 3.42136
# (145063, 63) -57.3466 8.00102 0.0 1.27078
# (145063, 63) -1627.74 51.3919 -0.214767 6.03656
# (145063, 63) 0.0 2.32094e+07 126.0 63765.9
# (145063, 63) 0.0 6.72643e+07 128.0 155484.0
# (145063, 63) 0.0 2.46307e+07 123.0 65785.6
# (145063, 63) 0.0 1.86702e+07 113.0 57469.1

# %%
arr_info((Z_input,))
# Out:
# shape, min, max, median, stdev
# (145063, 63) -7.4887 8.00102 0.0 0.959453

# %% [markdown]
# #### Min and max cases examination

# %% [markdown]
# np.argmin(Y_output, axis=0)

# %% [markdown]
# Y_output[8604]

# %% [markdown]
# Y_output_ori[8604]

# %% [markdown]
# fib_output_median[8604]

# %% [markdown]
# log(Y_output_ori[8604])

# %% [markdown]
# log(fib_output_median[8604])

# %% [markdown]
# np.std(log(Y_output_ori[8604]))

# %% [markdown]
# np.std(log(X_output_ori[8604]))

# %% [markdown]
# output_scale[8604]

# %% [markdown]
# #### Check if the inverse transformation is correct

# %% [markdown]
# #Undo transformation
# X_input_tt = unlog(untransform(X_input, train_center, train_scale))

# %% [markdown]
# X_input_tt_diff = X_input_tt - X_input_ori
# X_input_tt_diff.min(), X_input_tt_diff.max()

# %% [markdown]
# ## XZ Combine

# %%
X_input.shape, Z_input.shape
# Out:
# ((145063, 63), (145063, 63))

# %%
XZ_input = np.stack((X_input,Z_input), axis=-1)
XZ_output = np.stack((X_output,Z_output), axis=-1)

# %%
XZ_input.shape, XZ_output.shape
# Out:
# ((145063, 63, 2), (145063, 63, 2))

# %% [markdown]
# X_input[0]

# %% [markdown]
# Z_input[0]

# %% [markdown]
# XZ_input[0]

# %% [markdown]
# ## Split X,Y data into groups

# %% [markdown]
# X_input[input_gp == 1].shape

# %%
X_input_list = [X_input[input_gp == gp] for gp in gp_list]
X_output_list = [X_output[output_gp == gp] for gp in gp_list]

# %%
Y_input_list = [Y_input[input_gp == gp] for gp in gp_list]
if test_length:
    Y_output_list = [Y_output[output_gp == gp] for gp in gp_list]

# %% [markdown]
# Z_input_list = [Z_input[input_gp == gp] for gp in gp_list]
# Z_output_list = [Z_output[output_gp == gp] for gp in gp_list]

# %%
XZ_input_list = [XZ_input[input_gp == gp] for gp in gp_list]
XZ_output_list = [XZ_output[output_gp == gp] for gp in gp_list]

# %% [markdown]
# ## Additional input for the neural network

# %% [markdown]
# #Split center into group
# input_center_list = [input_center[input_gp == gp] for gp in gp_list]
# output_center_list = [output_center[output_gp == gp] for gp in gp_list]
#
# #Split scale into group
# input_scale_list = [input_scale[input_gp == gp] for gp in gp_list]
# output_scale_list = [output_scale[output_gp == gp] for gp in gp_list]

# %% [markdown]
# input_scale_list[0].shape

# %%
A_input = np.concatenate((input_center, input_scale), axis=1)
A_output = np.concatenate((output_center, output_scale), axis=1); A_input.shape, A_output.shape
# Out:
# ((145063, 2), (145063, 2))

# %%
A_input_list = [A_input[input_gp == gp] for gp in gp_list]
A_output_list = [A_output[output_gp == gp] for gp in gp_list]

# %%
a_length = len(A_input[0]); a_length
# Out:
# 2

# %% [markdown]
# ## Neural Network?

# %%
from keras.models import Sequential
#from keras.layers import Conv1D
from keras.layers import Dense, Dropout, Flatten
from keras.losses import mean_squared_error
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### SMAPE
# Symmetric mean absolute percentage error
#
# https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error

# %%
import keras.backend as K

def k_smape(y_true, y_pred):
    '''Symmetric mean absolute percentage error for keras metric'''
    diff = K.abs((y_true - y_pred) / K.clip(K.abs(y_true) + K.abs(y_pred),
                                            K.epsilon(), None))
    return 200. * K.mean(diff, axis=-1)

# %%
def smape(y_true, y_pred, axis=None):
    '''Symmetric mean absolute percentage error'''
    diff = np.abs((y_true - y_pred) / 
                  np.clip(np.abs(y_true) + np.abs(y_pred), np.float32(1e-07), None))
    return np.float32(200.) * np.nanmean(diff, axis=axis)

# %% [markdown]
# smape(np.array([0,1]),np.array([np.nan, 0])), smape(np.array([0]),np.array([0]))

# %%
# Benchmark SMAPE on the transformed data
smape(Y_input,X_input), smape(Y_input, X_output), smape(Y_input,Y_input)
# Out:
# (118.39848, 148.19037, 0.0)

# %%
# Benchmark SMAPE on the original data
smape(Y_input_raw,X_input_ori), smape(Y_input_ori,X_input_ori)
# Out:
# (60.41732, 58.828331)

# %%
if test_length: print(smape(Y_output_raw, X_output_ori), smape(Y_output, X_output))
# Out:
# 50.9386 142.088

# %%
print(smape(Y_input_raw, Y_input_fib))
if test_length: print(smape(Y_output_raw, Y_output_fib))
# Out:
# 48.325
# 40.4041

# %% [markdown]
# Doing better than the first two scores are better than simply copy and past the previous result.

# %% [markdown]
# ### Neural Network Model
# With the flavor of convolutional neural network

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv1D
from keras.layers import Flatten
from keras.layers import Reshape
from keras.layers import MaxPooling1D
from keras.layers import AveragePooling1D
from keras.layers import concatenate

# %%
n_ens = 5
ens_list = list(range(n_ens))

# %%
#runbelow
models_ens = []
for run in ens_list:
    print('Run', run, end=': ')
    models = []
    for gp in gp_list:
        print('Group-', gp, sep='', end=' ')
        layer_0 = Input(shape=(x_length, 2), name='xz_input')
        #layer_t = Reshape((-1, 1))(layer_0)
        layer_t = Conv1D(120, kernel_size=3, activation='relu')(layer_0)
        layer_t = AveragePooling1D(pool_size=2)(layer_t)
        layer_cnn_x = Flatten()(layer_t)
        
        layer_a = Input(shape=(a_length,), name='a_input')
        
        layer_t = concatenate([layer_cnn_x, layer_a])
        
        layer_t = Dense(120, activation='relu')(layer_t)
        layer_t = Dropout(0.25)(layer_t)
        layer_t = Dense(120, activation='relu')(layer_t)
        layer_t = Dropout(0.5)(layer_t)
        layer_f = Dense(y_length)(layer_t)
        
        model = Model(inputs=[layer_0, layer_a], outputs=layer_f)
        model.compile(optimizer='adam',
                      loss='mean_absolute_error', metrics=[k_smape])
        #model.summary()
        models.append(model)
    models_ens.append(models)
    print('')
# Out:
# Run 0: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 1: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 2: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 3: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 4: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5

# %%
models_ens[0][1].summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# xz_input (InputLayer)            (None, 63, 2)         0
# ____________________________________________________________________________________________________
# conv1d_2 (Conv1D)                (None, 61, 120)       840         xz_input[0][0]
# ____________________________________________________________________________________________________
# average_pooling1d_2 (AveragePool (None, 30, 120)       0           conv1d_2[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 3600)          0           average_pooling1d_2[0][0]
# ____________________________________________________________________________________________________
# a_input (InputLayer)             (None, 2)             0
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 3602)          0           flatten_2[0][0]
#                                                                    a_input[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 120)           432360      concatenate_2[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 120)           0           dense_4[0][0]
# ____________________________________________________________________________________________________
# dense_5 (Dense)                  (None, 120)           14520       dropout_3[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 120)           0           dense_5[0][0]
# ____________________________________________________________________________________________________
# dense_6 (Dense)                  (None, 63)            7623        dropout_4[0][0]
# ====================================================================================================
# Total params: 455,343
# Trainable params: 455,343
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
np.array(models_ens).shape
# Out:
# (5, 6)

# %%
len(gp_list)
# Out:
# 6

# %%
epochs_list = [1,1,40,40,60,80]  # change to smaller epochs later (1,1,20,40,60,80)

# %%
# %%time
hists_ens = []
for run, models in zip(ens_list, models_ens):
    print('=== Run:', run+1, '/', len(ens_list), '===')
    hists = []
    for (gp, model, XZ_in, Y_in, epochs, A_in) in zip(gp_list, models,
                                       XZ_input_list, Y_input_list, 
                                       epochs_list, A_input_list):
        print('--- Group:', gp+1, '/', len(gp_list), '---')
        hist = model.fit([XZ_in, A_in], Y_in, batch_size=128, 
                         epochs=epochs, 
                         validation_split=0.1, verbose=2)
        #validation_data=(X_val, Y_val))
        hists.append(hist)
    hists_ens.append(hists)
# Out:
# === Run: 1 / 5 ===
# --- Group: 1 / 6 ---
# Train on 1691 samples, validate on 188 samples
# Epoch 1/1
# 4s - loss: 0.9410 - k_smape: 199.1050 - val_loss: 0.9780 - val_k_smape: 199.9799
# --- Group: 2 / 6 ---
# Train on 20776 samples, validate on 2309 samples
# Epoch 1/1
# 5s - loss: 1.1281 - k_smape: 145.1944 - val_loss: 0.9850 - val_k_smape: 136.6878
# --- Group: 3 / 6 ---
# Train on 39321 samples, validate on 4370 samples
# Epoch 1/40
# 9s - loss: 1.3207 - k_smape: 127.3637 - val_loss: 1.0246 - val_k_smape: 117.1165
# Epoch 2/40
# 9s - loss: 1.2352 - k_smape: 118.2382 - val_loss: 1.1063 - val_k_smape: 126.2349
# Epoch 3/40
# 9s - loss: 1.2198 - k_smape: 115.8375 - val_loss: 1.0232 - val_k_smape: 120.1516
# Epoch 4/40
# 9s - loss: 1.2136 - k_smape: 114.8534 - val_loss: 1.0425 - val_k_smape: 118.3198
# Epoch 5/40
# 9s - loss: 1.2064 - k_smape: 114.1227 - val_loss: 1.0192 - val_k_smape: 117.5251
# Epoch 6/40
# 9s - loss: 1.1860 - k_smape: 113.1907 - val_loss: 1.0185 - val_k_smape: 120.5139
# Epoch 7/40
# 9s - loss: 1.1773 - k_smape: 112.9269 - val_loss: 1.0369 - val_k_smape: 118.6579
# Epoch 8/40
# 9s - loss: 1.1692 - k_smape: 112.1183 - val_loss: 0.9861 - val_k_smape: 112.6277
# Epoch 9/40
# 9s - loss: 1.1671 - k_smape: 111.8716 - val_loss: 1.0379 - val_k_smape: 122.5897
# Epoch 10/40
# 9s - loss: 1.1611 - k_smape: 111.6067 - val_loss: 0.9930 - val_k_smape: 114.7718
# Epoch 11/40
# 9s - loss: 1.1645 - k_smape: 111.2932 - val_loss: 0.9919 - val_k_smape: 116.9447
# Epoch 12/40
# 9s - loss: 1.1551 - k_smape: 110.9386 - val_loss: 1.0043 - val_k_smape: 113.8769
# Epoch 13/40
# 9s - loss: 1.1513 - k_smape: 110.6076 - val_loss: 1.0275 - val_k_smape: 114.9453
# Epoch 14/40
# 9s - loss: 1.1435 - k_smape: 110.4823 - val_loss: 1.0101 - val_k_smape: 116.1502
# Epoch 15/40
# 9s - loss: 1.1470 - k_smape: 110.2465 - val_loss: 1.0147 - val_k_smape: 115.9628
# Epoch 16/40
# 9s - loss: 1.1419 - k_smape: 109.9741 - val_loss: 1.0256 - val_k_smape: 116.3360
# Epoch 17/40
# 9s - loss: 1.1368 - k_smape: 109.9227 - val_loss: 1.0168 - val_k_smape: 117.2703
# Epoch 18/40
# 9s - loss: 1.1393 - k_smape: 109.6881 - val_loss: 1.0234 - val_k_smape: 116.2674
# Epoch 19/40
# 9s - loss: 1.1312 - k_smape: 109.3190 - val_loss: 1.0354 - val_k_smape: 117.6043
# Epoch 20/40
# 9s - loss: 1.1323 - k_smape: 109.1791 - val_loss: 1.0207 - val_k_smape: 117.2364
# Epoch 21/40
# 9s - loss: 1.1301 - k_smape: 108.7557 - val_loss: 0.9896 - val_k_smape: 115.2465
# Epoch 22/40
# 9s - loss: 1.1239 - k_smape: 108.6828 - val_loss: 0.9923 - val_k_smape: 112.7941
# Epoch 23/40
# 9s - loss: 1.1226 - k_smape: 108.5968 - val_loss: 1.0141 - val_k_smape: 113.5489
# Epoch 24/40
# 9s - loss: 1.1173 - k_smape: 108.5414 - val_loss: 1.0029 - val_k_smape: 114.2341
# Epoch 25/40
# 9s - loss: 1.1142 - k_smape: 107.9797 - val_loss: 1.0012 - val_k_smape: 116.3923
# Epoch 26/40
# 9s - loss: 1.1179 - k_smape: 107.9649 - val_loss: 1.0054 - val_k_smape: 113.7951
# Epoch 27/40
# 8s - loss: 1.1168 - k_smape: 107.9933 - val_loss: 1.0283 - val_k_smape: 115.7946
# Epoch 28/40
# 8s - loss: 1.1174 - k_smape: 107.9995 - val_loss: 1.0201 - val_k_smape: 113.2540
# Epoch 29/40
# 8s - loss: 1.1063 - k_smape: 107.7798 - val_loss: 1.0190 - val_k_smape: 116.1439
# Epoch 30/40
# 9s - loss: 1.1065 - k_smape: 107.5810 - val_loss: 1.0156 - val_k_smape: 116.4205
# Epoch 31/40
# 8s - loss: 1.1029 - k_smape: 107.3390 - val_loss: 0.9925 - val_k_smape: 112.1988
# Epoch 32/40
# 9s - loss: 1.1126 - k_smape: 107.4722 - val_loss: 1.0252 - val_k_smape: 117.1854
# Epoch 33/40
# 9s - loss: 1.0983 - k_smape: 107.2419 - val_loss: 1.0041 - val_k_smape: 112.8783
# Epoch 34/40
# 9s - loss: 1.1001 - k_smape: 107.1447 - val_loss: 1.0123 - val_k_smape: 113.2021
# Epoch 35/40
# 9s - loss: 1.0976 - k_smape: 106.7889 - val_loss: 1.0181 - val_k_smape: 116.2239
# Epoch 36/40
# 8s - loss: 1.1012 - k_smape: 107.0770 - val_loss: 1.0018 - val_k_smape: 113.3634
# Epoch 37/40
# 8s - loss: 1.1001 - k_smape: 106.8872 - val_loss: 1.0370 - val_k_smape: 117.4154
# Epoch 38/40
# 9s - loss: 1.0927 - k_smape: 106.8486 - val_loss: 1.0249 - val_k_smape: 115.3492
# Epoch 39/40
# 8s - loss: 1.0956 - k_smape: 106.8807 - val_loss: 1.0248 - val_k_smape: 114.5347
# Epoch 40/40
# 8s - loss: 1.0887 - k_smape: 106.5632 - val_loss: 1.0293 - val_k_smape: 116.2857
# --- Group: 4 / 6 ---
# Train on 68055 samples, validate on 7562 samples
# Epoch 1/40
# 16s - loss: 1.3436 - k_smape: 109.2011 - val_loss: 1.1403 - val_k_smape: 108.5428
# Epoch 2/40
# 15s - loss: 1.2330 - k_smape: 99.9782 - val_loss: 1.0857 - val_k_smape: 104.9294
# Epoch 3/40
# 15s - loss: 1.2035 - k_smape: 97.5711 - val_loss: 1.0913 - val_k_smape: 103.7456
# Epoch 4/40
# 15s - loss: 1.1908 - k_smape: 96.4186 - val_loss: 1.0963 - val_k_smape: 104.0710
# Epoch 5/40
# 15s - loss: 1.1747 - k_smape: 95.8853 - val_loss: 1.0738 - val_k_smape: 103.4465
# Epoch 6/40
# 15s - loss: 1.1690 - k_smape: 95.3158 - val_loss: 1.0523 - val_k_smape: 103.3761
# Epoch 7/40
# 15s - loss: 1.1610 - k_smape: 94.9686 - val_loss: 1.0995 - val_k_smape: 104.6431
# Epoch 8/40
# 15s - loss: 1.1597 - k_smape: 94.6169 - val_loss: 1.0595 - val_k_smape: 103.6295
# Epoch 9/40
# 15s - loss: 1.1466 - k_smape: 94.0912 - val_loss: 1.0821 - val_k_smape: 102.8436
# Epoch 10/40
# 15s - loss: 1.1427 - k_smape: 93.8358 - val_loss: 1.0722 - val_k_smape: 102.2524
# Epoch 11/40
# 15s - loss: 1.1425 - k_smape: 93.7347 - val_loss: 1.0550 - val_k_smape: 101.9926
# Epoch 12/40
# 16s - loss: 1.1357 - k_smape: 93.4617 - val_loss: 1.0576 - val_k_smape: 101.5113
# Epoch 13/40
# 16s - loss: 1.1327 - k_smape: 93.2991 - val_loss: 1.0535 - val_k_smape: 101.5845
# Epoch 14/40
# 16s - loss: 1.1273 - k_smape: 92.8370 - val_loss: 1.1245 - val_k_smape: 104.5449
# Epoch 15/40
# 15s - loss: 1.1270 - k_smape: 92.9270 - val_loss: 1.0486 - val_k_smape: 101.6824
# Epoch 16/40
# 15s - loss: 1.1222 - k_smape: 92.4666 - val_loss: 1.0882 - val_k_smape: 103.5685
# Epoch 17/40
# 15s - loss: 1.1181 - k_smape: 92.3975 - val_loss: 1.0406 - val_k_smape: 102.1408
# Epoch 18/40
# 15s - loss: 1.1155 - k_smape: 92.2488 - val_loss: 1.0602 - val_k_smape: 102.0290
# Epoch 19/40
# 15s - loss: 1.1122 - k_smape: 92.0994 - val_loss: 1.0711 - val_k_smape: 103.0687
# Epoch 20/40
# 16s - loss: 1.1098 - k_smape: 92.0164 - val_loss: 1.0685 - val_k_smape: 101.5962
# Epoch 21/40
# 15s - loss: 1.1028 - k_smape: 91.6797 - val_loss: 1.0504 - val_k_smape: 100.8294
# Epoch 22/40
# 16s - loss: 1.1031 - k_smape: 91.7240 - val_loss: 1.0706 - val_k_smape: 102.1176
# Epoch 23/40
# 16s - loss: 1.0990 - k_smape: 91.4847 - val_loss: 1.0675 - val_k_smape: 101.2976
# Epoch 24/40
# 16s - loss: 1.0946 - k_smape: 91.3564 - val_loss: 1.0433 - val_k_smape: 101.4143
# Epoch 25/40
# 16s - loss: 1.0910 - k_smape: 91.1292 - val_loss: 1.0778 - val_k_smape: 103.0054
# Epoch 26/40
# 16s - loss: 1.0903 - k_smape: 91.0505 - val_loss: 1.0700 - val_k_smape: 102.0227
# Epoch 27/40
# 15s - loss: 1.0896 - k_smape: 90.9408 - val_loss: 1.0776 - val_k_smape: 103.2314
# Epoch 28/40
# 16s - loss: 1.0878 - k_smape: 90.8742 - val_loss: 1.0616 - val_k_smape: 102.4396
# Epoch 29/40
# 15s - loss: 1.0833 - k_smape: 90.7816 - val_loss: 1.0711 - val_k_smape: 101.4778
# Epoch 30/40
# 16s - loss: 1.0819 - k_smape: 90.6848 - val_loss: 1.0355 - val_k_smape: 102.8673
# Epoch 31/40
# 15s - loss: 1.0821 - k_smape: 90.7868 - val_loss: 1.0662 - val_k_smape: 102.7622
# Epoch 32/40
# 15s - loss: 1.0803 - k_smape: 90.4821 - val_loss: 1.0504 - val_k_smape: 102.7167
# Epoch 33/40
# 15s - loss: 1.0750 - k_smape: 90.3944 - val_loss: 1.0498 - val_k_smape: 102.8616
# Epoch 34/40
# 15s - loss: 1.0735 - k_smape: 90.3407 - val_loss: 1.0797 - val_k_smape: 104.2314
# Epoch 35/40
# 15s - loss: 1.0725 - k_smape: 90.1912 - val_loss: 1.0629 - val_k_smape: 101.9292
# Epoch 36/40
# 15s - loss: 1.0689 - k_smape: 89.9663 - val_loss: 1.0500 - val_k_smape: 101.9197
# Epoch 37/40
# 15s - loss: 1.0676 - k_smape: 89.9033 - val_loss: 1.0662 - val_k_smape: 103.3324
# Epoch 38/40
# 15s - loss: 1.0695 - k_smape: 89.9127 - val_loss: 1.0600 - val_k_smape: 101.7806
# Epoch 39/40
# 15s - loss: 1.0628 - k_smape: 89.6500 - val_loss: 1.0519 - val_k_smape: 101.8013
# Epoch 40/40
# 16s - loss: 1.0617 - k_smape: 89.8218 - val_loss: 1.0657 - val_k_smape: 103.6007
# --- Group: 5 / 6 ---
# Train on 666 samples, validate on 74 samples
# Epoch 1/60
# 0s - loss: 2.9742 - k_smape: 153.1723 - val_loss: 3.1234 - val_k_smape: 145.0900
# Epoch 2/60
# 0s - loss: 2.5694 - k_smape: 139.8370 - val_loss: 2.7651 - val_k_smape: 134.8221
# Epoch 3/60
# 0s - loss: 2.3524 - k_smape: 127.4297 - val_loss: 2.5147 - val_k_smape: 128.2345
# Epoch 4/60
# 0s - loss: 2.1899 - k_smape: 125.6513 - val_loss: 2.2008 - val_k_smape: 120.8239
# Epoch 5/60
# 0s - loss: 2.1434 - k_smape: 118.7733 - val_loss: 2.1225 - val_k_smape: 118.9655
# Epoch 6/60
# 0s - loss: 1.9849 - k_smape: 115.1814 - val_loss: 1.9345 - val_k_smape: 110.2341
# Epoch 7/60
# 0s - loss: 1.9047 - k_smape: 107.8552 - val_loss: 1.8939 - val_k_smape: 112.5774
# Epoch 8/60
# 0s - loss: 1.8528 - k_smape: 109.8507 - val_loss: 1.7650 - val_k_smape: 105.7090
# Epoch 9/60
# 0s - loss: 1.8133 - k_smape: 103.1431 - val_loss: 1.4823 - val_k_smape: 99.4715
# Epoch 10/60
# 0s - loss: 1.7477 - k_smape: 103.0636 - val_loss: 1.8161 - val_k_smape: 107.6109
# Epoch 11/60
# 0s - loss: 1.7516 - k_smape: 101.9338 - val_loss: 1.8828 - val_k_smape: 105.5497
# Epoch 12/60
# 0s - loss: 1.6915 - k_smape: 101.1011 - val_loss: 1.4944 - val_k_smape: 98.1516
# Epoch 13/60
# 0s - loss: 1.6830 - k_smape: 98.2681 - val_loss: 1.6168 - val_k_smape: 102.2052
# Epoch 14/60
# 0s - loss: 1.6129 - k_smape: 95.7880 - val_loss: 1.5030 - val_k_smape: 100.6737
# Epoch 15/60
# 0s - loss: 1.5498 - k_smape: 95.7600 - val_loss: 1.4013 - val_k_smape: 96.3179
# Epoch 16/60
# 0s - loss: 1.5765 - k_smape: 92.7311 - val_loss: 1.4031 - val_k_smape: 95.7634
# Epoch 17/60
# 0s - loss: 1.5685 - k_smape: 91.9435 - val_loss: 1.7738 - val_k_smape: 99.6014
# Epoch 18/60
# 0s - loss: 1.5338 - k_smape: 90.4334 - val_loss: 1.4238 - val_k_smape: 96.0032
# Epoch 19/60
# 0s - loss: 1.5001 - k_smape: 94.3851 - val_loss: 1.3704 - val_k_smape: 95.5919
# Epoch 20/60
# 0s - loss: 1.4938 - k_smape: 88.7501 - val_loss: 1.6343 - val_k_smape: 97.8530
# Epoch 21/60
# 0s - loss: 1.4442 - k_smape: 89.0558 - val_loss: 1.4583 - val_k_smape: 94.7108
# Epoch 22/60
# 0s - loss: 1.4544 - k_smape: 89.0943 - val_loss: 1.3793 - val_k_smape: 94.8939
# Epoch 23/60
# 0s - loss: 1.5038 - k_smape: 88.5983 - val_loss: 1.3507 - val_k_smape: 92.4339
# Epoch 24/60
# 0s - loss: 1.4671 - k_smape: 86.9346 - val_loss: 1.3514 - val_k_smape: 92.4062
# Epoch 25/60
# 0s - loss: 1.4649 - k_smape: 85.6932 - val_loss: 1.6693 - val_k_smape: 94.8959
# Epoch 26/60
# 0s - loss: 1.4121 - k_smape: 84.0129 - val_loss: 1.3503 - val_k_smape: 92.2130
# Epoch 27/60
# 0s - loss: 1.4376 - k_smape: 85.7178 - val_loss: 1.4341 - val_k_smape: 92.6236
# Epoch 28/60
# 0s - loss: 1.4118 - k_smape: 85.0498 - val_loss: 1.3238 - val_k_smape: 89.4106
# Epoch 29/60
# 0s - loss: 1.4610 - k_smape: 83.3702 - val_loss: 1.6173 - val_k_smape: 98.1904
# Epoch 30/60
# 0s - loss: 1.3977 - k_smape: 83.9946 - val_loss: 1.5034 - val_k_smape: 90.9332
# Epoch 31/60
# 0s - loss: 1.3776 - k_smape: 83.7171 - val_loss: 1.3315 - val_k_smape: 91.9343
# Epoch 32/60
# 0s - loss: 1.3656 - k_smape: 84.8228 - val_loss: 1.3490 - val_k_smape: 93.0666
# Epoch 33/60
# 0s - loss: 1.3872 - k_smape: 83.1597 - val_loss: 1.7325 - val_k_smape: 95.4856
# Epoch 34/60
# 0s - loss: 1.3925 - k_smape: 81.3509 - val_loss: 1.3405 - val_k_smape: 91.0364
# Epoch 35/60
# 0s - loss: 1.3836 - k_smape: 83.3842 - val_loss: 1.3290 - val_k_smape: 90.8816
# Epoch 36/60
# 0s - loss: 1.3900 - k_smape: 82.5370 - val_loss: 1.5258 - val_k_smape: 96.3025
# Epoch 37/60
# 0s - loss: 1.3696 - k_smape: 82.0927 - val_loss: 1.3391 - val_k_smape: 89.1661
# Epoch 38/60
# 0s - loss: 1.3073 - k_smape: 80.5016 - val_loss: 1.2988 - val_k_smape: 92.5911
# Epoch 39/60
# 0s - loss: 1.3768 - k_smape: 81.7867 - val_loss: 1.6950 - val_k_smape: 95.2460
# Epoch 40/60
# 0s - loss: 1.3314 - k_smape: 80.5624 - val_loss: 1.3292 - val_k_smape: 87.4721
# Epoch 41/60
# 0s - loss: 1.3211 - k_smape: 81.2399 - val_loss: 1.3564 - val_k_smape: 92.1911
# Epoch 42/60
# 0s - loss: 1.3445 - k_smape: 80.5283 - val_loss: 1.4529 - val_k_smape: 89.8856
# Epoch 43/60
# 0s - loss: 1.3198 - k_smape: 79.5512 - val_loss: 1.3572 - val_k_smape: 89.2654
# Epoch 44/60
# 0s - loss: 1.2815 - k_smape: 80.0222 - val_loss: 1.3673 - val_k_smape: 93.6741
# Epoch 45/60
# 0s - loss: 1.3043 - k_smape: 81.3365 - val_loss: 1.3311 - val_k_smape: 87.7763
# Epoch 46/60
# 0s - loss: 1.2823 - k_smape: 79.6605 - val_loss: 1.3530 - val_k_smape: 89.5735
# Epoch 47/60
# 0s - loss: 1.3043 - k_smape: 79.8283 - val_loss: 1.3543 - val_k_smape: 90.9067
# Epoch 48/60
# 0s - loss: 1.2527 - k_smape: 79.4447 - val_loss: 1.3694 - val_k_smape: 90.8169
# Epoch 49/60
# 0s - loss: 1.2715 - k_smape: 77.9140 - val_loss: 1.3245 - val_k_smape: 88.7673
# Epoch 50/60
# 0s - loss: 1.2902 - k_smape: 77.9431 - val_loss: 1.4611 - val_k_smape: 93.7804
# Epoch 51/60
# 0s - loss: 1.2576 - k_smape: 79.3409 - val_loss: 1.3232 - val_k_smape: 86.3060
# Epoch 52/60
# 0s - loss: 1.2741 - k_smape: 77.8340 - val_loss: 1.4477 - val_k_smape: 91.3138
# Epoch 53/60
# 0s - loss: 1.2755 - k_smape: 77.2476 - val_loss: 1.4438 - val_k_smape: 90.6996
# Epoch 54/60
# 0s - loss: 1.2929 - k_smape: 79.2690 - val_loss: 1.3988 - val_k_smape: 90.2830
# Epoch 55/60
# 0s - loss: 1.3301 - k_smape: 79.1987 - val_loss: 1.3675 - val_k_smape: 89.5839
# Epoch 56/60
# 0s - loss: 1.2909 - k_smape: 79.7231 - val_loss: 1.7637 - val_k_smape: 96.6621
# Epoch 57/60
# 0s - loss: 1.4475 - k_smape: 82.8435 - val_loss: 1.2833 - val_k_smape: 87.1928
# Epoch 58/60
# 0s - loss: 1.2797 - k_smape: 77.0409 - val_loss: 1.6215 - val_k_smape: 99.3174
# Epoch 59/60
# 0s - loss: 1.3050 - k_smape: 83.7450 - val_loss: 1.2889 - val_k_smape: 88.9345
# Epoch 60/60
# 0s - loss: 1.2604 - k_smape: 76.6580 - val_loss: 1.5198 - val_k_smape: 93.2889
# --- Group: 6 / 6 ---
# Train on 45 samples, validate on 6 samples
# Epoch 1/80
# 0s - loss: 6.9406 - k_smape: 175.3681 - val_loss: 4.6679 - val_k_smape: 163.2261
# Epoch 2/80
# 0s - loss: 6.6100 - k_smape: 166.0220 - val_loss: 4.4245 - val_k_smape: 154.9616
# Epoch 3/80
# 0s - loss: 6.4180 - k_smape: 157.1250 - val_loss: 4.1544 - val_k_smape: 143.8273
# Epoch 4/80
# 0s - loss: 6.2439 - k_smape: 148.2440 - val_loss: 3.9162 - val_k_smape: 137.4019
# Epoch 5/80
# 0s - loss: 5.9168 - k_smape: 140.4577 - val_loss: 3.7258 - val_k_smape: 131.9797
# Epoch 6/80
# 0s - loss: 5.8358 - k_smape: 137.5361 - val_loss: 3.6162 - val_k_smape: 128.3031
# Epoch 7/80
# 0s - loss: 5.6534 - k_smape: 134.0774 - val_loss: 3.5599 - val_k_smape: 127.8147
# Epoch 8/80
# 0s - loss: 5.6809 - k_smape: 129.6157 - val_loss: 3.5171 - val_k_smape: 127.0292
# Epoch 9/80
# 0s - loss: 5.4631 - k_smape: 127.9769 - val_loss: 3.4505 - val_k_smape: 125.7888
# Epoch 10/80
# 0s - loss: 5.4392 - k_smape: 129.7852 - val_loss: 3.3705 - val_k_smape: 123.6079
# Epoch 11/80
# 0s - loss: 5.2343 - k_smape: 127.4822 - val_loss: 3.2863 - val_k_smape: 122.0463
# Epoch 12/80
# 0s - loss: 5.2595 - k_smape: 123.7566 - val_loss: 3.1680 - val_k_smape: 121.0879
# Epoch 13/80
# 0s - loss: 5.0606 - k_smape: 127.2533 - val_loss: 3.0280 - val_k_smape: 120.1156
# Epoch 14/80
# 0s - loss: 4.9491 - k_smape: 125.1197 - val_loss: 2.9011 - val_k_smape: 119.6940
# Epoch 15/80
# 0s - loss: 4.9906 - k_smape: 125.4529 - val_loss: 2.7968 - val_k_smape: 118.6710
# Epoch 16/80
# 0s - loss: 4.9773 - k_smape: 127.5998 - val_loss: 2.6624 - val_k_smape: 116.6198
# Epoch 17/80
# 0s - loss: 4.6995 - k_smape: 119.8029 - val_loss: 2.5782 - val_k_smape: 113.2315
# Epoch 18/80
# 0s - loss: 4.6502 - k_smape: 119.7365 - val_loss: 2.4927 - val_k_smape: 110.1077
# Epoch 19/80
# 0s - loss: 4.7143 - k_smape: 119.4056 - val_loss: 2.3702 - val_k_smape: 106.6701
# Epoch 20/80
# 0s - loss: 4.4753 - k_smape: 113.3293 - val_loss: 2.3500 - val_k_smape: 102.9594
# Epoch 21/80
# 0s - loss: 4.3764 - k_smape: 112.7666 - val_loss: 2.3472 - val_k_smape: 99.4362
# Epoch 22/80
# 0s - loss: 4.4918 - k_smape: 115.5484 - val_loss: 2.3513 - val_k_smape: 97.3859
# Epoch 23/80
# 0s - loss: 4.2389 - k_smape: 108.9900 - val_loss: 2.3765 - val_k_smape: 96.6011
# Epoch 24/80
# 0s - loss: 4.3992 - k_smape: 109.3583 - val_loss: 2.3426 - val_k_smape: 95.6213
# Epoch 25/80
# 0s - loss: 4.2106 - k_smape: 105.6894 - val_loss: 2.2132 - val_k_smape: 94.2852
# Epoch 26/80
# 0s - loss: 4.1948 - k_smape: 107.0714 - val_loss: 2.0891 - val_k_smape: 92.4780
# Epoch 27/80
# 0s - loss: 4.4335 - k_smape: 111.3458 - val_loss: 1.9750 - val_k_smape: 91.4624
# Epoch 28/80
# 0s - loss: 4.0182 - k_smape: 106.4121 - val_loss: 1.9561 - val_k_smape: 91.1933
# Epoch 29/80
# 0s - loss: 4.1320 - k_smape: 105.7831 - val_loss: 1.9404 - val_k_smape: 91.1183
# Epoch 30/80
# 0s - loss: 3.8404 - k_smape: 100.6303 - val_loss: 1.9719 - val_k_smape: 91.2347
# Epoch 31/80
# 0s - loss: 3.9942 - k_smape: 104.8821 - val_loss: 2.0376 - val_k_smape: 91.2732
# Epoch 32/80
# 0s - loss: 4.0837 - k_smape: 105.6313 - val_loss: 2.0407 - val_k_smape: 90.8987
# Epoch 33/80
# 0s - loss: 4.1774 - k_smape: 106.4890 - val_loss: 1.9021 - val_k_smape: 89.5849
# Epoch 34/80
# 0s - loss: 3.9377 - k_smape: 103.5187 - val_loss: 1.6944 - val_k_smape: 87.6114
# Epoch 35/80
# 0s - loss: 3.8236 - k_smape: 101.7437 - val_loss: 1.5034 - val_k_smape: 85.4839
# Epoch 36/80
# 0s - loss: 3.6874 - k_smape: 100.4829 - val_loss: 1.3496 - val_k_smape: 83.9653
# Epoch 37/80
# 0s - loss: 3.8080 - k_smape: 101.3010 - val_loss: 1.2791 - val_k_smape: 83.0824
# Epoch 38/80
# 0s - loss: 3.9474 - k_smape: 97.8482 - val_loss: 1.2421 - val_k_smape: 82.6365
# Epoch 39/80
# 0s - loss: 3.6917 - k_smape: 92.7352 - val_loss: 1.2092 - val_k_smape: 81.3084
# Epoch 40/80
# 0s - loss: 3.4771 - k_smape: 93.1606 - val_loss: 1.2221 - val_k_smape: 80.5222
# Epoch 41/80
# 0s - loss: 3.5278 - k_smape: 91.4412 - val_loss: 1.2761 - val_k_smape: 80.3934
# Epoch 42/80
# 0s - loss: 3.4195 - k_smape: 89.2859 - val_loss: 1.4853 - val_k_smape: 82.5271
# Epoch 43/80
# 0s - loss: 3.4950 - k_smape: 93.6050 - val_loss: 1.7610 - val_k_smape: 85.6937
# Epoch 44/80
# 0s - loss: 3.4847 - k_smape: 92.7296 - val_loss: 1.9963 - val_k_smape: 89.0020
# Epoch 45/80
# 0s - loss: 3.4078 - k_smape: 94.4540 - val_loss: 2.0816 - val_k_smape: 90.1753
# Epoch 46/80
# 0s - loss: 3.4742 - k_smape: 96.8276 - val_loss: 1.9420 - val_k_smape: 88.0114
# Epoch 47/80
# 0s - loss: 3.3653 - k_smape: 88.7413 - val_loss: 1.7868 - val_k_smape: 85.2163
# Epoch 48/80
# 0s - loss: 3.4819 - k_smape: 87.8247 - val_loss: 1.5772 - val_k_smape: 82.1479
# Epoch 49/80
# 0s - loss: 3.1818 - k_smape: 84.5684 - val_loss: 1.3773 - val_k_smape: 80.1006
# Epoch 50/80
# 0s - loss: 3.1638 - k_smape: 87.4784 - val_loss: 1.2195 - val_k_smape: 79.7285
# Epoch 51/80
# 0s - loss: 3.1219 - k_smape: 84.5085 - val_loss: 1.1092 - val_k_smape: 80.0697
# Epoch 52/80
# 0s - loss: 3.2169 - k_smape: 82.1716 - val_loss: 1.1755 - val_k_smape: 80.8809
# Epoch 53/80
# 0s - loss: 3.1638 - k_smape: 86.6887 - val_loss: 1.3457 - val_k_smape: 81.4012
# Epoch 54/80
# 0s - loss: 3.2612 - k_smape: 87.5895 - val_loss: 1.4271 - val_k_smape: 82.3440
# Epoch 55/80
# 0s - loss: 3.0338 - k_smape: 82.1077 - val_loss: 1.5343 - val_k_smape: 83.1729
# Epoch 56/80
# 0s - loss: 2.9670 - k_smape: 80.5744 - val_loss: 1.5222 - val_k_smape: 85.1266
# Epoch 57/80
# 0s - loss: 3.3475 - k_smape: 83.7463 - val_loss: 1.3372 - val_k_smape: 84.3261
# Epoch 58/80
# 0s - loss: 3.2412 - k_smape: 83.5763 - val_loss: 1.0973 - val_k_smape: 83.1219
# Epoch 59/80
# 0s - loss: 3.0060 - k_smape: 77.0239 - val_loss: 0.9660 - val_k_smape: 81.9143
# Epoch 60/80
# 0s - loss: 3.1194 - k_smape: 79.3929 - val_loss: 0.9318 - val_k_smape: 81.6057
# Epoch 61/80
# 0s - loss: 3.1866 - k_smape: 77.1789 - val_loss: 0.9310 - val_k_smape: 82.6413
# Epoch 62/80
# 0s - loss: 3.0312 - k_smape: 79.6546 - val_loss: 0.9943 - val_k_smape: 83.4744
# Epoch 63/80
# 0s - loss: 3.2579 - k_smape: 78.9090 - val_loss: 1.1371 - val_k_smape: 84.6556
# Epoch 64/80
# 0s - loss: 2.9025 - k_smape: 76.8113 - val_loss: 1.3985 - val_k_smape: 88.5987
# Epoch 65/80
# 0s - loss: 2.9158 - k_smape: 77.4022 - val_loss: 1.5979 - val_k_smape: 92.2533
# Epoch 66/80
# 0s - loss: 3.0065 - k_smape: 79.8669 - val_loss: 1.6791 - val_k_smape: 96.4094
# Epoch 67/80
# 0s - loss: 3.0389 - k_smape: 80.8411 - val_loss: 1.6718 - val_k_smape: 96.4345
# Epoch 68/80
# 0s - loss: 3.2038 - k_smape: 82.6888 - val_loss: 1.4577 - val_k_smape: 90.3069
# Epoch 69/80
# 0s - loss: 2.8332 - k_smape: 77.9678 - val_loss: 1.1910 - val_k_smape: 85.0081
# Epoch 70/80
# 0s - loss: 2.9224 - k_smape: 76.2851 - val_loss: 0.9846 - val_k_smape: 80.2246
# Epoch 71/80
# 0s - loss: 2.9757 - k_smape: 75.0956 - val_loss: 0.9098 - val_k_smape: 75.3016
# Epoch 72/80
# 0s - loss: 2.8762 - k_smape: 74.2796 - val_loss: 0.9189 - val_k_smape: 72.4964
# Epoch 73/80
# 0s - loss: 2.8602 - k_smape: 74.0057 - val_loss: 0.9933 - val_k_smape: 71.9181
# Epoch 74/80
# 0s - loss: 2.8045 - k_smape: 70.7968 - val_loss: 1.0730 - val_k_smape: 75.1175
# Epoch 75/80
# 0s - loss: 2.7200 - k_smape: 71.1038 - val_loss: 1.1991 - val_k_smape: 81.0477
# Epoch 76/80
# 0s - loss: 2.8060 - k_smape: 75.5617 - val_loss: 1.1903 - val_k_smape: 90.2478
# Epoch 77/80
# 0s - loss: 3.1796 - k_smape: 79.2551 - val_loss: 1.1187 - val_k_smape: 86.2774
# Epoch 78/80
# 0s - loss: 2.9474 - k_smape: 76.6948 - val_loss: 1.0830 - val_k_smape: 79.6162
# Epoch 79/80
# 0s - loss: 2.8579 - k_smape: 73.3615 - val_loss: 1.1437 - val_k_smape: 74.0529
# Epoch 80/80
# 0s - loss: 2.7740 - k_smape: 70.9934 - val_loss: 1.2058 - val_k_smape: 73.8761
# === Run: 2 / 5 ===
# --- Group: 1 / 6 ---
# Train on 1691 samples, validate on 188 samples
# Epoch 1/1
# 0s - loss: 0.9431 - k_smape: 198.3588 - val_loss: 0.9769 - val_k_smape: 199.7786
# --- Group: 2 / 6 ---
# Train on 20776 samples, validate on 2309 samples
# Epoch 1/1
# 5s - loss: 1.1213 - k_smape: 143.8883 - val_loss: 1.0202 - val_k_smape: 138.2610
# --- Group: 3 / 6 ---
# Train on 39321 samples, validate on 4370 samples
# Epoch 1/40
# 9s - loss: 1.3236 - k_smape: 127.0927 - val_loss: 1.0302 - val_k_smape: 118.1523
# Epoch 2/40
# 9s - loss: 1.2354 - k_smape: 117.9135 - val_loss: 1.0128 - val_k_smape: 118.4872
# Epoch 3/40
# 9s - loss: 1.2229 - k_smape: 116.0107 - val_loss: 1.0093 - val_k_smape: 116.1554
# Epoch 4/40
# 9s - loss: 1.2075 - k_smape: 114.8890 - val_loss: 1.0180 - val_k_smape: 119.1294
# Epoch 5/40
# 9s - loss: 1.2005 - k_smape: 113.9369 - val_loss: 1.0656 - val_k_smape: 118.6087
# Epoch 6/40
# 8s - loss: 1.1958 - k_smape: 113.1866 - val_loss: 1.0068 - val_k_smape: 113.2007
# Epoch 7/40
# 8s - loss: 1.1938 - k_smape: 112.9384 - val_loss: 1.0508 - val_k_smape: 118.0995
# Epoch 8/40
# 8s - loss: 1.1825 - k_smape: 112.6279 - val_loss: 1.0523 - val_k_smape: 119.2084
# Epoch 9/40
# 8s - loss: 1.1729 - k_smape: 112.0567 - val_loss: 1.0411 - val_k_smape: 119.0907
# Epoch 10/40
# 8s - loss: 1.1651 - k_smape: 111.3715 - val_loss: 0.9908 - val_k_smape: 114.5910
# Epoch 11/40
# 8s - loss: 1.1645 - k_smape: 111.4281 - val_loss: 1.0329 - val_k_smape: 118.8723
# Epoch 12/40
# 8s - loss: 1.1552 - k_smape: 111.0763 - val_loss: 1.0124 - val_k_smape: 115.8146
# Epoch 13/40
# 8s - loss: 1.1487 - k_smape: 110.5793 - val_loss: 1.0183 - val_k_smape: 114.6064
# Epoch 14/40
# 8s - loss: 1.1515 - k_smape: 110.4191 - val_loss: 1.0160 - val_k_smape: 115.3019
# Epoch 15/40
# 8s - loss: 1.1451 - k_smape: 110.2160 - val_loss: 1.0205 - val_k_smape: 115.6144
# Epoch 16/40
# 8s - loss: 1.1398 - k_smape: 110.0066 - val_loss: 1.0209 - val_k_smape: 115.8616
# Epoch 17/40
# 8s - loss: 1.1374 - k_smape: 109.7065 - val_loss: 1.0232 - val_k_smape: 114.6566
# Epoch 18/40
# 8s - loss: 1.1361 - k_smape: 109.5238 - val_loss: 1.0198 - val_k_smape: 114.4838
# Epoch 19/40
# 8s - loss: 1.1303 - k_smape: 109.2970 - val_loss: 1.0241 - val_k_smape: 116.0267
# Epoch 20/40
# 8s - loss: 1.1302 - k_smape: 109.4037 - val_loss: 1.0238 - val_k_smape: 115.4103
# Epoch 21/40
# 8s - loss: 1.1259 - k_smape: 109.1400 - val_loss: 0.9957 - val_k_smape: 114.6355
# Epoch 22/40
# 8s - loss: 1.1219 - k_smape: 108.9715 - val_loss: 1.0339 - val_k_smape: 116.8773
# Epoch 23/40
# 8s - loss: 1.1190 - k_smape: 108.6088 - val_loss: 1.0306 - val_k_smape: 114.8339
# Epoch 24/40
# 8s - loss: 1.1175 - k_smape: 108.4179 - val_loss: 1.0031 - val_k_smape: 113.5080
# Epoch 25/40
# 8s - loss: 1.1120 - k_smape: 108.6003 - val_loss: 1.0185 - val_k_smape: 115.3269
# Epoch 26/40
# 8s - loss: 1.1126 - k_smape: 108.1127 - val_loss: 1.0184 - val_k_smape: 116.8763
# Epoch 27/40
# 8s - loss: 1.1131 - k_smape: 107.9775 - val_loss: 1.0243 - val_k_smape: 115.9698
# Epoch 28/40
# 8s - loss: 1.1175 - k_smape: 107.8460 - val_loss: 1.0468 - val_k_smape: 119.7330
# Epoch 29/40
# 8s - loss: 1.1127 - k_smape: 107.5491 - val_loss: 1.0144 - val_k_smape: 114.4956
# Epoch 30/40
# 8s - loss: 1.1049 - k_smape: 107.4307 - val_loss: 1.0042 - val_k_smape: 114.1289
# Epoch 31/40
# 8s - loss: 1.1081 - k_smape: 107.4137 - val_loss: 1.0110 - val_k_smape: 115.8652
# Epoch 32/40
# 8s - loss: 1.1068 - k_smape: 107.5673 - val_loss: 1.0059 - val_k_smape: 112.6057
# Epoch 33/40
# 8s - loss: 1.0992 - k_smape: 107.3728 - val_loss: 1.0064 - val_k_smape: 115.6270
# Epoch 34/40
# 8s - loss: 1.0982 - k_smape: 107.2073 - val_loss: 1.0019 - val_k_smape: 115.1937
# Epoch 35/40
# 8s - loss: 1.0971 - k_smape: 107.0353 - val_loss: 1.0337 - val_k_smape: 117.6666
# Epoch 36/40
# 8s - loss: 1.0951 - k_smape: 107.0311 - val_loss: 1.0220 - val_k_smape: 115.3979
# Epoch 37/40
# 8s - loss: 1.0916 - k_smape: 106.8736 - val_loss: 1.0031 - val_k_smape: 112.3961
# Epoch 38/40
# 8s - loss: 1.0884 - k_smape: 106.5670 - val_loss: 1.0183 - val_k_smape: 114.9918
# Epoch 39/40
# 8s - loss: 1.0858 - k_smape: 106.5427 - val_loss: 1.0203 - val_k_smape: 117.3251
# Epoch 40/40
# 8s - loss: 1.0874 - k_smape: 106.4107 - val_loss: 0.9959 - val_k_smape: 113.6168
# --- Group: 4 / 6 ---
# Train on 68055 samples, validate on 7562 samples
# Epoch 1/40
# 15s - loss: 1.3386 - k_smape: 108.9100 - val_loss: 1.1007 - val_k_smape: 107.1461
# Epoch 2/40
# 15s - loss: 1.2321 - k_smape: 99.6200 - val_loss: 1.0734 - val_k_smape: 104.5270
# Epoch 3/40
# 15s - loss: 1.2087 - k_smape: 97.9556 - val_loss: 1.0819 - val_k_smape: 103.4112
# Epoch 4/40
# 15s - loss: 1.1877 - k_smape: 96.9393 - val_loss: 1.0949 - val_k_smape: 104.2013
# Epoch 5/40
# 15s - loss: 1.1850 - k_smape: 96.2974 - val_loss: 1.0918 - val_k_smape: 104.6729
# Epoch 6/40
# 15s - loss: 1.1718 - k_smape: 95.8588 - val_loss: 1.0748 - val_k_smape: 103.0417
# Epoch 7/40
# 15s - loss: 1.1670 - k_smape: 95.5045 - val_loss: 1.1070 - val_k_smape: 106.0174
# Epoch 8/40
# 15s - loss: 1.1597 - k_smape: 95.1571 - val_loss: 1.1109 - val_k_smape: 104.0105
# Epoch 9/40
# 15s - loss: 1.1546 - k_smape: 94.8307 - val_loss: 1.0792 - val_k_smape: 102.9000
# Epoch 10/40
# 15s - loss: 1.1461 - k_smape: 94.2786 - val_loss: 1.0851 - val_k_smape: 102.7042
# Epoch 11/40
# 15s - loss: 1.1385 - k_smape: 94.1751 - val_loss: 1.0886 - val_k_smape: 103.9967
# Epoch 12/40
# 15s - loss: 1.1376 - k_smape: 93.8251 - val_loss: 1.1121 - val_k_smape: 105.0790
# Epoch 13/40
# 15s - loss: 1.1373 - k_smape: 93.7863 - val_loss: 1.0352 - val_k_smape: 101.7670
# Epoch 14/40
# 15s - loss: 1.1319 - k_smape: 93.4718 - val_loss: 1.0852 - val_k_smape: 103.4204
# Epoch 15/40
# 15s - loss: 1.1237 - k_smape: 93.1595 - val_loss: 1.0718 - val_k_smape: 102.6901
# Epoch 16/40
# 15s - loss: 1.1238 - k_smape: 93.2522 - val_loss: 1.0886 - val_k_smape: 102.5063
# Epoch 17/40
# 15s - loss: 1.1193 - k_smape: 92.9139 - val_loss: 1.0934 - val_k_smape: 103.9812
# Epoch 18/40
# 15s - loss: 1.1189 - k_smape: 92.7517 - val_loss: 1.0928 - val_k_smape: 104.3399
# Epoch 19/40
# 15s - loss: 1.1097 - k_smape: 92.6346 - val_loss: 1.0898 - val_k_smape: 103.4442
# Epoch 20/40
# 15s - loss: 1.1122 - k_smape: 92.5219 - val_loss: 1.0985 - val_k_smape: 103.8316
# Epoch 21/40
# 15s - loss: 1.1100 - k_smape: 92.3062 - val_loss: 1.0660 - val_k_smape: 105.2220
# Epoch 22/40
# 15s - loss: 1.1029 - k_smape: 92.2958 - val_loss: 1.0604 - val_k_smape: 102.4657
# Epoch 23/40
# 15s - loss: 1.1019 - k_smape: 92.0325 - val_loss: 1.0552 - val_k_smape: 102.7623
# Epoch 24/40
# 15s - loss: 1.1004 - k_smape: 91.9065 - val_loss: 1.0746 - val_k_smape: 104.4765
# Epoch 25/40
# 15s - loss: 1.0986 - k_smape: 91.6153 - val_loss: 1.0851 - val_k_smape: 103.6934
# Epoch 26/40
# 15s - loss: 1.0971 - k_smape: 91.6378 - val_loss: 1.0898 - val_k_smape: 105.0695
# Epoch 27/40
# 15s - loss: 1.0934 - k_smape: 91.5609 - val_loss: 1.0645 - val_k_smape: 103.1889
# Epoch 28/40
# 15s - loss: 1.0905 - k_smape: 91.3853 - val_loss: 1.0705 - val_k_smape: 103.0996
# Epoch 29/40
# 15s - loss: 1.0890 - k_smape: 91.2277 - val_loss: 1.0575 - val_k_smape: 102.6230
# Epoch 30/40
# 15s - loss: 1.0831 - k_smape: 91.1148 - val_loss: 1.0574 - val_k_smape: 102.5127
# Epoch 31/40
# 15s - loss: 1.0855 - k_smape: 90.9339 - val_loss: 1.0767 - val_k_smape: 103.6287
# Epoch 32/40
# 15s - loss: 1.0845 - k_smape: 90.9287 - val_loss: 1.0567 - val_k_smape: 103.0807
# Epoch 33/40
# 15s - loss: 1.0788 - k_smape: 90.8460 - val_loss: 1.0725 - val_k_smape: 103.9269
# Epoch 34/40
# 15s - loss: 1.0780 - k_smape: 90.8032 - val_loss: 1.0668 - val_k_smape: 103.5573
# Epoch 35/40
# 15s - loss: 1.0772 - k_smape: 90.6580 - val_loss: 1.0720 - val_k_smape: 104.0951
# Epoch 36/40
# 15s - loss: 1.0773 - k_smape: 90.6952 - val_loss: 1.0435 - val_k_smape: 101.5527
# Epoch 37/40
# 15s - loss: 1.0743 - k_smape: 90.4940 - val_loss: 1.1010 - val_k_smape: 103.3632
# Epoch 38/40
# 15s - loss: 1.0753 - k_smape: 90.3021 - val_loss: 1.0659 - val_k_smape: 103.6168
# Epoch 39/40
# 15s - loss: 1.0749 - k_smape: 90.4605 - val_loss: 1.0629 - val_k_smape: 102.1570
# Epoch 40/40
# 15s - loss: 1.0689 - k_smape: 90.1618 - val_loss: 1.0571 - val_k_smape: 101.8511
# --- Group: 5 / 6 ---
# Train on 666 samples, validate on 74 samples
# Epoch 1/60
# 0s - loss: 2.8504 - k_smape: 151.7691 - val_loss: 2.6896 - val_k_smape: 130.0920
# Epoch 2/60
# 0s - loss: 2.4565 - k_smape: 129.2218 - val_loss: 2.8087 - val_k_smape: 134.9186
# Epoch 3/60
# 0s - loss: 2.3330 - k_smape: 129.9302 - val_loss: 2.2065 - val_k_smape: 119.5489
# Epoch 4/60
# 0s - loss: 2.1945 - k_smape: 121.7987 - val_loss: 2.3486 - val_k_smape: 122.5138
# Epoch 5/60
# 0s - loss: 2.1046 - k_smape: 120.7285 - val_loss: 1.9346 - val_k_smape: 112.4560
# Epoch 6/60
# 0s - loss: 1.9856 - k_smape: 113.5066 - val_loss: 2.1149 - val_k_smape: 116.6598
# Epoch 7/60
# 0s - loss: 1.9017 - k_smape: 113.3099 - val_loss: 2.0159 - val_k_smape: 111.4049
# Epoch 8/60
# 0s - loss: 1.8839 - k_smape: 108.8476 - val_loss: 1.6248 - val_k_smape: 106.6466
# Epoch 9/60
# 0s - loss: 1.8051 - k_smape: 106.4754 - val_loss: 2.2394 - val_k_smape: 117.1754
# Epoch 10/60
# 0s - loss: 1.8299 - k_smape: 107.1502 - val_loss: 1.5000 - val_k_smape: 99.1059
# Epoch 11/60
# 0s - loss: 1.7717 - k_smape: 101.5404 - val_loss: 2.0878 - val_k_smape: 114.9645
# Epoch 12/60
# 0s - loss: 1.7314 - k_smape: 102.9249 - val_loss: 1.4601 - val_k_smape: 102.8439
# Epoch 13/60
# 0s - loss: 1.6499 - k_smape: 102.1717 - val_loss: 1.7890 - val_k_smape: 106.4967
# Epoch 14/60
# 0s - loss: 1.6041 - k_smape: 97.9620 - val_loss: 1.4225 - val_k_smape: 96.3076
# Epoch 15/60
# 0s - loss: 1.6214 - k_smape: 94.1796 - val_loss: 1.7239 - val_k_smape: 106.0537
# Epoch 16/60
# 0s - loss: 1.6080 - k_smape: 96.9675 - val_loss: 1.5527 - val_k_smape: 99.2465
# Epoch 17/60
# 0s - loss: 1.6062 - k_smape: 92.1029 - val_loss: 1.5867 - val_k_smape: 97.6972
# Epoch 18/60
# 0s - loss: 1.5459 - k_smape: 92.6892 - val_loss: 1.4603 - val_k_smape: 94.8908
# Epoch 19/60
# 0s - loss: 1.6417 - k_smape: 93.1268 - val_loss: 1.8365 - val_k_smape: 105.2831
# Epoch 20/60
# 0s - loss: 1.5439 - k_smape: 94.9019 - val_loss: 1.5528 - val_k_smape: 92.9057
# Epoch 21/60
# 0s - loss: 1.6204 - k_smape: 91.3333 - val_loss: 1.7349 - val_k_smape: 95.6572
# Epoch 22/60
# 0s - loss: 1.5004 - k_smape: 88.8571 - val_loss: 1.3601 - val_k_smape: 93.7875
# Epoch 23/60
# 0s - loss: 1.4988 - k_smape: 91.4283 - val_loss: 1.4189 - val_k_smape: 96.2878
# Epoch 24/60
# 0s - loss: 1.4552 - k_smape: 87.9876 - val_loss: 1.5176 - val_k_smape: 93.5335
# Epoch 25/60
# 0s - loss: 1.4410 - k_smape: 86.0991 - val_loss: 1.4939 - val_k_smape: 93.3205
# Epoch 26/60
# 0s - loss: 1.4185 - k_smape: 87.6007 - val_loss: 1.3193 - val_k_smape: 91.6051
# Epoch 27/60
# 0s - loss: 1.4492 - k_smape: 85.8556 - val_loss: 1.5470 - val_k_smape: 96.9964
# Epoch 28/60
# 0s - loss: 1.4513 - k_smape: 86.6724 - val_loss: 1.3313 - val_k_smape: 89.5915
# Epoch 29/60
# 0s - loss: 1.4250 - k_smape: 85.2028 - val_loss: 1.3302 - val_k_smape: 89.3643
# Epoch 30/60
# 0s - loss: 1.5231 - k_smape: 85.3996 - val_loss: 1.8468 - val_k_smape: 103.7855
# Epoch 31/60
# 0s - loss: 1.4713 - k_smape: 90.9897 - val_loss: 1.3368 - val_k_smape: 87.7089
# Epoch 32/60
# 0s - loss: 1.4137 - k_smape: 85.6644 - val_loss: 1.6071 - val_k_smape: 95.3748
# Epoch 33/60
# 0s - loss: 1.4542 - k_smape: 84.5825 - val_loss: 1.3090 - val_k_smape: 90.9620
# Epoch 34/60
# 0s - loss: 1.3994 - k_smape: 86.2636 - val_loss: 1.5701 - val_k_smape: 91.9942
# Epoch 35/60
# 0s - loss: 1.3716 - k_smape: 81.9730 - val_loss: 1.3312 - val_k_smape: 88.2211
# Epoch 36/60
# 0s - loss: 1.3668 - k_smape: 84.0925 - val_loss: 1.6385 - val_k_smape: 95.2679
# Epoch 37/60
# 0s - loss: 1.3667 - k_smape: 82.4074 - val_loss: 1.2973 - val_k_smape: 88.0313
# Epoch 38/60
# 0s - loss: 1.3334 - k_smape: 82.6141 - val_loss: 1.4451 - val_k_smape: 90.9817
# Epoch 39/60
# 0s - loss: 1.3320 - k_smape: 81.5387 - val_loss: 1.3184 - val_k_smape: 90.7292
# Epoch 40/60
# 0s - loss: 1.3395 - k_smape: 82.7687 - val_loss: 1.3409 - val_k_smape: 91.4041
# Epoch 41/60
# 0s - loss: 1.3338 - k_smape: 82.3201 - val_loss: 1.3967 - val_k_smape: 91.6538
# Epoch 42/60
# 0s - loss: 1.3257 - k_smape: 82.1255 - val_loss: 1.4587 - val_k_smape: 90.6173
# Epoch 43/60
# 0s - loss: 1.3031 - k_smape: 79.8175 - val_loss: 1.2968 - val_k_smape: 86.8582
# Epoch 44/60
# 0s - loss: 1.3635 - k_smape: 80.6991 - val_loss: 1.3154 - val_k_smape: 88.9566
# Epoch 45/60
# 0s - loss: 1.3601 - k_smape: 80.2633 - val_loss: 1.7058 - val_k_smape: 94.0499
# Epoch 46/60
# 0s - loss: 1.3616 - k_smape: 81.5987 - val_loss: 1.3141 - val_k_smape: 84.7007
# Epoch 47/60
# 0s - loss: 1.3407 - k_smape: 79.2574 - val_loss: 1.5283 - val_k_smape: 92.2441
# Epoch 48/60
# 0s - loss: 1.3218 - k_smape: 81.0172 - val_loss: 1.2647 - val_k_smape: 86.7929
# Epoch 49/60
# 0s - loss: 1.2740 - k_smape: 78.9690 - val_loss: 1.4159 - val_k_smape: 87.1882
# Epoch 50/60
# 0s - loss: 1.3161 - k_smape: 76.8435 - val_loss: 1.2811 - val_k_smape: 90.2714
# Epoch 51/60
# 0s - loss: 1.2853 - k_smape: 82.0914 - val_loss: 1.3177 - val_k_smape: 89.5613
# Epoch 52/60
# 0s - loss: 1.3254 - k_smape: 77.5267 - val_loss: 1.5306 - val_k_smape: 89.9318
# Epoch 53/60
# 0s - loss: 1.2773 - k_smape: 77.9572 - val_loss: 1.2735 - val_k_smape: 88.0971
# Epoch 54/60
# 0s - loss: 1.2726 - k_smape: 77.7278 - val_loss: 1.4007 - val_k_smape: 89.2937
# Epoch 55/60
# 0s - loss: 1.2702 - k_smape: 77.8143 - val_loss: 1.2705 - val_k_smape: 85.1042
# Epoch 56/60
# 0s - loss: 1.2627 - k_smape: 77.5061 - val_loss: 1.3712 - val_k_smape: 90.3076
# Epoch 57/60
# 0s - loss: 1.2266 - k_smape: 77.4668 - val_loss: 1.3541 - val_k_smape: 88.1709
# Epoch 58/60
# 0s - loss: 1.2370 - k_smape: 77.3961 - val_loss: 1.2900 - val_k_smape: 85.7222
# Epoch 59/60
# 0s - loss: 1.1977 - k_smape: 77.0472 - val_loss: 1.4335 - val_k_smape: 89.8937
# Epoch 60/60
# 0s - loss: 1.2074 - k_smape: 76.6410 - val_loss: 1.2772 - val_k_smape: 85.5845
# --- Group: 6 / 6 ---
# Train on 45 samples, validate on 6 samples
# Epoch 1/80
# 0s - loss: 6.8358 - k_smape: 173.3154 - val_loss: 4.7379 - val_k_smape: 159.6130
# Epoch 2/80
# 0s - loss: 6.6238 - k_smape: 164.5730 - val_loss: 4.5513 - val_k_smape: 151.0909
# Epoch 3/80
# 0s - loss: 6.3548 - k_smape: 153.1994 - val_loss: 4.3506 - val_k_smape: 143.7638
# Epoch 4/80
# 0s - loss: 6.0279 - k_smape: 144.5941 - val_loss: 4.1402 - val_k_smape: 138.7663
# Epoch 5/80
# 0s - loss: 5.8152 - k_smape: 137.8761 - val_loss: 3.8821 - val_k_smape: 133.3936
# Epoch 6/80
# 0s - loss: 5.9449 - k_smape: 136.3628 - val_loss: 3.6371 - val_k_smape: 128.9969
# Epoch 7/80
# 0s - loss: 5.7389 - k_smape: 132.9471 - val_loss: 3.4589 - val_k_smape: 126.2785
# Epoch 8/80
# 0s - loss: 5.5481 - k_smape: 130.4778 - val_loss: 3.3365 - val_k_smape: 124.6717
# Epoch 9/80
# 0s - loss: 5.4796 - k_smape: 131.5053 - val_loss: 3.2343 - val_k_smape: 123.7705
# Epoch 10/80
# 0s - loss: 5.3798 - k_smape: 126.3859 - val_loss: 3.1988 - val_k_smape: 122.8080
# Epoch 11/80
# 0s - loss: 5.2991 - k_smape: 128.3430 - val_loss: 3.2053 - val_k_smape: 121.8062
# Epoch 12/80
# 0s - loss: 4.9853 - k_smape: 126.0201 - val_loss: 3.2386 - val_k_smape: 122.0938
# Epoch 13/80
# 0s - loss: 4.9969 - k_smape: 123.3765 - val_loss: 3.2378 - val_k_smape: 121.2220
# Epoch 14/80
# 0s - loss: 4.9136 - k_smape: 126.2584 - val_loss: 3.2051 - val_k_smape: 120.3253
# Epoch 15/80
# 0s - loss: 4.9285 - k_smape: 124.4592 - val_loss: 3.1130 - val_k_smape: 118.6993
# Epoch 16/80
# 0s - loss: 4.6523 - k_smape: 122.6022 - val_loss: 3.0023 - val_k_smape: 115.9297
# Epoch 17/80
# 0s - loss: 4.6499 - k_smape: 120.9316 - val_loss: 2.9116 - val_k_smape: 113.1553
# Epoch 18/80
# 0s - loss: 4.5453 - k_smape: 118.1299 - val_loss: 2.7955 - val_k_smape: 110.2415
# Epoch 19/80
# 0s - loss: 4.8144 - k_smape: 120.7315 - val_loss: 2.6276 - val_k_smape: 106.5605
# Epoch 20/80
# 0s - loss: 4.4871 - k_smape: 115.2051 - val_loss: 2.4676 - val_k_smape: 103.6890
# Epoch 21/80
# 0s - loss: 4.5855 - k_smape: 116.6926 - val_loss: 2.3408 - val_k_smape: 100.7597
# Epoch 22/80
# 0s - loss: 4.3246 - k_smape: 112.5809 - val_loss: 2.2366 - val_k_smape: 97.9745
# Epoch 23/80
# 0s - loss: 4.2373 - k_smape: 109.7747 - val_loss: 2.1480 - val_k_smape: 96.1303
# Epoch 24/80
# 0s - loss: 3.9934 - k_smape: 105.1733 - val_loss: 2.0910 - val_k_smape: 94.8206
# Epoch 25/80
# 0s - loss: 3.9955 - k_smape: 106.1840 - val_loss: 2.0923 - val_k_smape: 93.4046
# Epoch 26/80
# 0s - loss: 4.1176 - k_smape: 103.8873 - val_loss: 2.1457 - val_k_smape: 93.3277
# Epoch 27/80
# 0s - loss: 3.9108 - k_smape: 105.0031 - val_loss: 2.1708 - val_k_smape: 92.6387
# Epoch 28/80
# 0s - loss: 4.1167 - k_smape: 108.2613 - val_loss: 2.1381 - val_k_smape: 90.7399
# Epoch 29/80
# 0s - loss: 3.9270 - k_smape: 104.5877 - val_loss: 2.0942 - val_k_smape: 88.9517
# Epoch 30/80
# 0s - loss: 3.9622 - k_smape: 105.9112 - val_loss: 1.9824 - val_k_smape: 87.1856
# Epoch 31/80
# 0s - loss: 3.8696 - k_smape: 103.0069 - val_loss: 1.8477 - val_k_smape: 85.3892
# Epoch 32/80
# 0s - loss: 3.9596 - k_smape: 98.3536 - val_loss: 1.7259 - val_k_smape: 83.8824
# Epoch 33/80
# 0s - loss: 3.9843 - k_smape: 101.0130 - val_loss: 1.6493 - val_k_smape: 83.0425
# Epoch 34/80
# 0s - loss: 3.9561 - k_smape: 98.1239 - val_loss: 1.6249 - val_k_smape: 82.7937
# Epoch 35/80
# 0s - loss: 3.7119 - k_smape: 95.6699 - val_loss: 1.6393 - val_k_smape: 82.7703
# Epoch 36/80
# 0s - loss: 3.6538 - k_smape: 95.6655 - val_loss: 1.6576 - val_k_smape: 81.9617
# Epoch 37/80
# 0s - loss: 3.5769 - k_smape: 95.3125 - val_loss: 1.6827 - val_k_smape: 83.1357
# Epoch 38/80
# 0s - loss: 3.7449 - k_smape: 97.5846 - val_loss: 1.6505 - val_k_smape: 84.5565
# Epoch 39/80
# 0s - loss: 3.6922 - k_smape: 96.0069 - val_loss: 1.6571 - val_k_smape: 84.9866
# Epoch 40/80
# 0s - loss: 3.3452 - k_smape: 92.8107 - val_loss: 1.6690 - val_k_smape: 83.3632
# Epoch 41/80
# 0s - loss: 3.5073 - k_smape: 93.7495 - val_loss: 1.6780 - val_k_smape: 82.3119
# Epoch 42/80
# 0s - loss: 3.2787 - k_smape: 92.2238 - val_loss: 1.6528 - val_k_smape: 80.8704
# Epoch 43/80
# 0s - loss: 3.5911 - k_smape: 93.0782 - val_loss: 1.6091 - val_k_smape: 80.0079
# Epoch 44/80
# 0s - loss: 3.4469 - k_smape: 89.3402 - val_loss: 1.5420 - val_k_smape: 79.3691
# Epoch 45/80
# 0s - loss: 3.3055 - k_smape: 87.9727 - val_loss: 1.5000 - val_k_smape: 78.9037
# Epoch 46/80
# 0s - loss: 3.4064 - k_smape: 84.6822 - val_loss: 1.4410 - val_k_smape: 78.2271
# Epoch 47/80
# 0s - loss: 3.2811 - k_smape: 84.7046 - val_loss: 1.4049 - val_k_smape: 77.3820
# Epoch 48/80
# 0s - loss: 3.3001 - k_smape: 82.4355 - val_loss: 1.4290 - val_k_smape: 78.6540
# Epoch 49/80
# 0s - loss: 3.0607 - k_smape: 81.8765 - val_loss: 1.3915 - val_k_smape: 82.6446
# Epoch 50/80
# 0s - loss: 3.1526 - k_smape: 84.6040 - val_loss: 1.4016 - val_k_smape: 86.1814
# Epoch 51/80
# 0s - loss: 3.2576 - k_smape: 84.5804 - val_loss: 1.3886 - val_k_smape: 87.0692
# Epoch 52/80
# 0s - loss: 3.3232 - k_smape: 83.3674 - val_loss: 1.3133 - val_k_smape: 83.5020
# Epoch 53/80
# 0s - loss: 3.1450 - k_smape: 82.0886 - val_loss: 1.2829 - val_k_smape: 79.8871
# Epoch 54/80
# 0s - loss: 3.2172 - k_smape: 79.7363 - val_loss: 1.2553 - val_k_smape: 77.7700
# Epoch 55/80
# 0s - loss: 3.1365 - k_smape: 82.0683 - val_loss: 1.3514 - val_k_smape: 76.8494
# Epoch 56/80
# 0s - loss: 3.0892 - k_smape: 79.6550 - val_loss: 1.5047 - val_k_smape: 78.2408
# Epoch 57/80
# 0s - loss: 3.0360 - k_smape: 80.8514 - val_loss: 1.5363 - val_k_smape: 82.2752
# Epoch 58/80
# 0s - loss: 2.9553 - k_smape: 78.9691 - val_loss: 1.4851 - val_k_smape: 86.3287
# Epoch 59/80
# 0s - loss: 2.9273 - k_smape: 77.1148 - val_loss: 1.4806 - val_k_smape: 91.7532
# Epoch 60/80
# 0s - loss: 2.8844 - k_smape: 78.9833 - val_loss: 1.4776 - val_k_smape: 92.3821
# Epoch 61/80
# 0s - loss: 2.8016 - k_smape: 77.6975 - val_loss: 1.4903 - val_k_smape: 90.7876
# Epoch 62/80
# 0s - loss: 2.9246 - k_smape: 78.4135 - val_loss: 1.4486 - val_k_smape: 87.9039
# Epoch 63/80
# 0s - loss: 2.9475 - k_smape: 77.8977 - val_loss: 1.3298 - val_k_smape: 85.4709
# Epoch 64/80
# 0s - loss: 2.9860 - k_smape: 74.1876 - val_loss: 1.2177 - val_k_smape: 83.5469
# Epoch 65/80
# 0s - loss: 2.8502 - k_smape: 74.5813 - val_loss: 1.2116 - val_k_smape: 80.3519
# Epoch 66/80
# 0s - loss: 2.8038 - k_smape: 73.7238 - val_loss: 1.2470 - val_k_smape: 75.6527
# Epoch 67/80
# 0s - loss: 2.7854 - k_smape: 73.5882 - val_loss: 1.3421 - val_k_smape: 74.9244
# Epoch 68/80
# 0s - loss: 2.7693 - k_smape: 73.2949 - val_loss: 1.4642 - val_k_smape: 75.4779
# Epoch 69/80
# 0s - loss: 2.8019 - k_smape: 74.6955 - val_loss: 1.4743 - val_k_smape: 75.2906
# Epoch 70/80
# 0s - loss: 2.9655 - k_smape: 75.3190 - val_loss: 1.3462 - val_k_smape: 73.7840
# Epoch 71/80
# 0s - loss: 2.7964 - k_smape: 73.9646 - val_loss: 1.3084 - val_k_smape: 74.8267
# Epoch 72/80
# 0s - loss: 2.8457 - k_smape: 71.5714 - val_loss: 1.2941 - val_k_smape: 77.1446
# Epoch 73/80
# 0s - loss: 2.9327 - k_smape: 73.5870 - val_loss: 1.2819 - val_k_smape: 84.8037
# Epoch 74/80
# 0s - loss: 3.1816 - k_smape: 74.0189 - val_loss: 1.3363 - val_k_smape: 92.4281
# Epoch 75/80
# 0s - loss: 2.8399 - k_smape: 78.8236 - val_loss: 1.4262 - val_k_smape: 94.2061
# Epoch 76/80
# 0s - loss: 2.6816 - k_smape: 74.3404 - val_loss: 1.5097 - val_k_smape: 87.6022
# Epoch 77/80
# 0s - loss: 2.6974 - k_smape: 74.6420 - val_loss: 1.6141 - val_k_smape: 77.3916
# Epoch 78/80
# 0s - loss: 2.9325 - k_smape: 77.2123 - val_loss: 1.5466 - val_k_smape: 73.3149
# Epoch 79/80
# 0s - loss: 2.9971 - k_smape: 73.3624 - val_loss: 1.2802 - val_k_smape: 70.5210
# Epoch 80/80
# 0s - loss: 2.8582 - k_smape: 72.6796 - val_loss: 1.0660 - val_k_smape: 70.2746
# === Run: 3 / 5 ===
# --- Group: 1 / 6 ---
# Train on 1691 samples, validate on 188 samples
# Epoch 1/1
# 1s - loss: 0.9430 - k_smape: 198.6514 - val_loss: 0.9730 - val_k_smape: 199.3895
# --- Group: 2 / 6 ---
# Train on 20776 samples, validate on 2309 samples
# Epoch 1/1
# 5s - loss: 1.1308 - k_smape: 145.8728 - val_loss: 0.9690 - val_k_smape: 135.2376
# --- Group: 3 / 6 ---
# Train on 39321 samples, validate on 4370 samples
# Epoch 1/40
# 9s - loss: 1.3213 - k_smape: 127.5692 - val_loss: 1.0272 - val_k_smape: 120.7902
# Epoch 2/40
# 9s - loss: 1.2415 - k_smape: 118.3449 - val_loss: 1.0349 - val_k_smape: 121.2727
# Epoch 3/40
# 9s - loss: 1.2220 - k_smape: 115.8391 - val_loss: 1.0269 - val_k_smape: 116.8641
# Epoch 4/40
# 8s - loss: 1.1982 - k_smape: 114.3191 - val_loss: 1.0182 - val_k_smape: 114.5227
# Epoch 5/40
# 8s - loss: 1.2025 - k_smape: 113.6467 - val_loss: 1.0341 - val_k_smape: 115.4019
# Epoch 6/40
# 8s - loss: 1.1913 - k_smape: 112.9867 - val_loss: 1.0011 - val_k_smape: 112.5796
# Epoch 7/40
# 8s - loss: 1.1828 - k_smape: 112.9113 - val_loss: 1.0541 - val_k_smape: 119.8843
# Epoch 8/40
# 8s - loss: 1.1810 - k_smape: 112.3248 - val_loss: 1.0186 - val_k_smape: 116.2662
# Epoch 9/40
# 8s - loss: 1.1640 - k_smape: 111.6222 - val_loss: 1.0162 - val_k_smape: 117.4422
# Epoch 10/40
# 8s - loss: 1.1614 - k_smape: 111.4490 - val_loss: 1.0563 - val_k_smape: 123.2425
# Epoch 11/40
# 8s - loss: 1.1601 - k_smape: 111.3164 - val_loss: 1.0032 - val_k_smape: 112.4340
# Epoch 12/40
# 8s - loss: 1.1599 - k_smape: 110.8336 - val_loss: 1.0065 - val_k_smape: 116.5809
# Epoch 13/40
# 8s - loss: 1.1560 - k_smape: 110.6612 - val_loss: 1.0285 - val_k_smape: 118.2699
# Epoch 14/40
# 8s - loss: 1.1516 - k_smape: 110.4552 - val_loss: 1.0345 - val_k_smape: 116.3107
# Epoch 15/40
# 8s - loss: 1.1475 - k_smape: 110.0501 - val_loss: 1.0628 - val_k_smape: 121.5608
# Epoch 16/40
# 8s - loss: 1.1450 - k_smape: 110.0459 - val_loss: 1.0178 - val_k_smape: 116.5172
# Epoch 17/40
# 8s - loss: 1.1336 - k_smape: 109.5834 - val_loss: 1.0176 - val_k_smape: 115.2312
# Epoch 18/40
# 8s - loss: 1.1340 - k_smape: 109.5006 - val_loss: 1.0170 - val_k_smape: 115.2190
# Epoch 19/40
# 8s - loss: 1.1337 - k_smape: 109.0598 - val_loss: 1.0045 - val_k_smape: 115.6936
# Epoch 20/40
# 8s - loss: 1.1261 - k_smape: 108.9492 - val_loss: 1.0182 - val_k_smape: 114.2712
# Epoch 21/40
# 8s - loss: 1.1288 - k_smape: 108.8957 - val_loss: 1.0138 - val_k_smape: 114.9625
# Epoch 22/40
# 8s - loss: 1.1261 - k_smape: 108.5992 - val_loss: 1.0266 - val_k_smape: 115.3517
# Epoch 23/40
# 8s - loss: 1.1210 - k_smape: 108.7587 - val_loss: 1.0042 - val_k_smape: 114.8789
# Epoch 24/40
# 8s - loss: 1.1226 - k_smape: 108.6656 - val_loss: 1.0255 - val_k_smape: 118.1686
# Epoch 25/40
# 8s - loss: 1.1162 - k_smape: 108.3654 - val_loss: 1.0434 - val_k_smape: 116.6495
# Epoch 26/40
# 8s - loss: 1.1180 - k_smape: 108.4709 - val_loss: 1.0181 - val_k_smape: 117.2205
# Epoch 27/40
# 8s - loss: 1.1061 - k_smape: 108.0360 - val_loss: 1.0264 - val_k_smape: 117.1433
# Epoch 28/40
# 8s - loss: 1.1118 - k_smape: 107.9660 - val_loss: 1.0431 - val_k_smape: 119.8973
# Epoch 29/40
# 8s - loss: 1.1135 - k_smape: 108.1058 - val_loss: 1.0301 - val_k_smape: 117.6166
# Epoch 30/40
# 8s - loss: 1.1067 - k_smape: 107.8114 - val_loss: 1.0087 - val_k_smape: 114.7742
# Epoch 31/40
# 8s - loss: 1.1083 - k_smape: 107.7608 - val_loss: 1.0240 - val_k_smape: 116.8342
# Epoch 32/40
# 8s - loss: 1.1026 - k_smape: 107.5704 - val_loss: 1.0138 - val_k_smape: 116.2878
# Epoch 33/40
# 8s - loss: 1.1005 - k_smape: 107.4955 - val_loss: 1.0208 - val_k_smape: 116.6014
# Epoch 34/40
# 8s - loss: 1.0989 - k_smape: 107.4673 - val_loss: 1.0131 - val_k_smape: 114.6282
# Epoch 35/40
# 8s - loss: 1.0948 - k_smape: 107.1130 - val_loss: 1.0115 - val_k_smape: 116.3527
# Epoch 36/40
# 8s - loss: 1.0955 - k_smape: 107.0688 - val_loss: 1.0285 - val_k_smape: 118.5686
# Epoch 37/40
# 8s - loss: 1.0955 - k_smape: 107.1150 - val_loss: 1.0168 - val_k_smape: 114.7208
# Epoch 38/40
# 8s - loss: 1.0925 - k_smape: 106.9324 - val_loss: 1.0195 - val_k_smape: 114.7342
# Epoch 39/40
# 8s - loss: 1.0893 - k_smape: 106.8304 - val_loss: 1.0417 - val_k_smape: 116.6589
# Epoch 40/40
# 8s - loss: 1.0972 - k_smape: 107.0159 - val_loss: 1.0416 - val_k_smape: 118.1541
# --- Group: 4 / 6 ---
# Train on 68055 samples, validate on 7562 samples
# Epoch 1/40
# 16s - loss: 1.3379 - k_smape: 108.5157 - val_loss: 1.1339 - val_k_smape: 107.5385
# Epoch 2/40
# 15s - loss: 1.2258 - k_smape: 99.4034 - val_loss: 1.0795 - val_k_smape: 103.2088
# Epoch 3/40
# 15s - loss: 1.2083 - k_smape: 97.5591 - val_loss: 1.0660 - val_k_smape: 102.9347
# Epoch 4/40
# 15s - loss: 1.1902 - k_smape: 96.7193 - val_loss: 1.0837 - val_k_smape: 102.7474
# Epoch 5/40
# 15s - loss: 1.1793 - k_smape: 95.8907 - val_loss: 1.1206 - val_k_smape: 105.2837
# Epoch 6/40
# 15s - loss: 1.1705 - k_smape: 95.1190 - val_loss: 1.0682 - val_k_smape: 104.0851
# Epoch 7/40
# 15s - loss: 1.1587 - k_smape: 94.7608 - val_loss: 1.0625 - val_k_smape: 102.8833
# Epoch 8/40
# 15s - loss: 1.1509 - k_smape: 94.4217 - val_loss: 1.0987 - val_k_smape: 104.3359
# Epoch 9/40
# 15s - loss: 1.1465 - k_smape: 94.0504 - val_loss: 1.0679 - val_k_smape: 103.4508
# Epoch 10/40
# 15s - loss: 1.1397 - k_smape: 93.6480 - val_loss: 1.0895 - val_k_smape: 102.4326
# Epoch 11/40
# 15s - loss: 1.1362 - k_smape: 93.5320 - val_loss: 1.0797 - val_k_smape: 102.3867
# Epoch 12/40
# 15s - loss: 1.1320 - k_smape: 93.3207 - val_loss: 1.0725 - val_k_smape: 102.3397
# Epoch 13/40
# 15s - loss: 1.1274 - k_smape: 92.9088 - val_loss: 1.0874 - val_k_smape: 102.3529
# Epoch 14/40
# 15s - loss: 1.1223 - k_smape: 92.7024 - val_loss: 1.0788 - val_k_smape: 102.8399
# Epoch 15/40
# 15s - loss: 1.1183 - k_smape: 92.6089 - val_loss: 1.0667 - val_k_smape: 103.3377
# Epoch 16/40
# 15s - loss: 1.1129 - k_smape: 92.2246 - val_loss: 1.0577 - val_k_smape: 102.0495
# Epoch 17/40
# 15s - loss: 1.1082 - k_smape: 91.9976 - val_loss: 1.0516 - val_k_smape: 101.5706
# Epoch 18/40
# 15s - loss: 1.1086 - k_smape: 91.7645 - val_loss: 1.0803 - val_k_smape: 103.7970
# Epoch 19/40
# 15s - loss: 1.1035 - k_smape: 91.6612 - val_loss: 1.0965 - val_k_smape: 103.1142
# Epoch 20/40
# 15s - loss: 1.1023 - k_smape: 91.5379 - val_loss: 1.0605 - val_k_smape: 102.2381
# Epoch 21/40
# 15s - loss: 1.0988 - k_smape: 91.4203 - val_loss: 1.0721 - val_k_smape: 102.9033
# Epoch 22/40
# 15s - loss: 1.0970 - k_smape: 91.0456 - val_loss: 1.0540 - val_k_smape: 100.8268
# Epoch 23/40
# 15s - loss: 1.0918 - k_smape: 90.9339 - val_loss: 1.0658 - val_k_smape: 101.9484
# ...
# Epoch 9/40
# 15s - loss: 1.1550 - k_smape: 94.7881 - val_loss: 1.0774 - val_k_smape: 103.2659
# Epoch 10/40
# 15s - loss: 1.1487 - k_smape: 94.3212 - val_loss: 1.0584 - val_k_smape: 103.0887
# Epoch 11/40
# 15s - loss: 1.1459 - k_smape: 94.1412 - val_loss: 1.0867 - val_k_smape: 103.5481
# Epoch 12/40
# 15s - loss: 1.1350 - k_smape: 93.6932 - val_loss: 1.1034 - val_k_smape: 105.5333
# Epoch 13/40
# 15s - loss: 1.1344 - k_smape: 93.6827 - val_loss: 1.0622 - val_k_smape: 103.0093
# Epoch 14/40
# 15s - loss: 1.1283 - k_smape: 93.4172 - val_loss: 1.0608 - val_k_smape: 104.5385
# Epoch 15/40
# 15s - loss: 1.1271 - k_smape: 93.2337 - val_loss: 1.0982 - val_k_smape: 104.1481
# Epoch 16/40
# 15s - loss: 1.1177 - k_smape: 92.8876 - val_loss: 1.0681 - val_k_smape: 102.2614
# Epoch 17/40
# 15s - loss: 1.1153 - k_smape: 92.6579 - val_loss: 1.0514 - val_k_smape: 102.9135
# Epoch 18/40
# 15s - loss: 1.1132 - k_smape: 92.5559 - val_loss: 1.0715 - val_k_smape: 103.5234
# Epoch 19/40
# 15s - loss: 1.1115 - k_smape: 92.4849 - val_loss: 1.0704 - val_k_smape: 103.9764
# Epoch 20/40
# 15s - loss: 1.1069 - k_smape: 92.2187 - val_loss: 1.0712 - val_k_smape: 103.2497
# Epoch 21/40
# 15s - loss: 1.1056 - k_smape: 92.2255 - val_loss: 1.0899 - val_k_smape: 103.5227
# Epoch 22/40
# 15s - loss: 1.1001 - k_smape: 91.8695 - val_loss: 1.0702 - val_k_smape: 102.4960
# Epoch 23/40
# 15s - loss: 1.0989 - k_smape: 91.8805 - val_loss: 1.0894 - val_k_smape: 103.4186
# Epoch 24/40
# 15s - loss: 1.0987 - k_smape: 91.4825 - val_loss: 1.0602 - val_k_smape: 103.3153
# Epoch 25/40
# 15s - loss: 1.0936 - k_smape: 91.5071 - val_loss: 1.0584 - val_k_smape: 102.7222
# Epoch 26/40
# 15s - loss: 1.0915 - k_smape: 91.4773 - val_loss: 1.0752 - val_k_smape: 102.5279
# Epoch 27/40
# 15s - loss: 1.0894 - k_smape: 91.3183 - val_loss: 1.0645 - val_k_smape: 102.3834
# Epoch 28/40
# 15s - loss: 1.0857 - k_smape: 91.0268 - val_loss: 1.0673 - val_k_smape: 101.8575
# Epoch 29/40
# 15s - loss: 1.0837 - k_smape: 90.9403 - val_loss: 1.0484 - val_k_smape: 102.2574
# Epoch 30/40
# 15s - loss: 1.0824 - k_smape: 90.8869 - val_loss: 1.0518 - val_k_smape: 101.7984
# Epoch 31/40
# 15s - loss: 1.0827 - k_smape: 90.7764 - val_loss: 1.0766 - val_k_smape: 102.9986
# Epoch 32/40
# 15s - loss: 1.0783 - k_smape: 90.6172 - val_loss: 1.0440 - val_k_smape: 100.5101
# Epoch 33/40
# 15s - loss: 1.0737 - k_smape: 90.5256 - val_loss: 1.0486 - val_k_smape: 101.7350
# Epoch 34/40
# 15s - loss: 1.0751 - k_smape: 90.3318 - val_loss: 1.0352 - val_k_smape: 101.5232
# Epoch 35/40
# 15s - loss: 1.0703 - k_smape: 90.2349 - val_loss: 1.0630 - val_k_smape: 101.5885
# Epoch 36/40
# 15s - loss: 1.0704 - k_smape: 90.2079 - val_loss: 1.0479 - val_k_smape: 101.6537
# Epoch 37/40
# 15s - loss: 1.0697 - k_smape: 90.3258 - val_loss: 1.0684 - val_k_smape: 101.6668
# Epoch 38/40
# 15s - loss: 1.0674 - k_smape: 90.0418 - val_loss: 1.0691 - val_k_smape: 102.6376
# Epoch 39/40
# 15s - loss: 1.0651 - k_smape: 89.9361 - val_loss: 1.0463 - val_k_smape: 99.7266
# Epoch 40/40
# 15s - loss: 1.0604 - k_smape: 89.8437 - val_loss: 1.0286 - val_k_smape: 100.3537
# --- Group: 5 / 6 ---
# Train on 666 samples, validate on 74 samples
# Epoch 1/60
# 1s - loss: 2.9611 - k_smape: 155.7579 - val_loss: 3.1604 - val_k_smape: 144.7820
# Epoch 2/60
# 0s - loss: 2.6312 - k_smape: 138.2042 - val_loss: 2.9965 - val_k_smape: 141.7771
# Epoch 3/60
# 0s - loss: 2.4426 - k_smape: 133.3698 - val_loss: 2.4569 - val_k_smape: 127.4344
# Epoch 4/60
# 0s - loss: 2.2652 - k_smape: 124.3548 - val_loss: 2.3241 - val_k_smape: 123.7665
# Epoch 5/60
# 0s - loss: 2.1365 - k_smape: 120.9083 - val_loss: 2.0928 - val_k_smape: 116.9823
# Epoch 6/60
# 0s - loss: 2.0083 - k_smape: 115.6437 - val_loss: 2.0598 - val_k_smape: 114.8320
# Epoch 7/60
# 0s - loss: 1.9118 - k_smape: 109.6590 - val_loss: 1.8622 - val_k_smape: 108.1523
# Epoch 8/60
# 0s - loss: 1.8596 - k_smape: 106.4575 - val_loss: 1.7042 - val_k_smape: 106.2237
# Epoch 9/60
# 0s - loss: 1.8025 - k_smape: 104.1148 - val_loss: 1.6619 - val_k_smape: 104.9296
# Epoch 10/60
# 0s - loss: 1.7291 - k_smape: 100.7286 - val_loss: 1.7468 - val_k_smape: 104.1409
# Epoch 11/60
# 0s - loss: 1.6726 - k_smape: 101.2390 - val_loss: 1.4339 - val_k_smape: 96.9584
# Epoch 12/60
# 0s - loss: 1.6845 - k_smape: 96.7590 - val_loss: 1.7732 - val_k_smape: 100.7906
# Epoch 13/60
# 0s - loss: 1.6076 - k_smape: 95.3539 - val_loss: 1.5856 - val_k_smape: 97.9689
# Epoch 14/60
# 0s - loss: 1.5954 - k_smape: 93.7354 - val_loss: 1.9207 - val_k_smape: 101.1626
# Epoch 15/60
# 0s - loss: 1.6021 - k_smape: 91.2039 - val_loss: 1.6550 - val_k_smape: 96.3278
# Epoch 16/60
# 0s - loss: 1.5848 - k_smape: 92.6519 - val_loss: 1.3644 - val_k_smape: 94.0512
# Epoch 17/60
# 0s - loss: 1.5439 - k_smape: 94.5525 - val_loss: 1.4673 - val_k_smape: 93.4830
# Epoch 18/60
# 0s - loss: 1.5303 - k_smape: 88.5236 - val_loss: 1.6530 - val_k_smape: 97.9322
# Epoch 19/60
# 0s - loss: 1.5305 - k_smape: 91.8237 - val_loss: 1.3369 - val_k_smape: 90.4700
# Epoch 20/60
# 0s - loss: 1.4834 - k_smape: 87.5914 - val_loss: 1.5672 - val_k_smape: 98.7636
# Epoch 21/60
# 0s - loss: 1.4525 - k_smape: 88.6833 - val_loss: 1.3357 - val_k_smape: 92.6788
# Epoch 22/60
# 0s - loss: 1.4592 - k_smape: 86.6091 - val_loss: 1.3796 - val_k_smape: 93.6581
# Epoch 23/60
# 0s - loss: 1.4476 - k_smape: 86.8349 - val_loss: 1.5031 - val_k_smape: 92.0894
# Epoch 24/60
# 0s - loss: 1.4701 - k_smape: 84.2195 - val_loss: 1.5658 - val_k_smape: 96.0461
# Epoch 25/60
# 0s - loss: 1.4900 - k_smape: 87.1233 - val_loss: 1.2865 - val_k_smape: 88.7726
# Epoch 26/60
# 0s - loss: 1.4192 - k_smape: 87.0192 - val_loss: 1.4689 - val_k_smape: 93.3579
# Epoch 27/60
# 0s - loss: 1.3986 - k_smape: 84.9827 - val_loss: 1.2777 - val_k_smape: 88.4598
# Epoch 28/60
# 0s - loss: 1.4417 - k_smape: 86.9431 - val_loss: 1.5845 - val_k_smape: 92.4987
# Epoch 29/60
# 0s - loss: 1.4285 - k_smape: 82.9656 - val_loss: 1.3974 - val_k_smape: 90.7344
# Epoch 30/60
# 0s - loss: 1.4043 - k_smape: 84.7735 - val_loss: 1.2710 - val_k_smape: 89.7060
# Epoch 31/60
# 0s - loss: 1.4651 - k_smape: 83.6322 - val_loss: 1.4431 - val_k_smape: 88.9478
# Epoch 32/60
# 0s - loss: 1.3326 - k_smape: 80.4744 - val_loss: 1.3924 - val_k_smape: 90.0119
# Epoch 33/60
# 0s - loss: 1.3219 - k_smape: 82.1483 - val_loss: 1.4297 - val_k_smape: 88.5236
# Epoch 34/60
# 0s - loss: 1.3715 - k_smape: 80.5861 - val_loss: 1.2830 - val_k_smape: 85.7746
# Epoch 35/60
# 0s - loss: 1.3389 - k_smape: 80.9592 - val_loss: 1.3561 - val_k_smape: 89.6427
# Epoch 36/60
# 0s - loss: 1.3075 - k_smape: 80.0998 - val_loss: 1.3924 - val_k_smape: 86.4461
# Epoch 37/60
# 0s - loss: 1.3169 - k_smape: 79.6503 - val_loss: 1.2767 - val_k_smape: 86.1877
# Epoch 38/60
# 0s - loss: 1.3170 - k_smape: 81.6667 - val_loss: 1.4875 - val_k_smape: 88.3093
# Epoch 39/60
# 0s - loss: 1.3484 - k_smape: 79.1898 - val_loss: 1.3990 - val_k_smape: 90.6954
# Epoch 40/60
# 0s - loss: 1.2730 - k_smape: 81.2978 - val_loss: 1.2876 - val_k_smape: 85.8428
# Epoch 41/60
# 0s - loss: 1.2586 - k_smape: 77.0964 - val_loss: 1.3966 - val_k_smape: 88.1641
# Epoch 42/60
# 0s - loss: 1.2871 - k_smape: 78.7272 - val_loss: 1.2568 - val_k_smape: 85.1658
# Epoch 43/60
# 0s - loss: 1.2676 - k_smape: 78.4727 - val_loss: 1.4462 - val_k_smape: 89.4105
# Epoch 44/60
# 0s - loss: 1.2835 - k_smape: 79.0751 - val_loss: 1.3159 - val_k_smape: 84.6829
# Epoch 45/60
# 0s - loss: 1.3085 - k_smape: 77.1801 - val_loss: 1.4251 - val_k_smape: 88.8087
# Epoch 46/60
# 0s - loss: 1.2310 - k_smape: 77.7713 - val_loss: 1.5493 - val_k_smape: 87.2549
# Epoch 47/60
# 0s - loss: 1.2595 - k_smape: 77.2769 - val_loss: 1.3885 - val_k_smape: 86.0895
# Epoch 48/60
# 0s - loss: 1.3103 - k_smape: 81.0657 - val_loss: 1.4124 - val_k_smape: 86.9603
# Epoch 49/60
# 0s - loss: 1.2520 - k_smape: 75.6077 - val_loss: 1.3493 - val_k_smape: 86.8000
# Epoch 50/60
# 0s - loss: 1.2377 - k_smape: 78.0418 - val_loss: 1.3151 - val_k_smape: 84.6237
# Epoch 51/60
# 0s - loss: 1.2937 - k_smape: 77.2738 - val_loss: 1.3706 - val_k_smape: 88.1344
# Epoch 52/60
# 0s - loss: 1.2791 - k_smape: 79.6160 - val_loss: 1.4301 - val_k_smape: 88.7251
# Epoch 53/60
# 0s - loss: 1.2488 - k_smape: 76.4602 - val_loss: 1.3447 - val_k_smape: 87.3892
# Epoch 54/60
# 0s - loss: 1.2415 - k_smape: 76.4681 - val_loss: 1.3233 - val_k_smape: 85.6526
# Epoch 55/60
# 0s - loss: 1.2105 - k_smape: 76.3378 - val_loss: 1.2595 - val_k_smape: 86.5606
# Epoch 56/60
# 0s - loss: 1.2488 - k_smape: 76.3450 - val_loss: 1.4815 - val_k_smape: 86.3441
# Epoch 57/60
# 0s - loss: 1.2443 - k_smape: 76.6216 - val_loss: 1.2601 - val_k_smape: 85.1986
# Epoch 58/60
# 0s - loss: 1.2447 - k_smape: 77.7594 - val_loss: 1.2577 - val_k_smape: 84.2224
# Epoch 59/60
# 0s - loss: 1.2813 - k_smape: 74.4213 - val_loss: 1.4776 - val_k_smape: 90.1048
# Epoch 60/60
# 0s - loss: 1.2661 - k_smape: 77.5152 - val_loss: 1.4063 - val_k_smape: 83.9413
# --- Group: 6 / 6 ---
# Train on 45 samples, validate on 6 samples
# Epoch 1/80
# 0s - loss: 6.8766 - k_smape: 174.6686 - val_loss: 4.6625 - val_k_smape: 161.3589
# Epoch 2/80
# 0s - loss: 6.6411 - k_smape: 167.7718 - val_loss: 4.4003 - val_k_smape: 150.3509
# Epoch 3/80
# 0s - loss: 6.4648 - k_smape: 158.7205 - val_loss: 4.0651 - val_k_smape: 139.1992
# Epoch 4/80
# 0s - loss: 6.0672 - k_smape: 147.3108 - val_loss: 3.7471 - val_k_smape: 131.1801
# Epoch 5/80
# 0s - loss: 5.9033 - k_smape: 140.0899 - val_loss: 3.5066 - val_k_smape: 125.6536
# Epoch 6/80
# 0s - loss: 5.8672 - k_smape: 134.9758 - val_loss: 3.3485 - val_k_smape: 121.9965
# Epoch 7/80
# 0s - loss: 5.6385 - k_smape: 129.6616 - val_loss: 3.2713 - val_k_smape: 119.9671
# Epoch 8/80
# 0s - loss: 5.7031 - k_smape: 129.2581 - val_loss: 3.2223 - val_k_smape: 118.5073
# Epoch 9/80
# 0s - loss: 5.6547 - k_smape: 128.0546 - val_loss: 3.1871 - val_k_smape: 117.4069
# Epoch 10/80
# 0s - loss: 5.3002 - k_smape: 125.0900 - val_loss: 3.1474 - val_k_smape: 116.2985
# Epoch 11/80
# 0s - loss: 5.2397 - k_smape: 124.0552 - val_loss: 3.1030 - val_k_smape: 116.3254
# Epoch 12/80
# 0s - loss: 5.1562 - k_smape: 124.8882 - val_loss: 3.0375 - val_k_smape: 115.4927
# Epoch 13/80
# 0s - loss: 4.9510 - k_smape: 124.6970 - val_loss: 2.9591 - val_k_smape: 113.5750
# Epoch 14/80
# 0s - loss: 4.9303 - k_smape: 121.1816 - val_loss: 2.8820 - val_k_smape: 111.7644
# Epoch 15/80
# 0s - loss: 4.9289 - k_smape: 123.7193 - val_loss: 2.7719 - val_k_smape: 109.6723
# Epoch 16/80
# 0s - loss: 4.8901 - k_smape: 121.7628 - val_loss: 2.6663 - val_k_smape: 107.6264
# Epoch 17/80
# 0s - loss: 4.7386 - k_smape: 121.0358 - val_loss: 2.5911 - val_k_smape: 106.1159
# Epoch 18/80
# 0s - loss: 4.6032 - k_smape: 118.7684 - val_loss: 2.5016 - val_k_smape: 104.8691
# Epoch 19/80
# 0s - loss: 4.4706 - k_smape: 115.0674 - val_loss: 2.4958 - val_k_smape: 103.8546
# Epoch 20/80
# 0s - loss: 4.4951 - k_smape: 114.2754 - val_loss: 2.4890 - val_k_smape: 101.6053
# Epoch 21/80
# 0s - loss: 4.4224 - k_smape: 113.7937 - val_loss: 2.4405 - val_k_smape: 99.7072
# Epoch 22/80
# 0s - loss: 4.3827 - k_smape: 112.4185 - val_loss: 2.3513 - val_k_smape: 97.2746
# Epoch 23/80
# 0s - loss: 4.1968 - k_smape: 108.9386 - val_loss: 2.3245 - val_k_smape: 95.4896
# Epoch 24/80
# 0s - loss: 4.1488 - k_smape: 109.4096 - val_loss: 2.2659 - val_k_smape: 94.1051
# Epoch 25/80
# 0s - loss: 4.0934 - k_smape: 104.6748 - val_loss: 2.2349 - val_k_smape: 93.3478
# Epoch 26/80
# 0s - loss: 4.3747 - k_smape: 111.0151 - val_loss: 2.1372 - val_k_smape: 91.7653
# Epoch 27/80
# 0s - loss: 3.9577 - k_smape: 104.3746 - val_loss: 2.0451 - val_k_smape: 90.1951
# Epoch 28/80
# 0s - loss: 3.8827 - k_smape: 104.9567 - val_loss: 1.9680 - val_k_smape: 89.0110
# Epoch 29/80
# 0s - loss: 3.9880 - k_smape: 106.8821 - val_loss: 1.9022 - val_k_smape: 87.8410
# Epoch 30/80
# 0s - loss: 4.0764 - k_smape: 104.8113 - val_loss: 1.8816 - val_k_smape: 86.6069
# Epoch 31/80
# 0s - loss: 4.1476 - k_smape: 104.1388 - val_loss: 1.8335 - val_k_smape: 85.4350
# Epoch 32/80
# 0s - loss: 3.7094 - k_smape: 97.4251 - val_loss: 1.8179 - val_k_smape: 84.1292
# Epoch 33/80
# 0s - loss: 3.9725 - k_smape: 100.5842 - val_loss: 1.8484 - val_k_smape: 83.8101
# Epoch 34/80
# 0s - loss: 3.6423 - k_smape: 98.8142 - val_loss: 1.8772 - val_k_smape: 83.4716
# Epoch 35/80
# 0s - loss: 3.6427 - k_smape: 95.8351 - val_loss: 1.9731 - val_k_smape: 84.2470
# Epoch 36/80
# 0s - loss: 3.6898 - k_smape: 96.9831 - val_loss: 1.9567 - val_k_smape: 84.6721
# Epoch 37/80
# 0s - loss: 3.6530 - k_smape: 96.0893 - val_loss: 1.8356 - val_k_smape: 83.9870
# Epoch 38/80
# 0s - loss: 3.8138 - k_smape: 98.3901 - val_loss: 1.6608 - val_k_smape: 83.4920
# Epoch 39/80
# 0s - loss: 3.6079 - k_smape: 94.8910 - val_loss: 1.4945 - val_k_smape: 82.2005
# Epoch 40/80
# 0s - loss: 3.5181 - k_smape: 93.3928 - val_loss: 1.3627 - val_k_smape: 80.1750
# Epoch 41/80
# 0s - loss: 3.6019 - k_smape: 93.0534 - val_loss: 1.2667 - val_k_smape: 78.7950
# Epoch 42/80
# 0s - loss: 3.3694 - k_smape: 88.7626 - val_loss: 1.1855 - val_k_smape: 78.2104
# Epoch 43/80
# 0s - loss: 3.4219 - k_smape: 87.6924 - val_loss: 1.2097 - val_k_smape: 79.0192
# Epoch 44/80
# 0s - loss: 3.2977 - k_smape: 88.0404 - val_loss: 1.2928 - val_k_smape: 79.8603
# Epoch 45/80
# 0s - loss: 3.4015 - k_smape: 86.8995 - val_loss: 1.4555 - val_k_smape: 81.5159
# Epoch 46/80
# 0s - loss: 3.2536 - k_smape: 86.9442 - val_loss: 1.5603 - val_k_smape: 82.9957
# Epoch 47/80
# 0s - loss: 3.2015 - k_smape: 87.0201 - val_loss: 1.7329 - val_k_smape: 84.2241
# Epoch 48/80
# 0s - loss: 3.3973 - k_smape: 86.0441 - val_loss: 1.8082 - val_k_smape: 84.8635
# Epoch 49/80
# 0s - loss: 3.3523 - k_smape: 85.8772 - val_loss: 1.7194 - val_k_smape: 86.1149
# Epoch 50/80
# 0s - loss: 3.1432 - k_smape: 81.7544 - val_loss: 1.6576 - val_k_smape: 88.9315
# Epoch 51/80
# 0s - loss: 3.0046 - k_smape: 79.6935 - val_loss: 1.6747 - val_k_smape: 91.0137
# Epoch 52/80
# 0s - loss: 3.1285 - k_smape: 83.3108 - val_loss: 1.7053 - val_k_smape: 91.3602
# Epoch 53/80
# 0s - loss: 3.1962 - k_smape: 83.9265 - val_loss: 1.6471 - val_k_smape: 91.1521
# Epoch 54/80
# 0s - loss: 3.0284 - k_smape: 81.0924 - val_loss: 1.4633 - val_k_smape: 92.5467
# Epoch 55/80
# 0s - loss: 3.0420 - k_smape: 76.6604 - val_loss: 1.4208 - val_k_smape: 93.9175
# Epoch 56/80
# 0s - loss: 3.0486 - k_smape: 80.4618 - val_loss: 1.3413 - val_k_smape: 93.6127
# Epoch 57/80
# 0s - loss: 3.0361 - k_smape: 78.1016 - val_loss: 1.3853 - val_k_smape: 90.8549
# Epoch 58/80
# 0s - loss: 3.0576 - k_smape: 79.6671 - val_loss: 1.4492 - val_k_smape: 86.1087
# Epoch 59/80
# 0s - loss: 2.9685 - k_smape: 79.1721 - val_loss: 1.5148 - val_k_smape: 81.4241
# Epoch 60/80
# 0s - loss: 2.9889 - k_smape: 79.7840 - val_loss: 1.5936 - val_k_smape: 80.0800
# Epoch 61/80
# 0s - loss: 3.0057 - k_smape: 77.1007 - val_loss: 1.5043 - val_k_smape: 81.7577
# Epoch 62/80
# 0s - loss: 3.0662 - k_smape: 77.2051 - val_loss: 1.3833 - val_k_smape: 86.2040
# Epoch 63/80
# 0s - loss: 2.9313 - k_smape: 78.7029 - val_loss: 1.2832 - val_k_smape: 88.1827
# Epoch 64/80
# 0s - loss: 2.8500 - k_smape: 75.6524 - val_loss: 1.2898 - val_k_smape: 89.8007
# Epoch 65/80
# 0s - loss: 3.0533 - k_smape: 80.1311 - val_loss: 1.2362 - val_k_smape: 85.2104
# Epoch 66/80
# 0s - loss: 3.0336 - k_smape: 81.1513 - val_loss: 1.1305 - val_k_smape: 79.9265
# Epoch 67/80
# 0s - loss: 2.8812 - k_smape: 75.2650 - val_loss: 1.0394 - val_k_smape: 79.2563
# Epoch 68/80
# 0s - loss: 3.0155 - k_smape: 74.9389 - val_loss: 1.0105 - val_k_smape: 79.5500
# Epoch 69/80
# 0s - loss: 2.9809 - k_smape: 73.5883 - val_loss: 1.0585 - val_k_smape: 81.9018
# Epoch 70/80
# 0s - loss: 2.9511 - k_smape: 74.3271 - val_loss: 1.1048 - val_k_smape: 85.7024
# Epoch 71/80
# 0s - loss: 2.9650 - k_smape: 75.3645 - val_loss: 1.1826 - val_k_smape: 87.7857
# Epoch 72/80
# 0s - loss: 2.7591 - k_smape: 74.6439 - val_loss: 1.3334 - val_k_smape: 88.3815
# Epoch 73/80
# 0s - loss: 2.8802 - k_smape: 74.1648 - val_loss: 1.5376 - val_k_smape: 89.6723
# Epoch 74/80
# 0s - loss: 3.0258 - k_smape: 81.7017 - val_loss: 1.5484 - val_k_smape: 87.9841
# Epoch 75/80
# 0s - loss: 2.9718 - k_smape: 78.8759 - val_loss: 1.5502 - val_k_smape: 83.5053
# Epoch 76/80
# 0s - loss: 2.9974 - k_smape: 76.2266 - val_loss: 1.4509 - val_k_smape: 80.8399
# Epoch 77/80
# 0s - loss: 2.9770 - k_smape: 73.2329 - val_loss: 1.2979 - val_k_smape: 78.5360
# Epoch 78/80
# 0s - loss: 2.6109 - k_smape: 69.3959 - val_loss: 1.1515 - val_k_smape: 79.5942
# Epoch 79/80
# 0s - loss: 2.7223 - k_smape: 72.7835 - val_loss: 0.9540 - val_k_smape: 79.6921
# Epoch 80/80
# 0s - loss: 2.7151 - k_smape: 70.5129 - val_loss: 0.9387 - val_k_smape: 82.4769
# Wall time: 1h 23min 26s

# %% [markdown]
# ### Training History

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['loss'], label=str(run))
        plt.title('Mean Squared Error (Train) - Group ' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['val_loss'], label=str(run))
        plt.title('Mean Squared Error (Validation) - Group ' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['k_smape'], label=str(run))
        plt.title('SMAPE (Train) - Group ' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['val_k_smape'], label=str(run))
        plt.title('SMAPE (Validation) - Group ' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep:
        plt.plot(hist.history['loss'], label='train')
        plt.plot(hist.history['val_loss'], label='validation')
        plt.title('Mean Squared Error - ' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep:
        plt.plot(hist.history['k_smape'], label='train')
        plt.plot(hist.history['val_k_smape'], label='validation')
        plt.title('SMAPE - ' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['loss'], label=gp)
plt.title('Mean Squared Error - train')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['val_loss'], label=gp)
plt.title('Mean Squared Error - validation')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['k_smape'], label=gp)
plt.title('SMAPE - train')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['val_k_smape'], label=gp)
plt.title('SMAPE - validation')
plt.legend(); plt.show()

# %% [markdown]
# ### More Training

# %% [markdown]
# epochs_list2 = [0,10,0,0,10]

# %% [markdown]
# hists2 = []
# for (gp, model, X_in, Y_in, epochs) in zip(gp_list, models,
#                                    X_input_list, Y_input_list,
#                                    epochs_list2):
#     hist = model.fit(X_in, Y_in, batch_size=128,
#                      epochs=epochs,
#                      validation_split=0.05)
#     #validation_data=(X_val, Y_val))
#     hists2.append(hist)

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['loss'], label='train')
#         plt.plot(hist.history['val_loss'], label='validation')
#         plt.title('Mean Squared Error - ' + str(gp))
#         plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['k_smape'], label='train')
#         plt.plot(hist.history['val_k_smape'], label='validation')
#         plt.title('SMAPE - ' + str(gp))
#         plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['loss'], label=gp)
# plt.title('Mean Squared Error - train')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['val_loss'], label=gp)
# plt.title('Mean Squared Error - validation')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['k_smape'], label=gp)
# plt.title('SMAPE - train')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['val_k_smape'], label=gp)
# plt.title('SMAPE - validation')
# plt.legend(); plt.show()

# %% [markdown]
# ## Predict for Output Set

# %%
# %%time
Y_output_pred_list_ens = []
for models, run in zip(models_ens, ens_list):
    print('Run', run, end=': ')
    Y_output_pred_list = []
    for (gp, model, XZ, A) in zip(gp_list, models, XZ_output_list, A_output_list):
        print(gp, end=' ')
        Y_output_pred_list.append(model.predict([XZ, A]))
    Y_output_pred_list_ens.append(Y_output_pred_list)
    print('')
# Out:
# Run 0: 0 1 2 3 4 5
# Run 1: 0 1 2 3 4 5
# Run 2: 0 1 2 3 4 5
# Run 3: 0 1 2 3 4 5
# Run 4: 0 1 2 3 4 5
# Wall time: 1min 15s

# %% [markdown]
# Find the original index

# %%
output_index_range = np.arange(len(output_gp)); #output_index_range

# %%
# list for original index
output_index_list = [output_index_range[output_gp == gp] 
                     for gp in gp_list]

# %%
for o in output_index_list:
    print(o.shape, end=' ')
# Out:
# (1879,) (23085,) (43691,) (75617,) (740,) (51,)

# %%
output_index_list_comb = np.concatenate(output_index_list); #output_index_list_comb

# %%
Y_output_pred_ens = []
for Y_output_pred_list in Y_output_pred_list_ens:
    Y_output_pred_comb = np.concatenate(Y_output_pred_list)
    Y_output_pred = [0]*len(output_index_list_comb)

    for index, y in zip(output_index_list_comb, Y_output_pred_comb):
        Y_output_pred[index] = y

    Y_output_pred = np.array(Y_output_pred)  # make it an numpy array (which will also make a copy)
    Y_output_pred_ens.append(Y_output_pred)

del Y_output_pred_comb

# %%
# Inverse transform Y_output_pred to original Y
Y_output_pred_ori_ens = []
for Y_output_pred in Y_output_pred_ens:
    Y_output_pred_ori = unlog(untransform(Y_output_pred, 
                                          output_center, output_scale))
    Y_output_pred_ori_ens.append(Y_output_pred_ori)
Y_output_pred_ori_ens = np.array(Y_output_pred_ori_ens)
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.

# %%
# Inverse transform Y_output_pred to original Y
Y_output_pred_ori_ens = []
for Y_output_pred in Y_output_pred_ens:
    Y_output_pred_ori = unlog(untransform(Y_output_pred.astype('float64'), 
                                          output_center, output_scale))
    Y_output_pred_ori_ens.append(Y_output_pred_ori)
Y_output_pred_ori_ens = np.array(Y_output_pred_ori_ens)

# %% [markdown]
# Y_output_pred_ori_ens = Y_output_pred_ori_ens.astype('float32')

# %% [markdown]
# #### Check predict output

# %% [markdown]
# Y_output_pred

# %% [markdown]
# Y_output_pred_ori

# %% [markdown]
# examine(Y_output_pred)

# %% [markdown]
# examine(Y_output_pred_ori)

# %% [markdown]
# view(X_output_ori[126420])

# %% [markdown]
# ## SMAPE Scores

# %% [markdown]
# ### Model Score

# %%
# SMAPE scores for the model
if test_length:
    model_smape_ens = []
    model_smape_0_ens = []
    for Y_output_pred_ori in Y_output_pred_ori_ens:
        model_smape = smape(Y_output_raw, Y_output_pred_ori) # SMAPE score excluding nan (Correct one)
        model_smape_0 = smape(Y_output_ori, Y_output_pred_ori) # SMAPE assuming nan == 0
        print(model_smape, model_smape_0)
        
        model_smape_ens.append(model_smape)
        model_smape_0_ens.append(model_smape_0)
    model_smape_ens_mean = np.mean(model_smape_ens)
    model_smape_0_ens_mean = np.mean(model_smape_0_ens)
    print('-----------')
    print(model_smape_ens_mean, model_smape_0_ens_mean)
# Out:
# 43.4216709872 46.7662335703
# 44.8665830505 48.4170392554
# 42.3856009259 45.9936618077
# 42.7344966434 46.3873250254
# 42.9640607449 46.5882003781
# -----------
# 43.2744824704 46.8304920074

# %%
# SMAPE score for Fibonacci median
if test_length:
    fib_smape = smape(Y_output_raw, Y_output_fib)
    print(fib_smape)
# Out:
# 40.4041

# %% [markdown]
# ### Group Scores

# %%
# Prediction Y_output in group
Y_output_pred_ori_list_ens = [[Y_output_pred_ori[output_gp == gp] for gp in gp_list]
                              for Y_output_pred_ori in Y_output_pred_ori_ens]
#Y_output_pred_ori_list = [Y_output_pred_ori[output_gp == gp] for gp in gp_list]
Y_output_pred_ori_list = Y_output_pred_ori_list_ens[-1]  # in case you want to see one of them

# %%
# Fibonacci median in group
Y_output_fib_list = [Y_output_fib[output_gp == gp] for gp in gp_list]

# %%
# True Y_output in group
if test_length:
    # untransformed Y_output with nan replaced by 0
    Y_output_ori_list = [Y_output_ori[output_gp == gp] for gp in gp_list]
    
    # untransformed Y_output_ori with nan (for SMAPE estimation)
    Y_output_raw_list = [Y_output_raw[output_gp == gp] for gp in gp_list]

# %%
tot_n = len(output_gp); tot_n  # total number of pages in output set
# Out:
# 145063

# %%
def count_not_nan(data):
    return np.count_nonzero(~np.isnan(data))

# %% [markdown]
# if test_length: print(count_not_nan(Y_output_raw))

# %%
# Group scores for the model
if test_length:
    gp_n = [len(Y) for Y in Y_output_raw_list]
    # SMAPE assuming nan == 0
    #gp_smape_0 = [smape(Y, Y_p) for Y, Y_p 
    #              in zip(Y_output_ori_list, Y_output_pred_ori_list)]
    
    # SMAPE with nan values ignored (used by Kaggle)
    gp_smape_ens = [[smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_list)]
                    for Y_output_pred_ori_list in Y_output_pred_ori_list_ens]
    gp_smape = gp_smape_ens[-1]
    #gp_smape = [smape(Y, Y_p) for Y, Y_p 
    #            in zip(Y_output_raw_list, Y_output_pred_ori_list)]
    
    #n_not_nan = count_not_nan(Y_output_raw)
    #n_not_nan_gp = [count_not_nan(Y) for Y in Y_output_raw_list]
    #n_not_nan_ratio_gp = [n / (len(Y) * len(Y[0])) for Y,n 
    #                      in zip(Y_output_raw_list, n_not_nan_gp)]
    
    # SMAPE contribution
    #gp_smape_sum = [s * n for n, s in zip(gp_smape, n_not_nan_gp)]
    #gp_smape_cont = [s / n_not_nan for s in gp_smape_sum]

# %%
gp_smape_mean = np.mean(gp_smape_ens, axis=0); gp_smape_mean
# Out:
# array([ 159.35187353,   64.55167996,   43.19915552,   35.8236759 ,
#          43.98495056,   38.09155475])

# %%
# Group score for Fibonacci median
if test_length:
    gp_smape_fib = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_fib_list)]

# %%
if test_length:  # gp_score compare
    print('#### ' + model_name)
    print('', end='|')
    print('N_pages ', 'Fibonacci', ' Average ', sep='|', end='|')
    for run in ens_list: print(' Model', run, end=' |')
    print('')
    print('', end='|')
    print('--------', '---------', '---------', sep='|', end='|')
    for run in ens_list: print('---------', end='|')
    print('')
    for gp in gp_list:
        print('', end='|')
        print(' %6d ' % gp_n[gp], end='|')
        print(' %7.3f ' % gp_smape_fib[gp], end='|')
        print(' %7.3f ' % gp_smape_mean[gp], end='|')
        for run in ens_list:
            print(' %7.3f ' % gp_smape_ens[run][gp], end='|')
        print('')
    print('|  Total ', ' %7.3f ' % fib_smape, ' %7.3f ' % model_smape_ens_mean, sep='|', end='|')
    for run in ens_list:
            print(' %7.3f ' % model_smape_ens[run], end='|')
# Out:
# #### model_10_Modified_CNN_1_Z_2_2dim
# |N_pages |Fibonacci| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 159.352 | 135.240 | 158.578 | 164.300 | 171.268 | 167.373 |
# |  23085 |  61.354 |  64.552 |  65.863 |  64.358 |  64.197 |  64.473 |  63.868 |
# |  43691 |  40.612 |  43.199 |  43.329 |  44.678 |  42.223 |  43.185 |  42.581 |
# |  75617 |  34.284 |  35.824 |  36.045 |  37.941 |  34.745 |  34.744 |  35.643 |
# |    740 |  35.621 |  43.985 |  37.826 |  52.616 |  43.859 |  36.997 |  48.627 |
# |     51 |  20.224 |  38.092 |  38.679 |  43.013 |  45.262 |  36.894 |  26.609 |
# |  Total |  40.404 |  43.274 |  43.422 |  44.867 |  42.386 |  42.734 |  42.964 |

# %% [markdown]
# #### model_10_Modified_CNN_1_Z_2_2dim
# |N_pages |Fibonacci| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 159.352 | 135.240 | 158.578 | 164.300 | 171.268 | 167.373 |
# |  23085 |  61.354 |  64.552 |  65.863 |  64.358 |  64.197 |  64.473 |  63.868 |
# |  43691 |  40.612 |  43.198 |  43.329 |  44.675 |  42.223 |  43.185 |  42.581 |
# |  75617 |  34.284 |  35.824 |  36.045 |  37.941 |  34.745 |  34.744 |  35.643 |
# |    740 |  35.621 |  43.985 |  37.826 |  52.616 |  43.859 |  36.997 |  48.627 |
# |     51 |  20.224 |  38.092 |  38.679 |  43.013 |  45.262 |  36.894 |  26.609 |
# |  Total |  40.404 |  43.274 |  43.422 |  44.866 |  42.386 |  42.735 |  42.964 |
# #### model_10_Modified_CNN_1_Z
# |N_pages |Fibonacci| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 158.876 | 166.920 | 167.117 | 154.478 | 165.189 | 140.678 |
# |  23085 |  61.354 |  64.057 |  63.166 |  63.533 |  63.921 |  64.384 |  65.282 |
# |  43691 |  40.612 |  40.025 |  40.088 |  39.890 |  40.224 |  40.132 |  39.794 |
# |  75617 |  34.284 |  29.755 |  29.759 |  29.741 |  29.658 |  29.865 |  29.752 |
# |    740 |  35.621 |  33.983 |  33.411 |  33.945 |  34.447 |  34.013 |  34.100 |
# |     51 |  20.224 |  17.259 |  17.687 |  17.204 |  17.227 |  17.300 |  16.878 |
# |  Total |  40.404 |  38.937 |  38.881 |  38.869 |  38.897 |  39.122 |  38.914 |
# #### model_10_Modified_CNN_0_median_stdev_2_3_groups
# |N_pages |Fibonacci| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|
# |  24964 |  61.170 |  68.900 |  69.367 |  69.103 |  69.194 |  69.001 |  67.833 |
# |  43691 |  40.612 |  40.247 |  39.939 |  40.098 |  40.056 |  40.701 |  40.443 |
# |  76408 |  34.288 |  29.910 |  29.979 |  30.039 |  29.790 |  29.676 |  30.068 |
# |  Total |  40.404 |  39.140 |  39.154 |  39.194 |  39.062 |  39.169 |  39.119 |
# #### model_10_Modified_CNN_0_median_stdev
# |N_pages |Fibonacci| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 161.576 | 156.487 | 166.024 | 139.355 | 159.019 |
# |  23085 |  61.354 |  64.389 |  64.273 |  64.008 |  63.988 |  64.148 |
# |  43691 |  40.612 |  39.684 |  39.842 |  39.969 |  39.808 |  40.173 |
# |  75617 |  34.284 |  29.538 |  29.575 |  29.454 |  29.907 |  29.573 |
# |    740 |  35.621 |  33.564 |  33.710 |  33.397 |  33.666 |  33.965 |
# |     51 |  20.224 |  16.406 |  16.451 |  17.309 |  16.628 |  16.331 |
# #### model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3
# |N_pages |Fibonacci| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 161.230 | 166.806 | 139.008 | 152.935 | 170.833 |
# |  23085 |  61.354 |  64.048 |  63.281 |  63.966 |  63.664 |  63.569 |
# |  43691 |  40.612 |  40.004 |  39.860 |  40.201 |  39.817 |  40.143 |
# |  75617 |  34.284 |  30.201 |  29.582 |  29.611 |  29.744 |  29.618 |
# |    740 |  35.621 |  33.801 |  34.143 |  34.101 |  34.290 |  34.145 |
# |     51 |  20.224 |  16.933 |  17.094 |  16.930 |  17.424 |  16.985 |
#
# #### model_9_CNN_with_Fibonacci_4_Ensemble
# |N_pages |Fibonacci| Model 0 |
# |--------|---------|---------|
# |   1879 |  57.385 | 146.145 |
# |  23085 |  61.354 |  64.128 |
# |  43691 |  40.612 |  40.052 |
# |  75617 |  34.284 |  29.862 |
# |    740 |  35.621 |  34.607 |
# |     51 |  20.224 |  16.023 |

# %% [markdown]
# if test_length:
#     print('[Group SMAPE]')
#     print('W/ Nan, Nan=0, Contribution, Pages, Non-nan Ratio')
#     for score, score_0, c, n, nr in zip(gp_smape, gp_smape_0,
#                                     gp_smape_cont, gp_n,
#                                     n_not_nan_ratio_gp):
#         print('%6.2f' % score, '%6.2f' % score_0, '       %6.2f' % c, '%6d' % n,
#               '        %6.3f' % nr)
#     print('-------------------------------------------------')
#     print('%6.2f' % model_smape, '%6.2f' % model_smape_0)

# %% [markdown]
# n_not_nan_gp

# %% [markdown]
# ### Page Scores

# %%
if test_length:  # Page scores for the model
    smape_Y_pred_ens = []
    for Y_output_pred_ori in Y_output_pred_ori_ens:
        smape_Y_pred = np.nan_to_num(np.array([smape(yp, y) for yp, y 
                                               in zip(Y_output_pred_ori, Y_output_raw)]))
        smape_Y_pred_ens.append(smape_Y_pred)
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice
#   """

# %%
if test_length:  # Page score for Fib.
    smape_Y_fib = np.nan_to_num(np.array([smape(yp, y) for yp, y 
                                          in zip(Y_output_fib, Y_output_raw)]))
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice
#   """

# %% [markdown]
# if test_length:
#     for smape_Y_pred in smape_Y_pred_ens:
#         plt.hist(smape_Y_pred, bins=40, alpha=0.4)
#         #plt.yscale('log')
#     plt.title('Ensemble Page SMAPE'); plt.show()

# %%
if test_length:
    plt.hist(smape_Y_fib, bins=40, alpha=0.6, label='Fib.')
    plt.hist(smape_Y_pred, bins=40, alpha=0.6, label='Model')
    #plt.yscale('log')
    plt.legend(); plt.show()

# %% [markdown]
# ### Page Scores in Each Group

# %%
if test_length:  # The model
    smape_Y_pred_list_ens = []
    for smape_Y_pred in smape_Y_pred_ens:
        smape_Y_pred_list = [smape_Y_pred[output_gp == gp] for gp in gp_list]
        smape_Y_pred_list_ens.append(smape_Y_pred_list)

# %%
if test_length:  # Fib.
    smape_Y_fib_list = [smape_Y_fib[output_gp == gp] for gp in gp_list]

# %% [markdown]
# #### Plots

# %%
if test_length:
    for gp,s in zip(gp_list,smape_Y_pred_list):
        plt.hist(s, bins=40, normed=True, alpha=0.6, label='gp = ' + str(gp))
    #plt.yscale('log')
    plt.legend(); plt.show()

# %%
if test_length:
    for gp,s in zip(gp_list,smape_Y_pred_list):
        plt.hist(s, bins=40, alpha=0.6, label='gp = ' + str(gp))
    #plt.yscale('log')
    plt.legend(); plt.show()

# %%
if test_length:
    for gp in gp_list:
        plt.hist(smape_Y_fib_list[gp], bins=40, alpha=0.6, label='Fib.')
        plt.hist(smape_Y_pred_list[gp], bins=40, alpha=0.6, label='Model')
        plt.title('gp = '+str(gp)); plt.legend()
        plt.show()
    #plt.yscale('log')
    #plt.ylim([0,0.05])

# %% [markdown]
# ## Prediction Pre Combine
# Combine group 0, 1 from Fib and rest from the model

# %% [markdown]
# Y_output_fib.shape

# %%
Y_output_fib_ori = np.repeat(Y_output_fib, y_length, axis=1); Y_output_fib_ori.shape
# Out:
# (145063, 63)

# %%
# Select group 0 from Fib.
#fib_mask = (output_gp == 0).reshape(-1,1); fib_mask.shape
fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape
# Out:
# (145063, 1)

# %%
# The combined result
Y_output_fmc_ori_ens = []
for Y_output_pred_ori in Y_output_pred_ori_ens:
    
    Y_output_fmc_ori = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori
    
    Y_output_fmc_ori_ens.append(Y_output_fmc_ori)

# %% [markdown]
# Y_output_fmc_ori

# %% [markdown]
# #### Pre Combined Score

# %%
if test_length: 
    fmc_smape_ens = []
    for Y_output_fmc_ori in Y_output_fmc_ori_ens:
        fmc_smape = smape(Y_output_fmc_ori, Y_output_raw)
        fmc_smape_ens.append(fmc_smape)        
    fmc_smape_ens_mean = np.mean(fmc_smape_ens)
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.

# %%
if test_length: 
    for run, fmc_smape, model_smape in zip(ens_list, fmc_smape_ens, model_smape_ens):
        print('%6.3f' % fmc_smape, '(%6.3f)' % model_smape, '-', model_name, run)
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
# Out:
# 42.194 (43.422) - model_10_Modified_CNN_1_Z_2_2dim 0
# 43.692 (44.866) - model_10_Modified_CNN_1_Z_2_2dim 1
# 41.195 (42.386) - model_10_Modified_CNN_1_Z_2_2dim 2
# 41.453 (42.735) - model_10_Modified_CNN_1_Z_2_2dim 3
# 41.800 (42.964) - model_10_Modified_CNN_1_Z_2_2dim 4
# 42.067 (43.274) - model_10_Modified_CNN_1_Z_2_2dim Average

# %% [markdown]
# ## Ensemble Learning

# %% [markdown]
# ### Ensemble Median

# %%
Y_output_pred_ori_ens_med = np.median(Y_output_pred_ori_ens, axis=0)
Y_output_pred_ori_ens_med.shape
# Out:
# (145063, 63)

# %% [markdown]
# Y_output_pred_ori_ens_med

# %%
ens_med_smape = smape(Y_output_pred_ori_ens_med, Y_output_raw); ens_med_smape
# Out:
# 42.077374

# %% [markdown]
# Best ways seem to be taking median either before or after transformation.

# %% [markdown]
# ### Ensemble Combine with Fibonacci Median

# %% [markdown]
# #Select group 0, 1
# fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape

# %% [markdown]
# Y_output_pred_ori_ens_med

# %%
#Y_output_f_omean = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori_ens_mean
Y_output_f_omed  = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori_ens_med  # Our final output
#Y_output_f_meano = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ens_mean_ori
#Y_output_f_medo  = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ens_med_ori

# %% [markdown]
# ## All Model Scores

# %%
if test_length:  # Ensemble learning model score
    #f_omean_smape = smape(Y_output_raw, Y_output_f_omean)
    f_omed_smape = smape(Y_output_raw, Y_output_f_omed)
    #f_meano_smape = smape(Y_output_raw, Y_output_f_meano)
    #f_medo_smape = smape(Y_output_raw, Y_output_f_medo)

# %%
if test_length: # The_score with (without) combining Fibonacci median model
    #print('%6.3f         ' % f_omean_smape, '-', model_name, 'ori_ens_mean')
    print('%6.3f' % f_omed_smape, '(%6.3f)' % ens_med_smape,'-', model_name, 'ori_ensemble_median')
    #print('%6.3f         ' % f_meano_smape, '-', model_name, 'ens_mean_ori')
    #print('%6.3f         ' % f_medo_smape, '-', model_name, 'ens_med_ori')
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
    for run, fmc_smape, model_smape in zip(ens_list, fmc_smape_ens, model_smape_ens):
        print('%6.3f' % fmc_smape, '(%6.3f)' % model_smape, '-', model_name, run)
# Out:
# 40.735 (42.077) - model_10_Modified_CNN_1_Z_2_2dim ori_ensemble_median
# 42.067 (43.274) - model_10_Modified_CNN_1_Z_2_2dim Average
# 42.194 (43.422) - model_10_Modified_CNN_1_Z_2_2dim 0
# 43.692 (44.866) - model_10_Modified_CNN_1_Z_2_2dim 1
# 41.195 (42.386) - model_10_Modified_CNN_1_Z_2_2dim 2
# 41.453 (42.735) - model_10_Modified_CNN_1_Z_2_2dim 3
# 41.800 (42.964) - model_10_Modified_CNN_1_Z_2_2dim 4

# %% [markdown]
# 37.436          - model_10_Modified_CNN_0_median_stdev ori_ens_mean
# 37.382          - model_10_Modified_CNN_0_median_stdev ori_ens_med
# 37.394          - model_10_Modified_CNN_0_median_stdev ens_mean_ori
# 37.382          - model_10_Modified_CNN_0_median_stdev ens_med_ori
# 37.687 (38.816) - model_10_Modified_CNN_0_median_stdev Average

# %% [markdown]
# Ensemble of model are all better than the individual model.

# %% [markdown]
# fmc_smape_ens

# %% [markdown]
# fmc_smape_ens_mean

# %% [markdown]
#  Y_output_ori_list = [Y_output_ori[output_gp == gp] for gp in gp_list]

# %% [markdown]
# #### Combined Scores:
# 37.473          - model_10_Modified_CNN_1_Z ori_ensemble_median
#
# 37.535          - model_10_Modified_CNN_0_median_stdev_2_3_groups ori_ensemble_median
#
# 37.382          - model_10_Modified_CNN_0_median_stdev ori_ens_med
#
# 37.687 (38.816) - model_10_Modified_CNN_0_median_stdev Average
#
# 38.734 (39.415) - Model 9.1.0 - model_9_CNN_with_Fibonacci_1_no_group 1
#
# 38.227 (39.321) - Model 9.0.0 - model_9_CNN_with_Fibonacci_0_separate_Fib_median 1
#
# 43.009 (44.180) - Model 7.8.0 - model_7_CNN_with_Fibonacci_8_mean_absolute_error 2
#
# 44.070 (45.335) - Model 7.6.3 - model_7_CNN_with_Fibonacci_6_Wider_3_conv_120_Averagepool 1
#
# 44.473 (45.652) - Model 7.6.1 - model_7_CNN_with_Fibonacci_6_Wider_1_conv_120_Maxpool 1
#
# 44.433 - Model 7.5.0 - model_7_CNN_with_Fibonacci_5_Deeper_0_Initial
#
# 44.168 - Model 7.2.0

# %% [markdown]
# ## All Group Scores

# %%
# ensemble result Y_output in each group
#Y_output_pred_ori_ens_mean_list = [Y_output_pred_ori_ens_mean[output_gp == gp] for gp in gp_list]
Y_output_pred_ori_ens_med_list = [Y_output_pred_ori_ens_med[output_gp == gp] for gp in gp_list]
#Y_output_pred_ens_mean_ori_list = [Y_output_pred_ens_mean_ori[output_gp == gp] for gp in gp_list]
#Y_output_pred_ens_med_ori_list = [Y_output_pred_ens_med_ori[output_gp == gp] for gp in gp_list]

# %%
# Group SMAPE scores
if test_length:
    # SMAPE with nan values ignored (used by Kaggle)
    #gp_omean_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_ens_mean_list)]
    gp_omed_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_ens_med_list)]
    #gp_meano_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ens_mean_ori_list)]

# %%
if test_length:  # The_gp_score
    print('#### ' + model_name)
    print('', end='|')
    print(' N_pages', 'Fibonacci', 'Ens Media', ' Average ', sep='|', end='|')
    for run in ens_list: print(' Model', run, end=' |')
    print('')
    print('', end='|')
    print('--------', '---------', '---------', '---------', sep='|', end='|')
    for run in ens_list: print('---------', end='|')
    print('')
    for gp in gp_list:
        print('', end='|')
        print(' %6d ' % gp_n[gp], end='|')
        print(' %7.3f ' % gp_smape_fib[gp], end='|')
        #print(' %7.3f ' % gp_omean_smape[gp], end='|')
        print(' %7.3f ' % gp_omed_smape[gp], end='|')
        #print(' %7.3f ' % gp_meano_smape[gp], end='|')
        #print(' %7.3f ' % gp_medo_smape[gp], end='|')
        print(' %7.3f ' % gp_smape_mean[gp], end='|')
        for run in ens_list:
            print(' %7.3f ' % gp_smape_ens[run][gp], end='|')
        print('')
    print('|Over All', ' %7.3f ' % fib_smape, ' %7.3f ' % f_omed_smape,
          ' %7.3f ' % model_smape_ens_mean, sep='|', end='|')
    for run in ens_list:
            print(' %7.3f ' % model_smape_ens[run], end='|')

# Note The over all score for ensemble median (Ens Media) is the one after combining with 
# Fibonacci median model not the total score
# Out:
# #### model_10_Modified_CNN_1_Z_2_2dim
# | N_pages|Fibonacci|Ens Media| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 190.165 | 159.352 | 135.240 | 158.578 | 164.300 | 171.268 | 167.373 |
# |  23085 |  61.354 |  63.966 |  64.552 |  65.863 |  64.358 |  64.197 |  64.473 |  63.868 |
# |  43691 |  40.612 |  41.120 |  43.198 |  43.329 |  44.675 |  42.223 |  43.185 |  42.581 |
# |  75617 |  34.284 |  34.521 |  35.824 |  36.045 |  37.941 |  34.745 |  34.744 |  35.643 |
# |    740 |  35.621 |  43.971 |  43.985 |  37.826 |  52.616 |  43.859 |  36.997 |  48.627 |
# |     51 |  20.224 |  38.664 |  38.092 |  38.679 |  43.013 |  45.262 |  36.894 |  26.609 |
# |Over All|  40.404 |  40.735 |  43.274 |  43.422 |  44.866 |  42.386 |  42.735 |  42.964 |

# %% [markdown]
# #### model_10_Modified_CNN_0_median_stdev_2_3_groups
# | N_pages|Fibonacci|Ens Media| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|
# |  24964 |  61.170 |  68.909 |  68.900 |  69.367 |  69.103 |  69.194 |  69.001 |  67.833 |
# |  43691 |  40.612 |  39.821 |  40.247 |  39.939 |  40.098 |  40.056 |  40.701 |  40.443 |
# |  76408 |  34.288 |  29.400 |  29.910 |  29.979 |  30.039 |  29.790 |  29.676 |  30.068 |
# |Over All|  40.404 |  37.535 |  39.140 |  39.154 |  39.194 |  39.062 |  39.169 |  39.119 |
# #### model_10_Modified_CNN_0_median_stdev
# | N_pages|Fibonacci| ori mean|ori media| mean ori|media ori| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 199.741 | 172.496 | 191.624 | 172.496 | 161.576 | 156.487 | 166.024 | 139.355 | 159.019 |
# |  23085 |  61.354 |  64.110 |  64.122 |  64.116 |  64.122 |  64.389 |  64.273 |  64.008 |  63.988 |  64.148 |
# |  43691 |  40.612 |  39.620 |  39.564 |  39.574 |  39.564 |  39.684 |  39.842 |  39.969 |  39.808 |  40.173 |
# |  75617 |  34.284 |  29.300 |  29.231 |  29.248 |  29.231 |  29.538 |  29.575 |  29.454 |  29.907 |  29.573 |
# |    740 |  35.621 |  33.403 |  33.482 |  33.373 |  33.482 |  33.564 |  33.710 |  33.397 |  33.666 |  33.965 |
# |     51 |  20.224 |  16.360 |  16.338 |  16.361 |  16.338 |  16.406 |  16.451 |  17.309 |  16.628 |  16.331 |
# #### model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3
# | N_pages|Fibonacci| ori mean|ori media| mean ori|media ori| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 199.921 | 173.799 | 189.346 | 173.799 | 161.230 | 166.806 | 139.008 | 152.935 | 170.833 |
# |  23085 |  61.354 |  63.635 |  63.651 |  63.644 |  63.651 |  64.048 |  63.281 |  63.966 |  63.664 |  63.569 |
# |  43691 |  40.612 |  39.693 |  39.628 |  39.637 |  39.628 |  40.004 |  39.860 |  40.201 |  39.817 |  40.143 |
# |  75617 |  34.284 |  29.444 |  29.368 |  29.381 |  29.368 |  30.201 |  29.582 |  29.611 |  29.744 |  29.618 |
# |    740 |  35.621 |  33.858 |  33.893 |  33.837 |  33.893 |  33.801 |  34.143 |  34.101 |  34.290 |  34.145 |
# |     51 |  20.224 |  16.861 |  16.948 |  16.856 |  16.948 |  16.933 |  17.094 |  16.930 |  17.424 |  16.985 |

# %% [markdown]
# ## More Explore

# %% [markdown]
# ### Group Models in other Groups

# %%
# %%time
smape_gpm_gp_ens = []
for run in ens_list:
    print('Run', run)
    models = models_ens[run]
    Y_output_all_ori_list = unlog(np.array([untransform(model.predict([XZ_output, A_output]), 
                                                        output_center, output_scale) 
                                            for model in models]))
    # row: model of the group; column: group of Y
    smape_gpm_gp = [[smape(Y, Y_p[output_gp == gp]) for gp, Y in zip(gp_list, Y_output_raw_list)] 
                    for Y_p in Y_output_all_ori_list]
    smape_gpm_gp_ens.append(smape_gpm_gp)
# Out:
# Run 0
# Run 1
# c:\python3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.
# c:\python3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in true_divide
#   after removing the cwd from sys.path.
# Run 2
# Run 3
# Run 4
# Wall time: 6min 32s

# %%
smape_gpm_gp_ens = np.array(smape_gpm_gp_ens)

# %%
smape_gpm_gp_mean = np.mean(smape_gpm_gp_ens, axis=0)

# %%
print('Ensemble avg  ', end='|')
for j in range(len(smape_gpm_gp_mean[0])): print(' group', j, end='|')
print('')
print('--------------', end='|')
for j in range(len(smape_gpm_gp_mean[0])): print('--------', end='|')
print('')
for i in range(len(smape_gpm_gp_mean)):
    print('group model', i, end=' |')
    for j in range(len(smape_gpm_gp_mean[0])):
        print(' %6.2f ' % smape_gpm_gp_mean[i][j], end='|')
    print('')
# Out:
# Ensemble avg  | group 0| group 1| group 2| group 3| group 4| group 5|
# --------------|--------|--------|--------|--------|--------|--------|
# group model 0 | 159.35 |  61.38 |  40.63 |  34.31 |  35.68 |  20.22 |
# group model 1 | 157.66 |  64.55 |  41.93 |  35.85 |  41.33 |  20.21 |
# group model 2 | 162.11 |  66.49 |  43.20 |  34.36 |  37.78 |  29.65 |
# group model 3 | 163.95 |  68.10 |  45.69 |  35.82 |  43.15 |  27.69 |
# group model 4 | 117.50 |  74.64 |  50.48 |  40.34 |  43.98 |  35.92 |
# group model 5 | 162.46 |  76.65 |  56.21 |  48.36 |  53.20 |  38.09 |

# %% [markdown]
# Only group model 2 and 3 are useful

# %%
for x in gp_omed_smape: print(' %6.2f ' % x, end='|')
# Out:
#  190.16 |  63.97 |  41.12 |  34.52 |  43.97 |  38.66 |

# %%
for x in gp_smape_fib: print(' %6.2f ' % x, end='|')
# Out:
#   57.39 |  61.35 |  40.61 |  34.28 |  35.62 |  20.22 |

# %% [markdown]
# Group 4 is better at group 3 model. Group 5 is better at group 2 or 3 model

# %% [markdown]
# ## Optimize Group Models

# %%
gpm_list = np.argmin(smape_gpm_gp_mean,axis=0)

# %%
gpm_list
# Out:
# array([4, 0, 0, 0, 0, 1], dtype=int64)

# %%
# %%time
Y_output_all_ori_list_ens = unlog(np.array([[untransform(model.predict([XZ_output, A_output]), 
                                                         output_center, output_scale) 
                                            for model in models] for models in models_ens]))
#Take 7 min on PC and NB
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in power
#   after removing the cwd from sys.path.
# Wall time: 6min 30s

# %%
Y_output_all_ori_list_ens.shape
# Out:
# (5, 6, 145063, 63)

# %%
Y_output_all_ori_list_ens_med = np.median(Y_output_all_ori_list_ens, axis=0); Y_output_all_ori_list_ens_med.shape
# Out:
# (6, 145063, 63)

# %%
gpm_mask = np.array([gpm_list == gp for gp in gp_list]).T; gpm_mask
# Out:
# array([[False, False, False, False,  True, False],
#        [ True, False, False, False, False, False],
#        [ True, False, False, False, False, False],
#        [ True, False, False, False, False, False],
#        [ True, False, False, False, False, False],
#        [False,  True, False, False, False, False]], dtype=bool)

# %%
Y_output_ori_list_ens_med_temp = np.tensordot(gpm_mask, Y_output_all_ori_list_ens_med, axes=([1],[0]))

# %%
gp_mask = np.array([output_gp == gp for gp in gp_list]); gp_mask
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False,  True, ..., False,  True, False],
#        [ True,  True, False, ...,  True, False,  True],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %%
gp_mask_reshape = gp_mask.reshape(len(gp_mask),len(gp_mask[0]),1); gp_mask_reshape.shape
# Out:
# (6, 145063, 1)

# %%
Y_output_ori_list_ens_med_temp_mask = gp_mask_reshape * Y_output_ori_list_ens_med_temp

# %%
Y_output_ori_list_ens_med_temp_mask.shape
# Out:
# (6, 145063, 63)

# %%
Y_output_gpm_ens_med = np.sum(Y_output_ori_list_ens_med_temp_mask, axis=0)

# %%
Y_output_gpm_ens_med.shape
# Out:
# (145063, 63)

# %%
gpm_ens_smape = smape(Y_output_raw, Y_output_gpm_ens_med)

# %%
gpm_ens_smape, ens_med_smape
# Out:
# (40.848492, 42.077374)

# %% [markdown]
# #### Group scores

# %%
Y_output_gpm_ens_med_list = [Y_output_gpm_ens_med[output_gp == gp] for gp in gp_list]

# %%
# Group SMAPE scores
if test_length:
    gp_gpm_ens_med_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_gpm_ens_med_list)]

# %%
if test_length:
    #print('#### ' + model_name + 'group model optimized')
    #print('', end='|')
    print(' N_pages', 'Fibonacci', 'GPM Optim', 'Ens Media', ' Average ', sep='|', end='|')
    #or run in ens_list: print(' Model', run, end=' |')
    print('')
    print('', end='|')
    print('--------', '---------', '---------', '---------', '---------', sep='|', end='|')
    #for run in ens_list: print('---------', end='|')
    print('')
    for gp in gp_list:
        print('', end='|')
        print(' %6d ' % gp_n[gp], end='|')
        print(' %7.3f ' % gp_smape_fib[gp], end='|')
        print(' %7.3f ' % gp_gpm_ens_med_smape[gp], end='|')
        print(' %7.3f ' % gp_omed_smape[gp], end='|')
        print(' %7.3f ' % gp_smape_mean[gp], end='|')
        print('')
    #print('|Over All', ' %7.3f ' % fib_smape, ' %7.3f ' % f_omed_smape,
    #      ' %7.3f ' % model_smape_ens_mean, sep='|', end='|')    
# Note The over all score for ensemble median (Ens Media) is the one after combining with 
# Fibonacci median model not the total score
# Out:
#  N_pages|Fibonacci|GPM Optim|Ens Media| Average |
# |--------|---------|---------|---------|---------|
# |   1879 |  57.385 | 117.766 | 190.165 | 159.352 |
# |  23085 |  61.354 |  61.367 |  63.966 |  64.552 |
# |  43691 |  40.612 |  40.620 |  41.120 |  43.199 |
# |  75617 |  34.284 |  34.294 |  34.521 |  35.824 |
# |    740 |  35.621 |  35.641 |  43.971 |  43.985 |
# |     51 |  20.224 |  18.857 |  38.664 |  38.092 |

# %% [markdown]
# All of them are worse than Fib.

# %% [markdown]
# #### Combined with Fib.

# %%
#Select group 0
fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape
#fib_mask = (output_gp == 0).reshape(-1,1); fib_mask.shape

# %%
Y_output_f_gpm = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_gpm_ens_med  # Our final output

# %%
f_gpm_ens_smape = smape(Y_output_raw, Y_output_f_gpm)

# %%
print('%6.3f' % f_gpm_ens_smape, '(%6.3f)' % gpm_ens_smape, '-', model_name, 'GPM Optim Ens')

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Group model examination

# %%
Y_output_all_ori_list_ens_med.shape

# %% [markdown]
# #### Group = 5

# %%
gp = 5
Y_list = Y_output_all_ori_list_ens_med[:, output_gp == gp]

# %%
Y_list.shape

# %%
view_list = np.sort(np.random.choice(len(Y_list[0]), 5, replace=False)); view_list

# %%
print('Group ' + str(gp))
for i in view_list:
    print('i = ', i)
    plt.plot(Y_output_ori_list[gp][i], label='true')
    for gpm in gp_list:
        plt.plot(Y_list[gpm, i], label='gpm '+ str(gpm))
    plt.legend()
    plt.show()

# %%
orinal_view_list = np.arange(len(output_gp))[output_gp == gp][view_list];
np.array([view_list, orinal_view_list])

# %%
np.array([fib_input_median[orinal_view_list], fib_output_median[orinal_view_list]])

# %% [markdown]
# #### Group = 4

# %%
gp = 4
Y_list = Y_output_all_ori_list_ens_med[:, output_gp == gp]

# %%
Y_list.shape

# %%
view_list = np.sort(np.random.choice(len(Y_list[0]), 5, replace=False)); view_list

# %%
output_log_std_p = [1.]

# %%
print('Group ' + str(gp))
for i in view_list:
    print('i = ', i)
    plt.plot(Y_output_ori_list[gp][i], label='true')
    for gpm in gp_list:
        plt.plot(Y_list[gpm, i], label='gpm '+ str(gpm))
    plt.legend()
    plt.show()

# %%
print('Group ' + str(gp))
for i in view_list:
    print('i = ', i)
    plt.plot(Y_output_ori_list[gp][i], label='true')
    for gpm in gp_list:
        plt.plot(Y_list[gpm, i], label='gpm '+ str(gpm))
    plt.yscale('log')
    plt.legend(); plt.show()

# %%
orinal_view_list = np.arange(len(output_gp))[output_gp == gp][view_list];
np.array([view_list, orinal_view_list])

# %%
np.array([fib_input_median[orinal_view_list], fib_output_median[orinal_view_list]])

# %% [markdown]
# #### Case 131296

# %%
i = 131296

# %%
multi_view((Y_output_ori[i],Y_output_pred_ori[i]))

# %% [markdown]
# ### Cases study

# %%
view_list=[93175, 13986, 5464, 89589, 119659, 64392, 73856, 140331, 19234, 25591]

# %% [markdown]
# view_list = examine_list_gp((Y_output_ori,
#                              Y_output_pred_ori_ens_mean,
#                              Y_output_pred_ori_ens_med,
#                              Y_output_pred_ori_ens[-1],
#                              ), output_gp, view_list=view_list)

# %% [markdown]
# i = 93175
# plt.plot(Y_output_ori[i], label='true')
# plt.plot(Y_output_pred_ori_ens_mean[i], label='ens mean')
# plt.plot(Y_output_pred_ori_ens_med[i], label='ens median')
# plt.plot(Y_output_pred_ens_mean_ori[i], label='ens mean before transf')
# plt.plot(Y_output_pred_ens_med_ori[i], label='ens median before transf')
# plt.plot(Y_output_pred_ori_ens[-1][i], label='run: 4')
# plt.title('i = ' + str(i) + ' gp = ' + str(output_gp[i]))
# plt.legend()
# plt.show()

# %% [markdown]
# i = 93175
# plt.plot(Y_output_ori[i], label='true')
# for run in ens_list:
#     plt.plot(Y_output_pred_ori_ens[run][i], label='run' + str(run))
# plt.plot(Y_output_pred_ens_mean_ori[i], label='ens mean before transf')
# plt.title('i = ' + str(i) + ' gp = ' + str(output_gp[i]))
# plt.legend()
# plt.show()

# %%
view_list = examine_list_gp((Y_output_pred_ori_ens[-1], 
                             Y_output_pred_ori_ens_med,
                             Y_output_f_gpm, 
                             Y_output_ori), output_gp, view_list=view_list)

# %% [markdown]
# view_list = comp_examine(X_output, Y_output_pred, view_list=view_list)

# %% [markdown]
# view_list = comp_examine(X_output_ori, Y_output_pred_ori, view_list=view_list)

# %%
view_list = examine_list_gp((Y_output_pred_ori, X_output_ori, Y_input_ori), output_gp, view_list=view_list)

# %%
view_list = examine_list_gp((Y_output_pred_ori, X_output_ori, Y_input_ori), output_gp, view_list=view_list)

# %% [markdown]
# view_list = examine_list_gp((Y_output_pred, X_output, Y_input), output_gp, view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list((Y_output_pred, Y_output, X_output), view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list((Y_output_pred_ori, Y_output_ori, X_output_ori), view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list_gp((Y_output_pred, Y_output, X_output), output_gp,
#                              view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori), output_gp,
#                              view_list=view_list)

# %% [markdown]
# view_list_smape = [smape(Y_output_pred_ori[i], Y_output_raw[i]) for i in view_list]; view_list_smape

# %% [markdown]
# view_list_review = [score < model_smape for score in view_list_smape]; view_list_review

# %% [markdown]
# view_list_good = list(np.array(view_list)[view_list_review]); view_list_good

# %% [markdown]
# view_list_bad = list(np.array(view_list)[~np.array(view_list_review)]); view_list_bad

# %% [markdown]
# #### Good cases

# %% [markdown]
# examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori), output_gp,
#              view_list=view_list_good)

# %% [markdown]
# #### Bad cases

# %% [markdown]
# examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori),output_gp,
#              view_list=view_list_bad)

# %% [markdown]
# print(output_center[view_list_good].reshape(-1))
# print(output_center[view_list_bad].reshape(-1))

# %% [markdown]
# print(output_scale[view_list_good].reshape(-1))
# print(output_scale[view_list_bad].reshape(-1))

# %% [markdown]
# output_gp[view_list_good]

# %% [markdown]
# output_gp[view_list_bad]

# %% [markdown]
# #### Case 93175

# %% [markdown]
# i = 93175

# %% [markdown]
# multi_view((Y_output_pred_ori[i], Y_output_ori[i], X_output_ori[i]), yscale='log')
# multi_view((Y_output_pred_ori[i], Y_output_ori[i], X_output_ori[i]))

# %% [markdown]
# smape(Y_output_pred_ori[i], Y_output_raw[i])

# %% [markdown]
# input_center[i], output_center[i], input_scale[i], output_scale[i]

# %% [markdown]
# #### Case 41896

# %% [markdown]
# i = 41896

# %% [markdown]
# multi_view((X_input[i], Y_input[i]))

# %% [markdown]
# comp_view(X_input_ori[i], Y_input_ori[i])

# %% [markdown]
# comp_view(X_output_ori[i], Y_output_pred_ori[i])

# %% [markdown]
# comp_view(X_input_ori[i], Y_input_ori[i])

# %% [markdown]
# ### Good and bad cases

# %% [markdown]
# review_Y = np.array([score < model_smape for score in smape_Y_pred])
# good_Y_index = np.arange(len(Y_output_pred))[review_Y]; #good_Y_index
# bad_Y_index = np.arange(len(Y_output_pred))[~review_Y]; #bad_Y_index

# %% [markdown]
# good_input_scale = input_scale[good_Y_index]
# good_output_scale = output_scale[good_Y_index]
# bad_input_scale = input_scale[bad_Y_index]
# bad_output_scale = output_scale[bad_Y_index]

# %% [markdown]
# good_input_center = input_center[good_Y_index]
# good_output_center = output_center[good_Y_index]
# bad_input_center = input_center[bad_Y_index]
# bad_output_center = output_center[bad_Y_index]

# %% [markdown]
# examine_list_gp((Y_output_pred_ori[good_Y_index], Y_output_ori[good_Y_index], X_output_ori[good_Y_index]), output_gp[good_Y_index])

# %% [markdown]
# examine_list_gp((Y_output_pred_ori[bad_Y_index], Y_output_ori[bad_Y_index], X_output_ori[bad_Y_index]), output_gp[bad_Y_index])

# %% [markdown]
# good_output_scale.min(), good_output_scale.max()

# %% [markdown]
# bad_output_scale.min(), bad_output_scale.max()

# %% [markdown]
# plt.hist(good_input_scale, bins=40, alpha=0.6, label='good input')
# plt.hist(bad_input_scale, bins=40, alpha=0.6, label='bad input')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_output_scale, bins=40, alpha=0.6, label='good output')
# plt.hist(bad_output_scale, bins=40, alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_input_scale, bins=40, alpha=0.6, label='good input')
# plt.hist(bad_input_scale, bins=40, alpha=0.6, label='bad input')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_output_scale, bins=40, alpha=0.6, label='good output')
# plt.hist(bad_output_scale, bins=40, alpha=0.6, label='bad output')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(good_input_scale, bins=100, range=(0,0.8), alpha=0.6, label='good input')
# plt.hist(good_output_scale, bins=100, range=(0,0.8), alpha=0.6, label='good output')
# plt.hist(bad_input_scale, bins=100, range=(0,0.8), alpha=0.6, label='bad input')
# plt.hist(bad_output_scale, bins=100, range=(0,0.8), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# Should we split the data into std > and < 1.7 ?

# %% [markdown]
# np.mean(good_output_scale), np.mean(good_input_scale)

# %% [markdown]
# np.mean(bad_output_scale), np.mean(bad_input_scale)

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(bad_input_scale, bins=60, range=(0,0.8), alpha=0.6, label='bad input')
# plt.hist(bad_output_scale, bins=60, range=(0,0.8), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(output_scale, bins=40, alpha=0.6, label='output')
# plt.hist(input_scale, bins=40, alpha=0.6, label='input')
# plt.legend()
# plt.show()

# %% [markdown]
# np.histogram(output_scale, bins=np.arange(0,1,0.05))

# %% [markdown]
# #### Median

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(good_input_center, bins=100, range=(0,5), alpha=0.6, label='good input')
# plt.hist(good_output_center, bins=100, range=(0,5), alpha=0.6, label='good output')
# plt.hist(bad_input_center, bins=100, range=(0,5), alpha=0.6, label='bad input')
# plt.hist(bad_output_center, bins=100, range=(0,5), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# ### stdev/median

# %% [markdown]
# output_factor_1 = (output_center / output_scale).reshape(-1); output_factor_1

# %% [markdown]
# output_factor_1.min(), output_factor_1.max()

# %% [markdown]
# plt.hist(output_factor_1, bins=40, range=[0,50], alpha=0.6)
# plt.show()

# %% [markdown]
# plt.scatter(smape_Y_pred, output_scale, alpha=0.1, marker='.')
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_center, alpha=0.1, marker='.')
# plt.ylim([-0.1,5])
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_scale, alpha=0.1, marker='.')
# plt.ylim([0,0.5])
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(output_scale, output_center, alpha=0.1, marker='.')
# plt.ylim([0,4.5])
# plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_2 = (output_scale / output_center).reshape(-1); output_factor_2

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_2, alpha=0.1, marker='.')
# plt.ylim([0,0.8])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_3 = (output_scale / (output_center + 0.01)).reshape(-1); output_factor_3

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_3, alpha=0.1, marker='.')
# plt.ylim([0,4])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_4 = output_scale - input_scale

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_4, alpha=0.1, marker='.')
# plt.ylim([-1.5,0.5])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# ## Output Prediction
# For predicting stage only

# %% [markdown]
# ### Result DataFrame

# %% [markdown]
# predict_dates_index=pd.date_range(Y_output_first_day,
#                                   periods=np.timedelta64(y_length,'D'),
#                                   freq = 'D', unit = 'D')
# predict_dates_index

# %%
Y_output_dates

# %%
if test_length == 0:
    result_df = pd.DataFrame(Y_output_f_omed, columns = Y_output_dates)  # using ensemble median combined result
result_df

# %%
result_df['Page'] = input_df['Page']  # Append 'Page' column from input_df
result_df

# %%
result_flat_df = pd.melt(result_df, id_vars='Page', var_name='date',
                         value_name='Visits')
result_flat_df

# %% [markdown]
# ### Output DataFrame

# %%
if test_length == 0:
    print('%%% Reading data key_2.csv ...', end = '', flush = True)
    output_df = pd.read_csv("../data/key_2.csv")
    print('done!')

# %%
output_df['date'] = output_df.Page.apply(lambda a: a[-10:])  # take the last 10 characters from 'Page' as date
output_df['Page'] = output_df.Page.apply(lambda a: a[:-11])  # remove the last 10 caharacters from 'Page'
#output_df['date'] = output_df['date'].astype('datetime64[ns]')  # convert 'date' string to numpy datetime format
#test['weekday'] = test.date.dt.dayofweek  # find the day of week using the 'date' column
output_df.head()

# %%
output_df.info()

# %%
output_df['date'].values[0:62]  # Make sure the range is 60 days (see if the dates resume after 60)

# %%
Y_output_dates

# %%
output_df = output_df.merge(result_flat_df, how='left')  # fill the 'Visits" from result
output_df

# %%
del result_flat_df

# %%
gc.collect()

# %%
#Check if there is null value
output_df.loc[output_df.Visits.isnull(), 'Visits']

# %%
#output_df.loc[output_df.Visits.isnull(), 'Visits'] = 0.0  # Uncommend this line to Replace NaN with 0.0

# %%
print('%%% Writing result for ' + model_name + ' ...', 
      end = '', flush = True)
#Write only the 'Id' and 'Visits' to the result file
output_df[['Id','Visits']].to_csv('../results/submit_1_' + model_name
                                  + '.csv', index = False, 
                                  float_format='%.3f')
print('done!')

# %% [markdown]
# Kaggle LB Score:
#
# [6.0.0] 46.3 [Model 6.0.0 CNN - Conv(60, 7)-FC(120)-Drop(0.25)-FC(120)-Drop(0.5)-Linear, 20 epoches]
#
# [6.1.0] 46.7 [Model 6.1.0 CNN - Conv(30, 7)-Conv(60, 7)-FC(120)-Drop(0.25)-FC(120)-Drop(0.5)-Linear, 20 epoches]
#
# [7.1.2] 47.3 [Model 7.1.2 CNN Fibonacci - range corrected :-y_length - score corrected]
#
# [7.2.0] 46.5 [Model 7.2.0 CNN Fibonacci and original combined]
