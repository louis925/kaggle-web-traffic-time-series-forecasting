# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# ### Kaggle - Web Traffic Time Series Forecasting
#
# ## Model 10 - Modified CNN with Fibonacci
#
# ### v0 with second input of median and stdev
#
# by Louis Yang
#
# Use Fibonacci series median instead of median. The Fib. median are now compute on both training and CV set separately.
#
# Split into groups based on the scale of visit number and train individual model in each group
#
# The first 2 groups use original Fibonacci median as prediction. The rest groups use the trained CNN as prediction.
#
# v0 Feed second input (median and stdev) to the neural network after the CNN part.
#
# v0.3 Merge the original 0 and 1 groups and 4, 5 groups. Original 2,3 groups split into 2 based on stdev(> 1.7). Total number of groups is 6.
#
# Test on stage 2 data.
#
# Original model: 'model_10_Modified_CNN_0_median_stdev'
#
# Ensemble: automatically evaluate the same model 4 times

# %%
model_name = 'model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import gc  # Python garbage collect
from tools import *

# %% [markdown]
# ## Input

# %%
train_file = 'train_2.csv'

# %%
print('%%% Reading data '+ train_file + ' ... ', end = '', flush = True)
input_df = pd.read_csv('../data/' + train_file)
print('done!')
# Out:
# %%% Reading data train_2.csv ... done!

# %% [markdown]
# input_df.head()

# %% [markdown]
# input_df.info()

# %%
input_df_dates = input_df.columns[1:]; #input_df_dates

# %%
input_df_temp = input_df[input_df_dates].astype('float32')

# %%
input_df_temp['Page'] = input_df['Page']

# %%
input_df = input_df_temp
del input_df_temp

# %%
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145063 entries, 0 to 145062
# Columns: 794 entries, 2015-07-01 to Page
# dtypes: float32(793), object(1)
# memory usage: 439.9+ MB

# %%
input_df_dates = input_df.columns[:-1]; input_df_dates
# Out:
# Index(['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04', '2015-07-05',
#        '2015-07-06', '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10',
#        ...
#        '2017-08-22', '2017-08-23', '2017-08-24', '2017-08-25', '2017-08-26',
#        '2017-08-27', '2017-08-28', '2017-08-29', '2017-08-30', '2017-08-31'],
#       dtype='object', length=793)

# %% [markdown]
# ## Processing Data
# Generate training set and test (predict) set

# %% [markdown]
# ### Day of week alignment

# %%
from datetime import datetime
def weekday(datestr):
    return datetime.strptime(datestr,'%Y-%m-%d').weekday()
def daydiff(dstr1,dstr2):
    return datetime.strptime(dstr1,'%Y-%m-%d') - datetime.strptime(dstr2,'%Y-%m-%d')

# %% [markdown]
# We need to predict output (Y_output_pred) start from Sunday (6) for data set 1. (0: Monday, 6: Sunday)

# %%
# We take the x_length + y_length days of data only
# This part then split into x_length as input X and y_length as output Y
x_length = 63  # input period
y_length = 63  # predict period

# %%
#test_length = 0  # for predicting
test_length = y_length  # for self testing

# %% [markdown]
# Shift everything forward by y_length = 63 days to allows self testing without Kaggle

# %% [markdown]
# #### X

# %%
X_input_dates = input_df_dates[-x_length-test_length-364:-test_length-364]; #X_input_dates

# %%
X_input_first_day = X_input_dates[0]
X_input_final_day = X_input_dates[-1]
X_input_first_day, X_input_final_day
# Out:
# ('2016-04-29', '2016-06-30')

# %% [markdown]
# daydiff(X_input_first_day, X_input_final_day)  # should be 1 - y_length

# %%
# X for output set
if test_length:
    X_output_dates = input_df_dates[-x_length-test_length:-test_length]
else:
    X_output_dates = input_df_dates[-x_length:]
#X_output_dates

# %%
X_output_first_day = X_output_dates[0]
X_output_final_day = X_output_dates[-1]
X_output_first_day, X_output_final_day
# Out:
# ('2017-04-28', '2017-06-29')

# %% [markdown]
# daydiff(X_output_first_day, X_output_final_day)  # should be 1 - y_length

# %% [markdown]
# weekday(X_input_first_day), weekday(X_output_first_day)

# %% [markdown]
# Both are Wednesday (2).

# %% [markdown]
# #### Y

# %%
Y_input_dates = input_df_dates[-test_length-364:-test_length-364+y_length]; #Y_input_dates

# %%
Y_input_first_day = Y_input_dates[0]
Y_input_final_day = Y_input_dates[-1]
Y_input_first_day, Y_input_final_day
# Out:
# ('2016-07-01', '2016-09-01')

# %% [markdown]
# daydiff(Y_input_first_day, Y_input_final_day)

# %%
# Y for output set
if test_length:
    Y_output_dates = input_df_dates[-test_length:]
else:
    Y_output_first_day = '2017-09-12'  ## Make sure it is correct when predicting !!!!!!!
    Y_output_dates = pd.Index(np.arange(np.datetime64(Y_output_first_day), 
                                        np.datetime64(Y_output_first_day)
                                        + np.timedelta64(y_length, 'D')).astype('str'))
#Y_output_dates

# %%
Y_output_first_day = Y_output_dates[0]
Y_output_final_day = Y_output_dates[-1]
Y_output_first_day, Y_output_final_day
# Out:
# ('2017-06-30', '2017-08-31')

# %% [markdown]
# daydiff(Y_output_first_day, Y_output_final_day)  # should be 1 - y_length

# %% [markdown]
# weekday(Y_input_first_day), weekday(Y_output_first_day)

# %% [markdown]
# Both are Sunday (6).

# %% [markdown]
# ## Fibonacci

# %% [markdown]
# #### Window Sizes

# %% [markdown]
# The window sizes are given by Ehsan https://www.kaggle.com/safavieh

# %%
windows = [11, 18, 30, 48, 78, 126, 203, 329]
fib_length = max(windows)#; fib_length

# %% [markdown]
# #### Data selection

# %% [markdown]
# In this testing code, we did not include the last y_length days since in the real predicting stage, we don't know their visits.

# %%
if test_length:
    fib_output_dates = input_df_dates[-fib_length-test_length:-test_length]
else:
    fib_output_dates = input_df_dates[-fib_length:]
fib_input_dates = input_df_dates[-fib_length-test_length-364:-test_length-364]
fib_input_dates, fib_output_dates
# Out:
# (Index(['2015-08-07', '2015-08-08', '2015-08-09', '2015-08-10', '2015-08-11',
#         '2015-08-12', '2015-08-13', '2015-08-14', '2015-08-15', '2015-08-16',
#         ...
#         '2016-06-21', '2016-06-22', '2016-06-23', '2016-06-24', '2016-06-25',
#         '2016-06-26', '2016-06-27', '2016-06-28', '2016-06-29', '2016-06-30'],
#        dtype='object', length=329),
#  Index(['2016-08-05', '2016-08-06', '2016-08-07', '2016-08-08', '2016-08-09',
#         '2016-08-10', '2016-08-11', '2016-08-12', '2016-08-13', '2016-08-14',
#         ...
#         '2017-06-20', '2017-06-21', '2017-06-22', '2017-06-23', '2017-06-24',
#         '2017-06-25', '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29'],
#        dtype='object', length=329))

# %%
weekday(fib_input_dates[0]), weekday(fib_output_dates[0])
# Out:
# (4, 4)

# %%
fib_output_data = input_df[fib_output_dates].values; #fib_output_data

# %%
fib_input_data = input_df[fib_input_dates].values; #fib_input_data

# %% [markdown]
# #### Fibonacci median in each window

# %%
fib_input_median_list = np.array([np.nanmedian(fib_input_data[:, -w:] , axis=-1) 
                            for w in windows])
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
fib_output_median_list = np.array([np.nanmedian(fib_output_data[:, -w:] , axis=-1) 
                            for w in windows])
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %% [markdown]
# fib_input_median_list.T.shape

# %% [markdown]
# fib_output_median_na = np.nanmedian(fib_output_median_list.T, axis=-1)

# %% [markdown]
# fib_output_median_na

# %%
fib_input_median = np.nan_to_num(np.nanmedian(fib_input_median_list.T, axis=-1)); fib_input_median.shape
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# (145063,)

# %%
fib_output_median = np.nan_to_num(np.nanmedian(fib_output_median_list.T, axis=-1)); fib_output_median.shape
# Out:
# c:\python3\lib\site-packages\numpy\lib\function_base.py:4011: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# (145063,)

# %% [markdown]
# fib_input_median

# %% [markdown]
# fib_output_median

# %% [markdown]
# We will use this as the center and part of the result

# %%
Y_input_fib = fib_input_median.reshape(-1,1)
Y_output_fib = fib_output_median.reshape(-1,1)

# %% [markdown]
# ## Data Selection
# Select x_length + y_length days of data as input or ouput set.

# %% [markdown]
# ### Input data

# %% [markdown]
# input_data contains X_input and Y_input array

# %%
input_dates = pd.Index(np.concatenate((X_input_dates, Y_input_dates)))
input_dates, X_input_first_day, Y_input_final_day
# Out:
# (Index(['2016-04-29', '2016-04-30', '2016-05-01', '2016-05-02', '2016-05-03',
#         '2016-05-04', '2016-05-05', '2016-05-06', '2016-05-07', '2016-05-08',
#         ...
#         '2016-08-23', '2016-08-24', '2016-08-25', '2016-08-26', '2016-08-27',
#         '2016-08-28', '2016-08-29', '2016-08-30', '2016-08-31', '2016-09-01'],
#        dtype='object', length=126), '2016-04-29', '2016-09-01')

# %%
input_data = input_df[input_dates].values; #input_data  # input_data with nan

# %% [markdown]
# ##### Convert nan to number 0.

# %%
input_data_num = np.nan_to_num(input_data); #input_data_num  # intput_data with nan -> 0.

# %% [markdown]
# input_data_num.shape

# %% [markdown]
# ### Output Data

# %% [markdown]
# output_data for this self-testing script contains both X_output and Y_output

# %%
if test_length:
    output_dates = pd.Index(np.concatenate((X_output_dates, Y_output_dates)))
else:
    output_dates = X_output_dates
output_dates, X_output_first_day, X_output_final_day, Y_output_final_day
# Out:
# (Index(['2017-04-28', '2017-04-29', '2017-04-30', '2017-05-01', '2017-05-02',
#         '2017-05-03', '2017-05-04', '2017-05-05', '2017-05-06', '2017-05-07',
#         ...
#         '2017-08-22', '2017-08-23', '2017-08-24', '2017-08-25', '2017-08-26',
#         '2017-08-27', '2017-08-28', '2017-08-29', '2017-08-30', '2017-08-31'],
#        dtype='object', length=126), '2017-04-28', '2017-06-29', '2017-08-31')

# %%
output_dates.shape
# Out:
# (126,)

# %%
output_data = input_df[output_dates].values; #output_data

# %% [markdown]
# ##### Convert nan to number 0.

# %%
output_data_num = np.nan_to_num(output_data); output_data_num
# Out:
# array([[ 24.,  20.,  36., ...,  26.,  24.,  21.],
#        [ 19.,  18.,  12., ...,  29.,  34.,  25.],
#        [  2.,   0.,   3., ...,   8.,  12.,   9.],
#        ...,
#        [ 27.,  84.,  14., ...,  21.,  11.,   9.],
#        [  7.,  10.,  13., ...,   3.,   9.,   2.],
#        [ 34.,  16.,  16., ...,   9.,   6.,   5.]], dtype=float32)

# %%
output_data_num.shape
# Out:
# (145063, 126)

# %% [markdown]
# ### View

# %% [markdown]
# def view(x, xlim=None, ylim=None, yscale='linear', title=None, show=True):
#     plt.yscale(yscale)
#     plt.plot(x)
#     if ylim: plt.ylim(ylim)
#     if xlim: plt.xlim(xlim)
#     if title: plt.title(title)
#     if show: plt.show()
#
# def viewi(X, i, xlim=None, ylim=None, yscale='linear', show=True):
#     view(X[i], xlim=xlim, ylim=ylim, yscale=yscale, title='i = ' + str(i), show=show)
#
# def examine(X, n=5, xlim=None, ylim=None):
#     '''randomly show some example in feature and label'''
#     n_X = len(X)
#     view_list = np.random.choice(n_X, min(n, n_X), replace=False)
#     for i in view_list:
#         viewi(X, i, xlim=xlim, ylim=ylim)
#     return view_list

# %% [markdown]
# examine(input_data)

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Log

# %%
def log(X):
    return np.log10(X + 1.0)
def unlog(X):
    return np.clip(np.power(10., X) - 1.0, 0.0, None)

# %%
input_data_log = log(input_data_num)
output_data_log = log(output_data_num)

# %% [markdown]
# ##### Check Log transformation

# %%
input_data_log.shape, input_data.shape, output_data_log.shape, output_data.shape
# Out:
# ((145063, 126), (145063, 126), (145063, 126), (145063, 126))

# %% [markdown]
# input_data_log

# %% [markdown]
# output_data_log

# %% [markdown]
# #Check inverse log transformation
# input_data_log_tt = unlog(input_data_log)
# input_data_log_tt_dif = input_data_log_tt - input_data_num
# input_data_log_tt_dif.min(), input_data_log_tt_dif.max()

# %% [markdown]
# #Check inverse log transformation
# output_data_log_tt = unlog(output_data_log)
# output_data_log_tt_dif = output_data_log_tt - output_data_num
# output_data_log_tt_dif.min(), output_data_log_tt_dif.max()

# %% [markdown]
# del input_data_log_tt
# del input_data_log_tt_dif
# del output_data_log_tt
# del output_data_log_tt_dif

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# ### Normalization (Shift and Scale)

# %% [markdown]
# #### Use Fib Median as the Center

# %%
#input_center = log(fib_input_median).reshape(-1,1)
output_center = log(fib_output_median).reshape(-1,1)
input_center = output_center  # using output_center instead

# %% [markdown]
# input_center, output_center

# %% [markdown]
# #### Choice of default scale

# %%
input_raw_log = log(input_data)  # log of input_data with nan
output_raw_log = log(output_data)  # log of output_data with nan

# %% [markdown]
# np.median(np.nanstd(input_data_log[:,:x_length], axis=-1))

# %% [markdown]
# np.mean(np.nanstd(input_data_log[:,:x_length], axis=-1))

# %%
default_input_scale = np.nanmedian(np.nanstd(input_raw_log[:,:x_length], axis=-1))
default_input_scale
# Out:
# c:\python3\lib\site-packages\numpy\lib\nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# 0.17974041

# %%
default_output_scale = np.nanmedian(np.nanstd(output_raw_log[:,:x_length], axis=-1))
default_output_scale
# Out:
# c:\python3\lib\site-packages\numpy\lib\nanfunctions.py:1427: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# 0.16425449

# %% [markdown]
# #### Compute Median and Stdev

# %% [markdown]
# Here we are not using this median as center

# %% [markdown]
# input_center = np.nanmedian(input_data_log[:,:x_length], axis=-1).reshape(-1,1)
# input_center  # remember sample-wised center

# %%
input_scale = np.nanstd(input_data_log[:,:x_length], axis=-1).reshape(-1,1)
input_scale[input_scale == 0.0] = default_input_scale  # Prevent divid by zero 
# non-zero value is choose based on the median of other page with non-zero stdev)
input_scale  # remember sample-wised scale
# Out:
# array([[ 0.22042467],
#        [ 0.19443031],
#        [ 0.23390391],
#        ...,
#        [ 0.17974041],
#        [ 0.17974041],
#        [ 0.17974041]], dtype=float32)

# %% [markdown]
# output_center = np.nanmedian(output_data_log[:,:x_length], axis=-1).reshape(-1,1)
# output_center  # remember sample-wised center

# %%
output_scale = np.nanstd(output_data_log[:,:x_length], axis=-1).reshape(-1,1)
output_scale[output_scale == 0.0] = default_output_scale  # Prevent divid by zero
output_scale  # remember sample-wised scale
# Out:
# array([[ 0.15715757],
#        [ 0.23019141],
#        [ 0.29932547],
#        ...,
#        [ 0.30635026],
#        [ 0.30876896],
#        [ 0.41433722]], dtype=float32)

# %% [markdown]
# ##### Check zero in scale

# %% [markdown]
# #Check if there is any 0. in input_scale
# input_scale[input_scale == 0.]

# %% [markdown]
# #Check if there is any 0. in output_scale
# output_scale[output_scale == 0.]

# %% [markdown]
# #### Shift by Center and Scale by Scale

# %%
def transform(data_ori, center, scale):
    return (data_ori - center) / scale
def untransform(data, center, scale):
    return data * scale + center

# %%
# Normalize the input_data and output_data
input_data_norm = transform(input_data_log, input_center, input_scale)
output_data_norm = transform(output_data_log, output_center, output_scale)

# %% [markdown]
# ##### Check median and stdev transformations

# %%
def check_nan(X):
    return [x for x in X if np.isnan(x).any()]

# %% [markdown]
# check_nan(input_data_norm), check_nan(output_data_norm)  # Check if there is any nan in the input_data

# %% [markdown]
# #Check inverse scale transformation
# input_data_norm_it = untransform(input_data_norm, input_center, input_scale)
# input_data_norm_it_dif = input_data_norm_it - input_data_log
# input_data_norm_it_dif.min(), input_data_norm_it_dif.max()

# %% [markdown]
# #Check inverse scale transformation
# output_data_norm_it = untransform(output_data_norm, output_center, output_scale)
# output_data_norm_it_dif = output_data_norm_it - output_data_log
# output_data_norm_it_dif.min(), output_data_norm_it_dif.max()

# %% [markdown]
# del input_data_norm_it
# del input_data_norm_it_dif
# del output_data_norm_it
# del output_data_norm_it_dif
# gc.collect()

# %% [markdown]
# ## Center (Median) and Scale (Stdev) Investigation

# %% [markdown]
# ### Center

# %% [markdown]
# plt.hist(input_center, bins=40, alpha=0.7, label='input')
# plt.hist(output_center, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(input_center, bins=40, alpha=0.7, label='input')
# plt.hist(output_center, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.yscale('log')
# plt.show()

# %% [markdown]
# ### Scale

# %% [markdown]
# plt.hist(input_scale, bins=40, alpha=0.7, label='input')
# plt.hist(output_scale, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(input_scale, bins=40, alpha=0.7, label='input')
# plt.hist(output_scale, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.yscale('log')
# plt.show()

# %% [markdown]
# ### Group index based on scale of median (center)

# %%
def group_index(median, stdev):
    if median < 1.0: return 0
    elif median < 2.0: 
        if stdev < 0.17: return 1
        else: return 2
    elif median < 4.0: 
        if stdev < 0.17: return 3
        else: return 4
    else: return 5
#group_index_v = np.vectorize(group_index)
gp_list = list(range(6)); gp_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %% [markdown]
# def group_index(logx):
#     if logx == 0.: return 0
#     elif logx < 1.0: return 1
#     elif logx < 2.0: return 2
#     elif logx < 4.0: return 3
#     elif logx < 5.0: return 4
#     else: return 5
# group_index_v = np.vectorize(group_index)
# gp_list = list(range(6)); gp_list

# %%
input_gp = np.array([group_index(center, scale) for center, scale in zip(input_center, input_scale)]).reshape(-1)
output_gp = np.array([group_index(center, scale) for center, scale in zip(output_center, output_scale)]).reshape(-1)

# %%
input_gp, output_gp
# Out:
# (array([2, 2, 0, ..., 2, 0, 2]), array([1, 2, 0, ..., 2, 0, 2]))

# %% [markdown]
# input_gp = group_index_v(input_center).reshape(-1)
# output_gp = group_index_v(output_center).reshape(-1)
# #input_gp, output_gp

# %%
# group counts
gp_input_counts = [0] * len(gp_list)
for x in input_gp: gp_input_counts[x] += 1
gp_input_counts
# Out:
# [24964, 15540, 28151, 43351, 32266, 791]

# %%
# group counts
gp_output_counts = [0] * len(gp_list)
for x in output_gp: gp_output_counts[x] += 1
gp_output_counts
# Out:
# [24964, 20254, 23437, 51297, 24320, 791]

# %%
plt.hist(input_gp, alpha=0.8, label='input')
plt.hist(output_gp, alpha=0.3, label='output')
plt.yscale('linear')
plt.legend()
plt.show()

# %% [markdown]
# plt.hist(input_gp, alpha=0.8, label='input')
# plt.hist(output_gp, alpha=0.3, label='output')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# ## Make (X,Y) pairs data from data set

# %%
X_input = input_data_norm[:, :x_length]
Y_input = input_data_norm[:, -y_length:]
X_input.shape, Y_input.shape
# Out:
# ((145063, 63), (145063, 63))

# %%
X_output = output_data_norm[:, :x_length]
if test_length:
    Y_output = output_data_norm[:, -y_length:]
    print(X_output.shape, Y_output.shape)
else:
    print(X_output.shape, 'No Y_output')
# Out:
# (145063, 63) (145063, 63)

# %% [markdown]
# #### Original data

# %%
X_input_ori = input_data_num[:, :x_length]
Y_input_ori = input_data_num[:, -y_length:]
X_output_ori = output_data_num[:, :x_length]
if test_length: 
    Y_output_ori = output_data_num[:, -y_length:]

# %% [markdown]
# #### Raw data (with nan)

# %%
X_input_raw = input_data[:, :x_length]
Y_input_raw = input_data[:, -y_length:]
X_output_raw = output_data[:, :x_length]
if test_length:
    Y_output_raw = output_data[:, -y_length:]

# %% [markdown]
# #### Backward compatible

# %% [markdown]
# X_input = X_input
# Y_input = Y_input
# X_val = X_output
# if test_length:
#     Y_val = Y_output

# %% [markdown]
# X_input_ori = X_input_ori
# Y_input_ori = Y_input_ori
# X_val_ori = X_output_ori
# if test_length:
#     Y_val_ori = Y_output_ori

# %% [markdown]
# train_scale = input_scale
# train_center = input_center
# val_scale = output_scale
# val_center = output_center

# %% [markdown]
# #### Check

# %% [markdown]
# X_input, input_data_norm[:,:x_length]

# %% [markdown]
# Y_input, input_data_norm[:,-y_length:]

# %% [markdown]
# X_output, output_data_norm[:,:x_length]

# %% [markdown]
# if test_length:
#     print(Y_output)
#     print(output_data_norm[:,-y_length:])

# %% [markdown]
# X_input_ori, input_data_num

# %% [markdown]
# Y_input_ori, input_data_num

# %% [markdown]
# X_output_ori, output_data_num

# %% [markdown]
# if test_length:
#     print(Y_output_ori)
#     print(output_data_num)

# %%
if test_length:
    arr_info((X_input, Y_input, X_output, Y_output, 
              X_input_ori, Y_input_ori, X_output_ori, Y_output_ori))
else:
    arr_info((X_input, Y_input, X_output, 
              X_input_ori, Y_input_ori, X_output_ori))
# Out:
# shape, min, max, median, stdev
# (145063, 63) -104.945597725 182.183688699 0.0250217121081 3.34816141728
# (145063, 63) -104.945597725 181.969627538 -0.0156385758122 3.42135990909
# (145063, 63) -57.3465699314 8.00100800101 0.0 1.27077605981
# (145063, 63) -1627.7382547 51.3918797946 -0.214767758227 6.0365527548
# (145063, 63) 0.0 23209383.0 126.0 63765.8619057
# (145063, 63) 0.0 67264258.0 128.0 155483.953622
# (145063, 63) 0.0 24630674.0 123.0 65785.6552263
# (145063, 63) 0.0 18670230.0 113.0 57469.0537846

# %% [markdown]
# #### Min and max cases examination

# %% [markdown]
# np.argmin(Y_output, axis=0)

# %% [markdown]
# Y_output[8604]

# %% [markdown]
# Y_output_ori[8604]

# %% [markdown]
# fib_output_median[8604]

# %% [markdown]
# log(Y_output_ori[8604])

# %% [markdown]
# log(fib_output_median[8604])

# %% [markdown]
# np.std(log(Y_output_ori[8604]))

# %% [markdown]
# np.std(log(X_output_ori[8604]))

# %% [markdown]
# output_scale[8604]

# %% [markdown]
# #### Check if the inverse transformation is correct

# %% [markdown]
# #Undo transformation
# X_input_tt = unlog(untransform(X_input, train_center, train_scale))

# %% [markdown]
# X_input_tt_diff = X_input_tt - X_input_ori
# X_input_tt_diff.min(), X_input_tt_diff.max()

# %% [markdown]
# ## Split X,Y data into groups

# %% [markdown]
# X_input[input_gp == 1].shape

# %%
X_input_list = [X_input[input_gp == gp] for gp in gp_list]
Y_input_list = [Y_input[input_gp == gp] for gp in gp_list]
X_output_list = [X_output[output_gp == gp] for gp in gp_list]
if test_length:
    Y_output_list = [Y_output[output_gp == gp] for gp in gp_list]

# %% [markdown]
# ## Additional input for the neural network

# %% [markdown]
# #Split center into group
# input_center_list = [input_center[input_gp == gp] for gp in gp_list]
# output_center_list = [output_center[output_gp == gp] for gp in gp_list]
#
# #Split scale into group
# input_scale_list = [input_scale[input_gp == gp] for gp in gp_list]
# output_scale_list = [output_scale[output_gp == gp] for gp in gp_list]

# %% [markdown]
# input_scale_list[0].shape

# %%
A_input = np.concatenate((input_center, input_scale), axis=1)
A_output = np.concatenate((output_center, output_scale), axis=1); A_input.shape, A_output.shape
# Out:
# ((145063, 2), (145063, 2))

# %%
A_input_list = [A_input[input_gp == gp] for gp in gp_list]
A_output_list = [A_output[output_gp == gp] for gp in gp_list]

# %%
a_length = len(A_input[0]); a_length
# Out:
# 2

# %%
[A.shape for A in A_input_list]
# Out:
# [(24964, 2), (15540, 2), (28151, 2), (43351, 2), (32266, 2), (791, 2)]

# %% [markdown]
# ## Neural Network?

# %%
from keras.models import Sequential
#from keras.layers import Conv1D
from keras.layers import Dense, Dropout, Flatten
from keras.losses import mean_squared_error
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### SMAPE
# Symmetric mean absolute percentage error
#
# https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error

# %%
import keras.backend as K

def k_smape(y_true, y_pred):
    '''Symmetric mean absolute percentage error for keras metric'''
    diff = K.abs((y_true - y_pred) / K.clip(K.abs(y_true) + K.abs(y_pred),
                                            K.epsilon(), None))
    return 200. * K.mean(diff, axis=-1)

# %%
def smape(y_true, y_pred, axis=None):
    '''Symmetric mean absolute percentage error'''
    diff = np.abs((y_true - y_pred) / 
                  np.clip(np.abs(y_true) + np.abs(y_pred), np.float32(1e-07), None))
    return np.float32(200.) * np.nanmean(diff, axis=axis)

# %% [markdown]
# smape(np.array([0,1]),np.array([np.nan, 0])), smape(np.array([0]),np.array([0]))

# %%
np.float32(1e-7)
# Out:
# 1e-07

# %%
# Benchmark SMAPE on the transformed data
smape(Y_input,X_input), smape(Y_input, X_output), smape(Y_input,Y_input)
# Out:
# (118.39848, 148.19037, 0.0)

# %%
# Benchmark SMAPE on the original data
smape(Y_input_raw,X_input_ori), smape(Y_input_ori,X_input_ori)
# Out:
# (60.41732, 58.828331)

# %%
if test_length: print(smape(Y_output_raw, X_output_ori), smape(Y_output, X_output))
# Out:
# 50.9386 142.088

# %%
print(smape(Y_input_raw, Y_input_fib))
if test_length: print(smape(Y_output_raw, Y_output_fib))
# Out:
# 48.3250071896
# 40.4041165988

# %% [markdown]
# Doing better than the first two scores are better than simply copy and past the previous result.

# %% [markdown]
# ### Neural Network Model
# With the flavor of convolutional neural network

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv1D
from keras.layers import Flatten
from keras.layers import Reshape
from keras.layers import MaxPooling1D
from keras.layers import AveragePooling1D
from keras.layers import concatenate

# %%
n_ens = 5
ens_list = list(range(n_ens))

# %%
#runbelow
models_ens = []
for run in ens_list:
    print('Run', run, end=': ')
    models = []
    for gp in gp_list:
        print('Group-', gp, sep='', end=' ')
        layer_0 = Input(shape=(x_length,), name='x_input')
        layer_t = Reshape((-1, 1))(layer_0)
        layer_t = Conv1D(120, kernel_size=3, activation='relu')(layer_t)
        layer_t = AveragePooling1D(pool_size=2)(layer_t)
        layer_cnn = Flatten()(layer_t)
        
        layer_a = Input(shape=(a_length,), name='a_input')
        layer_t = concatenate([layer_cnn, layer_a])
        
        layer_t = Dense(120, activation='relu')(layer_t)
        layer_t = Dropout(0.25)(layer_t)
        layer_t = Dense(120, activation='relu')(layer_t)
        layer_t = Dropout(0.5)(layer_t)
        layer_f = Dense(y_length)(layer_t)
        
        model = Model(inputs=[layer_0, layer_a], outputs=layer_f)
        model.compile(optimizer='adam',
                      loss='mean_absolute_error', metrics=[k_smape])
        #model.summary()
        models.append(model)
    models_ens.append(models)
    print('')
# Out:
# Run 0: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 1: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 2: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 3: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 4: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5

# %%
models_ens[0][1].summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# x_input (InputLayer)             (None, 63)            0
# ____________________________________________________________________________________________________
# reshape_2 (Reshape)              (None, 63, 1)         0           x_input[0][0]
# ____________________________________________________________________________________________________
# conv1d_2 (Conv1D)                (None, 61, 120)       480         reshape_2[0][0]
# ____________________________________________________________________________________________________
# average_pooling1d_2 (AveragePool (None, 30, 120)       0           conv1d_2[0][0]
# ____________________________________________________________________________________________________
# flatten_2 (Flatten)              (None, 3600)          0           average_pooling1d_2[0][0]
# ____________________________________________________________________________________________________
# a_input (InputLayer)             (None, 2)             0
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 3602)          0           flatten_2[0][0]
#                                                                    a_input[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 120)           432360      concatenate_2[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 120)           0           dense_4[0][0]
# ____________________________________________________________________________________________________
# dense_5 (Dense)                  (None, 120)           14520       dropout_3[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 120)           0           dense_5[0][0]
# ____________________________________________________________________________________________________
# dense_6 (Dense)                  (None, 63)            7623        dropout_4[0][0]
# ====================================================================================================
# Total params: 454,983
# Trainable params: 454,983
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
np.array(models_ens).shape
# Out:
# (5, 6)

# %%
len(gp_list)
# Out:
# 6

# %%
epochs_list = [1,40,40,40,40,60]  # change to smaller epochs later (1,1,20,40,60,80)

# %%
# %%time
hists_ens = []
for run, models in zip(ens_list, models_ens):
    print('=== Run:', run+1, '/', len(ens_list), '===')
    hists = []
    for (gp, model, X_in, Y_in, epochs, A_in) in zip(gp_list, models,
                                       X_input_list, Y_input_list, 
                                       epochs_list, A_input_list):
        print('--- Group:', gp+1, '/', len(gp_list), '---')
        hist = model.fit([X_in, A_in], Y_in, batch_size=128, 
                         epochs=epochs, 
                         validation_split=0.1, verbose=2)
        #validation_data=(X_val, Y_val))
        hists.append(hist)
    hists_ens.append(hists)
# Out:
# === Run: 1 / 5 ===
# --- Group: 1 / 6 ---
# Train on 22467 samples, validate on 2497 samples
# Epoch 1/1
# 9s - loss: 1.1047 - k_smape: 149.6194 - val_loss: 0.9922 - val_k_smape: 145.4786
# --- Group: 2 / 6 ---
# Train on 13986 samples, validate on 1554 samples
# Epoch 1/40
# 3s - loss: 1.6704 - k_smape: 133.4159 - val_loss: 1.3201 - val_k_smape: 126.4261
# Epoch 2/40
# 3s - loss: 1.5387 - k_smape: 121.7148 - val_loss: 1.3270 - val_k_smape: 127.3575
# Epoch 3/40
# 3s - loss: 1.5069 - k_smape: 118.5946 - val_loss: 1.3480 - val_k_smape: 128.0669
# Epoch 4/40
# 3s - loss: 1.4966 - k_smape: 117.3264 - val_loss: 1.3133 - val_k_smape: 126.6177
# Epoch 5/40
# 3s - loss: 1.4894 - k_smape: 116.6591 - val_loss: 1.3291 - val_k_smape: 127.1567
# Epoch 6/40
# 3s - loss: 1.4782 - k_smape: 115.9583 - val_loss: 1.3098 - val_k_smape: 120.1657
# Epoch 7/40
# 3s - loss: 1.4830 - k_smape: 115.4238 - val_loss: 1.3045 - val_k_smape: 117.2538
# Epoch 8/40
# 3s - loss: 1.4692 - k_smape: 114.4057 - val_loss: 1.3129 - val_k_smape: 123.6311
# Epoch 9/40
# 3s - loss: 1.4614 - k_smape: 114.1082 - val_loss: 1.3102 - val_k_smape: 118.8329
# Epoch 10/40
# 3s - loss: 1.4610 - k_smape: 113.4531 - val_loss: 1.3173 - val_k_smape: 121.6073
# Epoch 11/40
# 3s - loss: 1.4560 - k_smape: 113.7466 - val_loss: 1.3160 - val_k_smape: 118.9195
# Epoch 12/40
# 3s - loss: 1.4517 - k_smape: 112.5817 - val_loss: 1.3128 - val_k_smape: 118.7289
# Epoch 13/40
# 3s - loss: 1.4491 - k_smape: 112.7087 - val_loss: 1.3131 - val_k_smape: 119.1662
# Epoch 14/40
# 3s - loss: 1.4567 - k_smape: 112.4348 - val_loss: 1.3059 - val_k_smape: 118.7838
# Epoch 15/40
# 3s - loss: 1.4359 - k_smape: 112.0733 - val_loss: 1.3134 - val_k_smape: 118.7913
# Epoch 16/40
# 3s - loss: 1.4427 - k_smape: 111.5872 - val_loss: 1.3093 - val_k_smape: 117.5322
# Epoch 17/40
# 3s - loss: 1.4373 - k_smape: 111.2034 - val_loss: 1.3046 - val_k_smape: 117.9553
# Epoch 18/40
# 3s - loss: 1.4258 - k_smape: 111.3062 - val_loss: 1.3053 - val_k_smape: 118.3870
# Epoch 19/40
# 3s - loss: 1.4353 - k_smape: 110.8197 - val_loss: 1.3555 - val_k_smape: 125.1813
# Epoch 20/40
# 3s - loss: 1.4351 - k_smape: 111.1929 - val_loss: 1.2977 - val_k_smape: 116.6386
# Epoch 21/40
# 3s - loss: 1.4296 - k_smape: 110.3679 - val_loss: 1.3066 - val_k_smape: 118.9046
# Epoch 22/40
# 3s - loss: 1.4206 - k_smape: 110.5266 - val_loss: 1.3117 - val_k_smape: 116.9183
# Epoch 23/40
# 3s - loss: 1.4205 - k_smape: 109.9635 - val_loss: 1.3042 - val_k_smape: 116.2266
# Epoch 24/40
# 3s - loss: 1.4087 - k_smape: 109.9444 - val_loss: 1.3126 - val_k_smape: 115.2973
# Epoch 25/40
# 3s - loss: 1.4232 - k_smape: 109.6848 - val_loss: 1.3096 - val_k_smape: 114.6996
# Epoch 26/40
# 3s - loss: 1.4292 - k_smape: 110.2989 - val_loss: 1.3195 - val_k_smape: 116.4127
# Epoch 27/40
# 3s - loss: 1.4152 - k_smape: 109.5232 - val_loss: 1.3174 - val_k_smape: 118.9358
# Epoch 28/40
# 3s - loss: 1.4054 - k_smape: 109.4092 - val_loss: 1.3061 - val_k_smape: 118.1565
# Epoch 29/40
# 3s - loss: 1.4072 - k_smape: 109.3731 - val_loss: 1.3215 - val_k_smape: 117.5792
# Epoch 30/40
# 3s - loss: 1.4087 - k_smape: 109.3559 - val_loss: 1.3024 - val_k_smape: 118.0121
# Epoch 31/40
# 3s - loss: 1.4098 - k_smape: 109.4147 - val_loss: 1.3122 - val_k_smape: 116.0389
# Epoch 32/40
# 3s - loss: 1.3922 - k_smape: 109.1770 - val_loss: 1.3151 - val_k_smape: 116.7465
# Epoch 33/40
# 3s - loss: 1.3905 - k_smape: 108.3941 - val_loss: 1.3273 - val_k_smape: 120.6169
# Epoch 34/40
# 3s - loss: 1.3923 - k_smape: 108.6170 - val_loss: 1.3204 - val_k_smape: 119.0361
# Epoch 35/40
# 3s - loss: 1.3811 - k_smape: 108.2098 - val_loss: 1.3143 - val_k_smape: 117.2709
# Epoch 36/40
# 3s - loss: 1.3889 - k_smape: 108.6895 - val_loss: 1.3258 - val_k_smape: 116.0280
# Epoch 37/40
# 3s - loss: 1.3774 - k_smape: 108.0983 - val_loss: 1.3262 - val_k_smape: 120.6202
# Epoch 38/40
# 3s - loss: 1.3824 - k_smape: 107.9649 - val_loss: 1.3044 - val_k_smape: 116.7310
# Epoch 39/40
# 3s - loss: 1.3741 - k_smape: 108.1278 - val_loss: 1.3243 - val_k_smape: 118.0862
# Epoch 40/40
# 3s - loss: 1.3804 - k_smape: 108.1052 - val_loss: 1.3288 - val_k_smape: 118.1536
# --- Group: 3 / 6 ---
# Train on 25335 samples, validate on 2816 samples
# Epoch 1/40
# 6s - loss: 1.1756 - k_smape: 130.1509 - val_loss: 0.9513 - val_k_smape: 119.0496
# Epoch 2/40
# 5s - loss: 1.0969 - k_smape: 120.1430 - val_loss: 0.9560 - val_k_smape: 116.9181
# Epoch 3/40
# 5s - loss: 1.0717 - k_smape: 117.1416 - val_loss: 0.9543 - val_k_smape: 117.3485
# Epoch 4/40
# 5s - loss: 1.0629 - k_smape: 115.9426 - val_loss: 0.9408 - val_k_smape: 117.7552
# Epoch 5/40
# 5s - loss: 1.0553 - k_smape: 114.9464 - val_loss: 0.9566 - val_k_smape: 117.8545
# Epoch 6/40
# 5s - loss: 1.0474 - k_smape: 114.6111 - val_loss: 1.0153 - val_k_smape: 122.4130
# Epoch 7/40
# 5s - loss: 1.0447 - k_smape: 113.9405 - val_loss: 0.9594 - val_k_smape: 119.3849
# Epoch 8/40
# 5s - loss: 1.0439 - k_smape: 114.1250 - val_loss: 0.9675 - val_k_smape: 117.0631
# Epoch 9/40
# 5s - loss: 1.0392 - k_smape: 113.5848 - val_loss: 0.9742 - val_k_smape: 116.8871
# Epoch 10/40
# 5s - loss: 1.0396 - k_smape: 113.2173 - val_loss: 1.0258 - val_k_smape: 125.0060
# Epoch 11/40
# 5s - loss: 1.0374 - k_smape: 113.2193 - val_loss: 0.9366 - val_k_smape: 114.6159
# Epoch 12/40
# 5s - loss: 1.0340 - k_smape: 113.0149 - val_loss: 0.9773 - val_k_smape: 117.5305
# Epoch 13/40
# 5s - loss: 1.0280 - k_smape: 112.6470 - val_loss: 0.9484 - val_k_smape: 117.4714
# Epoch 14/40
# 5s - loss: 1.0254 - k_smape: 112.6205 - val_loss: 0.9912 - val_k_smape: 118.6428
# Epoch 15/40
# 5s - loss: 1.0240 - k_smape: 112.3985 - val_loss: 0.9733 - val_k_smape: 117.5057
# Epoch 16/40
# 5s - loss: 1.0218 - k_smape: 112.1511 - val_loss: 0.9738 - val_k_smape: 118.0649
# Epoch 17/40
# 5s - loss: 1.0223 - k_smape: 112.1836 - val_loss: 0.9610 - val_k_smape: 113.6542
# Epoch 18/40
# 5s - loss: 1.0170 - k_smape: 111.5629 - val_loss: 0.9976 - val_k_smape: 122.3516
# Epoch 19/40
# 5s - loss: 1.0181 - k_smape: 111.8378 - val_loss: 1.0336 - val_k_smape: 126.9497
# Epoch 20/40
# 5s - loss: 1.0166 - k_smape: 111.5060 - val_loss: 0.9855 - val_k_smape: 118.5787
# Epoch 21/40
# 5s - loss: 1.0141 - k_smape: 111.3189 - val_loss: 0.9761 - val_k_smape: 119.0127
# Epoch 22/40
# 5s - loss: 1.0140 - k_smape: 111.3216 - val_loss: 0.9726 - val_k_smape: 115.6997
# Epoch 23/40
# 5s - loss: 1.0129 - k_smape: 111.3085 - val_loss: 0.9452 - val_k_smape: 115.1137
# Epoch 24/40
# 5s - loss: 1.0111 - k_smape: 111.2640 - val_loss: 0.9998 - val_k_smape: 117.9432
# Epoch 25/40
# 5s - loss: 1.0081 - k_smape: 110.8417 - val_loss: 0.9771 - val_k_smape: 116.3785
# Epoch 26/40
# 5s - loss: 1.0087 - k_smape: 111.0203 - val_loss: 0.9842 - val_k_smape: 113.3360
# Epoch 27/40
# 5s - loss: 1.0010 - k_smape: 110.6443 - val_loss: 1.0066 - val_k_smape: 118.9168
# Epoch 28/40
# 5s - loss: 1.0024 - k_smape: 110.5214 - val_loss: 0.9787 - val_k_smape: 121.1616
# Epoch 29/40
# 5s - loss: 0.9993 - k_smape: 110.2940 - val_loss: 0.9668 - val_k_smape: 117.6123
# Epoch 30/40
# 5s - loss: 1.0043 - k_smape: 110.4842 - val_loss: 0.9493 - val_k_smape: 113.9384
# Epoch 31/40
# 5s - loss: 1.0021 - k_smape: 110.5706 - val_loss: 0.9394 - val_k_smape: 113.4750
# Epoch 32/40
# 5s - loss: 0.9982 - k_smape: 110.0919 - val_loss: 0.9789 - val_k_smape: 116.1955
# Epoch 33/40
# 5s - loss: 0.9983 - k_smape: 110.1149 - val_loss: 0.9719 - val_k_smape: 115.5465
# Epoch 34/40
# 5s - loss: 0.9930 - k_smape: 110.1442 - val_loss: 0.9974 - val_k_smape: 118.9434
# Epoch 35/40
# 5s - loss: 0.9928 - k_smape: 110.1386 - val_loss: 1.0008 - val_k_smape: 116.2081
# Epoch 36/40
# 5s - loss: 0.9983 - k_smape: 109.9584 - val_loss: 0.9863 - val_k_smape: 119.2778
# Epoch 37/40
# 5s - loss: 0.9920 - k_smape: 109.7957 - val_loss: 0.9720 - val_k_smape: 118.5210
# Epoch 38/40
# 5s - loss: 0.9911 - k_smape: 109.4904 - val_loss: 0.9913 - val_k_smape: 117.8378
# Epoch 39/40
# 5s - loss: 0.9890 - k_smape: 109.8366 - val_loss: 0.9962 - val_k_smape: 118.3047
# Epoch 40/40
# 5s - loss: 0.9876 - k_smape: 109.6715 - val_loss: 0.9842 - val_k_smape: 118.1893
# --- Group: 4 / 6 ---
# Train on 39015 samples, validate on 4336 samples
# Epoch 1/40
# 9s - loss: 1.4854 - k_smape: 110.4440 - val_loss: 1.3588 - val_k_smape: 111.4544
# Epoch 2/40
# 8s - loss: 1.3670 - k_smape: 99.9453 - val_loss: 1.3346 - val_k_smape: 107.3154
# Epoch 3/40
# 8s - loss: 1.3502 - k_smape: 98.1812 - val_loss: 1.3527 - val_k_smape: 107.0101
# Epoch 4/40
# 8s - loss: 1.3377 - k_smape: 97.3228 - val_loss: 1.3260 - val_k_smape: 105.8079
# Epoch 5/40
# 8s - loss: 1.3268 - k_smape: 96.5784 - val_loss: 1.3333 - val_k_smape: 106.6861
# Epoch 6/40
# 8s - loss: 1.3244 - k_smape: 96.5281 - val_loss: 1.3303 - val_k_smape: 105.8282
# Epoch 7/40
# 8s - loss: 1.3179 - k_smape: 95.8998 - val_loss: 1.3428 - val_k_smape: 106.6424
# Epoch 8/40
# 8s - loss: 1.3086 - k_smape: 95.2876 - val_loss: 1.3205 - val_k_smape: 104.8808
# Epoch 9/40
# 8s - loss: 1.3078 - k_smape: 95.3515 - val_loss: 1.3218 - val_k_smape: 105.7610
# Epoch 10/40
# 8s - loss: 1.3003 - k_smape: 94.9844 - val_loss: 1.3216 - val_k_smape: 103.8310
# Epoch 11/40
# 8s - loss: 1.3089 - k_smape: 95.0047 - val_loss: 1.3164 - val_k_smape: 104.5321
# Epoch 12/40
# 8s - loss: 1.3002 - k_smape: 94.7561 - val_loss: 1.3203 - val_k_smape: 105.9119
# Epoch 13/40
# 8s - loss: 1.2942 - k_smape: 94.5333 - val_loss: 1.3215 - val_k_smape: 104.7590
# Epoch 14/40
# 8s - loss: 1.2955 - k_smape: 94.4205 - val_loss: 1.3310 - val_k_smape: 105.4296
# Epoch 15/40
# 8s - loss: 1.2961 - k_smape: 94.2230 - val_loss: 1.3218 - val_k_smape: 105.4001
# Epoch 16/40
# 8s - loss: 1.2870 - k_smape: 93.8649 - val_loss: 1.3167 - val_k_smape: 104.3080
# Epoch 17/40
# 8s - loss: 1.2851 - k_smape: 93.9099 - val_loss: 1.3235 - val_k_smape: 104.9968
# Epoch 18/40
# 8s - loss: 1.2814 - k_smape: 93.6427 - val_loss: 1.3209 - val_k_smape: 106.0148
# Epoch 19/40
# 8s - loss: 1.2792 - k_smape: 93.5500 - val_loss: 1.3175 - val_k_smape: 104.3693
# Epoch 20/40
# 8s - loss: 1.2795 - k_smape: 93.5036 - val_loss: 1.3153 - val_k_smape: 105.2773
# Epoch 21/40
# 8s - loss: 1.2799 - k_smape: 93.4976 - val_loss: 1.3139 - val_k_smape: 104.1915
# Epoch 22/40
# 8s - loss: 1.2759 - k_smape: 93.3853 - val_loss: 1.3076 - val_k_smape: 104.2544
# Epoch 23/40
# 8s - loss: 1.2756 - k_smape: 93.2454 - val_loss: 1.3128 - val_k_smape: 105.4954
# Epoch 24/40
# 8s - loss: 1.2730 - k_smape: 93.2686 - val_loss: 1.3154 - val_k_smape: 105.8667
# Epoch 25/40
# 8s - loss: 1.2706 - k_smape: 93.0468 - val_loss: 1.3113 - val_k_smape: 105.2462
# Epoch 26/40
# 8s - loss: 1.2670 - k_smape: 92.9303 - val_loss: 1.3106 - val_k_smape: 104.3237
# Epoch 27/40
# 8s - loss: 1.2656 - k_smape: 92.7763 - val_loss: 1.3055 - val_k_smape: 104.9437
# Epoch 28/40
# 8s - loss: 1.2747 - k_smape: 92.9405 - val_loss: 1.3099 - val_k_smape: 105.0308
# Epoch 29/40
# 8s - loss: 1.2610 - k_smape: 92.6727 - val_loss: 1.3067 - val_k_smape: 104.6077
# Epoch 30/40
# 8s - loss: 1.2598 - k_smape: 92.5866 - val_loss: 1.3064 - val_k_smape: 103.9602
# Epoch 31/40
# 8s - loss: 1.2605 - k_smape: 92.6235 - val_loss: 1.3011 - val_k_smape: 103.9636
# Epoch 32/40
# 8s - loss: 1.2600 - k_smape: 92.5095 - val_loss: 1.3158 - val_k_smape: 104.8265
# Epoch 33/40
# 8s - loss: 1.2539 - k_smape: 92.2018 - val_loss: 1.3114 - val_k_smape: 104.4493
# Epoch 34/40
# 8s - loss: 1.2536 - k_smape: 92.2121 - val_loss: 1.3072 - val_k_smape: 103.9254
# Epoch 35/40
# 8s - loss: 1.2521 - k_smape: 92.0609 - val_loss: 1.3070 - val_k_smape: 103.6612
# Epoch 36/40
# 8s - loss: 1.2504 - k_smape: 92.2591 - val_loss: 1.3071 - val_k_smape: 105.3813
# Epoch 37/40
# 8s - loss: 1.2516 - k_smape: 92.0999 - val_loss: 1.3060 - val_k_smape: 104.3705
# Epoch 38/40
# 8s - loss: 1.2453 - k_smape: 91.8769 - val_loss: 1.3039 - val_k_smape: 102.9090
# Epoch 39/40
# 8s - loss: 1.2506 - k_smape: 91.9724 - val_loss: 1.3030 - val_k_smape: 103.8332
# Epoch 40/40
# 8s - loss: 1.2484 - k_smape: 91.8009 - val_loss: 1.3033 - val_k_smape: 103.7712
# --- Group: 5 / 6 ---
# Train on 29039 samples, validate on 3227 samples
# Epoch 1/40
# 6s - loss: 1.2687 - k_smape: 117.2736 - val_loss: 0.9214 - val_k_smape: 108.5526
# Epoch 2/40
# 6s - loss: 1.1007 - k_smape: 104.7771 - val_loss: 0.8978 - val_k_smape: 109.2076
# Epoch 3/40
# 6s - loss: 1.0666 - k_smape: 102.3581 - val_loss: 0.8472 - val_k_smape: 102.8244
# Epoch 4/40
# 6s - loss: 1.0511 - k_smape: 100.9676 - val_loss: 0.9438 - val_k_smape: 108.0192
# Epoch 5/40
# 6s - loss: 1.0365 - k_smape: 100.1415 - val_loss: 0.8957 - val_k_smape: 107.5827
# Epoch 6/40
# 6s - loss: 1.0265 - k_smape: 99.6312 - val_loss: 0.9200 - val_k_smape: 107.2115
# Epoch 7/40
# 6s - loss: 1.0249 - k_smape: 99.2688 - val_loss: 0.9056 - val_k_smape: 104.3464
# Epoch 8/40
# 6s - loss: 1.0181 - k_smape: 98.9515 - val_loss: 0.8414 - val_k_smape: 102.9559
# Epoch 9/40
# 6s - loss: 1.0138 - k_smape: 98.4232 - val_loss: 0.8761 - val_k_smape: 105.3918
# Epoch 10/40
# 6s - loss: 1.0054 - k_smape: 98.1279 - val_loss: 0.9100 - val_k_smape: 104.3286
# Epoch 11/40
# 6s - loss: 1.0042 - k_smape: 97.7754 - val_loss: 0.8767 - val_k_smape: 103.2901
# Epoch 12/40
# 6s - loss: 1.0017 - k_smape: 97.9313 - val_loss: 0.8767 - val_k_smape: 104.0019
# Epoch 13/40
# 6s - loss: 1.0004 - k_smape: 97.3851 - val_loss: 0.8920 - val_k_smape: 104.0981
# Epoch 14/40
# 6s - loss: 0.9981 - k_smape: 97.0984 - val_loss: 0.9231 - val_k_smape: 104.7988
# Epoch 15/40
# 6s - loss: 0.9943 - k_smape: 96.9657 - val_loss: 0.8131 - val_k_smape: 101.2308
# Epoch 16/40
# 6s - loss: 0.9897 - k_smape: 96.6712 - val_loss: 0.9320 - val_k_smape: 105.5375
# Epoch 17/40
# 6s - loss: 0.9907 - k_smape: 96.4010 - val_loss: 0.8917 - val_k_smape: 105.3011
# Epoch 18/40
# 6s - loss: 0.9839 - k_smape: 96.3350 - val_loss: 0.9144 - val_k_smape: 105.4624
# Epoch 19/40
# 6s - loss: 0.9840 - k_smape: 96.0783 - val_loss: 0.9243 - val_k_smape: 103.8508
# Epoch 20/40
# 6s - loss: 0.9828 - k_smape: 95.8901 - val_loss: 0.8871 - val_k_smape: 102.5501
# Epoch 21/40
# 6s - loss: 0.9763 - k_smape: 95.8430 - val_loss: 0.9116 - val_k_smape: 103.2003
# Epoch 22/40
# 6s - loss: 0.9790 - k_smape: 95.5406 - val_loss: 0.9157 - val_k_smape: 102.2638
# Epoch 23/40
# 6s - loss: 0.9755 - k_smape: 95.4545 - val_loss: 0.8990 - val_k_smape: 102.3976
# Epoch 24/40
# 6s - loss: 0.9682 - k_smape: 95.1870 - val_loss: 0.9228 - val_k_smape: 103.3270
# Epoch 25/40
# 6s - loss: 0.9696 - k_smape: 95.4953 - val_loss: 0.9351 - val_k_smape: 103.1929
# Epoch 26/40
# 6s - loss: 0.9673 - k_smape: 95.0199 - val_loss: 0.9154 - val_k_smape: 104.4587
# Epoch 27/40
# 6s - loss: 0.9665 - k_smape: 94.9724 - val_loss: 0.9143 - val_k_smape: 102.7569
# Epoch 28/40
# 6s - loss: 0.9670 - k_smape: 94.8530 - val_loss: 0.9499 - val_k_smape: 104.0688
# Epoch 29/40
# 6s - loss: 0.9666 - k_smape: 94.8190 - val_loss: 0.9452 - val_k_smape: 105.4394
# Epoch 30/40
# 6s - loss: 0.9667 - k_smape: 94.9262 - val_loss: 0.8895 - val_k_smape: 101.7185
# Epoch 31/40
# 6s - loss: 0.9583 - k_smape: 94.2303 - val_loss: 0.9103 - val_k_smape: 101.7452
# Epoch 32/40
# 6s - loss: 0.9601 - k_smape: 94.5406 - val_loss: 0.8684 - val_k_smape: 101.9077
# Epoch 33/40
# 6s - loss: 0.9605 - k_smape: 94.4185 - val_loss: 0.9128 - val_k_smape: 104.8718
# Epoch 34/40
# 6s - loss: 0.9587 - k_smape: 94.4524 - val_loss: 0.9042 - val_k_smape: 104.1883
# Epoch 35/40
# 6s - loss: 0.9604 - k_smape: 94.1086 - val_loss: 0.8435 - val_k_smape: 102.4568
# Epoch 36/40
# 6s - loss: 0.9597 - k_smape: 94.1955 - val_loss: 0.9149 - val_k_smape: 101.5609
# Epoch 37/40
# 6s - loss: 0.9561 - k_smape: 94.0662 - val_loss: 0.9003 - val_k_smape: 104.1575
# Epoch 38/40
# 6s - loss: 0.9495 - k_smape: 94.1095 - val_loss: 0.8879 - val_k_smape: 103.8103
# Epoch 39/40
# 6s - loss: 0.9491 - k_smape: 93.7706 - val_loss: 0.9261 - val_k_smape: 104.9907
# Epoch 40/40
# 6s - loss: 0.9482 - k_smape: 93.6178 - val_loss: 0.8447 - val_k_smape: 100.7256
# --- Group: 6 / 6 ---
# Train on 711 samples, validate on 80 samples
# Epoch 1/60
# 0s - loss: 3.1733 - k_smape: 163.1585 - val_loss: 4.1339 - val_k_smape: 144.5644
# Epoch 2/60
# 0s - loss: 2.7685 - k_smape: 138.5445 - val_loss: 3.7042 - val_k_smape: 137.0750
# Epoch 3/60
# 0s - loss: 2.5377 - k_smape: 134.4009 - val_loss: 3.3156 - val_k_smape: 127.6243
# Epoch 4/60
# 0s - loss: 2.3691 - k_smape: 125.5622 - val_loss: 2.8767 - val_k_smape: 115.8201
# Epoch 5/60
# 0s - loss: 2.2115 - k_smape: 118.4884 - val_loss: 2.6689 - val_k_smape: 109.1548
# Epoch 6/60
# 0s - loss: 2.0797 - k_smape: 115.5130 - val_loss: 2.5042 - val_k_smape: 105.0223
# Epoch 7/60
# 0s - loss: 2.0396 - k_smape: 111.0880 - val_loss: 2.3495 - val_k_smape: 104.6169
# Epoch 8/60
# 0s - loss: 1.9282 - k_smape: 109.3674 - val_loss: 2.0744 - val_k_smape: 98.0042
# Epoch 9/60
# 0s - loss: 1.9135 - k_smape: 105.8248 - val_loss: 2.4780 - val_k_smape: 100.1419
# Epoch 10/60
# 0s - loss: 1.8959 - k_smape: 102.3462 - val_loss: 1.9072 - val_k_smape: 94.4211
# Epoch 11/60
# 0s - loss: 1.8062 - k_smape: 103.2561 - val_loss: 2.0589 - val_k_smape: 95.7694
# Epoch 12/60
# 0s - loss: 1.7543 - k_smape: 99.5394 - val_loss: 1.8971 - val_k_smape: 94.1424
# Epoch 13/60
# 0s - loss: 1.7458 - k_smape: 99.0769 - val_loss: 1.8071 - val_k_smape: 91.2382
# Epoch 14/60
# 0s - loss: 1.7340 - k_smape: 97.5113 - val_loss: 1.8416 - val_k_smape: 93.5379
# Epoch 15/60
# 0s - loss: 1.6709 - k_smape: 96.9265 - val_loss: 1.6016 - val_k_smape: 87.7345
# Epoch 16/60
# 0s - loss: 1.6857 - k_smape: 96.7505 - val_loss: 2.1789 - val_k_smape: 98.1708
# Epoch 17/60
# 0s - loss: 1.6714 - k_smape: 92.8206 - val_loss: 1.9339 - val_k_smape: 91.1825
# Epoch 18/60
# 0s - loss: 1.6773 - k_smape: 94.9592 - val_loss: 1.6969 - val_k_smape: 89.3659
# Epoch 19/60
# 0s - loss: 1.6907 - k_smape: 94.2343 - val_loss: 2.0118 - val_k_smape: 93.9354
# Epoch 20/60
# 0s - loss: 1.6130 - k_smape: 90.5680 - val_loss: 1.7781 - val_k_smape: 87.0452
# Epoch 21/60
# 0s - loss: 1.6558 - k_smape: 92.2855 - val_loss: 1.6179 - val_k_smape: 86.8128
# Epoch 22/60
# 0s - loss: 1.6745 - k_smape: 90.2251 - val_loss: 1.9722 - val_k_smape: 92.7426
# Epoch 23/60
# 0s - loss: 1.5896 - k_smape: 91.6797 - val_loss: 1.6521 - val_k_smape: 84.1477
# Epoch 24/60
# 0s - loss: 1.5699 - k_smape: 89.4001 - val_loss: 1.6726 - val_k_smape: 85.7854
# Epoch 25/60
# 0s - loss: 1.5603 - k_smape: 87.0411 - val_loss: 1.6422 - val_k_smape: 84.3950
# Epoch 26/60
# 0s - loss: 1.5271 - k_smape: 87.2997 - val_loss: 1.6911 - val_k_smape: 85.3245
# Epoch 27/60
# 0s - loss: 1.4875 - k_smape: 87.7031 - val_loss: 1.5378 - val_k_smape: 82.4036
# Epoch 28/60
# 0s - loss: 1.4868 - k_smape: 84.7957 - val_loss: 1.6788 - val_k_smape: 81.1763
# Epoch 29/60
# 0s - loss: 1.4884 - k_smape: 85.9533 - val_loss: 1.6213 - val_k_smape: 80.1649
# Epoch 30/60
# 0s - loss: 1.4931 - k_smape: 84.1768 - val_loss: 1.4987 - val_k_smape: 82.0550
# Epoch 31/60
# 0s - loss: 1.4549 - k_smape: 87.1391 - val_loss: 1.7965 - val_k_smape: 83.3522
# Epoch 32/60
# 0s - loss: 1.5368 - k_smape: 84.2849 - val_loss: 1.8134 - val_k_smape: 82.4693
# Epoch 33/60
# 0s - loss: 1.4607 - k_smape: 84.9771 - val_loss: 1.4630 - val_k_smape: 79.7005
# Epoch 34/60
# 0s - loss: 1.4678 - k_smape: 84.3528 - val_loss: 1.6643 - val_k_smape: 80.6017
# Epoch 35/60
# 0s - loss: 1.4160 - k_smape: 83.7013 - val_loss: 1.5594 - val_k_smape: 84.2432
# Epoch 36/60
# 0s - loss: 1.4626 - k_smape: 85.8338 - val_loss: 1.7494 - val_k_smape: 81.9269
# Epoch 37/60
# 0s - loss: 1.4443 - k_smape: 83.4035 - val_loss: 1.4555 - val_k_smape: 78.3649
# Epoch 38/60
# 0s - loss: 1.4485 - k_smape: 81.9622 - val_loss: 1.5784 - val_k_smape: 78.2515
# Epoch 39/60
# 0s - loss: 1.4493 - k_smape: 82.9362 - val_loss: 1.3496 - val_k_smape: 77.1339
# Epoch 40/60
# 0s - loss: 1.4600 - k_smape: 82.3231 - val_loss: 1.5785 - val_k_smape: 77.8365
# Epoch 41/60
# 0s - loss: 1.4327 - k_smape: 82.3665 - val_loss: 1.5210 - val_k_smape: 81.2378
# Epoch 42/60
# 0s - loss: 1.4173 - k_smape: 83.0913 - val_loss: 1.4992 - val_k_smape: 78.4067
# Epoch 43/60
# 0s - loss: 1.3854 - k_smape: 80.2107 - val_loss: 1.4853 - val_k_smape: 79.8986
# Epoch 44/60
# 0s - loss: 1.3745 - k_smape: 82.2782 - val_loss: 1.5266 - val_k_smape: 79.4961
# Epoch 45/60
# 0s - loss: 1.3541 - k_smape: 82.2178 - val_loss: 1.6801 - val_k_smape: 77.6969
# Epoch 46/60
# 0s - loss: 1.3879 - k_smape: 81.0822 - val_loss: 1.3386 - val_k_smape: 76.4446
# Epoch 47/60
# 0s - loss: 1.4229 - k_smape: 83.8119 - val_loss: 1.6544 - val_k_smape: 79.2833
# Epoch 48/60
# 0s - loss: 1.4190 - k_smape: 81.4996 - val_loss: 1.5181 - val_k_smape: 77.8262
# Epoch 49/60
# 0s - loss: 1.3482 - k_smape: 80.9567 - val_loss: 1.4734 - val_k_smape: 77.1825
# Epoch 50/60
# 0s - loss: 1.3528 - k_smape: 79.9185 - val_loss: 1.6818 - val_k_smape: 78.2577
# Epoch 51/60
# 0s - loss: 1.3569 - k_smape: 80.0648 - val_loss: 1.3700 - val_k_smape: 75.5288
# Epoch 52/60
# 0s - loss: 1.3543 - k_smape: 79.7688 - val_loss: 1.5303 - val_k_smape: 77.5623
# Epoch 53/60
# 0s - loss: 1.3639 - k_smape: 79.5767 - val_loss: 1.3829 - val_k_smape: 77.4417
# Epoch 54/60
# 0s - loss: 1.4289 - k_smape: 79.7317 - val_loss: 1.4432 - val_k_smape: 75.9025
# Epoch 55/60
# 0s - loss: 1.3354 - k_smape: 77.9122 - val_loss: 1.4691 - val_k_smape: 75.1606
# Epoch 56/60
# 0s - loss: 1.3695 - k_smape: 78.8857 - val_loss: 1.6641 - val_k_smape: 78.1763
# Epoch 57/60
# 0s - loss: 1.3214 - k_smape: 79.1898 - val_loss: 1.3308 - val_k_smape: 75.3039
# Epoch 58/60
# 0s - loss: 1.3591 - k_smape: 78.1270 - val_loss: 1.8832 - val_k_smape: 82.3991
# Epoch 59/60
# 0s - loss: 1.3624 - k_smape: 80.9381 - val_loss: 1.8825 - val_k_smape: 81.3677
# Epoch 60/60
# 0s - loss: 1.3864 - k_smape: 80.0975 - val_loss: 1.3704 - val_k_smape: 76.0466
# === Run: 2 / 5 ===
# --- Group: 1 / 6 ---
# Train on 22467 samples, validate on 2497 samples
# Epoch 1/1
# 5s - loss: 1.1059 - k_smape: 149.5475 - val_loss: 0.9661 - val_k_smape: 133.4822
# --- Group: 2 / 6 ---
# Train on 13986 samples, validate on 1554 samples
# Epoch 1/40
# 3s - loss: 1.6883 - k_smape: 134.8807 - val_loss: 1.3186 - val_k_smape: 127.7598
# Epoch 2/40
# 3s - loss: 1.5432 - k_smape: 122.2375 - val_loss: 1.3122 - val_k_smape: 127.8216
# Epoch 3/40
# 3s - loss: 1.5159 - k_smape: 119.6893 - val_loss: 1.3208 - val_k_smape: 125.1923
# Epoch 4/40
# 3s - loss: 1.4996 - k_smape: 117.9289 - val_loss: 1.3158 - val_k_smape: 122.6206
# Epoch 5/40
# 3s - loss: 1.4858 - k_smape: 116.9111 - val_loss: 1.3153 - val_k_smape: 120.4031
# Epoch 6/40
# 3s - loss: 1.4841 - k_smape: 116.2015 - val_loss: 1.3227 - val_k_smape: 125.3781
# Epoch 7/40
# 3s - loss: 1.4757 - k_smape: 115.7842 - val_loss: 1.3249 - val_k_smape: 121.1135
# Epoch 8/40
# 3s - loss: 1.4602 - k_smape: 114.2920 - val_loss: 1.3045 - val_k_smape: 119.6384
# Epoch 9/40
# 3s - loss: 1.4848 - k_smape: 114.1353 - val_loss: 1.3306 - val_k_smape: 121.6751
# Epoch 10/40
# 3s - loss: 1.4749 - k_smape: 114.7716 - val_loss: 1.3210 - val_k_smape: 120.4160
# Epoch 11/40
# 3s - loss: 1.4565 - k_smape: 113.9775 - val_loss: 1.2989 - val_k_smape: 119.0505
# Epoch 12/40
# 3s - loss: 1.4583 - k_smape: 113.5253 - val_loss: 1.3160 - val_k_smape: 122.8248
# Epoch 13/40
# 3s - loss: 1.4460 - k_smape: 113.0490 - val_loss: 1.3111 - val_k_smape: 118.1604
# Epoch 14/40
# 3s - loss: 1.4444 - k_smape: 112.5440 - val_loss: 1.3130 - val_k_smape: 117.9342
# Epoch 15/40
# 3s - loss: 1.4568 - k_smape: 112.5959 - val_loss: 1.3092 - val_k_smape: 123.3784
# Epoch 16/40
# 3s - loss: 1.4436 - k_smape: 112.3992 - val_loss: 1.3209 - val_k_smape: 122.1595
# Epoch 17/40
# 3s - loss: 1.4705 - k_smape: 112.8070 - val_loss: 1.3104 - val_k_smape: 118.4002
# Epoch 18/40
# 3s - loss: 1.4452 - k_smape: 111.9710 - val_loss: 1.3236 - val_k_smape: 121.5058
# Epoch 19/40
# 3s - loss: 1.4440 - k_smape: 111.9913 - val_loss: 1.3053 - val_k_smape: 118.2956
# Epoch 20/40
# 3s - loss: 1.4339 - k_smape: 111.6773 - val_loss: 1.3328 - val_k_smape: 122.8709
# Epoch 21/40
# 3s - loss: 1.4245 - k_smape: 111.0995 - val_loss: 1.3272 - val_k_smape: 122.0965
# Epoch 22/40
# 3s - loss: 1.4339 - k_smape: 111.1601 - val_loss: 1.3147 - val_k_smape: 119.1077
# Epoch 23/40
# 3s - loss: 1.4319 - k_smape: 111.1364 - val_loss: 1.3075 - val_k_smape: 120.0731
# Epoch 24/40
# 3s - loss: 1.4381 - k_smape: 111.3334 - val_loss: 1.3191 - val_k_smape: 119.6729
# Epoch 25/40
# 3s - loss: 1.4241 - k_smape: 110.9355 - val_loss: 1.3102 - val_k_smape: 120.9324
# Epoch 26/40
# 3s - loss: 1.4189 - k_smape: 110.4794 - val_loss: 1.3141 - val_k_smape: 120.7391
# Epoch 27/40
# 3s - loss: 1.4213 - k_smape: 110.5229 - val_loss: 1.2994 - val_k_smape: 117.2324
# Epoch 28/40
# 3s - loss: 1.4174 - k_smape: 110.5428 - val_loss: 1.3084 - val_k_smape: 118.9336
# Epoch 29/40
# 3s - loss: 1.4119 - k_smape: 109.5880 - val_loss: 1.3032 - val_k_smape: 118.1426
# Epoch 30/40
# 3s - loss: 1.4191 - k_smape: 110.4984 - val_loss: 1.3202 - val_k_smape: 122.0955
# Epoch 31/40
# 3s - loss: 1.4119 - k_smape: 109.8623 - val_loss: 1.3256 - val_k_smape: 119.9702
# Epoch 32/40
# 3s - loss: 1.4142 - k_smape: 109.8147 - val_loss: 1.3183 - val_k_smape: 119.1453
# Epoch 33/40
# 3s - loss: 1.4082 - k_smape: 109.6707 - val_loss: 1.3054 - val_k_smape: 118.6544
# Epoch 34/40
# 3s - loss: 1.3990 - k_smape: 109.2667 - val_loss: 1.3033 - val_k_smape: 117.8684
# Epoch 35/40
# 3s - loss: 1.3972 - k_smape: 109.2878 - val_loss: 1.3129 - val_k_smape: 117.8806
# Epoch 36/40
# 3s - loss: 1.3999 - k_smape: 108.7033 - val_loss: 1.3033 - val_k_smape: 119.2092
# Epoch 37/40
# 3s - loss: 1.3976 - k_smape: 109.5941 - val_loss: 1.3165 - val_k_smape: 117.0655
# Epoch 38/40
# 3s - loss: 1.3971 - k_smape: 108.9500 - val_loss: 1.3112 - val_k_smape: 117.3766
# Epoch 39/40
# 3s - loss: 1.3790 - k_smape: 108.9705 - val_loss: 1.3104 - val_k_smape: 116.3568
# Epoch 40/40
# 3s - loss: 1.4151 - k_smape: 109.2433 - val_loss: 1.3269 - val_k_smape: 118.5151
# --- Group: 3 / 6 ---
# Train on 25335 samples, validate on 2816 samples
# Epoch 1/40
# 6s - loss: 1.1751 - k_smape: 129.8478 - val_loss: 0.9511 - val_k_smape: 113.3852
# Epoch 2/40
# 5s - loss: 1.0897 - k_smape: 119.4767 - val_loss: 0.9736 - val_k_smape: 119.2944
# Epoch 3/40
# 5s - loss: 1.0744 - k_smape: 117.0862 - val_loss: 0.9318 - val_k_smape: 110.7749
# Epoch 4/40
# 5s - loss: 1.0621 - k_smape: 115.7383 - val_loss: 0.9513 - val_k_smape: 120.5717
# Epoch 5/40
# 5s - loss: 1.0515 - k_smape: 115.0441 - val_loss: 0.9380 - val_k_smape: 120.7831
# Epoch 6/40
# 5s - loss: 1.0477 - k_smape: 114.5899 - val_loss: 0.9501 - val_k_smape: 115.7226
# Epoch 7/40
# 5s - loss: 1.0423 - k_smape: 113.6512 - val_loss: 0.9290 - val_k_smape: 117.0460
# Epoch 8/40
# 5s - loss: 1.0380 - k_smape: 113.4713 - val_loss: 0.9678 - val_k_smape: 117.2119
# Epoch 9/40
# 5s - loss: 1.0366 - k_smape: 113.3347 - val_loss: 0.9510 - val_k_smape: 114.5791
# Epoch 10/40
# 5s - loss: 1.0340 - k_smape: 113.0498 - val_loss: 0.9597 - val_k_smape: 116.7397
# Epoch 11/40
# 5s - loss: 1.0330 - k_smape: 112.9017 - val_loss: 0.9411 - val_k_smape: 116.9680
# Epoch 12/40
# 5s - loss: 1.0278 - k_smape: 112.4511 - val_loss: 1.0009 - val_k_smape: 121.5563
# Epoch 13/40
# 5s - loss: 1.0298 - k_smape: 112.3653 - val_loss: 0.9507 - val_k_smape: 119.1117
# Epoch 14/40
# 5s - loss: 1.0279 - k_smape: 112.3702 - val_loss: 0.9546 - val_k_smape: 118.6622
# Epoch 15/40
# 5s - loss: 1.0217 - k_smape: 111.7023 - val_loss: 0.9565 - val_k_smape: 116.0356
# Epoch 16/40
# 5s - loss: 1.0190 - k_smape: 111.5643 - val_loss: 0.9566 - val_k_smape: 119.3910
# Epoch 17/40
# 5s - loss: 1.0190 - k_smape: 111.6212 - val_loss: 0.9515 - val_k_smape: 117.0881
# Epoch 18/40
# 5s - loss: 1.0202 - k_smape: 111.2351 - val_loss: 0.9647 - val_k_smape: 118.2914
# Epoch 19/40
# 5s - loss: 1.0141 - k_smape: 111.1636 - val_loss: 0.9440 - val_k_smape: 114.8744
# Epoch 20/40
# 5s - loss: 1.0154 - k_smape: 111.3911 - val_loss: 1.0003 - val_k_smape: 121.8524
# Epoch 21/40
# 5s - loss: 1.0130 - k_smape: 111.0783 - val_loss: 0.9457 - val_k_smape: 115.3176
# Epoch 22/40
# 5s - loss: 1.0102 - k_smape: 110.9995 - val_loss: 0.9767 - val_k_smape: 117.4769
# Epoch 23/40
# 5s - loss: 1.0097 - k_smape: 110.6003 - val_loss: 0.9658 - val_k_smape: 119.0066
# Epoch 24/40
# 5s - loss: 1.0082 - k_smape: 110.5769 - val_loss: 0.9586 - val_k_smape: 116.6736
# Epoch 25/40
# 5s - loss: 1.0056 - k_smape: 110.3490 - val_loss: 0.9609 - val_k_smape: 116.6928
# Epoch 26/40
# 5s - loss: 1.0018 - k_smape: 110.0577 - val_loss: 0.9707 - val_k_smape: 115.9594
# Epoch 27/40
# 5s - loss: 1.0034 - k_smape: 110.3089 - val_loss: 0.9539 - val_k_smape: 116.7291
# Epoch 28/40
# 5s - loss: 1.0014 - k_smape: 110.0801 - val_loss: 0.9785 - val_k_smape: 116.5231
# Epoch 29/40
# 5s - loss: 1.0028 - k_smape: 110.1865 - val_loss: 0.9753 - val_k_smape: 117.4614
# Epoch 30/40
# 5s - loss: 0.9994 - k_smape: 109.7451 - val_loss: 0.9836 - val_k_smape: 118.9002
# Epoch 31/40
# 5s - loss: 0.9940 - k_smape: 109.7446 - val_loss: 0.9662 - val_k_smape: 115.5469
# Epoch 32/40
# 5s - loss: 0.9940 - k_smape: 109.6061 - val_loss: 0.9622 - val_k_smape: 114.6892
# Epoch 33/40
# 5s - loss: 0.9926 - k_smape: 109.4490 - val_loss: 0.9748 - val_k_smape: 116.9244
# Epoch 34/40
# 5s - loss: 0.9886 - k_smape: 109.3718 - val_loss: 0.9556 - val_k_smape: 115.9645
# Epoch 35/40
# 5s - loss: 0.9890 - k_smape: 109.0331 - val_loss: 0.9693 - val_k_smape: 121.0357
# Epoch 36/40
# 5s - loss: 0.9879 - k_smape: 109.2020 - val_loss: 0.9691 - val_k_smape: 118.0873
# Epoch 37/40
# 5s - loss: 0.9866 - k_smape: 109.0914 - val_loss: 0.9597 - val_k_smape: 116.4239
# Epoch 38/40
# 5s - loss: 0.9869 - k_smape: 109.0739 - val_loss: 0.9668 - val_k_smape: 115.9867
# Epoch 39/40
# 5s - loss: 0.9846 - k_smape: 108.8723 - val_loss: 0.9682 - val_k_smape: 114.8412
# Epoch 40/40
# 5s - loss: 0.9830 - k_smape: 108.7865 - val_loss: 0.9666 - val_k_smape: 115.9257
# --- Group: 4 / 6 ---
# Train on 39015 samples, validate on 4336 samples
# Epoch 1/40
# 9s - loss: 1.4807 - k_smape: 110.0281 - val_loss: 1.3411 - val_k_smape: 107.6711
# Epoch 2/40
# 8s - loss: 1.3704 - k_smape: 100.1168 - val_loss: 1.3366 - val_k_smape: 108.1210
# Epoch 3/40
# 8s - loss: 1.3461 - k_smape: 98.2508 - val_loss: 1.3500 - val_k_smape: 107.3688
# Epoch 4/40
# 8s - loss: 1.3337 - k_smape: 97.4475 - val_loss: 1.3395 - val_k_smape: 105.9014
# Epoch 5/40
# 8s - loss: 1.3263 - k_smape: 96.6946 - val_loss: 1.3272 - val_k_smape: 106.7757
# Epoch 6/40
# 8s - loss: 1.3190 - k_smape: 96.1487 - val_loss: 1.3246 - val_k_smape: 105.1724
# Epoch 7/40
# 8s - loss: 1.3168 - k_smape: 95.9169 - val_loss: 1.3338 - val_k_smape: 105.1854
# Epoch 8/40
# 8s - loss: 1.3124 - k_smape: 95.5426 - val_loss: 1.3236 - val_k_smape: 104.1227
# Epoch 9/40
# 8s - loss: 1.3087 - k_smape: 95.0239 - val_loss: 1.3239 - val_k_smape: 105.5357
# Epoch 10/40
# 8s - loss: 1.3040 - k_smape: 94.9779 - val_loss: 1.3188 - val_k_smape: 105.1345
# Epoch 11/40
# 8s - loss: 1.2989 - k_smape: 94.6694 - val_loss: 1.3270 - val_k_smape: 104.8990
# Epoch 12/40
# 8s - loss: 1.2985 - k_smape: 94.7597 - val_loss: 1.3164 - val_k_smape: 105.3816
# Epoch 13/40
# 8s - loss: 1.2929 - k_smape: 94.3680 - val_loss: 1.3117 - val_k_smape: 104.3914
# Epoch 14/40
# 8s - loss: 1.2885 - k_smape: 94.1225 - val_loss: 1.3254 - val_k_smape: 106.9607
# Epoch 15/40
# 8s - loss: 1.2871 - k_smape: 93.9564 - val_loss: 1.3083 - val_k_smape: 104.1226
# Epoch 16/40
# 8s - loss: 1.2851 - k_smape: 93.7990 - val_loss: 1.3125 - val_k_smape: 103.6866
# Epoch 17/40
# 8s - loss: 1.2851 - k_smape: 93.6721 - val_loss: 1.3165 - val_k_smape: 104.8248
# Epoch 18/40
# 8s - loss: 1.2797 - k_smape: 93.4128 - val_loss: 1.3142 - val_k_smape: 105.6864
# Epoch 19/40
# 8s - loss: 1.2808 - k_smape: 93.6697 - val_loss: 1.3123 - val_k_smape: 105.3670
# Epoch 20/40
# 8s - loss: 1.2771 - k_smape: 93.2250 - val_loss: 1.3103 - val_k_smape: 105.1600
# Epoch 21/40
# 8s - loss: 1.2761 - k_smape: 93.2918 - val_loss: 1.3029 - val_k_smape: 103.9174
# Epoch 22/40
# 8s - loss: 1.2727 - k_smape: 93.1309 - val_loss: 1.3207 - val_k_smape: 105.6953
# Epoch 23/40
# 8s - loss: 1.2724 - k_smape: 93.1133 - val_loss: 1.3055 - val_k_smape: 104.3099
# Epoch 24/40
# 8s - loss: 1.2693 - k_smape: 92.8552 - val_loss: 1.3068 - val_k_smape: 103.8861
# Epoch 25/40
# 8s - loss: 1.2657 - k_smape: 92.8096 - val_loss: 1.3148 - val_k_smape: 105.6643
# Epoch 26/40
# 8s - loss: 1.2622 - k_smape: 92.5164 - val_loss: 1.3061 - val_k_smape: 105.4070
# Epoch 27/40
# 8s - loss: 1.2656 - k_smape: 92.7916 - val_loss: 1.3053 - val_k_smape: 104.3196
# Epoch 28/40
# 8s - loss: 1.2591 - k_smape: 92.2256 - val_loss: 1.3021 - val_k_smape: 104.5491
# Epoch 29/40
# 8s - loss: 1.2587 - k_smape: 92.2990 - val_loss: 1.3055 - val_k_smape: 105.4713
# Epoch 30/40
# 8s - loss: 1.2570 - k_smape: 92.3791 - val_loss: 1.2969 - val_k_smape: 103.8567
# Epoch 31/40
# 8s - loss: 1.2512 - k_smape: 92.1791 - val_loss: 1.2929 - val_k_smape: 103.9440
# Epoch 32/40
# 8s - loss: 1.2504 - k_smape: 92.0177 - val_loss: 1.2959 - val_k_smape: 104.6698
# Epoch 33/40
# 8s - loss: 1.2498 - k_smape: 92.0591 - val_loss: 1.2997 - val_k_smape: 103.8453
# Epoch 34/40
# 8s - loss: 1.2494 - k_smape: 92.0062 - val_loss: 1.3011 - val_k_smape: 103.2983
# Epoch 35/40
# 8s - loss: 1.2465 - k_smape: 91.7519 - val_loss: 1.2897 - val_k_smape: 102.5087
# Epoch 36/40
# 8s - loss: 1.2456 - k_smape: 91.7492 - val_loss: 1.2968 - val_k_smape: 103.2919
# Epoch 37/40
# 8s - loss: 1.2439 - k_smape: 91.6602 - val_loss: 1.2953 - val_k_smape: 104.2853
# Epoch 38/40
# 8s - loss: 1.2389 - k_smape: 91.7169 - val_loss: 1.2976 - val_k_smape: 103.9720
# Epoch 39/40
# 8s - loss: 1.2412 - k_smape: 91.7337 - val_loss: 1.2943 - val_k_smape: 104.7136
# Epoch 40/40
# 8s - loss: 1.2398 - k_smape: 91.7101 - val_loss: 1.2943 - val_k_smape: 103.8087
# --- Group: 5 / 6 ---
# Train on 29039 samples, validate on 3227 samples
# Epoch 1/40
# 7s - loss: 1.2744 - k_smape: 118.4855 - val_loss: 0.9595 - val_k_smape: 115.4576
# Epoch 2/40
# 6s - loss: 1.1102 - k_smape: 106.4593 - val_loss: 0.9818 - val_k_smape: 113.3878
# Epoch 3/40
# 6s - loss: 1.0923 - k_smape: 104.3371 - val_loss: 1.0058 - val_k_smape: 111.7222
# Epoch 4/40
# 6s - loss: 1.0574 - k_smape: 102.5975 - val_loss: 0.8495 - val_k_smape: 108.5257
# Epoch 5/40
# 6s - loss: 1.0373 - k_smape: 101.2595 - val_loss: 0.8411 - val_k_smape: 104.9498
# Epoch 6/40
# 6s - loss: 1.0371 - k_smape: 100.9075 - val_loss: 0.8550 - val_k_smape: 106.0924
# Epoch 7/40
# 6s - loss: 1.0249 - k_smape: 99.9181 - val_loss: 0.8431 - val_k_smape: 104.2206
# Epoch 8/40
# 6s - loss: 1.0190 - k_smape: 99.5376 - val_loss: 0.8411 - val_k_smape: 104.7939
# Epoch 9/40
# 6s - loss: 1.0128 - k_smape: 99.1311 - val_loss: 0.8207 - val_k_smape: 102.6155
# Epoch 10/40
# 6s - loss: 1.0106 - k_smape: 98.9719 - val_loss: 0.8437 - val_k_smape: 103.2394
# Epoch 11/40
# 6s - loss: 1.0051 - k_smape: 98.3897 - val_loss: 0.9075 - val_k_smape: 103.0035
# Epoch 12/40
# 6s - loss: 1.0091 - k_smape: 98.5960 - val_loss: 0.8566 - val_k_smape: 106.4845
# Epoch 13/40
# 6s - loss: 1.0046 - k_smape: 98.1370 - val_loss: 0.9013 - val_k_smape: 105.2897
# Epoch 14/40
# 6s - loss: 1.0018 - k_smape: 97.7507 - val_loss: 0.8460 - val_k_smape: 102.1090
# Epoch 15/40
# 6s - loss: 0.9992 - k_smape: 97.7211 - val_loss: 0.8967 - val_k_smape: 104.2645
# Epoch 16/40
# 6s - loss: 0.9958 - k_smape: 97.6891 - val_loss: 0.8180 - val_k_smape: 104.2192
# Epoch 17/40
# 6s - loss: 0.9991 - k_smape: 97.4094 - val_loss: 0.8395 - val_k_smape: 103.7908
# Epoch 18/40
# 6s - loss: 0.9905 - k_smape: 96.9948 - val_loss: 0.8506 - val_k_smape: 101.9506
# Epoch 19/40
# 6s - loss: 0.9863 - k_smape: 96.7158 - val_loss: 0.8152 - val_k_smape: 102.4082
# Epoch 20/40
# 6s - loss: 0.9872 - k_smape: 96.8276 - val_loss: 0.8239 - val_k_smape: 103.2818
# Epoch 21/40
# 6s - loss: 0.9839 - k_smape: 96.5678 - val_loss: 0.8865 - val_k_smape: 104.1815
# Epoch 22/40
# 6s - loss: 0.9820 - k_smape: 96.0532 - val_loss: 0.8640 - val_k_smape: 103.0565
# Epoch 23/40
# 6s - loss: 0.9811 - k_smape: 96.0467 - val_loss: 0.8680 - val_k_smape: 102.2639
# Epoch 24/40
# 6s - loss: 0.9856 - k_smape: 96.2058 - val_loss: 0.8628 - val_k_smape: 100.4801
# Epoch 25/40
# 6s - loss: 0.9804 - k_smape: 96.1847 - val_loss: 0.8165 - val_k_smape: 101.2536
# Epoch 26/40
# 6s - loss: 0.9842 - k_smape: 96.0320 - val_loss: 0.8259 - val_k_smape: 101.5655
# Epoch 27/40
# 6s - loss: 0.9791 - k_smape: 95.6919 - val_loss: 0.8651 - val_k_smape: 102.4912
# Epoch 28/40
# 6s - loss: 0.9771 - k_smape: 95.7750 - val_loss: 0.8472 - val_k_smape: 103.0288
# Epoch 29/40
# 6s - loss: 0.9702 - k_smape: 95.5190 - val_loss: 0.8242 - val_k_smape: 100.8327
# Epoch 30/40
# 6s - loss: 0.9679 - k_smape: 95.3055 - val_loss: 0.8314 - val_k_smape: 101.5201
# Epoch 31/40
# 6s - loss: 0.9684 - k_smape: 95.2004 - val_loss: 0.8573 - val_k_smape: 103.0191
# Epoch 32/40
# 6s - loss: 0.9703 - k_smape: 95.1591 - val_loss: 0.8544 - val_k_smape: 102.3457
# Epoch 33/40
# 6s - loss: 0.9709 - k_smape: 95.0647 - val_loss: 0.8176 - val_k_smape: 101.8132
# Epoch 34/40
# 6s - loss: 0.9658 - k_smape: 95.1661 - val_loss: 0.8139 - val_k_smape: 101.5905
# Epoch 35/40
# 6s - loss: 0.9665 - k_smape: 94.8870 - val_loss: 0.8298 - val_k_smape: 101.0215
# Epoch 36/40
# 6s - loss: 0.9666 - k_smape: 94.5262 - val_loss: 0.8932 - val_k_smape: 101.5562
# Epoch 37/40
# 6s - loss: 0.9642 - k_smape: 94.4513 - val_loss: 0.8686 - val_k_smape: 101.8859
# Epoch 38/40
# 6s - loss: 0.9639 - k_smape: 94.9414 - val_loss: 0.8467 - val_k_smape: 100.0517
# Epoch 39/40
# 6s - loss: 0.9645 - k_smape: 94.6808 - val_loss: 0.8436 - val_k_smape: 100.7331
# Epoch 40/40
# 6s - loss: 0.9616 - k_smape: 94.3315 - val_loss: 0.8357 - val_k_smape: 100.3319
# --- Group: 6 / 6 ---
# Train on 711 samples, validate on 80 samples
# Epoch 1/60
# 0s - loss: 3.1274 - k_smape: 161.4038 - val_loss: 4.0280 - val_k_smape: 145.9247
# Epoch 2/60
# 0s - loss: 2.7137 - k_smape: 137.3601 - val_loss: 3.5897 - val_k_smape: 140.2104
# Epoch 3/60
# 0s - loss: 2.5005 - k_smape: 134.7127 - val_loss: 3.2181 - val_k_smape: 129.9446
# Epoch 4/60
# 0s - loss: 2.3155 - k_smape: 127.2766 - val_loss: 3.0945 - val_k_smape: 122.8955
# Epoch 5/60
# 0s - loss: 2.1894 - k_smape: 120.9838 - val_loss: 2.8140 - val_k_smape: 114.1381
# Epoch 6/60
# 0s - loss: 2.0588 - k_smape: 115.6206 - val_loss: 2.4188 - val_k_smape: 105.7251
# Epoch 7/60
# 0s - loss: 1.9971 - k_smape: 109.7124 - val_loss: 2.6055 - val_k_smape: 106.0299
# Epoch 8/60
# 0s - loss: 1.9559 - k_smape: 108.9070 - val_loss: 2.0370 - val_k_smape: 96.8427
# Epoch 9/60
# 0s - loss: 1.8658 - k_smape: 104.6153 - val_loss: 2.4253 - val_k_smape: 101.8945
# Epoch 10/60
# 0s - loss: 1.9059 - k_smape: 103.3005 - val_loss: 1.9151 - val_k_smape: 94.1414
# Epoch 11/60
# 0s - loss: 1.7964 - k_smape: 102.7716 - val_loss: 1.9248 - val_k_smape: 91.7991
# Epoch 12/60
# 0s - loss: 1.7893 - k_smape: 98.4180 - val_loss: 2.0986 - val_k_smape: 99.7913
# Epoch 13/60
# 0s - loss: 1.7229 - k_smape: 102.1928 - val_loss: 1.7583 - val_k_smape: 88.8454
# Epoch 14/60
# 0s - loss: 1.8081 - k_smape: 96.3153 - val_loss: 2.0448 - val_k_smape: 95.6870
# Epoch 15/60
# 0s - loss: 1.6712 - k_smape: 98.2249 - val_loss: 1.6606 - val_k_smape: 90.3585
# Epoch 16/60
# 0s - loss: 1.6952 - k_smape: 96.8922 - val_loss: 1.9191 - val_k_smape: 88.1031
# Epoch 17/60
# 0s - loss: 1.6402 - k_smape: 91.4360 - val_loss: 1.6289 - val_k_smape: 87.4429
# Epoch 18/60
# 0s - loss: 1.6383 - k_smape: 96.2919 - val_loss: 1.7963 - val_k_smape: 88.9603
# Epoch 19/60
# 0s - loss: 1.6069 - k_smape: 91.4065 - val_loss: 1.9057 - val_k_smape: 90.3282
# Epoch 20/60
# 0s - loss: 1.5656 - k_smape: 91.6773 - val_loss: 1.7501 - val_k_smape: 86.9939
# Epoch 21/60
# 0s - loss: 1.5587 - k_smape: 90.5229 - val_loss: 1.6609 - val_k_smape: 86.2371
# Epoch 22/60
# 0s - loss: 1.5708 - k_smape: 91.6379 - val_loss: 1.7920 - val_k_smape: 85.5061
# Epoch 23/60
# 0s - loss: 1.5529 - k_smape: 88.6181 - val_loss: 1.8030 - val_k_smape: 85.9623
# Epoch 24/60
# 0s - loss: 1.5686 - k_smape: 91.4182 - val_loss: 1.5893 - val_k_smape: 88.7671
# Epoch 25/60
# 0s - loss: 1.5929 - k_smape: 91.4525 - val_loss: 1.7965 - val_k_smape: 84.6448
# Epoch 26/60
# 0s - loss: 1.5193 - k_smape: 87.6265 - val_loss: 1.7292 - val_k_smape: 87.9632
# Epoch 27/60
# 0s - loss: 1.5153 - k_smape: 88.6525 - val_loss: 1.5573 - val_k_smape: 82.9977
# Epoch 28/60
# 0s - loss: 1.5159 - k_smape: 87.6659 - val_loss: 1.8165 - val_k_smape: 88.3988
# Epoch 29/60
# 0s - loss: 1.4846 - k_smape: 87.1358 - val_loss: 1.6822 - val_k_smape: 83.2666
# Epoch 30/60
# 0s - loss: 1.5332 - k_smape: 85.8890 - val_loss: 1.4797 - val_k_smape: 79.0576
# Epoch 31/60
# 0s - loss: 1.5386 - k_smape: 88.3557 - val_loss: 1.8291 - val_k_smape: 86.8406
# Epoch 32/60
# 0s - loss: 1.5437 - k_smape: 86.2845 - val_loss: 1.7037 - val_k_smape: 83.2163
# Epoch 33/60
# 0s - loss: 1.4823 - k_smape: 87.8171 - val_loss: 1.4704 - val_k_smape: 78.8205
# Epoch 34/60
# 0s - loss: 1.4393 - k_smape: 83.1251 - val_loss: 2.0053 - val_k_smape: 88.3191
# Epoch 35/60
# 0s - loss: 1.4719 - k_smape: 86.0888 - val_loss: 1.4819 - val_k_smape: 81.6406
# Epoch 36/60
# 0s - loss: 1.4625 - k_smape: 83.7644 - val_loss: 1.6342 - val_k_smape: 80.7830
# Epoch 37/60
# 0s - loss: 1.4918 - k_smape: 82.2691 - val_loss: 1.4825 - val_k_smape: 81.2839
# Epoch 38/60
# 0s - loss: 1.4350 - k_smape: 84.5742 - val_loss: 1.3562 - val_k_smape: 77.2041
# Epoch 39/60
# 0s - loss: 1.4122 - k_smape: 82.1045 - val_loss: 1.6498 - val_k_smape: 79.6045
# Epoch 40/60
# 0s - loss: 1.3794 - k_smape: 81.0274 - val_loss: 1.4972 - val_k_smape: 81.4516
# Epoch 41/60
# 0s - loss: 1.3972 - k_smape: 83.6456 - val_loss: 1.4780 - val_k_smape: 77.4629
# Epoch 42/60
# 0s - loss: 1.4103 - k_smape: 80.8248 - val_loss: 1.6649 - val_k_smape: 79.1029
# Epoch 43/60
# 0s - loss: 1.3739 - k_smape: 82.8061 - val_loss: 1.5819 - val_k_smape: 82.3255
# Epoch 44/60
# 0s - loss: 1.4243 - k_smape: 83.2448 - val_loss: 1.6839 - val_k_smape: 81.3049
# Epoch 45/60
# 0s - loss: 1.4026 - k_smape: 81.4147 - val_loss: 1.6298 - val_k_smape: 79.5618
# Epoch 46/60
# 0s - loss: 1.3763 - k_smape: 81.2585 - val_loss: 1.5186 - val_k_smape: 83.5219
# Epoch 47/60
# 0s - loss: 1.3845 - k_smape: 83.4027 - val_loss: 1.5290 - val_k_smape: 79.4169
# Epoch 48/60
# 0s - loss: 1.3742 - k_smape: 79.8225 - val_loss: 1.4806 - val_k_smape: 76.4747
# Epoch 49/60
# 0s - loss: 1.3968 - k_smape: 80.0878 - val_loss: 1.6079 - val_k_smape: 78.0556
# Epoch 50/60
# 0s - loss: 1.3914 - k_smape: 79.5522 - val_loss: 1.5497 - val_k_smape: 80.0366
# Epoch 51/60
# 0s - loss: 1.3780 - k_smape: 83.5444 - val_loss: 1.3231 - val_k_smape: 75.2569
# Epoch 52/60
# 0s - loss: 1.3501 - k_smape: 79.4004 - val_loss: 1.6966 - val_k_smape: 79.7996
# Epoch 53/60
# 0s - loss: 1.3656 - k_smape: 80.4305 - val_loss: 1.6743 - val_k_smape: 81.2579
# Epoch 54/60
# 0s - loss: 1.3548 - k_smape: 81.8817 - val_loss: 1.3756 - val_k_smape: 75.0807
# Epoch 55/60
# 0s - loss: 1.3083 - k_smape: 77.6345 - val_loss: 1.4935 - val_k_smape: 77.1560
# Epoch 56/60
# 0s - loss: 1.3540 - k_smape: 79.3585 - val_loss: 1.4814 - val_k_smape: 78.2372
# Epoch 57/60
# 0s - loss: 1.3264 - k_smape: 79.4798 - val_loss: 1.4999 - val_k_smape: 75.9187
# Epoch 58/60
# 0s - loss: 1.3252 - k_smape: 77.9391 - val_loss: 1.4036 - val_k_smape: 75.6444
# Epoch 59/60
# 0s - loss: 1.3431 - k_smape: 77.3574 - val_loss: 1.4764 - val_k_smape: 77.5495
# Epoch 60/60
# 0s - loss: 1.3309 - k_smape: 79.1592 - val_loss: 1.3467 - val_k_smape: 75.4691
# === Run: 3 / 5 ===
# --- Group: 1 / 6 ---
# Train on 22467 samples, validate on 2497 samples
# Epoch 1/1
# 5s - loss: 1.1093 - k_smape: 149.5651 - val_loss: 0.9886 - val_k_smape: 140.7295
# --- Group: 2 / 6 ---
# Train on 13986 samples, validate on 1554 samples
# Epoch 1/40
# 3s - loss: 1.6782 - k_smape: 134.5091 - val_loss: 1.3206 - val_k_smape: 125.9817
# Epoch 2/40
# 3s - loss: 1.5409 - k_smape: 122.1355 - val_loss: 1.3164 - val_k_smape: 122.0097
# Epoch 3/40
# 3s - loss: 1.5151 - k_smape: 119.6828 - val_loss: 1.3087 - val_k_smape: 120.3112
# Epoch 4/40
# 3s - loss: 1.4956 - k_smape: 117.8445 - val_loss: 1.3406 - val_k_smape: 126.6526
# Epoch 5/40
# 3s - loss: 1.4855 - k_smape: 116.5332 - val_loss: 1.3641 - val_k_smape: 124.9411
# Epoch 6/40
# 3s - loss: 1.4852 - k_smape: 115.9475 - val_loss: 1.3234 - val_k_smape: 122.9896
# Epoch 7/40
# 3s - loss: 1.4807 - k_smape: 115.3671 - val_loss: 1.3322 - val_k_smape: 123.9159
# Epoch 8/40
# 3s - loss: 1.4712 - k_smape: 114.3608 - val_loss: 1.2994 - val_k_smape: 120.3697
# Epoch 9/40
# 3s - loss: 1.4673 - k_smape: 114.1941 - val_loss: 1.3192 - val_k_smape: 125.4056
# Epoch 10/40
# 3s - loss: 1.4521 - k_smape: 113.9902 - val_loss: 1.2988 - val_k_smape: 119.8593
# Epoch 11/40
# 3s - loss: 1.4664 - k_smape: 113.8138 - val_loss: 1.3102 - val_k_smape: 118.9570
# Epoch 12/40
# 3s - loss: 1.4601 - k_smape: 112.8161 - val_loss: 1.3093 - val_k_smape: 122.8075
# Epoch 13/40
# 3s - loss: 1.4436 - k_smape: 112.9657 - val_loss: 1.3062 - val_k_smape: 120.0270
# Epoch 14/40
# 3s - loss: 1.4430 - k_smape: 112.3727 - val_loss: 1.3026 - val_k_smape: 118.8328
# Epoch 15/40
# 3s - loss: 1.4431 - k_smape: 112.4449 - val_loss: 1.3191 - val_k_smape: 119.2054
# Epoch 16/40
# 3s - loss: 1.4316 - k_smape: 111.6471 - val_loss: 1.3115 - val_k_smape: 119.0995
# Epoch 17/40
# 3s - loss: 1.4321 - k_smape: 111.4547 - val_loss: 1.2980 - val_k_smape: 121.1636
# Epoch 18/40
# 3s - loss: 1.4329 - k_smape: 111.7635 - val_loss: 1.3066 - val_k_smape: 118.0996
# Epoch 19/40
# 3s - loss: 1.4301 - k_smape: 110.9828 - val_loss: 1.2971 - val_k_smape: 117.6206
# Epoch 20/40
# 3s - loss: 1.4400 - k_smape: 111.4368 - val_loss: 1.3118 - val_k_smape: 117.0836
# Epoch 21/40
# 3s - loss: 1.4238 - k_smape: 110.6219 - val_loss: 1.3095 - val_k_smape: 118.8444
# Epoch 22/40
# 3s - loss: 1.4251 - k_smape: 110.9415 - val_loss: 1.3121 - val_k_smape: 120.8638
# Epoch 23/40
# 3s - loss: 1.4303 - k_smape: 110.4513 - val_loss: 1.3204 - val_k_smape: 115.5840
# Epoch 24/40
# 3s - loss: 1.4181 - k_smape: 110.0768 - val_loss: 1.3059 - val_k_smape: 117.3718
# Epoch 25/40
# 3s - loss: 1.4056 - k_smape: 109.9913 - val_loss: 1.3108 - val_k_smape: 119.7906
# Epoch 26/40
# 3s - loss: 1.4052 - k_smape: 109.9548 - val_loss: 1.3122 - val_k_smape: 119.4413
# Epoch 27/40
# 3s - loss: 1.4041 - k_smape: 109.5232 - val_loss: 1.3068 - val_k_smape: 120.2050
# Epoch 28/40
# 3s - loss: 1.4116 - k_smape: 109.8497 - val_loss: 1.3090 - val_k_smape: 118.4896
# Epoch 29/40
# 3s - loss: 1.4029 - k_smape: 109.4330 - val_loss: 1.3159 - val_k_smape: 121.7764
# Epoch 30/40
# 3s - loss: 1.3860 - k_smape: 108.9713 - val_loss: 1.3181 - val_k_smape: 119.3951
# Epoch 31/40
# 3s - loss: 1.3934 - k_smape: 109.1071 - val_loss: 1.3157 - val_k_smape: 118.4714
# Epoch 32/40
# 3s - loss: 1.3947 - k_smape: 108.9022 - val_loss: 1.3521 - val_k_smape: 119.9175
# Epoch 33/40
# 3s - loss: 1.3960 - k_smape: 109.0964 - val_loss: 1.3140 - val_k_smape: 118.2548
# Epoch 34/40
# 3s - loss: 1.3854 - k_smape: 108.6065 - val_loss: 1.3094 - val_k_smape: 119.5955
# Epoch 35/40
# 3s - loss: 1.3815 - k_smape: 108.5880 - val_loss: 1.3074 - val_k_smape: 117.5049
# Epoch 36/40
# 3s - loss: 1.3840 - k_smape: 108.6221 - val_loss: 1.3450 - val_k_smape: 119.8585
# Epoch 37/40
# 3s - loss: 1.3790 - k_smape: 108.2280 - val_loss: 1.3368 - val_k_smape: 117.7511
# Epoch 38/40
# 3s - loss: 1.3775 - k_smape: 108.0209 - val_loss: 1.3243 - val_k_smape: 121.1059
# Epoch 39/40
# 3s - loss: 1.3749 - k_smape: 108.6311 - val_loss: 1.3310 - val_k_smape: 118.1817
# Epoch 40/40
# 3s - loss: 1.3662 - k_smape: 108.0649 - val_loss: 1.3269 - val_k_smape: 116.4017
# --- Group: 3 / 6 ---
# Train on 25335 samples, validate on 2816 samples
# Epoch 1/40
# 6s - loss: 1.1760 - k_smape: 130.1335 - val_loss: 0.9736 - val_k_smape: 117.6548
# Epoch 2/40
# 5s - loss: 1.0934 - k_smape: 119.7731 - val_loss: 0.9382 - val_k_smape: 109.9496
# Epoch 3/40
# 5s - loss: 1.0711 - k_smape: 117.1223 - val_loss: 0.9555 - val_k_smape: 114.8073
# Epoch 4/40
# 5s - loss: 1.0588 - k_smape: 115.5948 - val_loss: 0.9310 - val_k_smape: 116.5406
# Epoch 5/40
# 5s - loss: 1.0493 - k_smape: 114.6564 - val_loss: 0.9328 - val_k_smape: 115.0226
# Epoch 6/40
# 5s - loss: 1.0466 - k_smape: 114.2346 - val_loss: 0.9450 - val_k_smape: 115.3916
# Epoch 7/40
# 5s - loss: 1.0426 - k_smape: 113.6798 - val_loss: 0.9443 - val_k_smape: 112.5188
# Epoch 8/40
# 5s - loss: 1.0375 - k_smape: 113.2066 - val_loss: 0.9825 - val_k_smape: 122.3351
# Epoch 9/40
# 5s - loss: 1.0341 - k_smape: 112.9958 - val_loss: 0.9488 - val_k_smape: 117.4906
# Epoch 10/40
# 5s - loss: 1.0317 - k_smape: 112.5338 - val_loss: 0.9371 - val_k_smape: 114.0323
# Epoch 11/40
# 5s - loss: 1.0320 - k_smape: 112.7252 - val_loss: 0.9350 - val_k_smape: 113.0580
# Epoch 12/40
# 5s - loss: 1.0241 - k_smape: 112.0526 - val_loss: 0.9178 - val_k_smape: 111.1110
# Epoch 13/40
# 5s - loss: 1.0258 - k_smape: 112.3228 - val_loss: 0.9209 - val_k_smape: 114.2733
# Epoch 14/40
# 5s - loss: 1.0206 - k_smape: 112.1142 - val_loss: 0.9677 - val_k_smape: 117.3148
# Epoch 15/40
# 5s - loss: 1.0216 - k_smape: 111.4577 - val_loss: 0.9439 - val_k_smape: 116.9513
# Epoch 16/40
# 5s - loss: 1.0133 - k_smape: 111.5247 - val_loss: 0.9248 - val_k_smape: 115.5372
# Epoch 17/40
# 5s - loss: 1.0187 - k_smape: 111.5078 - val_loss: 0.9563 - val_k_smape: 118.5174
# Epoch 18/40
# 5s - loss: 1.0155 - k_smape: 111.3602 - val_loss: 0.9568 - val_k_smape: 116.8939
# Epoch 19/40
# 5s - loss: 1.0120 - k_smape: 110.8105 - val_loss: 0.9871 - val_k_smape: 120.0644
# Epoch 20/40
# 5s - loss: 1.0148 - k_smape: 111.1300 - val_loss: 0.9609 - val_k_smape: 116.7363
# Epoch 21/40
# 5s - loss: 1.0104 - k_smape: 110.6419 - val_loss: 0.9257 - val_k_smape: 117.9939
# Epoch 22/40
# 5s - loss: 1.0109 - k_smape: 110.7795 - val_loss: 0.9457 - val_k_smape: 119.5233
# Epoch 23/40
# 5s - loss: 1.0039 - k_smape: 110.3618 - val_loss: 0.9272 - val_k_smape: 116.4385
# Epoch 24/40
# 5s - loss: 1.0020 - k_smape: 110.2507 - val_loss: 0.9521 - val_k_smape: 115.5265
# Epoch 25/40
# 5s - loss: 1.0039 - k_smape: 110.2421 - val_loss: 0.9582 - val_k_smape: 116.1691
# Epoch 26/40
# 5s - loss: 1.0038 - k_smape: 110.3799 - val_loss: 0.9655 - val_k_smape: 119.3748
# Epoch 27/40
# ...
# Epoch 10/40
# 5s - loss: 1.0401 - k_smape: 113.1270 - val_loss: 0.9286 - val_k_smape: 116.5152
# Epoch 11/40
# 5s - loss: 1.0357 - k_smape: 112.9668 - val_loss: 0.9661 - val_k_smape: 113.8837
# Epoch 12/40
# 5s - loss: 1.0290 - k_smape: 112.5807 - val_loss: 0.9268 - val_k_smape: 112.3160
# Epoch 13/40
# 5s - loss: 1.0296 - k_smape: 112.7227 - val_loss: 0.9438 - val_k_smape: 116.6339
# Epoch 14/40
# 5s - loss: 1.0271 - k_smape: 112.4316 - val_loss: 0.9535 - val_k_smape: 115.3790
# Epoch 15/40
# 5s - loss: 1.0254 - k_smape: 111.9547 - val_loss: 0.9457 - val_k_smape: 116.0281
# Epoch 16/40
# 5s - loss: 1.0231 - k_smape: 111.7769 - val_loss: 0.9459 - val_k_smape: 115.0961
# Epoch 17/40
# 5s - loss: 1.0216 - k_smape: 111.8663 - val_loss: 0.9647 - val_k_smape: 117.4527
# Epoch 18/40
# 5s - loss: 1.0200 - k_smape: 111.6048 - val_loss: 0.9551 - val_k_smape: 117.5971
# Epoch 19/40
# 5s - loss: 1.0164 - k_smape: 111.6078 - val_loss: 0.9674 - val_k_smape: 116.5312
# Epoch 20/40
# 5s - loss: 1.0152 - k_smape: 111.3369 - val_loss: 0.9297 - val_k_smape: 113.2902
# Epoch 21/40
# 5s - loss: 1.0134 - k_smape: 111.2078 - val_loss: 0.9927 - val_k_smape: 116.9904
# Epoch 22/40
# 5s - loss: 1.0119 - k_smape: 111.2515 - val_loss: 0.9537 - val_k_smape: 114.9773
# Epoch 23/40
# 5s - loss: 1.0110 - k_smape: 110.7606 - val_loss: 0.9978 - val_k_smape: 120.8227
# Epoch 24/40
# 5s - loss: 1.0103 - k_smape: 110.9864 - val_loss: 0.9763 - val_k_smape: 117.8724
# Epoch 25/40
# 5s - loss: 1.0081 - k_smape: 110.9932 - val_loss: 0.9777 - val_k_smape: 115.8855
# Epoch 26/40
# 5s - loss: 1.0048 - k_smape: 110.7455 - val_loss: 0.9710 - val_k_smape: 117.7641
# Epoch 27/40
# 5s - loss: 1.0050 - k_smape: 110.6398 - val_loss: 0.9884 - val_k_smape: 119.7751
# Epoch 28/40
# 5s - loss: 1.0010 - k_smape: 110.4988 - val_loss: 0.9685 - val_k_smape: 117.1070
# Epoch 29/40
# 5s - loss: 0.9997 - k_smape: 110.3354 - val_loss: 0.9627 - val_k_smape: 115.1041
# Epoch 30/40
# 5s - loss: 1.0011 - k_smape: 110.5231 - val_loss: 0.9534 - val_k_smape: 117.6344
# Epoch 31/40
# 5s - loss: 0.9997 - k_smape: 110.2345 - val_loss: 0.9902 - val_k_smape: 117.7041
# Epoch 32/40
# 5s - loss: 0.9943 - k_smape: 109.8438 - val_loss: 0.9519 - val_k_smape: 116.6865
# Epoch 33/40
# 5s - loss: 0.9943 - k_smape: 110.1402 - val_loss: 0.9829 - val_k_smape: 115.2708
# Epoch 34/40
# 5s - loss: 0.9945 - k_smape: 110.0106 - val_loss: 0.9504 - val_k_smape: 114.8428
# Epoch 35/40
# 5s - loss: 0.9940 - k_smape: 109.8066 - val_loss: 0.9738 - val_k_smape: 118.0101
# Epoch 36/40
# 5s - loss: 0.9945 - k_smape: 109.9770 - val_loss: 0.9377 - val_k_smape: 112.8515
# Epoch 37/40
# 5s - loss: 0.9908 - k_smape: 109.5871 - val_loss: 0.9800 - val_k_smape: 115.6739
# Epoch 38/40
# 5s - loss: 0.9933 - k_smape: 109.4617 - val_loss: 0.9983 - val_k_smape: 121.8933
# Epoch 39/40
# 5s - loss: 0.9894 - k_smape: 109.5485 - val_loss: 1.0094 - val_k_smape: 118.3243
# Epoch 40/40
# 5s - loss: 0.9898 - k_smape: 109.1867 - val_loss: 0.9572 - val_k_smape: 115.3115
# --- Group: 4 / 6 ---
# Train on 39015 samples, validate on 4336 samples
# Epoch 1/40
# 9s - loss: 1.4890 - k_smape: 110.9902 - val_loss: 1.3627 - val_k_smape: 109.2172
# Epoch 2/40
# 8s - loss: 1.3701 - k_smape: 100.0453 - val_loss: 1.3403 - val_k_smape: 106.5412
# Epoch 3/40
# 8s - loss: 1.3505 - k_smape: 98.3458 - val_loss: 1.3448 - val_k_smape: 109.3101
# Epoch 4/40
# 8s - loss: 1.3392 - k_smape: 97.4661 - val_loss: 1.3257 - val_k_smape: 104.1386
# Epoch 5/40
# 8s - loss: 1.3276 - k_smape: 96.7503 - val_loss: 1.3236 - val_k_smape: 104.1771
# Epoch 6/40
# 8s - loss: 1.3187 - k_smape: 96.1101 - val_loss: 1.3239 - val_k_smape: 104.7993
# Epoch 7/40
# 8s - loss: 1.3117 - k_smape: 95.5712 - val_loss: 1.3176 - val_k_smape: 104.4137
# Epoch 8/40
# 8s - loss: 1.3125 - k_smape: 95.3678 - val_loss: 1.3385 - val_k_smape: 107.1580
# Epoch 9/40
# 8s - loss: 1.3093 - k_smape: 95.1058 - val_loss: 1.3341 - val_k_smape: 106.4841
# Epoch 10/40
# 8s - loss: 1.3093 - k_smape: 95.0371 - val_loss: 1.3150 - val_k_smape: 103.5946
# Epoch 11/40
# 8s - loss: 1.3043 - k_smape: 94.8031 - val_loss: 1.3204 - val_k_smape: 104.0122
# Epoch 12/40
# 8s - loss: 1.2976 - k_smape: 94.6977 - val_loss: 1.3271 - val_k_smape: 106.2266
# Epoch 13/40
# 8s - loss: 1.2965 - k_smape: 94.4580 - val_loss: 1.3235 - val_k_smape: 105.6946
# Epoch 14/40
# 8s - loss: 1.2933 - k_smape: 94.2605 - val_loss: 1.3099 - val_k_smape: 103.9578
# Epoch 15/40
# 8s - loss: 1.2902 - k_smape: 94.1336 - val_loss: 1.3277 - val_k_smape: 104.6933
# Epoch 16/40
# 8s - loss: 1.2913 - k_smape: 94.0284 - val_loss: 1.3085 - val_k_smape: 104.5015
# Epoch 17/40
# 8s - loss: 1.2853 - k_smape: 93.8061 - val_loss: 1.3200 - val_k_smape: 105.7182
# Epoch 18/40
# 8s - loss: 1.2804 - k_smape: 93.6662 - val_loss: 1.3088 - val_k_smape: 104.3713
# Epoch 19/40
# 8s - loss: 1.2810 - k_smape: 93.7024 - val_loss: 1.3162 - val_k_smape: 104.5300
# Epoch 20/40
# 8s - loss: 1.2767 - k_smape: 93.4643 - val_loss: 1.3122 - val_k_smape: 104.2906
# Epoch 21/40
# 8s - loss: 1.2760 - k_smape: 93.2712 - val_loss: 1.3053 - val_k_smape: 104.5786
# Epoch 22/40
# 8s - loss: 1.2740 - k_smape: 93.4574 - val_loss: 1.3116 - val_k_smape: 105.4795
# Epoch 23/40
# 8s - loss: 1.2695 - k_smape: 93.1020 - val_loss: 1.3174 - val_k_smape: 105.7281
# Epoch 24/40
# 8s - loss: 1.2704 - k_smape: 93.0685 - val_loss: 1.3206 - val_k_smape: 105.7522
# Epoch 25/40
# 8s - loss: 1.2652 - k_smape: 92.8996 - val_loss: 1.3099 - val_k_smape: 105.6838
# Epoch 26/40
# 8s - loss: 1.2624 - k_smape: 92.6764 - val_loss: 1.3097 - val_k_smape: 104.2592
# Epoch 27/40
# 8s - loss: 1.2621 - k_smape: 92.7310 - val_loss: 1.3106 - val_k_smape: 104.7922
# Epoch 28/40
# 8s - loss: 1.2579 - k_smape: 92.5763 - val_loss: 1.3002 - val_k_smape: 103.9802
# Epoch 29/40
# 8s - loss: 1.2538 - k_smape: 92.4275 - val_loss: 1.3112 - val_k_smape: 103.9571
# Epoch 30/40
# 8s - loss: 1.2565 - k_smape: 92.4167 - val_loss: 1.3028 - val_k_smape: 104.0099
# Epoch 31/40
# 8s - loss: 1.2531 - k_smape: 92.2556 - val_loss: 1.3028 - val_k_smape: 103.9110
# Epoch 32/40
# 8s - loss: 1.2491 - k_smape: 92.0721 - val_loss: 1.3104 - val_k_smape: 105.3561
# Epoch 33/40
# 8s - loss: 1.2470 - k_smape: 92.1779 - val_loss: 1.3136 - val_k_smape: 104.9851
# Epoch 34/40
# 8s - loss: 1.2510 - k_smape: 92.2496 - val_loss: 1.3033 - val_k_smape: 102.3069
# Epoch 35/40
# 8s - loss: 1.2491 - k_smape: 92.0371 - val_loss: 1.3155 - val_k_smape: 105.1652
# Epoch 36/40
# 8s - loss: 1.2415 - k_smape: 91.8691 - val_loss: 1.3055 - val_k_smape: 103.6390
# Epoch 37/40
# 8s - loss: 1.2399 - k_smape: 91.7775 - val_loss: 1.2953 - val_k_smape: 103.9365
# Epoch 38/40
# 8s - loss: 1.2435 - k_smape: 91.9759 - val_loss: 1.3042 - val_k_smape: 104.6639
# Epoch 39/40
# 8s - loss: 1.2408 - k_smape: 91.8635 - val_loss: 1.2937 - val_k_smape: 103.1982
# Epoch 40/40
# 8s - loss: 1.2368 - k_smape: 91.5234 - val_loss: 1.2924 - val_k_smape: 103.7605
# --- Group: 5 / 6 ---
# Train on 29039 samples, validate on 3227 samples
# Epoch 1/40
# 7s - loss: 1.2632 - k_smape: 117.9339 - val_loss: 0.9080 - val_k_smape: 110.5700
# Epoch 2/40
# 6s - loss: 1.0993 - k_smape: 105.2912 - val_loss: 0.8777 - val_k_smape: 108.2446
# Epoch 3/40
# 6s - loss: 1.0692 - k_smape: 102.5476 - val_loss: 0.8880 - val_k_smape: 107.8011
# Epoch 4/40
# 6s - loss: 1.0473 - k_smape: 101.3691 - val_loss: 0.8464 - val_k_smape: 108.7978
# Epoch 5/40
# 6s - loss: 1.0360 - k_smape: 100.4142 - val_loss: 0.8643 - val_k_smape: 104.4943
# Epoch 6/40
# 6s - loss: 1.0305 - k_smape: 100.5380 - val_loss: 0.8336 - val_k_smape: 102.1280
# Epoch 7/40
# 6s - loss: 1.0312 - k_smape: 99.6707 - val_loss: 0.8298 - val_k_smape: 101.6900
# Epoch 8/40
# 6s - loss: 1.0233 - k_smape: 99.1095 - val_loss: 0.8946 - val_k_smape: 107.6626
# Epoch 9/40
# 6s - loss: 1.0132 - k_smape: 98.5721 - val_loss: 0.9208 - val_k_smape: 105.1268
# Epoch 10/40
# 6s - loss: 1.0087 - k_smape: 98.4230 - val_loss: 0.8202 - val_k_smape: 103.1021
# Epoch 11/40
# 6s - loss: 1.0098 - k_smape: 98.2065 - val_loss: 0.8499 - val_k_smape: 103.4460
# Epoch 12/40
# 6s - loss: 1.0061 - k_smape: 98.0185 - val_loss: 0.8441 - val_k_smape: 105.5631
# Epoch 13/40
# 6s - loss: 1.0037 - k_smape: 97.5943 - val_loss: 0.8178 - val_k_smape: 102.3548
# Epoch 14/40
# 6s - loss: 0.9973 - k_smape: 97.3376 - val_loss: 0.8532 - val_k_smape: 101.7584
# Epoch 15/40
# 6s - loss: 0.9947 - k_smape: 97.0475 - val_loss: 0.8391 - val_k_smape: 103.3060
# Epoch 16/40
# 6s - loss: 0.9889 - k_smape: 96.7822 - val_loss: 0.8526 - val_k_smape: 104.1362
# Epoch 17/40
# 6s - loss: 0.9902 - k_smape: 96.6888 - val_loss: 0.8125 - val_k_smape: 102.5691
# Epoch 18/40
# 6s - loss: 0.9824 - k_smape: 96.4699 - val_loss: 0.8746 - val_k_smape: 101.7111
# Epoch 19/40
# 6s - loss: 0.9913 - k_smape: 96.4251 - val_loss: 0.8385 - val_k_smape: 102.9086
# Epoch 20/40
# 6s - loss: 0.9848 - k_smape: 96.3017 - val_loss: 0.8763 - val_k_smape: 103.2582
# Epoch 21/40
# 6s - loss: 0.9873 - k_smape: 96.1420 - val_loss: 0.8430 - val_k_smape: 103.1759
# Epoch 22/40
# 6s - loss: 0.9850 - k_smape: 96.0122 - val_loss: 0.8250 - val_k_smape: 101.9240
# Epoch 23/40
# 6s - loss: 0.9806 - k_smape: 95.8456 - val_loss: 0.8433 - val_k_smape: 101.7522
# Epoch 24/40
# 6s - loss: 0.9829 - k_smape: 95.6795 - val_loss: 0.8074 - val_k_smape: 100.9016
# Epoch 25/40
# 6s - loss: 0.9757 - k_smape: 95.7008 - val_loss: 0.8074 - val_k_smape: 99.1831
# Epoch 26/40
# 6s - loss: 0.9773 - k_smape: 95.2561 - val_loss: 0.8294 - val_k_smape: 101.6146
# Epoch 27/40
# 6s - loss: 0.9801 - k_smape: 95.2760 - val_loss: 0.8177 - val_k_smape: 101.2446
# Epoch 28/40
# 6s - loss: 0.9709 - k_smape: 95.1177 - val_loss: 0.8107 - val_k_smape: 100.3043
# Epoch 29/40
# 6s - loss: 0.9728 - k_smape: 94.8489 - val_loss: 0.7932 - val_k_smape: 99.9769
# Epoch 30/40
# 6s - loss: 0.9723 - k_smape: 95.1140 - val_loss: 0.8429 - val_k_smape: 101.3243
# Epoch 31/40
# 6s - loss: 0.9726 - k_smape: 94.7342 - val_loss: 0.8431 - val_k_smape: 103.3346
# Epoch 32/40
# 6s - loss: 0.9666 - k_smape: 94.4448 - val_loss: 0.9060 - val_k_smape: 104.7680
# Epoch 33/40
# 6s - loss: 0.9681 - k_smape: 94.5044 - val_loss: 0.8467 - val_k_smape: 101.1597
# Epoch 34/40
# 6s - loss: 0.9670 - k_smape: 94.2754 - val_loss: 0.7939 - val_k_smape: 100.3865
# Epoch 35/40
# 6s - loss: 0.9686 - k_smape: 94.3482 - val_loss: 0.8367 - val_k_smape: 103.3363
# Epoch 36/40
# 6s - loss: 0.9618 - k_smape: 94.1184 - val_loss: 0.8832 - val_k_smape: 102.7767
# Epoch 37/40
# 6s - loss: 0.9618 - k_smape: 94.0362 - val_loss: 0.8043 - val_k_smape: 101.0000
# Epoch 38/40
# 6s - loss: 0.9627 - k_smape: 93.9160 - val_loss: 0.8028 - val_k_smape: 100.1534
# Epoch 39/40
# 6s - loss: 0.9613 - k_smape: 94.1001 - val_loss: 0.8464 - val_k_smape: 100.7371
# Epoch 40/40
# 6s - loss: 0.9595 - k_smape: 93.9522 - val_loss: 0.8009 - val_k_smape: 101.0187
# --- Group: 6 / 6 ---
# Train on 711 samples, validate on 80 samples
# Epoch 1/60
# 1s - loss: 3.0172 - k_smape: 153.5674 - val_loss: 3.8100 - val_k_smape: 141.2515
# Epoch 2/60
# 0s - loss: 2.6525 - k_smape: 138.0884 - val_loss: 3.5336 - val_k_smape: 133.9306
# Epoch 3/60
# 0s - loss: 2.4279 - k_smape: 129.1191 - val_loss: 3.1162 - val_k_smape: 122.4088
# Epoch 4/60
# 0s - loss: 2.2691 - k_smape: 123.1769 - val_loss: 3.0799 - val_k_smape: 118.0981
# Epoch 5/60
# 0s - loss: 2.1516 - k_smape: 116.7680 - val_loss: 2.6749 - val_k_smape: 108.2673
# Epoch 6/60
# 0s - loss: 2.0335 - k_smape: 111.5196 - val_loss: 2.6986 - val_k_smape: 107.5817
# Epoch 7/60
# 0s - loss: 1.9378 - k_smape: 108.8742 - val_loss: 2.1755 - val_k_smape: 99.9563
# Epoch 8/60
# 0s - loss: 1.8850 - k_smape: 107.5523 - val_loss: 2.4922 - val_k_smape: 101.3128
# Epoch 9/60
# 0s - loss: 1.9023 - k_smape: 102.7959 - val_loss: 2.2071 - val_k_smape: 99.6614
# Epoch 10/60
# 0s - loss: 1.8127 - k_smape: 104.8585 - val_loss: 1.8183 - val_k_smape: 94.0658
# Epoch 11/60
# 0s - loss: 1.8040 - k_smape: 100.1311 - val_loss: 2.2203 - val_k_smape: 97.2728
# Epoch 12/60
# 0s - loss: 1.6983 - k_smape: 97.9439 - val_loss: 2.0134 - val_k_smape: 93.2748
# Epoch 13/60
# 0s - loss: 1.7197 - k_smape: 98.3792 - val_loss: 1.7005 - val_k_smape: 88.3069
# Epoch 14/60
# 0s - loss: 1.7293 - k_smape: 96.1045 - val_loss: 2.0598 - val_k_smape: 95.7146
# Epoch 15/60
# 0s - loss: 1.6789 - k_smape: 95.5341 - val_loss: 1.9500 - val_k_smape: 90.7309
# Epoch 16/60
# 0s - loss: 1.6737 - k_smape: 96.4316 - val_loss: 1.5388 - val_k_smape: 84.6385
# Epoch 17/60
# 0s - loss: 1.6070 - k_smape: 91.4476 - val_loss: 2.1436 - val_k_smape: 93.7223
# Epoch 18/60
# 0s - loss: 1.6088 - k_smape: 93.5623 - val_loss: 1.5938 - val_k_smape: 89.6967
# Epoch 19/60
# 0s - loss: 1.5927 - k_smape: 92.8388 - val_loss: 1.7091 - val_k_smape: 85.1484
# Epoch 20/60
# 0s - loss: 1.6074 - k_smape: 89.0723 - val_loss: 1.9671 - val_k_smape: 89.6384
# Epoch 21/60
# 0s - loss: 1.6055 - k_smape: 90.8462 - val_loss: 1.6075 - val_k_smape: 85.7666
# Epoch 22/60
# 0s - loss: 1.5117 - k_smape: 90.8282 - val_loss: 1.7379 - val_k_smape: 87.1999
# Epoch 23/60
# 0s - loss: 1.5634 - k_smape: 87.3453 - val_loss: 1.6244 - val_k_smape: 82.9129
# Epoch 24/60
# 0s - loss: 1.5553 - k_smape: 86.7631 - val_loss: 1.5288 - val_k_smape: 85.0639
# Epoch 25/60
# 0s - loss: 1.5299 - k_smape: 91.6991 - val_loss: 1.7846 - val_k_smape: 88.0786
# Epoch 26/60
# 0s - loss: 1.5257 - k_smape: 87.4899 - val_loss: 1.7334 - val_k_smape: 83.7100
# Epoch 27/60
# 0s - loss: 1.4640 - k_smape: 87.3279 - val_loss: 1.7410 - val_k_smape: 85.6067
# Epoch 28/60
# 0s - loss: 1.4785 - k_smape: 85.5841 - val_loss: 1.6799 - val_k_smape: 83.4512
# Epoch 29/60
# 0s - loss: 1.5092 - k_smape: 85.3025 - val_loss: 2.0349 - val_k_smape: 87.0062
# Epoch 30/60
# 0s - loss: 1.4850 - k_smape: 84.8799 - val_loss: 1.3799 - val_k_smape: 80.1950
# Epoch 31/60
# 0s - loss: 1.5384 - k_smape: 86.6531 - val_loss: 1.5172 - val_k_smape: 83.3844
# Epoch 32/60
# 0s - loss: 1.5636 - k_smape: 84.3094 - val_loss: 2.1841 - val_k_smape: 90.6312
# Epoch 33/60
# 0s - loss: 1.5468 - k_smape: 87.2385 - val_loss: 1.4749 - val_k_smape: 80.0843
# Epoch 34/60
# 0s - loss: 1.4456 - k_smape: 83.6809 - val_loss: 1.6220 - val_k_smape: 83.0504
# Epoch 35/60
# 0s - loss: 1.3973 - k_smape: 84.2236 - val_loss: 1.6062 - val_k_smape: 81.5457
# Epoch 36/60
# 0s - loss: 1.4299 - k_smape: 83.2941 - val_loss: 1.5905 - val_k_smape: 79.8446
# Epoch 37/60
# 0s - loss: 1.4091 - k_smape: 81.9638 - val_loss: 1.4038 - val_k_smape: 80.1947
# Epoch 38/60
# 0s - loss: 1.3954 - k_smape: 83.1409 - val_loss: 1.7327 - val_k_smape: 82.1032
# Epoch 39/60
# 0s - loss: 1.4323 - k_smape: 82.0883 - val_loss: 1.4130 - val_k_smape: 80.8708
# Epoch 40/60
# 0s - loss: 1.4394 - k_smape: 84.6635 - val_loss: 1.4516 - val_k_smape: 79.3016
# Epoch 41/60
# 0s - loss: 1.4141 - k_smape: 79.8557 - val_loss: 1.5722 - val_k_smape: 80.1479
# Epoch 42/60
# 0s - loss: 1.3683 - k_smape: 82.6791 - val_loss: 1.4895 - val_k_smape: 79.8640
# Epoch 43/60
# 0s - loss: 1.3874 - k_smape: 80.3437 - val_loss: 1.7956 - val_k_smape: 82.6118
# Epoch 44/60
# 0s - loss: 1.3873 - k_smape: 82.6399 - val_loss: 1.6362 - val_k_smape: 81.6050
# Epoch 45/60
# 0s - loss: 1.3966 - k_smape: 82.3990 - val_loss: 1.4775 - val_k_smape: 78.8271
# Epoch 46/60
# 0s - loss: 1.3475 - k_smape: 80.1710 - val_loss: 1.5837 - val_k_smape: 79.0112
# Epoch 47/60
# 0s - loss: 1.3889 - k_smape: 80.0526 - val_loss: 1.3633 - val_k_smape: 78.8750
# Epoch 48/60
# 0s - loss: 1.3836 - k_smape: 80.8837 - val_loss: 1.4480 - val_k_smape: 78.4464
# Epoch 49/60
# 0s - loss: 1.3327 - k_smape: 79.5603 - val_loss: 1.6139 - val_k_smape: 80.6666
# Epoch 50/60
# 0s - loss: 1.3352 - k_smape: 79.9800 - val_loss: 1.4860 - val_k_smape: 76.6569
# Epoch 51/60
# 0s - loss: 1.3501 - k_smape: 78.7794 - val_loss: 1.6441 - val_k_smape: 81.2786
# Epoch 52/60
# 0s - loss: 1.3289 - k_smape: 80.5058 - val_loss: 1.4045 - val_k_smape: 78.2900
# Epoch 53/60
# 0s - loss: 1.3433 - k_smape: 80.0938 - val_loss: 1.4445 - val_k_smape: 76.1521
# Epoch 54/60
# 0s - loss: 1.4395 - k_smape: 79.0704 - val_loss: 1.8430 - val_k_smape: 84.9325
# Epoch 55/60
# 0s - loss: 1.3740 - k_smape: 83.5336 - val_loss: 1.3531 - val_k_smape: 77.5209
# Epoch 56/60
# 0s - loss: 1.3667 - k_smape: 78.0065 - val_loss: 1.7876 - val_k_smape: 81.8453
# Epoch 57/60
# 0s - loss: 1.3585 - k_smape: 80.6779 - val_loss: 1.4472 - val_k_smape: 79.5815
# Epoch 58/60
# 0s - loss: 1.3203 - k_smape: 78.0376 - val_loss: 1.5930 - val_k_smape: 79.2729
# Epoch 59/60
# 0s - loss: 1.3198 - k_smape: 77.8715 - val_loss: 1.5030 - val_k_smape: 78.1633
# Epoch 60/60
# 0s - loss: 1.3053 - k_smape: 77.4608 - val_loss: 1.5925 - val_k_smape: 78.3935
# Wall time: 1h 21min 29s

# %% [markdown]
# ### Training History

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['loss'], label=str(run))
        plt.title('Mean Squared Error (Train) - Group ' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['val_loss'], label=str(run))
        plt.title('Mean Squared Error (Validation) - Group ' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['k_smape'], label=str(run))
        plt.title('SMAPE (Train) - Group ' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['val_k_smape'], label=str(run))
        plt.title('SMAPE (Validation) - Group ' + str(gp))
        plt.legend(); plt.show()

# %% [markdown]
# group 2 (median < 2 and stdev > 0.17) is bad to train

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep:
        plt.plot(hist.history['loss'], label='train')
        plt.plot(hist.history['val_loss'], label='validation')
        plt.title('Mean Squared Error - ' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep:
        plt.plot(hist.history['k_smape'], label='train')
        plt.plot(hist.history['val_k_smape'], label='validation')
        plt.title('SMAPE - ' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['loss'], label=gp)
plt.title('Mean Squared Error - train')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['val_loss'], label=gp)
plt.title('Mean Squared Error - validation')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['k_smape'], label=gp)
plt.title('SMAPE - train')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['val_k_smape'], label=gp)
plt.title('SMAPE - validation')
plt.legend(); plt.show()

# %% [markdown]
# ### More Training

# %% [markdown]
# epochs_list2 = [0,10,0,0,10]

# %% [markdown]
# hists2 = []
# for (gp, model, X_in, Y_in, epochs) in zip(gp_list, models,
#                                    X_input_list, Y_input_list,
#                                    epochs_list2):
#     hist = model.fit(X_in, Y_in, batch_size=128,
#                      epochs=epochs,
#                      validation_split=0.05)
#     #validation_data=(X_val, Y_val))
#     hists2.append(hist)

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['loss'], label='train')
#         plt.plot(hist.history['val_loss'], label='validation')
#         plt.title('Mean Squared Error - ' + str(gp))
#         plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['k_smape'], label='train')
#         plt.plot(hist.history['val_k_smape'], label='validation')
#         plt.title('SMAPE - ' + str(gp))
#         plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['loss'], label=gp)
# plt.title('Mean Squared Error - train')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['val_loss'], label=gp)
# plt.title('Mean Squared Error - validation')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['k_smape'], label=gp)
# plt.title('SMAPE - train')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['val_k_smape'], label=gp)
# plt.title('SMAPE - validation')
# plt.legend(); plt.show()

# %% [markdown]
# ## Predict for Output Set

# %%
Y_output_pred_list_ens = []
for models, run in zip(models_ens, ens_list):
    print('Run', run, end=': ')
    Y_output_pred_list = []
    for (gp, model, X, A) in zip(gp_list, models, X_output_list, A_output_list):
        print(gp, end=' ')
        Y_output_pred_list.append(model.predict([X,A]))
    Y_output_pred_list_ens.append(Y_output_pred_list)
    print('')
# Out:
# Run 0: 0 1 2 3 4 5
# Run 1: 0 1 2 3 4 5
# Run 2: 0 1 2 3 4 5
# Run 3: 0 1 2 3 4 5
# Run 4: 0 1 2 3 4 5

# %% [markdown]
# Find the original index

# %%
output_index_range = np.arange(len(output_gp)); #output_index_range

# %%
# list for original index
output_index_list = [output_index_range[output_gp == gp] 
                     for gp in gp_list]

# %%
for o in output_index_list:
    print(o.shape, end=' ')
# Out:
# (24964,) (20254,) (23437,) (51297,) (24320,) (791,)

# %%
output_index_list_comb = np.concatenate(output_index_list); #output_index_list_comb

# %%
Y_output_pred_ens = []
for Y_output_pred_list in Y_output_pred_list_ens:
    Y_output_pred_comb = np.concatenate(Y_output_pred_list)
    Y_output_pred = [0]*len(output_index_list_comb)

    for index, y in zip(output_index_list_comb, Y_output_pred_comb):
        Y_output_pred[index] = y

    Y_output_pred = np.array(Y_output_pred)  # make it an numpy array (which will also make a copy)
    Y_output_pred_ens.append(Y_output_pred)

del Y_output_pred_comb

# %%
# Inverse transform Y_output_pred to original Y
Y_output_pred_ori_ens = []
for Y_output_pred in Y_output_pred_ens:
    Y_output_pred_ori = unlog(untransform(Y_output_pred, 
                                          output_center, output_scale))
    Y_output_pred_ori_ens.append(Y_output_pred_ori)

# %% [markdown]
# #### Check predict output

# %% [markdown]
# Y_output_pred

# %% [markdown]
# Y_output_pred_ori

# %% [markdown]
# examine(Y_output_pred)

# %% [markdown]
# examine(Y_output_pred_ori)

# %% [markdown]
# view(X_output_ori[126420])

# %% [markdown]
# ## SMAPE Scores

# %% [markdown]
# ### Model Score

# %%
# SMAPE scores for the model
if test_length:
    model_smape_ens = []
    model_smape_0_ens = []
    for Y_output_pred_ori in Y_output_pred_ori_ens:
        model_smape = smape(Y_output_raw, Y_output_pred_ori) # SMAPE score excluding nan (Correct one)
        model_smape_0 = smape(Y_output_ori, Y_output_pred_ori) # SMAPE assuming nan == 0
        print(model_smape, model_smape_0)
        
        model_smape_ens.append(model_smape)
        model_smape_0_ens.append(model_smape_0)
    model_smape_ens_mean = np.mean(model_smape_ens)
    model_smape_0_ens_mean = np.mean(model_smape_0_ens)
    print('-----------')
    print(model_smape_ens_mean, model_smape_0_ens_mean)
# Out:
# 38.9538250592 42.5456900284
# 39.2273637954 42.6147957687
# 38.9250640431 42.4147446697
# 39.1251480733 42.6920045942
# 39.0317922025 42.4462769379
# -----------
# 39.0526386347 42.5427023998

# %%
# SMAPE score for Fibonacci median
if test_length:
    fib_smape = smape(Y_output_raw, Y_output_fib)
    print(fib_smape)
# Out:
# 40.4041165988

# %% [markdown]
# ### Group Scores

# %%
# Prediction Y_output in group
Y_output_pred_ori_list_ens = [[Y_output_pred_ori[output_gp == gp] for gp in gp_list]
                              for Y_output_pred_ori in Y_output_pred_ori_ens]
#Y_output_pred_ori_list = [Y_output_pred_ori[output_gp == gp] for gp in gp_list]
Y_output_pred_ori_list = Y_output_pred_ori_list_ens[-1]  # in case you want to see one of them

# %%
# Fibonacci median in group
Y_output_fib_list = [Y_output_fib[output_gp == gp] for gp in gp_list]

# %%
# True Y_output in group
if test_length:
    # untransformed Y_output with nan replaced by 0
    Y_output_ori_list = [Y_output_ori[output_gp == gp] for gp in gp_list]
    
    # untransformed Y_output_ori with nan (for SMAPE estimation)
    Y_output_raw_list = [Y_output_raw[output_gp == gp] for gp in gp_list]

# %%
tot_n = len(output_gp); tot_n  # total number of pages in output set
# Out:
# 145063

# %%
def count_not_nan(data):
    return np.count_nonzero(~np.isnan(data))

# %% [markdown]
# if test_length: print(count_not_nan(Y_output_raw))

# %%
# Group scores for the model
if test_length:
    gp_n = [len(Y) for Y in Y_output_raw_list]
    # SMAPE assuming nan == 0
    #gp_smape_0 = [smape(Y, Y_p) for Y, Y_p 
    #              in zip(Y_output_ori_list, Y_output_pred_ori_list)]
    
    # SMAPE with nan values ignored (used by Kaggle)
    gp_smape_ens = [[smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_list)]
                    for Y_output_pred_ori_list in Y_output_pred_ori_list_ens]
    gp_smape = gp_smape_ens[-1]
    #gp_smape = [smape(Y, Y_p) for Y, Y_p 
    #            in zip(Y_output_raw_list, Y_output_pred_ori_list)]
    
    #n_not_nan = count_not_nan(Y_output_raw)
    #n_not_nan_gp = [count_not_nan(Y) for Y in Y_output_raw_list]
    #n_not_nan_ratio_gp = [n / (len(Y) * len(Y[0])) for Y,n 
    #                      in zip(Y_output_raw_list, n_not_nan_gp)]
    
    # SMAPE contribution
    #gp_smape_sum = [s * n for n, s in zip(gp_smape, n_not_nan_gp)]
    #gp_smape_cont = [s / n_not_nan for s in gp_smape_sum]

# %%
gp_smape_mean = np.mean(gp_smape_ens, axis=0); gp_smape_mean
# Out:
# array([ 68.41063052,  33.49648428,  46.20504409,  24.84693367,
#         40.26724275,  32.97775653])

# %%
# Group score for Fibonacci median
if test_length:
    gp_smape_fib = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_fib_list)]

# %%
if test_length:  # gp_score compare
    print('#### ' + model_name)
    print('', end='|')
    print('N_pages ', 'Fibonacci', ' Average ', sep='|', end='|')
    for run in ens_list: print(' Model', run, end=' |')
    print('')
    print('', end='|')
    print('--------', '---------', '---------', sep='|', end='|')
    for run in ens_list: print('---------', end='|')
    print('')
    for gp in gp_list:
        print('', end='|')
        print(' %6d ' % gp_n[gp], end='|')
        print(' %7.3f ' % gp_smape_fib[gp], end='|')
        print(' %7.3f ' % gp_smape_mean[gp], end='|')
        for run in ens_list:
            print(' %7.3f ' % gp_smape_ens[run][gp], end='|')
        print('')
    print('|  Total ', ' %7.3f ' % fib_smape, ' %7.3f ' % model_smape_ens_mean, sep='|', end='|')
    for run in ens_list:
            print(' %7.3f ' % model_smape_ens[run], end='|')
# Out:
# #### model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev
# |N_pages |Fibonacci| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|
# |  24964 |  61.170 |  68.411 |  67.987 |  69.443 |  68.199 |  68.666 |  67.758 |
# |  20254 |  33.442 |  33.496 |  33.489 |  33.297 |  33.566 |  33.620 |  33.511 |
# |  23437 |  46.780 |  46.205 |  45.830 |  46.474 |  46.254 |  46.212 |  46.255 |
# |  51297 |  28.655 |  24.847 |  24.910 |  24.928 |  24.820 |  24.754 |  24.823 |
# |  24320 |  46.139 |  40.267 |  40.307 |  40.107 |  39.652 |  40.540 |  40.730 |
# |    791 |  34.653 |  32.978 |  33.070 |  32.405 |  33.399 |  33.131 |  32.884 |
# |  Total |  40.404 |  39.053 |  38.954 |  39.227 |  38.925 |  39.125 |  39.032 |

# %% [markdown]
# #### model_10_Modified_CNN_0_median_stdev_2_3_groups
# |N_pages |Fibonacci| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|
# |  24964 |  61.170 |  68.900 |  69.367 |  69.103 |  69.194 |  69.001 |  67.833 |
# |  43691 |  40.612 |  40.247 |  39.939 |  40.098 |  40.056 |  40.701 |  40.443 |
# |  76408 |  34.288 |  29.910 |  29.979 |  30.039 |  29.790 |  29.676 |  30.068 |
# |  Total |  40.404 |  39.140 |  39.154 |  39.194 |  39.062 |  39.169 |  39.119 |
# #### model_10_Modified_CNN_0_median_stdev
# |N_pages |Fibonacci| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 161.576 | 156.487 | 166.024 | 139.355 | 159.019 |
# |  23085 |  61.354 |  64.389 |  64.273 |  64.008 |  63.988 |  64.148 |
# |  43691 |  40.612 |  39.684 |  39.842 |  39.969 |  39.808 |  40.173 |
# |  75617 |  34.284 |  29.538 |  29.575 |  29.454 |  29.907 |  29.573 |
# |    740 |  35.621 |  33.564 |  33.710 |  33.397 |  33.666 |  33.965 |
# |     51 |  20.224 |  16.406 |  16.451 |  17.309 |  16.628 |  16.331 |
# #### model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3
# |N_pages |Fibonacci| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 161.230 | 166.806 | 139.008 | 152.935 | 170.833 |
# |  23085 |  61.354 |  64.048 |  63.281 |  63.966 |  63.664 |  63.569 |
# |  43691 |  40.612 |  40.004 |  39.860 |  40.201 |  39.817 |  40.143 |
# |  75617 |  34.284 |  30.201 |  29.582 |  29.611 |  29.744 |  29.618 |
# |    740 |  35.621 |  33.801 |  34.143 |  34.101 |  34.290 |  34.145 |
# |     51 |  20.224 |  16.933 |  17.094 |  16.930 |  17.424 |  16.985 |
#
# #### model_9_CNN_with_Fibonacci_4_Ensemble
# |N_pages |Fibonacci| Model 0 |
# |--------|---------|---------|
# |   1879 |  57.385 | 146.145 |
# |  23085 |  61.354 |  64.128 |
# |  43691 |  40.612 |  40.052 |
# |  75617 |  34.284 |  29.862 |
# |    740 |  35.621 |  34.607 |
# |     51 |  20.224 |  16.023 |

# %% [markdown]
# if test_length:
#     print('[Group SMAPE]')
#     print('W/ Nan, Nan=0, Contribution, Pages, Non-nan Ratio')
#     for score, score_0, c, n, nr in zip(gp_smape, gp_smape_0,
#                                     gp_smape_cont, gp_n,
#                                     n_not_nan_ratio_gp):
#         print('%6.2f' % score, '%6.2f' % score_0, '       %6.2f' % c, '%6d' % n,
#               '        %6.3f' % nr)
#     print('-------------------------------------------------')
#     print('%6.2f' % model_smape, '%6.2f' % model_smape_0)

# %% [markdown]
# n_not_nan_gp

# %% [markdown]
# ### Page Scores

# %%
if test_length:  # Page scores for the model
    smape_Y_pred_ens = []
    for Y_output_pred_ori in Y_output_pred_ori_ens:
        smape_Y_pred = np.nan_to_num(np.array([smape(yp, y) for yp, y 
                                               in zip(Y_output_pred_ori, Y_output_raw)]))
        smape_Y_pred_ens.append(smape_Y_pred)
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice
#   """

# %%
if test_length:  # Page score for Fib.
    smape_Y_fib = np.nan_to_num(np.array([smape(yp, y) for yp, y 
                                          in zip(Y_output_fib, Y_output_raw)]))
# Out:
# c:\python3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice
#   """

# %%
if test_length:
    for smape_Y_pred in smape_Y_pred_ens:
        plt.hist(smape_Y_pred, bins=40, alpha=0.4)
        #plt.yscale('log')
    plt.title('Ensemble Page SMAPE'); plt.show()

# %%
if test_length:
    plt.hist(smape_Y_fib, bins=40, alpha=0.6, label='Fib.')
    plt.hist(smape_Y_pred, bins=40, alpha=0.6, label='Model')
    #plt.yscale('log')
    plt.legend(); plt.show()

# %% [markdown]
# ### Page Scores in Each Group

# %%
if test_length:  # The model
    smape_Y_pred_list_ens = []
    for smape_Y_pred in smape_Y_pred_ens:
        smape_Y_pred_list = [smape_Y_pred[output_gp == gp] for gp in gp_list]
        smape_Y_pred_list_ens.append(smape_Y_pred_list)

# %%
if test_length:  # Fib.
    smape_Y_fib_list = [smape_Y_fib[output_gp == gp] for gp in gp_list]

# %% [markdown]
# #### Plots

# %%
if test_length:
    for gp,s in zip(gp_list,smape_Y_pred_list):
        plt.hist(s, bins=40, normed=True, alpha=0.6, label='gp = ' + str(gp))
    #plt.yscale('log')
    plt.legend(); plt.show()

# %%
if test_length:
    for gp,s in zip(gp_list,smape_Y_pred_list):
        plt.hist(s, bins=40, alpha=0.6, label='gp = ' + str(gp))
    #plt.yscale('log')
    plt.legend(); plt.show()

# %%
if test_length:
    for gp in gp_list:
        plt.hist(smape_Y_fib_list[gp], bins=40, alpha=0.6, label='Fib.')
        plt.hist(smape_Y_pred_list[gp], bins=40, alpha=0.6, label='Model')
        plt.title('gp = '+str(gp)); plt.legend()
        plt.show()
    #plt.yscale('log')
    #plt.ylim([0,0.05])

# %% [markdown]
# ## Prediction Pre Combine
# Combine group 0, 1 from Fib and rest from the model

# %% [markdown]
# Y_output_fib.shape

# %%
Y_output_fib_ori = np.repeat(Y_output_fib, y_length, axis=1); Y_output_fib_ori.shape
# Out:
# (145063, 63)

# %%
# Select group 0 from Fib.
#fib_mask = (output_gp == 0).reshape(-1,1); fib_mask.shape
#fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape
fib_mask = ((output_gp == 0)|(output_gp == 1)|(output_gp == 2)).reshape(-1,1); fib_mask.shape
# Out:
# (145063, 1)

# %%
# The combined result
Y_output_fmc_ori_ens = []
for Y_output_pred_ori in Y_output_pred_ori_ens:
    
    Y_output_fmc_ori = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori
    
    Y_output_fmc_ori_ens.append(Y_output_fmc_ori)

# %% [markdown]
# Y_output_fmc_ori

# %% [markdown]
# #### Pre Combined Score

# %%
if test_length: 
    fmc_smape_ens = []
    for Y_output_fmc_ori in Y_output_fmc_ori_ens:
        fmc_smape = smape(Y_output_fmc_ori, Y_output_raw)
        fmc_smape_ens.append(fmc_smape)        
    fmc_smape_ens_mean = np.mean(fmc_smape_ens)

# %%
if test_length: 
    for run, fmc_smape, model_smape in zip(ens_list, fmc_smape_ens, model_smape_ens):
        print('%6.3f' % fmc_smape, '(%6.3f)' % model_smape, '-', model_name, run)
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
# Out:
# 38.047 (38.954) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 0
# 38.015 (39.227) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 1
# 37.904 (38.925) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 2
# 38.031 (39.125) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 3
# 38.087 (39.032) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 4
# 38.017 (39.053) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev Average

# %% [markdown]
# ## Ensemble Learning

# %% [markdown]
# ### Ensemble Median

# %%
Y_output_pred_ori_ens_med = np.median(Y_output_pred_ori_ens, axis=0)
Y_output_pred_ori_ens_med.shape
# Out:
# (145063, 63)

# %% [markdown]
# Y_output_pred_ori_ens_med

# %%
ens_med_smape = smape(Y_output_pred_ori_ens_med, Y_output_raw); ens_med_smape
# Out:
# 38.692509065608007

# %% [markdown]
# Best ways seem to be taking median either before or after transformation.

# %% [markdown]
# ### Ensemble Combine with Fibonacci Median

# %% [markdown]
# #Select group 0, 1
# fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape

# %% [markdown]
# Y_output_pred_ori_ens_med

# %%
#Y_output_f_omean = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori_ens_mean
Y_output_f_omed  = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori_ens_med  # Our final output
#Y_output_f_meano = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ens_mean_ori
#Y_output_f_medo  = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ens_med_ori

# %% [markdown]
# ## All Model Scores

# %%
if test_length:  # Ensemble learning model score
    #f_omean_smape = smape(Y_output_raw, Y_output_f_omean)
    f_omed_smape = smape(Y_output_raw, Y_output_f_omed)
    #f_meano_smape = smape(Y_output_raw, Y_output_f_meano)
    #f_medo_smape = smape(Y_output_raw, Y_output_f_medo)

# %%
if test_length: # The_score with (without) combining Fibonacci median model
    #print('%6.3f         ' % f_omean_smape, '-', model_name, 'ori_ens_mean')
    print('%6.3f' % f_omed_smape, '(%6.3f)' % ens_med_smape,'-', model_name, 'ori_ensemble_median')
    #print('%6.3f         ' % f_meano_smape, '-', model_name, 'ens_mean_ori')
    #print('%6.3f         ' % f_medo_smape, '-', model_name, 'ens_med_ori')
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
    for run, fmc_smape, model_smape in zip(ens_list, fmc_smape_ens, model_smape_ens):
        print('%6.3f' % fmc_smape, '(%6.3f)' % model_smape, '-', model_name, run)
# Out:
# 37.791 (38.693) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev ori_ensemble_median
# 38.017 (39.053) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev Average
# 38.047 (38.954) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 0
# 38.015 (39.227) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 1
# 37.904 (38.925) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 2
# 38.031 (39.125) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 3
# 38.087 (39.032) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev 4

# %% [markdown]
# 37.436          - model_10_Modified_CNN_0_median_stdev ori_ens_mean
# 37.382          - model_10_Modified_CNN_0_median_stdev ori_ens_med
# 37.394          - model_10_Modified_CNN_0_median_stdev ens_mean_ori
# 37.382          - model_10_Modified_CNN_0_median_stdev ens_med_ori
# 37.687 (38.816) - model_10_Modified_CNN_0_median_stdev Average

# %% [markdown]
# Ensemble of model are all better than the individual model.

# %% [markdown]
# fmc_smape_ens

# %% [markdown]
# fmc_smape_ens_mean

# %% [markdown]
#  Y_output_ori_list = [Y_output_ori[output_gp == gp] for gp in gp_list]

# %% [markdown]
# #### Combined Scores:
# 37.535          - model_10_Modified_CNN_0_median_stdev_2_3_groups ori_ensemble_median
#
# 37.382          - model_10_Modified_CNN_0_median_stdev ori_ens_med
#
# 37.687 (38.816) - model_10_Modified_CNN_0_median_stdev Average
#
# 38.734 (39.415) - Model 9.1.0 - model_9_CNN_with_Fibonacci_1_no_group 1
#
# 38.227 (39.321) - Model 9.0.0 - model_9_CNN_with_Fibonacci_0_separate_Fib_median 1
#
# 43.009 (44.180) - Model 7.8.0 - model_7_CNN_with_Fibonacci_8_mean_absolute_error 2
#
# 44.070 (45.335) - Model 7.6.3 - model_7_CNN_with_Fibonacci_6_Wider_3_conv_120_Averagepool 1
#
# 44.473 (45.652) - Model 7.6.1 - model_7_CNN_with_Fibonacci_6_Wider_1_conv_120_Maxpool 1
#
# 44.433 - Model 7.5.0 - model_7_CNN_with_Fibonacci_5_Deeper_0_Initial
#
# 44.168 - Model 7.2.0

# %% [markdown]
# ## All Group Scores

# %%
# ensemble result Y_output in each group
#Y_output_pred_ori_ens_mean_list = [Y_output_pred_ori_ens_mean[output_gp == gp] for gp in gp_list]
Y_output_pred_ori_ens_med_list = [Y_output_pred_ori_ens_med[output_gp == gp] for gp in gp_list]
#Y_output_pred_ens_mean_ori_list = [Y_output_pred_ens_mean_ori[output_gp == gp] for gp in gp_list]
#Y_output_pred_ens_med_ori_list = [Y_output_pred_ens_med_ori[output_gp == gp] for gp in gp_list]

# %%
# Group SMAPE scores
if test_length:
    # SMAPE with nan values ignored (used by Kaggle)
    #gp_omean_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_ens_mean_list)]
    gp_omed_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_ens_med_list)]
    #gp_meano_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ens_mean_ori_list)]

# %%
if test_length:  # The_gp_score
    print('#### ' + model_name)
    print('', end='|')
    print(' N_pages', 'Fibonacci', 'Ens Media', ' Average ', sep='|', end='|')
    for run in ens_list: print(' Model', run, end=' |')
    print('')
    print('', end='|')
    print('--------', '---------', '---------', '---------', sep='|', end='|')
    for run in ens_list: print('---------', end='|')
    print('')
    for gp in gp_list:
        print('', end='|')
        print(' %6d ' % gp_n[gp], end='|')
        print(' %7.3f ' % gp_smape_fib[gp], end='|')
        #print(' %7.3f ' % gp_omean_smape[gp], end='|')
        print(' %7.3f ' % gp_omed_smape[gp], end='|')
        #print(' %7.3f ' % gp_meano_smape[gp], end='|')
        #print(' %7.3f ' % gp_medo_smape[gp], end='|')
        print(' %7.3f ' % gp_smape_mean[gp], end='|')
        for run in ens_list:
            print(' %7.3f ' % gp_smape_ens[run][gp], end='|')
        print('')
    print('|Over All', ' %7.3f ' % fib_smape, ' %7.3f ' % f_omed_smape,
          ' %7.3f ' % model_smape_ens_mean, sep='|', end='|')
    for run in ens_list:
            print(' %7.3f ' % model_smape_ens[run], end='|')
# Note The over all score for ensemble median (Ens Media) is the one after combining with 
# Fibonacci median model not the total score
# Out:
# #### model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev
# | N_pages|Fibonacci|Ens Media| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|
# |  24964 |  61.170 |  68.411 |  68.411 |  67.987 |  69.443 |  68.199 |  68.666 |  67.758 |
# |  20254 |  33.442 |  33.161 |  33.496 |  33.489 |  33.297 |  33.566 |  33.620 |  33.511 |
# |  23437 |  46.780 |  45.682 |  46.205 |  45.830 |  46.474 |  46.254 |  46.212 |  46.255 |
# |  51297 |  28.655 |  24.490 |  24.847 |  24.910 |  24.928 |  24.820 |  24.754 |  24.823 |
# |  24320 |  46.139 |  39.706 |  40.267 |  40.307 |  40.107 |  39.652 |  40.540 |  40.730 |
# |    791 |  34.653 |  32.719 |  32.978 |  33.070 |  32.405 |  33.399 |  33.131 |  32.884 |
# |Over All|  40.404 |  37.791 |  39.053 |  38.954 |  39.227 |  38.925 |  39.125 |  39.032 |

# %% [markdown]
# #### model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev
# | N_pages|Fibonacci|Ens Media| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|
# |  24964 |  61.170 |  68.411 |  68.411 |  67.987 |  69.443 |  68.199 |  68.666 |  67.758 |
# |  20254 |  33.442 |  33.161 |  33.496 |  33.489 |  33.297 |  33.566 |  33.620 |  33.511 |
# |  23437 |  46.780 |  45.682 |  46.205 |  45.830 |  46.474 |  46.254 |  46.212 |  46.255 |
# |  51297 |  28.655 |  24.490 |  24.847 |  24.910 |  24.928 |  24.820 |  24.754 |  24.823 |
# |  24320 |  46.139 |  39.706 |  40.267 |  40.307 |  40.107 |  39.652 |  40.540 |  40.730 |
# |    791 |  34.653 |  32.719 |  32.978 |  33.070 |  32.405 |  33.399 |  33.131 |  32.884 |
# |Over All|  40.404 |  37.791 |  39.053 |  38.954 |  39.227 |  38.925 |  39.125 |  39.032 |
# #### model_10_Modified_CNN_0_median_stdev_2_3_groups
# | N_pages|Fibonacci|Ens Media| Average | Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|
# |  24964 |  61.170 |  68.909 |  68.900 |  69.367 |  69.103 |  69.194 |  69.001 |  67.833 |
# |  43691 |  40.612 |  39.821 |  40.247 |  39.939 |  40.098 |  40.056 |  40.701 |  40.443 |
# |  76408 |  34.288 |  29.400 |  29.910 |  29.979 |  30.039 |  29.790 |  29.676 |  30.068 |
# |Over All|  40.404 |  37.535 |  39.140 |  39.154 |  39.194 |  39.062 |  39.169 |  39.119 |
# #### model_10_Modified_CNN_0_median_stdev
# | N_pages|Fibonacci| ori mean|ori media| mean ori|media ori| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 199.741 | 172.496 | 191.624 | 172.496 | 161.576 | 156.487 | 166.024 | 139.355 | 159.019 |
# |  23085 |  61.354 |  64.110 |  64.122 |  64.116 |  64.122 |  64.389 |  64.273 |  64.008 |  63.988 |  64.148 |
# |  43691 |  40.612 |  39.620 |  39.564 |  39.574 |  39.564 |  39.684 |  39.842 |  39.969 |  39.808 |  40.173 |
# |  75617 |  34.284 |  29.300 |  29.231 |  29.248 |  29.231 |  29.538 |  29.575 |  29.454 |  29.907 |  29.573 |
# |    740 |  35.621 |  33.403 |  33.482 |  33.373 |  33.482 |  33.564 |  33.710 |  33.397 |  33.666 |  33.965 |
# |     51 |  20.224 |  16.360 |  16.338 |  16.361 |  16.338 |  16.406 |  16.451 |  17.309 |  16.628 |  16.331 |
# #### model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3
# | N_pages|Fibonacci| ori mean|ori media| mean ori|media ori| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 199.921 | 173.799 | 189.346 | 173.799 | 161.230 | 166.806 | 139.008 | 152.935 | 170.833 |
# |  23085 |  61.354 |  63.635 |  63.651 |  63.644 |  63.651 |  64.048 |  63.281 |  63.966 |  63.664 |  63.569 |
# |  43691 |  40.612 |  39.693 |  39.628 |  39.637 |  39.628 |  40.004 |  39.860 |  40.201 |  39.817 |  40.143 |
# |  75617 |  34.284 |  29.444 |  29.368 |  29.381 |  29.368 |  30.201 |  29.582 |  29.611 |  29.744 |  29.618 |
# |    740 |  35.621 |  33.858 |  33.893 |  33.837 |  33.893 |  33.801 |  34.143 |  34.101 |  34.290 |  34.145 |
# |     51 |  20.224 |  16.861 |  16.948 |  16.856 |  16.948 |  16.933 |  17.094 |  16.930 |  17.424 |  16.985 |

# %% [markdown]
# ## More Explore

# %% [markdown]
# ### Group Models in other Groups

# %%
# %%time
smape_gpm_gp_ens = []
for run in ens_list:
    print('Run', run)
    models = models_ens[run]
    Y_output_all_ori_list = unlog(np.array([untransform(model.predict([X_output, A_output]), output_center, output_scale) 
                                            for model in models]))
    # row: model of the group; column: group of Y
    smape_gpm_gp = [[smape(Y, Y_p[output_gp == gp]) for gp, Y in zip(gp_list, Y_output_raw_list)] 
                    for Y_p in Y_output_all_ori_list]
    smape_gpm_gp_ens.append(smape_gpm_gp)
# Out:
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Wall time: 6min 51s

# %%
smape_gpm_gp_ens = np.array(smape_gpm_gp_ens)

# %%
smape_gpm_gp_mean = np.mean(smape_gpm_gp_ens, axis=0)

# %%
print('Ensemble avg  ', end='|')
for j in range(len(smape_gpm_gp_mean[0])): print(' group', j, end='|')
print('')
print('--------------', end='|')
for j in range(len(smape_gpm_gp_mean[0])): print('--------', end='|')
print('')
for i in range(len(smape_gpm_gp_mean)):
    print('group model', i, end=' |')
    for j in range(len(smape_gpm_gp_mean[0])):
        print(' %6.2f ' % smape_gpm_gp_mean[i][j], end='|')
    print('')
# Out:
# Ensemble avg  | group 0| group 1| group 2| group 3| group 4| group 5|
# --------------|--------|--------|--------|--------|--------|--------|
# group model 0 |  68.41 |  33.37 |  46.89 |  28.38 |  47.26 |  36.22 |
# group model 1 |  70.31 |  33.50 |  47.43 |  26.41 |  47.31 |  36.45 |
# group model 2 |  68.97 |  33.25 |  46.21 |  25.55 |  42.40 |  31.76 |
# group model 3 |  70.92 |  33.87 |  48.11 |  24.85 |  42.02 |  30.71 |
# group model 4 |  70.68 |  33.42 |  46.19 |  24.59 |  40.27 |  29.82 |
# group model 5 |  75.35 |  35.79 |  50.90 |  26.83 |  46.39 |  32.98 |

# %% [markdown]
# ## Optimize Group Models

# %%
gpm_list = np.argmin(smape_gpm_gp_mean,axis=0)

# %%
gpm_list
# Out:
# array([0, 2, 4, 4, 4, 4], dtype=int64)

# %%
# %%time
Y_output_all_ori_list_ens = unlog(np.array([[untransform(model.predict([X_output, A_output]), 
                                                         output_center, output_scale) 
                                            for model in models] for models in models_ens]))
#Take 7 min on PC

# %%
Y_output_all_ori_list_ens.shape
# Out:
# (5, 6, 145063, 63)

# %%
Y_output_all_ori_list_ens_med = np.median(Y_output_all_ori_list_ens, axis=0); Y_output_all_ori_list_ens_med.shape
# Out:
# (6, 145063, 63)

# %%
gpm_mask = np.array([gpm_list == gp for gp in gp_list]).T; gpm_mask
# Out:
# array([[ True, False, False, False, False, False],
#        [False, False,  True, False, False, False],
#        [False, False, False, False,  True, False],
#        [False, False, False, False,  True, False],
#        [False, False, False, False,  True, False],
#        [False, False, False, False,  True, False]], dtype=bool)

# %%
Y_output_ori_list_ens_med_temp = np.tensordot(gpm_mask, Y_output_all_ori_list_ens_med, axes=([1],[0]))

# %%
Y_output_ori_list_ens_med_temp
# Out:
# (6, 145063, 63)

# %%
gp_mask = np.array([output_gp == gp for gp in gp_list]); gp_mask
# Out:
# array([[False, False,  True, ..., False,  True, False],
#        [ True, False, False, ..., False, False, False],
#        [False,  True, False, ...,  True, False,  True],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]], dtype=bool)

# %%
gp_mask_reshape = gp_mask.reshape(len(gp_mask),len(gp_mask[0]),1); gp_mask_reshape.shape
# Out:
# (6, 145063, 1)

# %%
Y_output_ori_list_ens_med_temp_mask = gp_mask_reshape * Y_output_ori_list_ens_med_temp

# %%
Y_output_ori_list_ens_med_temp_mask.shape
# Out:
# (6, 145063, 63)

# %%
Y_output_gpm_ens_med = np.sum(Y_output_ori_list_ens_med_temp_mask, axis=0)

# %%
Y_output_gpm_ens_med.shape
# Out:
# (145063, 63)

# %%
gpm_ens_smape = smape(Y_output_raw, Y_output_gpm_ens_med)

# %%
gpm_ens_smape, ens_med_smape
# Out:
# (38.571133, 38.692509065608007)

# %% [markdown]
# Group model selection is better

# %% [markdown]
# #### Group scores

# %%
Y_output_gpm_ens_med_list = [Y_output_gpm_ens_med[output_gp == gp] for gp in gp_list]

# %%
# Group SMAPE scores
if test_length:
    gp_gpm_ens_med_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_gpm_ens_med_list)]

# %%
if test_length:
    #print('#### ' + model_name + 'group model optimized')
    #print('', end='|')
    print(' N_pages', 'Fibonacci', 'GPM Optim', 'Ens Media', ' Average ', sep='|', end='|')
    #or run in ens_list: print(' Model', run, end=' |')
    print('')
    print('', end='|')
    print('--------', '---------', '---------', '---------', '---------', sep='|', end='|')
    #for run in ens_list: print('---------', end='|')
    print('')
    for gp in gp_list:
        print('', end='|')
        print(' %6d ' % gp_n[gp], end='|')
        print(' %7.3f ' % gp_smape_fib[gp], end='|')
        print(' %7.3f ' % gp_gpm_ens_med_smape[gp], end='|')
        print(' %7.3f ' % gp_omed_smape[gp], end='|')
        print(' %7.3f ' % gp_smape_mean[gp], end='|')
        print('')
    #print('|Over All', ' %7.3f ' % fib_smape, ' %7.3f ' % f_omed_smape,
    #      ' %7.3f ' % model_smape_ens_mean, sep='|', end='|')    
# Note The over all score for ensemble median (Ens Media) is the one after combining with 
# Fibonacci median model not the total score
# Out:
#  N_pages|Fibonacci|GPM Optim|Ens Media| Average |
# |--------|---------|---------|---------|---------|
# |  24964 |  61.170 |  68.411 |  68.411 |  68.411 |
# |  20254 |  33.442 |  32.970 |  33.161 |  33.496 |
# |  23437 |  46.780 |  45.545 |  45.682 |  46.205 |
# |  51297 |  28.655 |  24.340 |  24.490 |  24.847 |
# |  24320 |  46.139 |  39.706 |  39.706 |  40.267 |
# |    791 |  34.653 |  29.521 |  32.719 |  32.978 |

# %% [markdown]
# Only group 0 of GPM Optimized is worse than Fib.

# %% [markdown]
# #### Combined with Fib.

# %%
#Select group 0
#fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape
fib_mask = (output_gp == 0).reshape(-1,1); fib_mask.shape
# Out:
# (145063, 1)

# %%
Y_output_f_gpm = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_gpm_ens_med  # Our final output

# %%
f_gpm_ens_smape = smape(Y_output_raw, Y_output_f_gpm)

# %%
print('%6.3f' % f_gpm_ens_smape, '(%6.3f)' % gpm_ens_smape, '-', model_name, 'GPM Optim Ens')
# Out:
# 37.448 (38.571) - model_10_Modified_CNN_0_median_stdev_3_6_groups_with_stdev GPM Optim Ens

# %% [markdown]
# ## Case Study

# %%
view_list=[93175, 13986, 5464, 89589, 119659, 64392, 73856, 140331, 19234, 25591]

# %% [markdown]
# view_list = examine_list_gp((Y_output_ori,
#                              Y_output_pred_ori_ens_mean,
#                              Y_output_pred_ori_ens_med,
#                              Y_output_pred_ori_ens[-1],
#                              ), output_gp, view_list=view_list)

# %% [markdown]
# i = 93175
# plt.plot(Y_output_ori[i], label='true')
# plt.plot(Y_output_pred_ori_ens_mean[i], label='ens mean')
# plt.plot(Y_output_pred_ori_ens_med[i], label='ens median')
# plt.plot(Y_output_pred_ens_mean_ori[i], label='ens mean before transf')
# plt.plot(Y_output_pred_ens_med_ori[i], label='ens median before transf')
# plt.plot(Y_output_pred_ori_ens[-1][i], label='run: 4')
# plt.title('i = ' + str(i) + ' gp = ' + str(output_gp[i]))
# plt.legend()
# plt.show()

# %% [markdown]
# i = 93175
# plt.plot(Y_output_ori[i], label='true')
# for run in ens_list:
#     plt.plot(Y_output_pred_ori_ens[run][i], label='run' + str(run))
# plt.plot(Y_output_pred_ens_mean_ori[i], label='ens mean before transf')
# plt.title('i = ' + str(i) + ' gp = ' + str(output_gp[i]))
# plt.legend()
# plt.show()

# %%
view_list = examine_list_gp((Y_output_pred_ori_ens_med,
                             Y_output_f_gpm, 
                             Y_output_ori), output_gp, view_list=view_list)

# %%
view_list = examine_list_gp((Y_output_pred_ori,
                             Y_output_f_gpm, 
                             Y_output_ori), output_gp, view_list=view_list)

# %% [markdown]
# view_list = comp_examine(X_output, Y_output_pred, view_list=view_list)

# %% [markdown]
# view_list = comp_examine(X_output_ori, Y_output_pred_ori, view_list=view_list)

# %%
view_list = examine_list_gp((Y_output_pred_ori, X_output_ori, Y_input_ori), output_gp, view_list=view_list)

# %% [markdown]
# view_list = examine_list_gp((Y_output_pred, X_output, Y_input), output_gp, view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list((Y_output_pred, Y_output, X_output), view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list((Y_output_pred_ori, Y_output_ori, X_output_ori), view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list_gp((Y_output_pred, Y_output, X_output), output_gp,
#                              view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori), output_gp,
#                              view_list=view_list)

# %% [markdown]
# view_list_smape = [smape(Y_output_pred_ori[i], Y_output_raw[i]) for i in view_list]; view_list_smape

# %% [markdown]
# view_list_review = [score < model_smape for score in view_list_smape]; view_list_review

# %% [markdown]
# view_list_good = list(np.array(view_list)[view_list_review]); view_list_good

# %% [markdown]
# view_list_bad = list(np.array(view_list)[~np.array(view_list_review)]); view_list_bad

# %% [markdown]
# #### Good cases

# %% [markdown]
# examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori), output_gp,
#              view_list=view_list_good)

# %% [markdown]
# #### Bad cases

# %% [markdown]
# examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori),output_gp,
#              view_list=view_list_bad)

# %% [markdown]
# print(output_center[view_list_good].reshape(-1))
# print(output_center[view_list_bad].reshape(-1))

# %% [markdown]
# print(output_scale[view_list_good].reshape(-1))
# print(output_scale[view_list_bad].reshape(-1))

# %% [markdown]
# output_gp[view_list_good]

# %% [markdown]
# output_gp[view_list_bad]

# %% [markdown]
# #### Case 93175

# %% [markdown]
# i = 93175

# %% [markdown]
# multi_view((Y_output_pred_ori[i], Y_output_ori[i], X_output_ori[i]), yscale='log')
# multi_view((Y_output_pred_ori[i], Y_output_ori[i], X_output_ori[i]))

# %% [markdown]
# smape(Y_output_pred_ori[i], Y_output_raw[i])

# %% [markdown]
# input_center[i], output_center[i], input_scale[i], output_scale[i]

# %% [markdown]
# #### Case 41896

# %% [markdown]
# i = 41896

# %% [markdown]
# multi_view((X_input[i], Y_input[i]))

# %% [markdown]
# comp_view(X_input_ori[i], Y_input_ori[i])

# %% [markdown]
# comp_view(X_output_ori[i], Y_output_pred_ori[i])

# %% [markdown]
# comp_view(X_input_ori[i], Y_input_ori[i])

# %% [markdown]
# ### Good and bad cases

# %% [markdown]
# review_Y = np.array([score < model_smape for score in smape_Y_pred])
# good_Y_index = np.arange(len(Y_output_pred))[review_Y]; #good_Y_index
# bad_Y_index = np.arange(len(Y_output_pred))[~review_Y]; #bad_Y_index

# %% [markdown]
# good_input_scale = input_scale[good_Y_index]
# good_output_scale = output_scale[good_Y_index]
# bad_input_scale = input_scale[bad_Y_index]
# bad_output_scale = output_scale[bad_Y_index]

# %% [markdown]
# good_input_center = input_center[good_Y_index]
# good_output_center = output_center[good_Y_index]
# bad_input_center = input_center[bad_Y_index]
# bad_output_center = output_center[bad_Y_index]

# %% [markdown]
# examine_list_gp((Y_output_pred_ori[good_Y_index], Y_output_ori[good_Y_index], X_output_ori[good_Y_index]), output_gp[good_Y_index])

# %% [markdown]
# examine_list_gp((Y_output_pred_ori[bad_Y_index], Y_output_ori[bad_Y_index], X_output_ori[bad_Y_index]), output_gp[bad_Y_index])

# %% [markdown]
# good_output_scale.min(), good_output_scale.max()

# %% [markdown]
# bad_output_scale.min(), bad_output_scale.max()

# %% [markdown]
# plt.hist(good_input_scale, bins=40, alpha=0.6, label='good input')
# plt.hist(bad_input_scale, bins=40, alpha=0.6, label='bad input')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_output_scale, bins=40, alpha=0.6, label='good output')
# plt.hist(bad_output_scale, bins=40, alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_input_scale, bins=40, alpha=0.6, label='good input')
# plt.hist(bad_input_scale, bins=40, alpha=0.6, label='bad input')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_output_scale, bins=40, alpha=0.6, label='good output')
# plt.hist(bad_output_scale, bins=40, alpha=0.6, label='bad output')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(good_input_scale, bins=100, range=(0,0.8), alpha=0.6, label='good input')
# plt.hist(good_output_scale, bins=100, range=(0,0.8), alpha=0.6, label='good output')
# plt.hist(bad_input_scale, bins=100, range=(0,0.8), alpha=0.6, label='bad input')
# plt.hist(bad_output_scale, bins=100, range=(0,0.8), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# Should we split the data into std > and < 1.7 ?

# %% [markdown]
# np.mean(good_output_scale), np.mean(good_input_scale)

# %% [markdown]
# np.mean(bad_output_scale), np.mean(bad_input_scale)

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(bad_input_scale, bins=60, range=(0,0.8), alpha=0.6, label='bad input')
# plt.hist(bad_output_scale, bins=60, range=(0,0.8), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(output_scale, bins=40, alpha=0.6, label='output')
# plt.hist(input_scale, bins=40, alpha=0.6, label='input')
# plt.legend()
# plt.show()

# %% [markdown]
# np.histogram(output_scale, bins=np.arange(0,1,0.05))

# %% [markdown]
# #### Median

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(good_input_center, bins=100, range=(0,5), alpha=0.6, label='good input')
# plt.hist(good_output_center, bins=100, range=(0,5), alpha=0.6, label='good output')
# plt.hist(bad_input_center, bins=100, range=(0,5), alpha=0.6, label='bad input')
# plt.hist(bad_output_center, bins=100, range=(0,5), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# ### stdev/median

# %% [markdown]
# output_factor_1 = (output_center / output_scale).reshape(-1); output_factor_1

# %% [markdown]
# output_factor_1.min(), output_factor_1.max()

# %% [markdown]
# plt.hist(output_factor_1, bins=40, range=[0,50], alpha=0.6)
# plt.show()

# %% [markdown]
# plt.scatter(smape_Y_pred, output_scale, alpha=0.1, marker='.')
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_center, alpha=0.1, marker='.')
# plt.ylim([-0.1,5])
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_scale, alpha=0.1, marker='.')
# plt.ylim([0,0.5])
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(output_scale, output_center, alpha=0.1, marker='.')
# plt.ylim([0,4.5])
# plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_2 = (output_scale / output_center).reshape(-1); output_factor_2

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_2, alpha=0.1, marker='.')
# plt.ylim([0,0.8])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_3 = (output_scale / (output_center + 0.01)).reshape(-1); output_factor_3

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_3, alpha=0.1, marker='.')
# plt.ylim([0,4])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_4 = output_scale - input_scale

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_4, alpha=0.1, marker='.')
# plt.ylim([-1.5,0.5])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# ## Output Prediction
# For predicting stage only

# %% [markdown]
# ### Result DataFrame

# %% [markdown]
# predict_dates_index=pd.date_range(Y_output_first_day,
#                                   periods=np.timedelta64(y_length,'D'),
#                                   freq = 'D', unit = 'D')
# predict_dates_index

# %%
Y_output_dates

# %%
if test_length == 0:
    result_df = pd.DataFrame(Y_output_f_omed, columns = Y_output_dates)  # using ensemble median combined result
result_df

# %%
result_df['Page'] = input_df['Page']  # Append 'Page' column from input_df
result_df

# %%
result_flat_df = pd.melt(result_df, id_vars='Page', var_name='date',
                         value_name='Visits')
result_flat_df

# %% [markdown]
# ### Output DataFrame

# %%
if test_length == 0:
    print('%%% Reading data key_2.csv ...', end = '', flush = True)
    output_df = pd.read_csv("../data/key_2.csv")
    print('done!')

# %%
output_df['date'] = output_df.Page.apply(lambda a: a[-10:])  # take the last 10 characters from 'Page' as date
output_df['Page'] = output_df.Page.apply(lambda a: a[:-11])  # remove the last 10 caharacters from 'Page'
#output_df['date'] = output_df['date'].astype('datetime64[ns]')  # convert 'date' string to numpy datetime format
#test['weekday'] = test.date.dt.dayofweek  # find the day of week using the 'date' column
output_df.head()

# %%
output_df.info()

# %%
output_df['date'].values[0:62]  # Make sure the range is 60 days (see if the dates resume after 60)

# %%
Y_output_dates

# %%
output_df = output_df.merge(result_flat_df, how='left')  # fill the 'Visits" from result
output_df

# %%
del result_flat_df

# %%
gc.collect()

# %%
#Check if there is null value
output_df.loc[output_df.Visits.isnull(), 'Visits']

# %%
#output_df.loc[output_df.Visits.isnull(), 'Visits'] = 0.0  # Uncommend this line to Replace NaN with 0.0

# %%
print('%%% Writing result for ' + model_name + ' ...', 
      end = '', flush = True)
#Write only the 'Id' and 'Visits' to the result file
output_df[['Id','Visits']].to_csv('../results/submit_1_' + model_name
                                  + '.csv', index = False, 
                                  float_format='%.3f')
print('done!')

# %% [markdown]
# Kaggle LB Score:
#
# [6.0.0] 46.3 [Model 6.0.0 CNN - Conv(60, 7)-FC(120)-Drop(0.25)-FC(120)-Drop(0.5)-Linear, 20 epoches]
#
# [6.1.0] 46.7 [Model 6.1.0 CNN - Conv(30, 7)-Conv(60, 7)-FC(120)-Drop(0.25)-FC(120)-Drop(0.5)-Linear, 20 epoches]
#
# [7.1.2] 47.3 [Model 7.1.2 CNN Fibonacci - range corrected :-y_length - score corrected]
#
# [7.2.0] 46.5 [Model 7.2.0 CNN Fibonacci and original combined]
