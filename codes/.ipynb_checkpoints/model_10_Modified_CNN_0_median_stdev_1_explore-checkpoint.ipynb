# %%
# %autosave 0
# Out:
# Autosave disabled

# %% [markdown]
# ### Kaggle - Web Traffic Time Series Forecasting
#
# ## Model 10 - Modified CNN with Fibonacci
#
# ### v0 with second input of median and stdev
#
# by Louis Yang
#
# Use Fibonacci series median instead of median. The Fib. median are now compute on both training and CV set separately.
#
# Split into groups based on the scale of visit number and train individual model in each group
#
# The first 2 groups use original Fibonacci median as prediction. The rest groups use the trained CNN as prediction.
#
# Test on stage 2 data.
#
# Original model: 'model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3'
#
# Ensemble: automatically evaluate the same model 4 times

# %%
model_name = 'model_10_Modified_CNN_0_median_stdev'

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import gc  # Python garbage collect
from tools import *

# %% [markdown]
# ## Input

# %%
train_file = 'train_2.csv'

# %%
print('%%% Reading data '+ train_file + ' ... ', end = '', flush = True)
input_df = pd.read_csv('../data/' + train_file)
print('done!')
# Out:
# %%% Reading data train_2.csv ... done!

# %% [markdown]
# input_df.head()

# %% [markdown]
# input_df.info()

# %%
input_df_dates = input_df.columns[1:]; #input_df_dates

# %% [markdown]
# ## Processing Data
# Generate training set and test (predict) set

# %% [markdown]
# ### Day of week alignment

# %%
from datetime import datetime
def weekday(datestr):
    return datetime.strptime(datestr,'%Y-%m-%d').weekday()
def daydiff(dstr1,dstr2):
    return datetime.strptime(dstr1,'%Y-%m-%d') - datetime.strptime(dstr2,'%Y-%m-%d')

# %% [markdown]
# We need to predict output (Y_output_pred) start from Sunday (6) for data set 1. (0: Monday, 6: Sunday)

# %%
# We take the x_length + y_length days of data only
# This part then split into x_length as input X and y_length as output Y
x_length = 63  # input period
y_length = 63  # predict period

# %%
#test_length = 0  # for predicting
test_length = y_length  # for self testing

# %% [markdown]
# Shift everything forward by y_length = 63 days to allows self testing without Kaggle

# %% [markdown]
# #### X

# %%
X_input_dates = input_df_dates[-x_length-test_length-364:-test_length-364]; #X_input_dates

# %%
X_input_first_day = X_input_dates[0]
X_input_final_day = X_input_dates[-1]
X_input_first_day, X_input_final_day
# Out:
# ('2016-04-29', '2016-06-30')

# %% [markdown]
# daydiff(X_input_first_day, X_input_final_day)  # should be 1 - y_length

# %%
# X for output set
if test_length:
    X_output_dates = input_df_dates[-x_length-test_length:-test_length]
else:
    X_output_dates = input_df_dates[-x_length:]
#X_output_dates

# %%
X_output_first_day = X_output_dates[0]
X_output_final_day = X_output_dates[-1]
X_output_first_day, X_output_final_day
# Out:
# ('2017-04-28', '2017-06-29')

# %% [markdown]
# daydiff(X_output_first_day, X_output_final_day)  # should be 1 - y_length

# %% [markdown]
# weekday(X_input_first_day), weekday(X_output_first_day)

# %% [markdown]
# Both are Wednesday (2).

# %% [markdown]
# #### Y

# %%
Y_input_dates = input_df_dates[-test_length-364:-test_length-364+y_length]; #Y_input_dates

# %%
Y_input_first_day = Y_input_dates[0]
Y_input_final_day = Y_input_dates[-1]
Y_input_first_day, Y_input_final_day
# Out:
# ('2016-07-01', '2016-09-01')

# %% [markdown]
# daydiff(Y_input_first_day, Y_input_final_day)

# %%
# Y for output set
if test_length:
    Y_output_dates = input_df_dates[-test_length:]
else:
    Y_output_first_day = '2017-09-12'  ## Make sure it is correct when predicting !!!!!!!
    Y_output_dates = pd.Index(np.arange(np.datetime64(Y_output_first_day), 
                                        np.datetime64(Y_output_first_day)
                                        + np.timedelta64(y_length, 'D')).astype('str'))
#Y_output_dates

# %%
Y_output_first_day = Y_output_dates[0]
Y_output_final_day = Y_output_dates[-1]
Y_output_first_day, Y_output_final_day
# Out:
# ('2017-06-30', '2017-08-31')

# %% [markdown]
# daydiff(Y_output_first_day, Y_output_final_day)  # should be 1 - y_length

# %% [markdown]
# weekday(Y_input_first_day), weekday(Y_output_first_day)

# %% [markdown]
# Both are Sunday (6).

# %% [markdown]
# ## Fibonacci

# %% [markdown]
# #### Window Sizes

# %% [markdown]
# The window sizes are given by Ehsan https://www.kaggle.com/safavieh

# %%
windows = [11, 18, 30, 48, 78, 126, 203, 329]
fib_length = max(windows)#; fib_length

# %% [markdown]
# #### Data selection

# %% [markdown]
# In this testing code, we did not include the last y_length days since in the real predicting stage, we don't know their visits.

# %%
if test_length:
    fib_output_dates = input_df_dates[-fib_length-test_length:-test_length]
else:
    fib_output_dates = input_df_dates[-fib_length:]
fib_input_dates = input_df_dates[-fib_length-test_length-364:-test_length-364]
fib_input_dates, fib_output_dates
# Out:
# (Index(['2015-08-07', '2015-08-08', '2015-08-09', '2015-08-10', '2015-08-11',
#         '2015-08-12', '2015-08-13', '2015-08-14', '2015-08-15', '2015-08-16',
#         ...
#         '2016-06-21', '2016-06-22', '2016-06-23', '2016-06-24', '2016-06-25',
#         '2016-06-26', '2016-06-27', '2016-06-28', '2016-06-29', '2016-06-30'],
#        dtype='object', length=329),
#  Index(['2016-08-05', '2016-08-06', '2016-08-07', '2016-08-08', '2016-08-09',
#         '2016-08-10', '2016-08-11', '2016-08-12', '2016-08-13', '2016-08-14',
#         ...
#         '2017-06-20', '2017-06-21', '2017-06-22', '2017-06-23', '2017-06-24',
#         '2017-06-25', '2017-06-26', '2017-06-27', '2017-06-28', '2017-06-29'],
#        dtype='object', length=329))

# %%
weekday(fib_input_dates[0]), weekday(fib_output_dates[0])
# Out:
# (4, 4)

# %%
fib_output_data = input_df[fib_output_dates].values; fib_output_data
# Out:
# array([[  49.,   10.,   19., ...,   32.,   34.,   21.],
#        [  30.,   16.,   54., ...,  127.,  104.,   20.],
#        [   7.,    2.,    1., ...,    5.,    5.,    0.],
#        ...,
#        [  nan,   nan,   nan, ...,   35.,   46.,   43.],
#        [  nan,   nan,   nan, ...,    6.,    6.,    7.],
#        [  nan,   nan,   nan, ...,   21.,   20.,   14.]])

# %%
fib_input_data = input_df[fib_input_dates].values; fib_input_data
# Out:
# array([[  4.,  11.,  10., ...,  18.,  23.,  12.],
#        [  2.,  23.,  12., ...,  24.,  16.,  15.],
#        [  5.,   1.,   4., ...,   5.,   1.,   4.],
#        ...,
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan]])

# %% [markdown]
# #### Fibonacci median in each window

# %%
fib_input_median_list = np.array([np.nanmedian(fib_input_data[:, -w:] , axis=-1) 
                            for w in windows])
# Out:
# c:\python36\lib\site-packages\numpy\lib\function_base.py:3858: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %%
fib_output_median_list = np.array([np.nanmedian(fib_output_data[:, -w:] , axis=-1) 
                            for w in windows])
# Out:
# c:\python36\lib\site-packages\numpy\lib\function_base.py:3858: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)

# %% [markdown]
# fib_input_median_list.T.shape

# %% [markdown]
# fib_output_median_na = np.nanmedian(fib_output_median_list.T, axis=-1)

# %% [markdown]
# fib_output_median_na

# %%
fib_input_median = np.nan_to_num(np.nanmedian(fib_input_median_list.T, axis=-1)); fib_input_median.shape
# Out:
# c:\python36\lib\site-packages\numpy\lib\function_base.py:3858: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# (145063,)

# %%
fib_output_median = np.nan_to_num(np.nanmedian(fib_output_median_list.T, axis=-1)); fib_output_median.shape
# Out:
# c:\python36\lib\site-packages\numpy\lib\function_base.py:3858: RuntimeWarning: All-NaN slice encountered
#   r = func(a, **kwargs)
# (145063,)

# %%
fib_input_median
# Out:
# array([ 16.5 ,  15.25,   4.  , ...,   0.  ,   0.  ,   0.  ])

# %%
fib_output_median
# Out:
# array([ 24.  ,  22.5 ,   4.  , ...,  34.  ,   7.75,  11.25])

# %% [markdown]
# We will use this as the center and part of the result

# %%
Y_input_fib = fib_input_median.reshape(-1,1)
Y_output_fib = fib_output_median.reshape(-1,1)

# %% [markdown]
# ## Data Selection
# Select x_length + y_length days of data as input or ouput set.

# %% [markdown]
# ### Input data

# %% [markdown]
# input_data contains X_input and Y_input array

# %%
input_dates = pd.Index(np.concatenate((X_input_dates, Y_input_dates)))
input_dates, X_input_first_day, Y_input_final_day
# Out:
# (Index(['2016-04-29', '2016-04-30', '2016-05-01', '2016-05-02', '2016-05-03',
#         '2016-05-04', '2016-05-05', '2016-05-06', '2016-05-07', '2016-05-08',
#         ...
#         '2016-08-23', '2016-08-24', '2016-08-25', '2016-08-26', '2016-08-27',
#         '2016-08-28', '2016-08-29', '2016-08-30', '2016-08-31', '2016-09-01'],
#        dtype='object', length=126), '2016-04-29', '2016-09-01')

# %%
input_data = input_df[input_dates].values; #input_data  # input_data with nan

# %% [markdown]
# ##### Convert nan to number 0.

# %%
input_data_num = np.nan_to_num(input_data); #input_data_num  # intput_data with nan -> 0.

# %% [markdown]
# input_data_num.shape

# %% [markdown]
# ### Output Data

# %% [markdown]
# output_data for this self-testing script contains both X_output and Y_output

# %%
if test_length:
    output_dates = pd.Index(np.concatenate((X_output_dates, Y_output_dates)))
else:
    output_dates = X_output_dates
output_dates, X_output_first_day, X_output_final_day, Y_output_final_day
# Out:
# (Index(['2017-04-28', '2017-04-29', '2017-04-30', '2017-05-01', '2017-05-02',
#         '2017-05-03', '2017-05-04', '2017-05-05', '2017-05-06', '2017-05-07',
#         ...
#         '2017-08-22', '2017-08-23', '2017-08-24', '2017-08-25', '2017-08-26',
#         '2017-08-27', '2017-08-28', '2017-08-29', '2017-08-30', '2017-08-31'],
#        dtype='object', length=126), '2017-04-28', '2017-06-29', '2017-08-31')

# %%
output_dates.shape
# Out:
# (126,)

# %%
output_data = input_df[output_dates].values; #output_data

# %% [markdown]
# ##### Convert nan to number 0.

# %%
output_data_num = np.nan_to_num(output_data); output_data_num
# Out:
# array([[ 24.,  20.,  36., ...,  26.,  24.,  21.],
#        [ 19.,  18.,  12., ...,  29.,  34.,  25.],
#        [  2.,   0.,   3., ...,   8.,  12.,   9.],
#        ...,
#        [ 27.,  84.,  14., ...,  21.,  11.,   9.],
#        [  7.,  10.,  13., ...,   3.,   9.,   2.],
#        [ 34.,  16.,  16., ...,   9.,   6.,   5.]])

# %%
output_data_num.shape
# Out:
# (145063, 126)

# %% [markdown]
# ### View

# %% [markdown]
# def view(x, xlim=None, ylim=None, yscale='linear', title=None, show=True):
#     plt.yscale(yscale)
#     plt.plot(x)
#     if ylim: plt.ylim(ylim)
#     if xlim: plt.xlim(xlim)
#     if title: plt.title(title)
#     if show: plt.show()
#
# def viewi(X, i, xlim=None, ylim=None, yscale='linear', show=True):
#     view(X[i], xlim=xlim, ylim=ylim, yscale=yscale, title='i = ' + str(i), show=show)
#
# def examine(X, n=5, xlim=None, ylim=None):
#     '''randomly show some example in feature and label'''
#     n_X = len(X)
#     view_list = np.random.choice(n_X, min(n, n_X), replace=False)
#     for i in view_list:
#         viewi(X, i, xlim=xlim, ylim=ylim)
#     return view_list

# %% [markdown]
# examine(input_data)

# %% [markdown]
# ## Transform Data

# %% [markdown]
# ### Log

# %%
def log(X):
    return np.log10(X + 1.0)
def unlog(X):
    return np.clip(np.power(10., X) - 1.0, 0.0, None)

# %%
input_data_log = log(input_data_num)
output_data_log = log(output_data_num)

# %% [markdown]
# ##### Check Log transformation

# %%
input_data_log.shape, input_data.shape, output_data_log.shape, output_data.shape
# Out:
# ((145063, 126), (145063, 126), (145063, 126), (145063, 126))

# %% [markdown]
# input_data_log

# %% [markdown]
# output_data_log

# %% [markdown]
# #Check inverse log transformation
# input_data_log_tt = unlog(input_data_log)
# input_data_log_tt_dif = input_data_log_tt - input_data_num
# input_data_log_tt_dif.min(), input_data_log_tt_dif.max()

# %% [markdown]
# #Check inverse log transformation
# output_data_log_tt = unlog(output_data_log)
# output_data_log_tt_dif = output_data_log_tt - output_data_num
# output_data_log_tt_dif.min(), output_data_log_tt_dif.max()

# %% [markdown]
# del input_data_log_tt
# del input_data_log_tt_dif
# del output_data_log_tt
# del output_data_log_tt_dif

# %%
gc.collect()
# Out:
# 283

# %% [markdown]
# ### Normalization (Shift and Scale)

# %% [markdown]
# #### Use Fib Median as the Center

# %%
#input_center = log(fib_input_median).reshape(-1,1)
output_center = log(fib_output_median).reshape(-1,1)
input_center = output_center  # using output_center instead

# %%
input_center, output_center
# Out:
# (array([[ 1.39794001],
#         [ 1.37106786],
#         [ 0.69897   ],
#         ...,
#         [ 1.54406804],
#         [ 0.94200805],
#         [ 1.08813609]]), array([[ 1.39794001],
#         [ 1.37106786],
#         [ 0.69897   ],
#         ...,
#         [ 1.54406804],
#         [ 0.94200805],
#         [ 1.08813609]]))

# %% [markdown]
# #### Choice of default scale

# %%
input_raw_log = log(input_data)  # log of input_data with nan
output_raw_log = log(output_data)  # log of output_data with nan

# %% [markdown]
# np.median(np.nanstd(input_data_log[:,:x_length], axis=-1))

# %% [markdown]
# np.mean(np.nanstd(input_data_log[:,:x_length], axis=-1))

# %%
default_input_scale = np.nanmedian(np.nanstd(input_raw_log[:,:x_length], axis=-1))
default_input_scale
# Out:
# c:\python36\lib\site-packages\numpy\lib\nanfunctions.py:1423: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# 0.17974041809557845

# %%
default_output_scale = np.nanmedian(np.nanstd(output_raw_log[:,:x_length], axis=-1))
default_output_scale
# Out:
# c:\python36\lib\site-packages\numpy\lib\nanfunctions.py:1423: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)
# 0.16425448559207598

# %% [markdown]
# #### Compute Median and Stdev

# %% [markdown]
# Here we are not using this median as center

# %% [markdown]
# input_center = np.nanmedian(input_data_log[:,:x_length], axis=-1).reshape(-1,1)
# input_center  # remember sample-wised center

# %%
input_scale = np.nanstd(input_data_log[:,:x_length], axis=-1).reshape(-1,1)
input_scale[input_scale == 0.0] = default_input_scale  # Prevent divid by zero 
# non-zero value is choose based on the median of other page with non-zero stdev)
input_scale  # remember sample-wised scale
# Out:
# array([[ 0.22042467],
#        [ 0.1944303 ],
#        [ 0.23390395],
#        ...,
#        [ 0.17974042],
#        [ 0.17974042],
#        [ 0.17974042]])

# %% [markdown]
# output_center = np.nanmedian(output_data_log[:,:x_length], axis=-1).reshape(-1,1)
# output_center  # remember sample-wised center

# %%
output_scale = np.nanstd(output_data_log[:,:x_length], axis=-1).reshape(-1,1)
output_scale[output_scale == 0.0] = default_output_scale  # Prevent divid by zero
output_scale  # remember sample-wised scale
# Out:
# array([[ 0.15715761],
#        [ 0.23019142],
#        [ 0.29932548],
#        ...,
#        [ 0.30635028],
#        [ 0.308769  ],
#        [ 0.41433723]])

# %% [markdown]
# ##### Check zero in scale

# %% [markdown]
# #Check if there is any 0. in input_scale
# input_scale[input_scale == 0.]

# %% [markdown]
# #Check if there is any 0. in output_scale
# output_scale[output_scale == 0.]

# %% [markdown]
# #### Shift by Center and Scale by Scale

# %%
def transform(data_ori, center, scale):
    return (data_ori - center) / scale
def untransform(data, center, scale):
    return data * scale + center

# %%
# Normalize the input_data and output_data
input_data_norm = transform(input_data_log, input_center, input_scale)
output_data_norm = transform(output_data_log, output_center, output_scale)

# %% [markdown]
# ##### Check median and stdev transformations

# %%
def check_nan(X):
    return [x for x in X if np.isnan(x).any()]

# %% [markdown]
# check_nan(input_data_norm), check_nan(output_data_norm)  # Check if there is any nan in the input_data

# %% [markdown]
# #Check inverse scale transformation
# input_data_norm_it = untransform(input_data_norm, input_center, input_scale)
# input_data_norm_it_dif = input_data_norm_it - input_data_log
# input_data_norm_it_dif.min(), input_data_norm_it_dif.max()

# %% [markdown]
# #Check inverse scale transformation
# output_data_norm_it = untransform(output_data_norm, output_center, output_scale)
# output_data_norm_it_dif = output_data_norm_it - output_data_log
# output_data_norm_it_dif.min(), output_data_norm_it_dif.max()

# %% [markdown]
# del input_data_norm_it
# del input_data_norm_it_dif
# del output_data_norm_it
# del output_data_norm_it_dif
# gc.collect()

# %% [markdown]
# ## Center (Median) and Scale (Stdev) Investigation

# %% [markdown]
# ### Center

# %% [markdown]
# plt.hist(input_center, bins=40, alpha=0.7, label='input')
# plt.hist(output_center, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(input_center, bins=40, alpha=0.7, label='input')
# plt.hist(output_center, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.yscale('log')
# plt.show()

# %% [markdown]
# ### Scale

# %% [markdown]
# plt.hist(input_scale, bins=40, alpha=0.7, label='input')
# plt.hist(output_scale, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(input_scale, bins=40, alpha=0.7, label='input')
# plt.hist(output_scale, bins=40, alpha=0.7, label='output')
# plt.legend()
# plt.yscale('log')
# plt.show()

# %% [markdown]
# ### Group index based on scale of median (center)

# %%
def group_index(logx):
    if logx == 0.: return 0
    elif logx < 1.0: return 1
    elif logx < 2.0: return 2
    elif logx < 4.0: return 3
    elif logx < 5.0: return 4
    else: return 5
group_index_v = np.vectorize(group_index)
gp_list = list(range(6)); gp_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
input_gp = group_index_v(input_center).reshape(-1)
output_gp = group_index_v(output_center).reshape(-1)
#input_gp, output_gp

# %%
# group counts
gp_input_counts = [0] * len(gp_list)
for x in input_gp: gp_input_counts[x] += 1
#gp_input_counts

# %%
# group counts
gp_output_counts = [0] * len(gp_list)
for x in output_gp: gp_output_counts[x] += 1
#gp_output_counts

# %% [markdown]
# plt.hist(input_gp, alpha=0.8, label='input')
# plt.hist(output_gp, alpha=0.3, label='output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(input_gp, alpha=0.8, label='input')
# plt.hist(output_gp, alpha=0.3, label='output')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# ## Make (X,Y) pairs data from data set

# %%
X_input = input_data_norm[:, :x_length]
Y_input = input_data_norm[:, -y_length:]
X_input.shape, Y_input.shape
# Out:
# ((145063, 63), (145063, 63))

# %%
X_output = output_data_norm[:, :x_length]
if test_length:
    Y_output = output_data_norm[:, -y_length:]
    print(X_output.shape, Y_output.shape)
else:
    print(X_output.shape, 'No Y_output')
# Out:
# (145063, 63) (145063, 63)

# %% [markdown]
# #### Original data

# %%
X_input_ori = input_data_num[:, :x_length]
Y_input_ori = input_data_num[:, -y_length:]
X_output_ori = output_data_num[:, :x_length]
if test_length: 
    Y_output_ori = output_data_num[:, -y_length:]

# %% [markdown]
# #### Raw data (with nan)

# %%
X_input_raw = input_data[:, :x_length]
Y_input_raw = input_data[:, -y_length:]
X_output_raw = output_data[:, :x_length]
if test_length:
    Y_output_raw = output_data[:, -y_length:]

# %% [markdown]
# #### Backward compatible

# %% [markdown]
# X_input = X_input
# Y_input = Y_input
# X_val = X_output
# if test_length:
#     Y_val = Y_output

# %% [markdown]
# X_input_ori = X_input_ori
# Y_input_ori = Y_input_ori
# X_val_ori = X_output_ori
# if test_length:
#     Y_val_ori = Y_output_ori

# %% [markdown]
# train_scale = input_scale
# train_center = input_center
# val_scale = output_scale
# val_center = output_center

# %% [markdown]
# #### Check

# %% [markdown]
# X_input, input_data_norm[:,:x_length]

# %% [markdown]
# Y_input, input_data_norm[:,-y_length:]

# %% [markdown]
# X_output, output_data_norm[:,:x_length]

# %% [markdown]
# if test_length:
#     print(Y_output)
#     print(output_data_norm[:,-y_length:])

# %% [markdown]
# X_input_ori, input_data_num

# %% [markdown]
# Y_input_ori, input_data_num

# %% [markdown]
# X_output_ori, output_data_num

# %% [markdown]
# if test_length:
#     print(Y_output_ori)
#     print(output_data_num)

# %%
if test_length:
    arr_info((X_input, Y_input, X_output, Y_output, 
              X_input_ori, Y_input_ori, X_output_ori, Y_output_ori))
else:
    arr_info((X_input, Y_input, X_output, 
              X_input_ori, Y_input_ori, X_output_ori))
# Out:
# shape, min, max, median, stdev
# (145063, 63) -104.945597725 182.183688699 0.0250217121081 3.34816141728
# (145063, 63) -104.945597725 181.969627538 -0.0156385758122 3.42135990909
# (145063, 63) -57.3465699314 8.00100800101 0.0 1.27077605981
# (145063, 63) -1627.7382547 51.3918797946 -0.214767758227 6.0365527548
# (145063, 63) 0.0 23209383.0 126.0 63765.8619057
# (145063, 63) 0.0 67264258.0 128.0 155483.953622
# (145063, 63) 0.0 24630674.0 123.0 65785.6552263
# (145063, 63) 0.0 18670230.0 113.0 57469.0537846

# %% [markdown]
# #### Min and max cases examination

# %% [markdown]
# np.argmin(Y_output, axis=0)

# %% [markdown]
# Y_output[8604]

# %% [markdown]
# Y_output_ori[8604]

# %% [markdown]
# fib_output_median[8604]

# %% [markdown]
# log(Y_output_ori[8604])

# %% [markdown]
# log(fib_output_median[8604])

# %% [markdown]
# np.std(log(Y_output_ori[8604]))

# %% [markdown]
# np.std(log(X_output_ori[8604]))

# %% [markdown]
# output_scale[8604]

# %% [markdown]
# #### Check if the inverse transformation is correct

# %% [markdown]
# #Undo transformation
# X_input_tt = unlog(untransform(X_input, train_center, train_scale))

# %% [markdown]
# X_input_tt_diff = X_input_tt - X_input_ori
# X_input_tt_diff.min(), X_input_tt_diff.max()

# %% [markdown]
# ## Split X,Y data into groups

# %% [markdown]
# X_input[input_gp == 1].shape

# %%
X_input_list = [X_input[input_gp == gp] for gp in gp_list]
Y_input_list = [Y_input[input_gp == gp] for gp in gp_list]
X_output_list = [X_output[output_gp == gp] for gp in gp_list]
if test_length:
    Y_output_list = [Y_output[output_gp == gp] for gp in gp_list]

# %% [markdown]
# ## Additional input for the neural network

# %% [markdown]
# #Split center into group
# input_center_list = [input_center[input_gp == gp] for gp in gp_list]
# output_center_list = [output_center[output_gp == gp] for gp in gp_list]
#
# #Split scale into group
# input_scale_list = [input_scale[input_gp == gp] for gp in gp_list]
# output_scale_list = [output_scale[output_gp == gp] for gp in gp_list]

# %% [markdown]
# input_scale_list[0].shape

# %%
A_input = np.concatenate((input_center, input_scale), axis=1)
A_output = np.concatenate((output_center, output_scale), axis=1); A_input.shape, A_output.shape
# Out:
# ((145063, 2), (145063, 2))

# %%
A_input_list = [A_input[input_gp == gp] for gp in gp_list]
A_output_list = [A_output[output_gp == gp] for gp in gp_list]

# %%
a_length = len(A_input[0]); a_length
# Out:
# 2

# %% [markdown]
# ## Neural Network?

# %%
from keras.models import Sequential
#from keras.layers import Conv1D
from keras.layers import Dense, Dropout, Flatten
from keras.losses import mean_squared_error
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### SMAPE
# Symmetric mean absolute percentage error
#
# https://en.wikipedia.org/wiki/Symmetric_mean_absolute_percentage_error

# %%
import keras.backend as K

def k_smape(y_true, y_pred):
    '''Symmetric mean absolute percentage error for keras metric'''
    diff = K.abs((y_true - y_pred) / K.clip(K.abs(y_true) + K.abs(y_pred),
                                            K.epsilon(), None))
    return 200. * K.mean(diff, axis=-1)

# %%
def smape(y_true, y_pred, axis=None):
    '''Symmetric mean absolute percentage error'''
    diff = np.abs((y_true - y_pred) / 
                  np.clip(np.abs(y_true) + np.abs(y_pred), 1e-07, None))
    return 200. * np.nanmean(diff, axis=axis)

# %% [markdown]
# smape(np.array([0,1]),np.array([np.nan, 0])), smape(np.array([0]),np.array([0]))

# %%
# Benchmark SMAPE on the transformed data
smape(Y_input,X_input), smape(Y_input, X_output), smape(Y_input,Y_input)
# Out:
# (118.39849931396679, 148.1903381452849, 0.0)

# %%
# Benchmark SMAPE on the original data
smape(Y_input_raw,X_input_ori), smape(Y_input_ori,X_input_ori)
# Out:
# (60.417294139521594, 58.828327132034431)

# %%
if test_length: print(smape(Y_output_raw, X_output_ori), smape(Y_output, X_output))
# Out:
# 50.9386336667 142.088333627

# %%
print(smape(Y_input_raw, Y_input_fib))
if test_length: print(smape(Y_output_raw, Y_output_fib))
# Out:
# 48.3250071896
# 40.4041165988

# %% [markdown]
# Doing better than the first two scores are better than simply copy and past the previous result.

# %% [markdown]
# ### Neural Network Model
# With the flavor of convolutional neural network

# %%
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv1D
from keras.layers import Flatten
from keras.layers import Reshape
from keras.layers import MaxPooling1D
from keras.layers import AveragePooling1D
from keras.layers import concatenate

# %%
n_ens = 5
ens_list = list(range(n_ens))

# %%
#runbelow
models_ens = []
for run in ens_list:
    print('Run', run, end=': ')
    models = []
    for gp in gp_list:
        print('Group-', gp, sep='', end=' ')
        layer_0 = Input(shape=(x_length,), name='x_input')
        layer_t = Reshape((-1, 1))(layer_0)
        layer_t = Conv1D(120, kernel_size=3, activation='relu')(layer_t)
        layer_t = AveragePooling1D(pool_size=2)(layer_t)
        layer_cnn = Flatten()(layer_t)
        
        layer_a = Input(shape=(a_length,), name='a_input')
        layer_t = concatenate([layer_cnn, layer_a])
        
        layer_t = Dense(120, activation='relu')(layer_t)
        layer_t = Dropout(0.25)(layer_t)
        layer_t = Dense(120, activation='relu')(layer_t)
        layer_t = Dropout(0.5)(layer_t)
        layer_f = Dense(y_length)(layer_t)
        
        model = Model(inputs=[layer_0, layer_a], outputs=layer_f)
        model.compile(optimizer='adam',
                      loss='mean_absolute_error', metrics=[k_smape])
        #model.summary()
        models.append(model)
    models_ens.append(models)
    print('')
# Out:
# Run 0: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 1: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 2: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 3: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5
# Run 4: Group-0 Group-1 Group-2 Group-3 Group-4 Group-5

# %%
models_ens[0][1].summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# x_input (InputLayer)             (None, 63)            0
# ____________________________________________________________________________________________________
# reshape_9 (Reshape)              (None, 63, 1)         0           x_input[0][0]
# ____________________________________________________________________________________________________
# conv1d_9 (Conv1D)                (None, 61, 120)       480         reshape_9[0][0]
# ____________________________________________________________________________________________________
# average_pooling1d_9 (AveragePool (None, 30, 120)       0           conv1d_9[0][0]
# ____________________________________________________________________________________________________
# flatten_9 (Flatten)              (None, 3600)          0           average_pooling1d_9[0][0]
# ____________________________________________________________________________________________________
# a_input (InputLayer)             (None, 2)             0
# ____________________________________________________________________________________________________
# concatenate_8 (Concatenate)      (None, 3602)          0           flatten_9[0][0]
#                                                                    a_input[0][0]
# ____________________________________________________________________________________________________
# dense_22 (Dense)                 (None, 120)           432360      concatenate_8[0][0]
# ____________________________________________________________________________________________________
# dropout_15 (Dropout)             (None, 120)           0           dense_22[0][0]
# ____________________________________________________________________________________________________
# dense_23 (Dense)                 (None, 120)           14520       dropout_15[0][0]
# ____________________________________________________________________________________________________
# dropout_16 (Dropout)             (None, 120)           0           dense_23[0][0]
# ____________________________________________________________________________________________________
# dense_24 (Dense)                 (None, 63)            7623        dropout_16[0][0]
# ====================================================================================================
# Total params: 454,983
# Trainable params: 454,983
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
np.array(models_ens).shape
# Out:
# (5, 6)

# %%
len(gp_list)
# Out:
# 6

# %%
epochs_list = [1,1,40,40,60,80]  # change to smaller epochs later (1,1,20,40,60,80)

# %%
# %%time
hists_ens = []
for run, models in zip(ens_list, models_ens):
    print('=== Run:', run, '/', len(ens_list), '===')
    hists = []
    for (gp, model, X_in, Y_in, epochs, A_in) in zip(gp_list, models,
                                       X_input_list, Y_input_list, 
                                       epochs_list, A_input_list):
        print('-- Group:', gp, '/', len(gp_list), '--')
        hist = model.fit([X_in, A_in], Y_in, batch_size=128, 
                         epochs=epochs, 
                         validation_split=0.1, verbose=2)
        #validation_data=(X_val, Y_val))
        hists.append(hist)
    hists_ens.append(hists)
# Out:
# === Run: 0 / 5 ===
# -- Group: 0 / 6 --
# Train on 1691 samples, validate on 188 samples
# Epoch 1/1
# 2s - loss: 0.9469 - k_smape: 196.3787 - val_loss: 0.9693 - val_k_smape: 198.8594
# -- Group: 1 / 6 --
# Train on 20776 samples, validate on 2309 samples
# Epoch 1/1
# 4s - loss: 1.1332 - k_smape: 143.6262 - val_loss: 0.9890 - val_k_smape: 137.5529
# -- Group: 2 / 6 --
# Train on 39321 samples, validate on 4370 samples
# Epoch 1/40
# 7s - loss: 1.3226 - k_smape: 127.2032 - val_loss: 1.0399 - val_k_smape: 125.6744
# Epoch 2/40
# 7s - loss: 1.2415 - k_smape: 118.2442 - val_loss: 1.0163 - val_k_smape: 117.6199
# Epoch 3/40
# 7s - loss: 1.2409 - k_smape: 117.2215 - val_loss: 1.0567 - val_k_smape: 120.6209
# Epoch 4/40
# 7s - loss: 1.2206 - k_smape: 115.6295 - val_loss: 1.0129 - val_k_smape: 119.4258
# Epoch 5/40
# 7s - loss: 1.2137 - k_smape: 115.0117 - val_loss: 1.0083 - val_k_smape: 114.4268
# Epoch 6/40
# 7s - loss: 1.2129 - k_smape: 114.8984 - val_loss: 1.0207 - val_k_smape: 117.7420
# Epoch 7/40
# 7s - loss: 1.1995 - k_smape: 114.1032 - val_loss: 1.0289 - val_k_smape: 117.7273
# Epoch 8/40
# 7s - loss: 1.2021 - k_smape: 114.3186 - val_loss: 1.0301 - val_k_smape: 113.6241
# Epoch 9/40
# 7s - loss: 1.2041 - k_smape: 114.0912 - val_loss: 1.0049 - val_k_smape: 114.2932
# Epoch 10/40
# 7s - loss: 1.1967 - k_smape: 113.6593 - val_loss: 1.0469 - val_k_smape: 121.5431
# Epoch 11/40
# 7s - loss: 1.1935 - k_smape: 113.8076 - val_loss: 1.0196 - val_k_smape: 117.1516
# Epoch 12/40
# 7s - loss: 1.1932 - k_smape: 113.4223 - val_loss: 1.0179 - val_k_smape: 117.4207
# Epoch 13/40
# 7s - loss: 1.1934 - k_smape: 113.2556 - val_loss: 1.0029 - val_k_smape: 112.8606
# Epoch 14/40
# 7s - loss: 1.1894 - k_smape: 112.9385 - val_loss: 1.0615 - val_k_smape: 122.2168
# Epoch 15/40
# 7s - loss: 1.1930 - k_smape: 112.9574 - val_loss: 1.0223 - val_k_smape: 117.3872
# Epoch 16/40
# 7s - loss: 1.1839 - k_smape: 112.8377 - val_loss: 1.0364 - val_k_smape: 119.2013
# Epoch 17/40
# 7s - loss: 1.1838 - k_smape: 112.5725 - val_loss: 1.0342 - val_k_smape: 117.0160
# Epoch 18/40
# 7s - loss: 1.1853 - k_smape: 112.6589 - val_loss: 1.0189 - val_k_smape: 117.7094
# Epoch 19/40
# 7s - loss: 1.1816 - k_smape: 112.2419 - val_loss: 1.0134 - val_k_smape: 112.3205
# Epoch 20/40
# 7s - loss: 1.1801 - k_smape: 112.0088 - val_loss: 0.9998 - val_k_smape: 116.8175
# Epoch 21/40
# 7s - loss: 1.1819 - k_smape: 112.1733 - val_loss: 1.0045 - val_k_smape: 117.3499
# Epoch 22/40
# 7s - loss: 1.1771 - k_smape: 112.0255 - val_loss: 1.0160 - val_k_smape: 115.6907
# Epoch 23/40
# 7s - loss: 1.1753 - k_smape: 111.8319 - val_loss: 1.0212 - val_k_smape: 116.5115
# Epoch 24/40
# 7s - loss: 1.1741 - k_smape: 111.5313 - val_loss: 1.0334 - val_k_smape: 118.6191
# Epoch 25/40
# 7s - loss: 1.1694 - k_smape: 111.5229 - val_loss: 1.0077 - val_k_smape: 116.7586
# Epoch 26/40
# 7s - loss: 1.1742 - k_smape: 111.6213 - val_loss: 1.0265 - val_k_smape: 114.8612
# Epoch 27/40
# 7s - loss: 1.1693 - k_smape: 111.4726 - val_loss: 1.0238 - val_k_smape: 117.1846
# Epoch 28/40
# 7s - loss: 1.1660 - k_smape: 111.2866 - val_loss: 1.0271 - val_k_smape: 118.5286
# Epoch 29/40
# 7s - loss: 1.1666 - k_smape: 111.4062 - val_loss: 1.0135 - val_k_smape: 114.2930
# Epoch 30/40
# 7s - loss: 1.1668 - k_smape: 111.2259 - val_loss: 1.0463 - val_k_smape: 117.8331
# Epoch 31/40
# 7s - loss: 1.1631 - k_smape: 111.2599 - val_loss: 1.0362 - val_k_smape: 118.2932
# Epoch 32/40
# 7s - loss: 1.1598 - k_smape: 111.0457 - val_loss: 1.0315 - val_k_smape: 116.0696
# Epoch 33/40
# 7s - loss: 1.1659 - k_smape: 111.3121 - val_loss: 1.0153 - val_k_smape: 117.8119
# Epoch 34/40
# 7s - loss: 1.1596 - k_smape: 111.0775 - val_loss: 1.0362 - val_k_smape: 118.1662
# Epoch 35/40
# 7s - loss: 1.1599 - k_smape: 111.0559 - val_loss: 1.0146 - val_k_smape: 116.5406
# Epoch 36/40
# 7s - loss: 1.1585 - k_smape: 110.9559 - val_loss: 1.0312 - val_k_smape: 117.2122
# Epoch 37/40
# 7s - loss: 1.1554 - k_smape: 110.9076 - val_loss: 0.9956 - val_k_smape: 114.8099
# Epoch 38/40
# 7s - loss: 1.1584 - k_smape: 110.8891 - val_loss: 1.0176 - val_k_smape: 115.4599
# Epoch 39/40
# 7s - loss: 1.1576 - k_smape: 110.8830 - val_loss: 1.0170 - val_k_smape: 114.7485
# Epoch 40/40
# 7s - loss: 1.1514 - k_smape: 110.6706 - val_loss: 1.0151 - val_k_smape: 115.8903
# -- Group: 3 / 6 --
# Train on 68055 samples, validate on 7562 samples
# Epoch 1/40
# 12s - loss: 1.3414 - k_smape: 108.7291 - val_loss: 1.1029 - val_k_smape: 106.7169
# Epoch 2/40
# 12s - loss: 1.2474 - k_smape: 100.9758 - val_loss: 1.1079 - val_k_smape: 104.9602
# Epoch 3/40
# 12s - loss: 1.2214 - k_smape: 99.2035 - val_loss: 1.0820 - val_k_smape: 104.7589
# Epoch 4/40
# 12s - loss: 1.2131 - k_smape: 98.7015 - val_loss: 1.0754 - val_k_smape: 104.0799
# Epoch 5/40
# 12s - loss: 1.2084 - k_smape: 98.0045 - val_loss: 1.1011 - val_k_smape: 105.1992
# Epoch 6/40
# 12s - loss: 1.1961 - k_smape: 97.5036 - val_loss: 1.1543 - val_k_smape: 107.2850
# Epoch 7/40
# 12s - loss: 1.1979 - k_smape: 97.4167 - val_loss: 1.1065 - val_k_smape: 105.3039
# Epoch 8/40
# 12s - loss: 1.1952 - k_smape: 97.3508 - val_loss: 1.1039 - val_k_smape: 106.3179
# Epoch 9/40
# 12s - loss: 1.1951 - k_smape: 97.0695 - val_loss: 1.0788 - val_k_smape: 106.0676
# Epoch 10/40
# 12s - loss: 1.1856 - k_smape: 96.7833 - val_loss: 1.0877 - val_k_smape: 106.2475
# Epoch 11/40
# 12s - loss: 1.1815 - k_smape: 96.4250 - val_loss: 1.0813 - val_k_smape: 105.6070
# Epoch 12/40
# 12s - loss: 1.1814 - k_smape: 96.4980 - val_loss: 1.0888 - val_k_smape: 105.3064
# Epoch 13/40
# 12s - loss: 1.1805 - k_smape: 96.3122 - val_loss: 1.0897 - val_k_smape: 105.8713
# Epoch 14/40
# 12s - loss: 1.1787 - k_smape: 96.0533 - val_loss: 1.0988 - val_k_smape: 107.4969
# Epoch 15/40
# 12s - loss: 1.1768 - k_smape: 96.0969 - val_loss: 1.0898 - val_k_smape: 104.6791
# Epoch 16/40
# 12s - loss: 1.1749 - k_smape: 96.0013 - val_loss: 1.0849 - val_k_smape: 103.5505
# Epoch 17/40
# 12s - loss: 1.1707 - k_smape: 95.7650 - val_loss: 1.0940 - val_k_smape: 105.7992
# Epoch 18/40
# 12s - loss: 1.1720 - k_smape: 95.9989 - val_loss: 1.1091 - val_k_smape: 106.1727
# Epoch 19/40
# 12s - loss: 1.1679 - k_smape: 95.6351 - val_loss: 1.0714 - val_k_smape: 105.1502
# Epoch 20/40
# 12s - loss: 1.1669 - k_smape: 95.5964 - val_loss: 1.0834 - val_k_smape: 103.7036
# Epoch 21/40
# 12s - loss: 1.1623 - k_smape: 95.5459 - val_loss: 1.0738 - val_k_smape: 103.9607
# Epoch 22/40
# 12s - loss: 1.1607 - k_smape: 95.3481 - val_loss: 1.1016 - val_k_smape: 104.6744
# Epoch 23/40
# 12s - loss: 1.1565 - k_smape: 95.4034 - val_loss: 1.1048 - val_k_smape: 105.6802
# Epoch 24/40
# 12s - loss: 1.1544 - k_smape: 95.1778 - val_loss: 1.1002 - val_k_smape: 106.6262
# Epoch 25/40
# 12s - loss: 1.1560 - k_smape: 95.1747 - val_loss: 1.0862 - val_k_smape: 104.9000
# Epoch 26/40
# 12s - loss: 1.1525 - k_smape: 94.9106 - val_loss: 1.0873 - val_k_smape: 103.3342
# Epoch 27/40
# 12s - loss: 1.1514 - k_smape: 95.0162 - val_loss: 1.1112 - val_k_smape: 105.7514
# Epoch 28/40
# 12s - loss: 1.1514 - k_smape: 94.9526 - val_loss: 1.1049 - val_k_smape: 103.8849
# Epoch 29/40
# 12s - loss: 1.1531 - k_smape: 94.8952 - val_loss: 1.0937 - val_k_smape: 104.5931
# Epoch 30/40
# 12s - loss: 1.1435 - k_smape: 94.6609 - val_loss: 1.0870 - val_k_smape: 104.3995
# Epoch 31/40
# 12s - loss: 1.1439 - k_smape: 94.6092 - val_loss: 1.0989 - val_k_smape: 105.5152
# Epoch 32/40
# 12s - loss: 1.1433 - k_smape: 94.6674 - val_loss: 1.0787 - val_k_smape: 103.3999
# Epoch 33/40
# 12s - loss: 1.1434 - k_smape: 94.4346 - val_loss: 1.0735 - val_k_smape: 103.8063
# Epoch 34/40
# 12s - loss: 1.1441 - k_smape: 94.4669 - val_loss: 1.0599 - val_k_smape: 103.4526
# Epoch 35/40
# 12s - loss: 1.1395 - k_smape: 94.4402 - val_loss: 1.1061 - val_k_smape: 104.5911
# Epoch 36/40
# 12s - loss: 1.1410 - k_smape: 94.3645 - val_loss: 1.0640 - val_k_smape: 102.9745
# Epoch 37/40
# 12s - loss: 1.1347 - k_smape: 94.1920 - val_loss: 1.0879 - val_k_smape: 103.2300
# Epoch 38/40
# 12s - loss: 1.1337 - k_smape: 94.2761 - val_loss: 1.0848 - val_k_smape: 105.1070
# Epoch 39/40
# 12s - loss: 1.1325 - k_smape: 94.1850 - val_loss: 1.0981 - val_k_smape: 105.2163
# Epoch 40/40
# 12s - loss: 1.1308 - k_smape: 94.1787 - val_loss: 1.0768 - val_k_smape: 103.4144
# -- Group: 4 / 6 --
# Train on 666 samples, validate on 74 samples
# Epoch 1/60
# 0s - loss: 2.8649 - k_smape: 154.7816 - val_loss: 2.7183 - val_k_smape: 134.4034
# Epoch 2/60
# 0s - loss: 2.4697 - k_smape: 131.7424 - val_loss: 2.7343 - val_k_smape: 134.8428
# Epoch 3/60
# 0s - loss: 2.3776 - k_smape: 130.8148 - val_loss: 2.2370 - val_k_smape: 122.3986
# Epoch 4/60
# 0s - loss: 2.1896 - k_smape: 122.3216 - val_loss: 2.3522 - val_k_smape: 123.6346
# Epoch 5/60
# 0s - loss: 2.1026 - k_smape: 122.0497 - val_loss: 2.0459 - val_k_smape: 115.5067
# Epoch 6/60
# 0s - loss: 2.0392 - k_smape: 113.8442 - val_loss: 1.9733 - val_k_smape: 112.4788
# Epoch 7/60
# 0s - loss: 1.9296 - k_smape: 113.2363 - val_loss: 1.9112 - val_k_smape: 110.3416
# Epoch 8/60
# 0s - loss: 1.9076 - k_smape: 106.2423 - val_loss: 1.8517 - val_k_smape: 110.0158
# Epoch 9/60
# 0s - loss: 1.8562 - k_smape: 108.1208 - val_loss: 1.7184 - val_k_smape: 105.5109
# Epoch 10/60
# 0s - loss: 1.7908 - k_smape: 102.3994 - val_loss: 1.7893 - val_k_smape: 106.4474
# Epoch 11/60
# 0s - loss: 1.7419 - k_smape: 102.5379 - val_loss: 1.5680 - val_k_smape: 102.2809
# Epoch 12/60
# 0s - loss: 1.6965 - k_smape: 99.3463 - val_loss: 1.8867 - val_k_smape: 105.6833
# Epoch 13/60
# 0s - loss: 1.7029 - k_smape: 100.2279 - val_loss: 1.4953 - val_k_smape: 96.9833
# Epoch 14/60
# 0s - loss: 1.7014 - k_smape: 95.6700 - val_loss: 1.4589 - val_k_smape: 101.4773
# Epoch 15/60
# 0s - loss: 1.6980 - k_smape: 96.9710 - val_loss: 1.7226 - val_k_smape: 103.3261
# Epoch 16/60
# 0s - loss: 1.6431 - k_smape: 96.7156 - val_loss: 1.5371 - val_k_smape: 98.6583
# Epoch 17/60
# 0s - loss: 1.6192 - k_smape: 94.0154 - val_loss: 1.4673 - val_k_smape: 96.2803
# Epoch 18/60
# 0s - loss: 1.6059 - k_smape: 91.6060 - val_loss: 1.5263 - val_k_smape: 96.1160
# Epoch 19/60
# 0s - loss: 1.5663 - k_smape: 91.0726 - val_loss: 1.7050 - val_k_smape: 98.7439
# Epoch 20/60
# 0s - loss: 1.5750 - k_smape: 91.4820 - val_loss: 1.4244 - val_k_smape: 94.8252
# Epoch 21/60
# 0s - loss: 1.5763 - k_smape: 92.7959 - val_loss: 1.4718 - val_k_smape: 96.0076
# Epoch 22/60
# 0s - loss: 1.5416 - k_smape: 89.4527 - val_loss: 1.3718 - val_k_smape: 93.0671
# Epoch 23/60
# 0s - loss: 1.5189 - k_smape: 87.8468 - val_loss: 1.5716 - val_k_smape: 96.0202
# Epoch 24/60
# 0s - loss: 1.5052 - k_smape: 89.9222 - val_loss: 1.3418 - val_k_smape: 91.6439
# Epoch 25/60
# 0s - loss: 1.4856 - k_smape: 86.8403 - val_loss: 1.7259 - val_k_smape: 95.1534
# Epoch 26/60
# 0s - loss: 1.5251 - k_smape: 86.5270 - val_loss: 1.3316 - val_k_smape: 91.6706
# Epoch 27/60
# 0s - loss: 1.5014 - k_smape: 88.7221 - val_loss: 1.5634 - val_k_smape: 93.2989
# Epoch 28/60
# 0s - loss: 1.4388 - k_smape: 85.7448 - val_loss: 1.4862 - val_k_smape: 89.2890
# Epoch 29/60
# 0s - loss: 1.4774 - k_smape: 84.5597 - val_loss: 1.4215 - val_k_smape: 90.2070
# Epoch 30/60
# 0s - loss: 1.4608 - k_smape: 85.6767 - val_loss: 1.3215 - val_k_smape: 88.7407
# Epoch 31/60
# 0s - loss: 1.4324 - k_smape: 85.9262 - val_loss: 1.5492 - val_k_smape: 91.1126
# Epoch 32/60
# 0s - loss: 1.3869 - k_smape: 84.4595 - val_loss: 1.3475 - val_k_smape: 89.2749
# Epoch 33/60
# 0s - loss: 1.4369 - k_smape: 83.6420 - val_loss: 1.3069 - val_k_smape: 85.7383
# Epoch 34/60
# 0s - loss: 1.4802 - k_smape: 83.3546 - val_loss: 1.5014 - val_k_smape: 92.6633
# Epoch 35/60
# 0s - loss: 1.4090 - k_smape: 85.1375 - val_loss: 1.3475 - val_k_smape: 86.9815
# Epoch 36/60
# 0s - loss: 1.4141 - k_smape: 83.5021 - val_loss: 1.3026 - val_k_smape: 87.2409
# Epoch 37/60
# 0s - loss: 1.3487 - k_smape: 83.0620 - val_loss: 1.5380 - val_k_smape: 90.4366
# Epoch 38/60
# 0s - loss: 1.3860 - k_smape: 83.3965 - val_loss: 1.2534 - val_k_smape: 83.8566
# Epoch 39/60
# 0s - loss: 1.4116 - k_smape: 82.1552 - val_loss: 1.7972 - val_k_smape: 88.3085
# Epoch 40/60
# 0s - loss: 1.5196 - k_smape: 82.4644 - val_loss: 1.3494 - val_k_smape: 85.4031
# Epoch 41/60
# 0s - loss: 1.4195 - k_smape: 84.7012 - val_loss: 1.4261 - val_k_smape: 89.7029
# Epoch 42/60
# 0s - loss: 1.3685 - k_smape: 83.2849 - val_loss: 1.2877 - val_k_smape: 85.3750
# Epoch 43/60
# 0s - loss: 1.3723 - k_smape: 83.3245 - val_loss: 1.4303 - val_k_smape: 85.0264
# Epoch 44/60
# 0s - loss: 1.3515 - k_smape: 79.8917 - val_loss: 1.3080 - val_k_smape: 86.6237
# Epoch 45/60
# 0s - loss: 1.3168 - k_smape: 80.3876 - val_loss: 1.4584 - val_k_smape: 83.8335
# Epoch 46/60
# 0s - loss: 1.3776 - k_smape: 79.8326 - val_loss: 1.2620 - val_k_smape: 86.2380
# Epoch 47/60
# 0s - loss: 1.3189 - k_smape: 81.6446 - val_loss: 1.3656 - val_k_smape: 85.0029
# Epoch 48/60
# 0s - loss: 1.3194 - k_smape: 78.9043 - val_loss: 1.3160 - val_k_smape: 83.1772
# Epoch 49/60
# 0s - loss: 1.3086 - k_smape: 79.0419 - val_loss: 1.4384 - val_k_smape: 87.1762
# Epoch 50/60
# 0s - loss: 1.2865 - k_smape: 80.7421 - val_loss: 1.2454 - val_k_smape: 84.8340
# Epoch 51/60
# 0s - loss: 1.2870 - k_smape: 80.8452 - val_loss: 1.2524 - val_k_smape: 82.5863
# Epoch 52/60
# 0s - loss: 1.3107 - k_smape: 77.7935 - val_loss: 1.4753 - val_k_smape: 86.7486
# Epoch 53/60
# 0s - loss: 1.3428 - k_smape: 81.1176 - val_loss: 1.2647 - val_k_smape: 81.4326
# Epoch 54/60
# 0s - loss: 1.3470 - k_smape: 77.7390 - val_loss: 1.5696 - val_k_smape: 87.2547
# Epoch 55/60
# 0s - loss: 1.3110 - k_smape: 79.5272 - val_loss: 1.2437 - val_k_smape: 83.8473
# Epoch 56/60
# 0s - loss: 1.2939 - k_smape: 79.2392 - val_loss: 1.3273 - val_k_smape: 83.1878
# Epoch 57/60
# 0s - loss: 1.3148 - k_smape: 77.9730 - val_loss: 1.2436 - val_k_smape: 82.7985
# Epoch 58/60
# 0s - loss: 1.2850 - k_smape: 79.5885 - val_loss: 1.2738 - val_k_smape: 83.5005
# Epoch 59/60
# 0s - loss: 1.2974 - k_smape: 78.0525 - val_loss: 1.4498 - val_k_smape: 85.9343
# Epoch 60/60
# 0s - loss: 1.3126 - k_smape: 78.7728 - val_loss: 1.2731 - val_k_smape: 81.8725
# -- Group: 5 / 6 --
# Train on 45 samples, validate on 6 samples
# Epoch 1/80
# 0s - loss: 6.9492 - k_smape: 176.3567 - val_loss: 4.7869 - val_k_smape: 171.8660
# Epoch 2/80
# 0s - loss: 6.5853 - k_smape: 167.8787 - val_loss: 4.6376 - val_k_smape: 161.3245
# Epoch 3/80
# 0s - loss: 6.2283 - k_smape: 155.7406 - val_loss: 4.5109 - val_k_smape: 152.7697
# Epoch 4/80
# 0s - loss: 6.0993 - k_smape: 147.5876 - val_loss: 4.3604 - val_k_smape: 144.7957
# Epoch 5/80
# 0s - loss: 5.8352 - k_smape: 139.6637 - val_loss: 4.1817 - val_k_smape: 139.9176
# Epoch 6/80
# 0s - loss: 5.6890 - k_smape: 136.5740 - val_loss: 3.9999 - val_k_smape: 136.9869
# Epoch 7/80
# 0s - loss: 5.8657 - k_smape: 135.5004 - val_loss: 3.8135 - val_k_smape: 133.7352
# Epoch 8/80
# 0s - loss: 5.4190 - k_smape: 131.0427 - val_loss: 3.6511 - val_k_smape: 131.4039
# Epoch 9/80
# 0s - loss: 5.5534 - k_smape: 130.4198 - val_loss: 3.5437 - val_k_smape: 130.7179
# Epoch 10/80
# 0s - loss: 5.4887 - k_smape: 131.0174 - val_loss: 3.4627 - val_k_smape: 130.3567
# Epoch 11/80
# 0s - loss: 5.3466 - k_smape: 130.4665 - val_loss: 3.3741 - val_k_smape: 129.5862
# Epoch 12/80
# 0s - loss: 5.0936 - k_smape: 130.3389 - val_loss: 3.3015 - val_k_smape: 128.0366
# Epoch 13/80
# 0s - loss: 5.1596 - k_smape: 127.7873 - val_loss: 3.2381 - val_k_smape: 126.8977
# Epoch 14/80
# 0s - loss: 5.1270 - k_smape: 128.2878 - val_loss: 3.1590 - val_k_smape: 125.3453
# Epoch 15/80
# 0s - loss: 5.0786 - k_smape: 125.5944 - val_loss: 3.0991 - val_k_smape: 123.3986
# Epoch 16/80
# 0s - loss: 4.9621 - k_smape: 122.9725 - val_loss: 3.0770 - val_k_smape: 120.9999
# Epoch 17/80
# 0s - loss: 4.8414 - k_smape: 122.4611 - val_loss: 3.0795 - val_k_smape: 119.3318
# Epoch 18/80
# 0s - loss: 4.8798 - k_smape: 119.5343 - val_loss: 3.0718 - val_k_smape: 117.4228
# Epoch 19/80
# 0s - loss: 4.5657 - k_smape: 114.9946 - val_loss: 3.0556 - val_k_smape: 115.4978
# Epoch 20/80
# 0s - loss: 4.7182 - k_smape: 119.3140 - val_loss: 3.0132 - val_k_smape: 113.6986
# Epoch 21/80
# 0s - loss: 4.4353 - k_smape: 113.8188 - val_loss: 2.9149 - val_k_smape: 112.2096
# Epoch 22/80
# 0s - loss: 4.6333 - k_smape: 115.1044 - val_loss: 2.7678 - val_k_smape: 110.4217
# Epoch 23/80
# 0s - loss: 4.4593 - k_smape: 112.3835 - val_loss: 2.6325 - val_k_smape: 109.2348
# Epoch 24/80
# 0s - loss: 4.4956 - k_smape: 113.5256 - val_loss: 2.4990 - val_k_smape: 108.1230
# Epoch 25/80
# 0s - loss: 4.1734 - k_smape: 111.2205 - val_loss: 2.3457 - val_k_smape: 107.4174
# Epoch 26/80
# 0s - loss: 4.3999 - k_smape: 115.9063 - val_loss: 2.1723 - val_k_smape: 106.0767
# Epoch 27/80
# 0s - loss: 4.3319 - k_smape: 108.9448 - val_loss: 2.1166 - val_k_smape: 104.4949
# Epoch 28/80
# 0s - loss: 4.0249 - k_smape: 105.5355 - val_loss: 2.1177 - val_k_smape: 103.2619
# Epoch 29/80
# 0s - loss: 4.0063 - k_smape: 104.8397 - val_loss: 2.0906 - val_k_smape: 101.7274
# Epoch 30/80
# 0s - loss: 4.0252 - k_smape: 104.2309 - val_loss: 2.1001 - val_k_smape: 100.9354
# Epoch 31/80
# 0s - loss: 3.9417 - k_smape: 102.1853 - val_loss: 2.1022 - val_k_smape: 100.0888
# Epoch 32/80
# 0s - loss: 4.0745 - k_smape: 105.9743 - val_loss: 2.1051 - val_k_smape: 99.6492
# Epoch 33/80
# 0s - loss: 3.8702 - k_smape: 104.2616 - val_loss: 2.0954 - val_k_smape: 99.8533
# Epoch 34/80
# 0s - loss: 3.8600 - k_smape: 101.8186 - val_loss: 2.0876 - val_k_smape: 99.9293
# Epoch 35/80
# 0s - loss: 3.8380 - k_smape: 98.9768 - val_loss: 2.0790 - val_k_smape: 99.8365
# Epoch 36/80
# 0s - loss: 3.7722 - k_smape: 104.0755 - val_loss: 2.0660 - val_k_smape: 99.6796
# Epoch 37/80
# 0s - loss: 3.7189 - k_smape: 99.9909 - val_loss: 2.0400 - val_k_smape: 98.9534
# Epoch 38/80
# 0s - loss: 3.7830 - k_smape: 98.3628 - val_loss: 1.9409 - val_k_smape: 97.8623
# Epoch 39/80
# 0s - loss: 3.6346 - k_smape: 95.8739 - val_loss: 1.8022 - val_k_smape: 96.7819
# Epoch 40/80
# 0s - loss: 3.6020 - k_smape: 94.6238 - val_loss: 1.6589 - val_k_smape: 95.3110
# Epoch 41/80
# 0s - loss: 3.6054 - k_smape: 94.2995 - val_loss: 1.5051 - val_k_smape: 93.6415
# Epoch 42/80
# 0s - loss: 3.5807 - k_smape: 89.1664 - val_loss: 1.3922 - val_k_smape: 92.4723
# Epoch 43/80
# 0s - loss: 3.4151 - k_smape: 92.1911 - val_loss: 1.3554 - val_k_smape: 91.9103
# Epoch 44/80
# 0s - loss: 3.5994 - k_smape: 91.5402 - val_loss: 1.3866 - val_k_smape: 92.3084
# Epoch 45/80
# 0s - loss: 3.3902 - k_smape: 87.1597 - val_loss: 1.5913 - val_k_smape: 93.4609
# Epoch 46/80
# 0s - loss: 3.3792 - k_smape: 92.3698 - val_loss: 1.7563 - val_k_smape: 94.0441
# Epoch 47/80
# 0s - loss: 3.5568 - k_smape: 90.2065 - val_loss: 1.8256 - val_k_smape: 93.1771
# Epoch 48/80
# 0s - loss: 3.2147 - k_smape: 88.3397 - val_loss: 1.7975 - val_k_smape: 91.8367
# Epoch 49/80
# 0s - loss: 3.3206 - k_smape: 88.2018 - val_loss: 1.7369 - val_k_smape: 90.9283
# Epoch 50/80
# 0s - loss: 3.3776 - k_smape: 87.4318 - val_loss: 1.6891 - val_k_smape: 90.4097
# Epoch 51/80
# 0s - loss: 3.1377 - k_smape: 83.5804 - val_loss: 1.5919 - val_k_smape: 89.7819
# Epoch 52/80
# 0s - loss: 3.3343 - k_smape: 85.4388 - val_loss: 1.4910 - val_k_smape: 89.0449
# Epoch 53/80
# 0s - loss: 3.4184 - k_smape: 87.6997 - val_loss: 1.2797 - val_k_smape: 88.4551
# Epoch 54/80
# 0s - loss: 3.0316 - k_smape: 83.4382 - val_loss: 1.0869 - val_k_smape: 87.8417
# Epoch 55/80
# 0s - loss: 3.2127 - k_smape: 82.8617 - val_loss: 1.0319 - val_k_smape: 87.6607
# Epoch 56/80
# 0s - loss: 3.1959 - k_smape: 80.6480 - val_loss: 1.0240 - val_k_smape: 87.0264
# Epoch 57/80
# 0s - loss: 2.9331 - k_smape: 81.3206 - val_loss: 1.0742 - val_k_smape: 86.4368
# Epoch 58/80
# 0s - loss: 3.0398 - k_smape: 81.0937 - val_loss: 1.1568 - val_k_smape: 85.8270
# Epoch 59/80
# 0s - loss: 2.9833 - k_smape: 78.8069 - val_loss: 1.3153 - val_k_smape: 85.6487
# Epoch 60/80
# 0s - loss: 3.0317 - k_smape: 81.2479 - val_loss: 1.4260 - val_k_smape: 86.4852
# Epoch 61/80
# 0s - loss: 3.1979 - k_smape: 82.7478 - val_loss: 1.3690 - val_k_smape: 87.0370
# Epoch 62/80
# 0s - loss: 3.1412 - k_smape: 79.5093 - val_loss: 1.3530 - val_k_smape: 89.2200
# Epoch 63/80
# 0s - loss: 3.0399 - k_smape: 79.0889 - val_loss: 1.3533 - val_k_smape: 92.7084
# Epoch 64/80
# 0s - loss: 2.8949 - k_smape: 78.7367 - val_loss: 1.4416 - val_k_smape: 95.8105
# Epoch 65/80
# 0s - loss: 2.8435 - k_smape: 79.6916 - val_loss: 1.4956 - val_k_smape: 95.9339
# Epoch 66/80
# 0s - loss: 3.0834 - k_smape: 81.7131 - val_loss: 1.3843 - val_k_smape: 93.6713
# Epoch 67/80
# 0s - loss: 2.9388 - k_smape: 81.0331 - val_loss: 1.3285 - val_k_smape: 89.3377
# Epoch 68/80
# 0s - loss: 2.8586 - k_smape: 77.1090 - val_loss: 1.3348 - val_k_smape: 85.9370
# Epoch 69/80
# 0s - loss: 2.9981 - k_smape: 77.9577 - val_loss: 1.2639 - val_k_smape: 84.0258
# Epoch 70/80
# 0s - loss: 2.9718 - k_smape: 76.9040 - val_loss: 1.1970 - val_k_smape: 83.8904
# Epoch 71/80
# 0s - loss: 2.8707 - k_smape: 73.6073 - val_loss: 1.1743 - val_k_smape: 84.7426
# Epoch 72/80
# 0s - loss: 2.9907 - k_smape: 77.4175 - val_loss: 1.2009 - val_k_smape: 85.4296
# Epoch 73/80
# 0s - loss: 2.8500 - k_smape: 73.3163 - val_loss: 1.2693 - val_k_smape: 86.8444
# Epoch 74/80
# 0s - loss: 2.8954 - k_smape: 78.5919 - val_loss: 1.2503 - val_k_smape: 87.5610
# Epoch 75/80
# 0s - loss: 3.3202 - k_smape: 82.6343 - val_loss: 1.2410 - val_k_smape: 87.3646
# Epoch 76/80
# 0s - loss: 2.9334 - k_smape: 77.1120 - val_loss: 1.4164 - val_k_smape: 86.7569
# Epoch 77/80
# 0s - loss: 3.1550 - k_smape: 82.1107 - val_loss: 1.5158 - val_k_smape: 85.8774
# Epoch 78/80
# 0s - loss: 2.7449 - k_smape: 73.9738 - val_loss: 1.5012 - val_k_smape: 85.2287
# Epoch 79/80
# 0s - loss: 2.8540 - k_smape: 72.4702 - val_loss: 1.3907 - val_k_smape: 85.7279
# Epoch 80/80
# 0s - loss: 3.1854 - k_smape: 73.2122 - val_loss: 1.2616 - val_k_smape: 86.0393
# === Run: 1 / 5 ===
# -- Group: 0 / 6 --
# Train on 1691 samples, validate on 188 samples
# Epoch 1/1
# 0s - loss: 0.9431 - k_smape: 198.4281 - val_loss: 0.9762 - val_k_smape: 199.6801
# -- Group: 1 / 6 --
# Train on 20776 samples, validate on 2309 samples
# Epoch 1/1
# 4s - loss: 1.1331 - k_smape: 144.1755 - val_loss: 1.0033 - val_k_smape: 139.6657
# -- Group: 2 / 6 --
# Train on 39321 samples, validate on 4370 samples
# Epoch 1/40
# 7s - loss: 1.3270 - k_smape: 127.3118 - val_loss: 1.0328 - val_k_smape: 113.4334
# Epoch 2/40
# 7s - loss: 1.2503 - k_smape: 118.3455 - val_loss: 1.0314 - val_k_smape: 119.4226
# Epoch 3/40
# 7s - loss: 1.2304 - k_smape: 116.6340 - val_loss: 1.0155 - val_k_smape: 119.5609
# Epoch 4/40
# 7s - loss: 1.2185 - k_smape: 115.5491 - val_loss: 1.0250 - val_k_smape: 117.6250
# Epoch 5/40
# 7s - loss: 1.2139 - k_smape: 115.0422 - val_loss: 1.0597 - val_k_smape: 123.0021
# Epoch 6/40
# 7s - loss: 1.2126 - k_smape: 114.5027 - val_loss: 1.0426 - val_k_smape: 120.9378
# Epoch 7/40
# 7s - loss: 1.2056 - k_smape: 114.4368 - val_loss: 1.0297 - val_k_smape: 120.0555
# Epoch 8/40
# 7s - loss: 1.2049 - k_smape: 113.8572 - val_loss: 1.0777 - val_k_smape: 122.7474
# Epoch 9/40
# 7s - loss: 1.1966 - k_smape: 113.5553 - val_loss: 1.0253 - val_k_smape: 116.5936
# Epoch 10/40
# 7s - loss: 1.1958 - k_smape: 113.7429 - val_loss: 1.0051 - val_k_smape: 116.5495
# Epoch 11/40
# 7s - loss: 1.1929 - k_smape: 113.3661 - val_loss: 1.0333 - val_k_smape: 118.8985
# Epoch 12/40
# 7s - loss: 1.1970 - k_smape: 113.2252 - val_loss: 1.0126 - val_k_smape: 113.7969
# Epoch 13/40
# 7s - loss: 1.1915 - k_smape: 112.9935 - val_loss: 1.0193 - val_k_smape: 118.3935
# Epoch 14/40
# 7s - loss: 1.1882 - k_smape: 112.9943 - val_loss: 1.0079 - val_k_smape: 118.3650
# Epoch 15/40
# 7s - loss: 1.1919 - k_smape: 112.9971 - val_loss: 1.0436 - val_k_smape: 118.7339
# Epoch 16/40
# 7s - loss: 1.1855 - k_smape: 112.5964 - val_loss: 1.0125 - val_k_smape: 118.2265
# Epoch 17/40
# 7s - loss: 1.1799 - k_smape: 112.2490 - val_loss: 1.0346 - val_k_smape: 119.3818
# Epoch 18/40
# 7s - loss: 1.1820 - k_smape: 112.2525 - val_loss: 1.0240 - val_k_smape: 117.8185
# Epoch 19/40
# 7s - loss: 1.1771 - k_smape: 112.2095 - val_loss: 1.0009 - val_k_smape: 114.7490
# Epoch 20/40
# 7s - loss: 1.1768 - k_smape: 112.1396 - val_loss: 1.0286 - val_k_smape: 117.5368
# Epoch 21/40
# 7s - loss: 1.1761 - k_smape: 111.9170 - val_loss: 1.0027 - val_k_smape: 117.5183
# Epoch 22/40
# 7s - loss: 1.1724 - k_smape: 111.8136 - val_loss: 1.0357 - val_k_smape: 115.3636
# Epoch 23/40
# 7s - loss: 1.1726 - k_smape: 111.6809 - val_loss: 1.0459 - val_k_smape: 117.9880
# Epoch 24/40
# 7s - loss: 1.1770 - k_smape: 111.7011 - val_loss: 1.0236 - val_k_smape: 118.9750
# Epoch 25/40
# 7s - loss: 1.1683 - k_smape: 111.6989 - val_loss: 1.0412 - val_k_smape: 117.5276
# Epoch 26/40
# 7s - loss: 1.1768 - k_smape: 111.7765 - val_loss: 1.0445 - val_k_smape: 118.7207
# Epoch 27/40
# 7s - loss: 1.1714 - k_smape: 111.5547 - val_loss: 1.0217 - val_k_smape: 115.9133
# Epoch 28/40
# 7s - loss: 1.1696 - k_smape: 111.2288 - val_loss: 1.0201 - val_k_smape: 118.0025
# Epoch 29/40
# 7s - loss: 1.1664 - k_smape: 111.2608 - val_loss: 1.0446 - val_k_smape: 119.4682
# Epoch 30/40
# 7s - loss: 1.1646 - k_smape: 111.2343 - val_loss: 1.0232 - val_k_smape: 117.5769
# Epoch 31/40
# 7s - loss: 1.1632 - k_smape: 111.2145 - val_loss: 1.0337 - val_k_smape: 117.2138
# Epoch 32/40
# 7s - loss: 1.1584 - k_smape: 110.9246 - val_loss: 1.0075 - val_k_smape: 116.7583
# Epoch 33/40
# 7s - loss: 1.1595 - k_smape: 110.8352 - val_loss: 1.0390 - val_k_smape: 117.7128
# Epoch 34/40
# 7s - loss: 1.1561 - k_smape: 110.7060 - val_loss: 1.0118 - val_k_smape: 115.7742
# Epoch 35/40
# 7s - loss: 1.1534 - k_smape: 110.5734 - val_loss: 1.0569 - val_k_smape: 121.1541
# Epoch 36/40
# 7s - loss: 1.1548 - k_smape: 110.8771 - val_loss: 1.0347 - val_k_smape: 117.7652
# Epoch 37/40
# 7s - loss: 1.1530 - k_smape: 110.6724 - val_loss: 1.0493 - val_k_smape: 119.0666
# Epoch 38/40
# 7s - loss: 1.1534 - k_smape: 110.6267 - val_loss: 1.0228 - val_k_smape: 117.1593
# Epoch 39/40
# 7s - loss: 1.1531 - k_smape: 110.5312 - val_loss: 1.0528 - val_k_smape: 118.7220
# Epoch 40/40
# 7s - loss: 1.1479 - k_smape: 110.3188 - val_loss: 1.0116 - val_k_smape: 115.8830
# -- Group: 3 / 6 --
# Train on 68055 samples, validate on 7562 samples
# Epoch 1/40
# 12s - loss: 1.3461 - k_smape: 109.0997 - val_loss: 1.1577 - val_k_smape: 112.1192
# Epoch 2/40
# 12s - loss: 1.2434 - k_smape: 100.9582 - val_loss: 1.1045 - val_k_smape: 106.7929
# Epoch 3/40
# 12s - loss: 1.2284 - k_smape: 99.3893 - val_loss: 1.0903 - val_k_smape: 103.8162
# Epoch 4/40
# 12s - loss: 1.2169 - k_smape: 98.7029 - val_loss: 1.1074 - val_k_smape: 105.7710
# Epoch 5/40
# 12s - loss: 1.2088 - k_smape: 98.0362 - val_loss: 1.1396 - val_k_smape: 106.3654
# Epoch 6/40
# 12s - loss: 1.2009 - k_smape: 97.5283 - val_loss: 1.1155 - val_k_smape: 106.0867
# Epoch 7/40
# 12s - loss: 1.1956 - k_smape: 97.3731 - val_loss: 1.0719 - val_k_smape: 104.4896
# Epoch 8/40
# 12s - loss: 1.1920 - k_smape: 97.1468 - val_loss: 1.0918 - val_k_smape: 105.7537
# Epoch 9/40
# 12s - loss: 1.1868 - k_smape: 96.8123 - val_loss: 1.1062 - val_k_smape: 105.4235
# Epoch 10/40
# 12s - loss: 1.1860 - k_smape: 96.6054 - val_loss: 1.1193 - val_k_smape: 105.6586
# Epoch 11/40
# 12s - loss: 1.1850 - k_smape: 96.5035 - val_loss: 1.0878 - val_k_smape: 104.1543
# Epoch 12/40
# 12s - loss: 1.1820 - k_smape: 96.2035 - val_loss: 1.1156 - val_k_smape: 106.9401
# Epoch 13/40
# 12s - loss: 1.1780 - k_smape: 96.2066 - val_loss: 1.0920 - val_k_smape: 104.0596
# Epoch 14/40
# 12s - loss: 1.1733 - k_smape: 95.9855 - val_loss: 1.1078 - val_k_smape: 106.7328
# Epoch 15/40
# 12s - loss: 1.1737 - k_smape: 95.9584 - val_loss: 1.1038 - val_k_smape: 103.9133
# Epoch 16/40
# 12s - loss: 1.1705 - k_smape: 95.6518 - val_loss: 1.1003 - val_k_smape: 105.0418
# Epoch 17/40
# 12s - loss: 1.1648 - k_smape: 95.5719 - val_loss: 1.1008 - val_k_smape: 104.7347
# Epoch 18/40
# 12s - loss: 1.1705 - k_smape: 95.6570 - val_loss: 1.0814 - val_k_smape: 105.1174
# Epoch 19/40
# 12s - loss: 1.1657 - k_smape: 95.3343 - val_loss: 1.1102 - val_k_smape: 105.0441
# Epoch 20/40
# 12s - loss: 1.1614 - k_smape: 95.4834 - val_loss: 1.1167 - val_k_smape: 107.1160
# Epoch 21/40
# 12s - loss: 1.1604 - k_smape: 95.2945 - val_loss: 1.1365 - val_k_smape: 107.2483
# Epoch 22/40
# 12s - loss: 1.1597 - k_smape: 95.2401 - val_loss: 1.1200 - val_k_smape: 105.2424
# Epoch 23/40
# 12s - loss: 1.1563 - k_smape: 95.1062 - val_loss: 1.0940 - val_k_smape: 104.3877
# Epoch 24/40
# 12s - loss: 1.1529 - k_smape: 95.0800 - val_loss: 1.0944 - val_k_smape: 103.5584
# Epoch 25/40
# 12s - loss: 1.1494 - k_smape: 94.9220 - val_loss: 1.0945 - val_k_smape: 106.2277
# Epoch 26/40
# 12s - loss: 1.1496 - k_smape: 94.9614 - val_loss: 1.1060 - val_k_smape: 106.2720
# Epoch 27/40
# 12s - loss: 1.1504 - k_smape: 94.9755 - val_loss: 1.0927 - val_k_smape: 104.1524
# Epoch 28/40
# 12s - loss: 1.1483 - k_smape: 94.8500 - val_loss: 1.1173 - val_k_smape: 105.8600
# Epoch 29/40
# 12s - loss: 1.1445 - k_smape: 94.5179 - val_loss: 1.1009 - val_k_smape: 107.7523
# Epoch 30/40
# 12s - loss: 1.1454 - k_smape: 94.6224 - val_loss: 1.0981 - val_k_smape: 103.6037
# Epoch 31/40
# 12s - loss: 1.1430 - k_smape: 94.5715 - val_loss: 1.0897 - val_k_smape: 104.9034
# Epoch 32/40
# 12s - loss: 1.1444 - k_smape: 94.4009 - val_loss: 1.1282 - val_k_smape: 109.4584
# Epoch 33/40
# 12s - loss: 1.1424 - k_smape: 94.6362 - val_loss: 1.0918 - val_k_smape: 105.5971
# Epoch 34/40
# 12s - loss: 1.1400 - k_smape: 94.4696 - val_loss: 1.1036 - val_k_smape: 104.5511
# Epoch 35/40
# 12s - loss: 1.1377 - k_smape: 94.2916 - val_loss: 1.0945 - val_k_smape: 105.5050
# Epoch 36/40
# 12s - loss: 1.1361 - k_smape: 94.2412 - val_loss: 1.0777 - val_k_smape: 105.5774
# Epoch 37/40
# 12s - loss: 1.1372 - k_smape: 94.2499 - val_loss: 1.1016 - val_k_smape: 106.0553
# Epoch 38/40
# 12s - loss: 1.1332 - k_smape: 94.1720 - val_loss: 1.1082 - val_k_smape: 106.2580
# Epoch 39/40
# 12s - loss: 1.1312 - k_smape: 94.0771 - val_loss: 1.0741 - val_k_smape: 104.2062
# Epoch 40/40
# 12s - loss: 1.1309 - k_smape: 93.9299 - val_loss: 1.0917 - val_k_smape: 104.6425
# -- Group: 4 / 6 --
# Train on 666 samples, validate on 74 samples
# Epoch 1/60
# 0s - loss: 2.9799 - k_smape: 160.8281 - val_loss: 3.1908 - val_k_smape: 149.1743
# Epoch 2/60
# 0s - loss: 2.6646 - k_smape: 142.1265 - val_loss: 2.8560 - val_k_smape: 138.7897
# Epoch 3/60
# 0s - loss: 2.4071 - k_smape: 134.9135 - val_loss: 2.4549 - val_k_smape: 128.5524
# Epoch 4/60
# 0s - loss: 2.2581 - k_smape: 126.5516 - val_loss: 2.3742 - val_k_smape: 125.5332
# Epoch 5/60
# 0s - loss: 2.1369 - k_smape: 123.3116 - val_loss: 2.2224 - val_k_smape: 119.7080
# Epoch 6/60
# 0s - loss: 2.0079 - k_smape: 117.1977 - val_loss: 2.1544 - val_k_smape: 115.2639
# Epoch 7/60
# 0s - loss: 2.0092 - k_smape: 114.1356 - val_loss: 1.6796 - val_k_smape: 106.8900
# Epoch 8/60
# 0s - loss: 1.9113 - k_smape: 108.8402 - val_loss: 2.2019 - val_k_smape: 116.1132
# Epoch 9/60
# 0s - loss: 1.8638 - k_smape: 109.9245 - val_loss: 1.5743 - val_k_smape: 103.3644
# Epoch 10/60
# 0s - loss: 1.8050 - k_smape: 104.5685 - val_loss: 2.2738 - val_k_smape: 113.2434
# Epoch 11/60
# 0s - loss: 1.7900 - k_smape: 104.8637 - val_loss: 1.5673 - val_k_smape: 100.5636
# Epoch 12/60
# 0s - loss: 1.7898 - k_smape: 101.9238 - val_loss: 1.7473 - val_k_smape: 107.6352
# Epoch 13/60
# 0s - loss: 1.7271 - k_smape: 101.7824 - val_loss: 1.6817 - val_k_smape: 107.3903
# Epoch 14/60
# 0s - loss: 1.6801 - k_smape: 101.3004 - val_loss: 1.7307 - val_k_smape: 104.8388
# Epoch 15/60
# 0s - loss: 1.6439 - k_smape: 97.5707 - val_loss: 1.8171 - val_k_smape: 103.4736
# Epoch 16/60
# 0s - loss: 1.6898 - k_smape: 97.0037 - val_loss: 1.4407 - val_k_smape: 100.2442
# Epoch 17/60
# 0s - loss: 1.6565 - k_smape: 97.4188 - val_loss: 1.7012 - val_k_smape: 104.7591
# Epoch 18/60
# 0s - loss: 1.6243 - k_smape: 95.7270 - val_loss: 1.6744 - val_k_smape: 101.1379
# Epoch 19/60
# 0s - loss: 1.6820 - k_smape: 95.8117 - val_loss: 1.5038 - val_k_smape: 95.3777
# Epoch 20/60
# 0s - loss: 1.6053 - k_smape: 91.9602 - val_loss: 1.7973 - val_k_smape: 102.6720
# Epoch 21/60
# 0s - loss: 1.5651 - k_smape: 93.3593 - val_loss: 1.4088 - val_k_smape: 96.7879
# Epoch 22/60
# 0s - loss: 1.5937 - k_smape: 93.4161 - val_loss: 1.5855 - val_k_smape: 98.7241
# Epoch 23/60
# 0s - loss: 1.5325 - k_smape: 90.4177 - val_loss: 1.4872 - val_k_smape: 95.2535
# Epoch 24/60
# 0s - loss: 1.4705 - k_smape: 91.5616 - val_loss: 1.6202 - val_k_smape: 94.2872
# Epoch 25/60
# 0s - loss: 1.5170 - k_smape: 88.3139 - val_loss: 1.4070 - val_k_smape: 94.6871
# Epoch 26/60
# 0s - loss: 1.5024 - k_smape: 89.7436 - val_loss: 1.6798 - val_k_smape: 97.3441
# Epoch 27/60
# 0s - loss: 1.4991 - k_smape: 89.4562 - val_loss: 1.4136 - val_k_smape: 94.3368
# Epoch 28/60
# 0s - loss: 1.5449 - k_smape: 91.2066 - val_loss: 1.5520 - val_k_smape: 95.0058
# Epoch 29/60
# 0s - loss: 1.4834 - k_smape: 86.1511 - val_loss: 1.4972 - val_k_smape: 95.0975
# Epoch 30/60
# 0s - loss: 1.4574 - k_smape: 89.7534 - val_loss: 1.3916 - val_k_smape: 91.2159
# Epoch 31/60
# 0s - loss: 1.5052 - k_smape: 85.3811 - val_loss: 1.6166 - val_k_smape: 95.4427
# Epoch 32/60
# 0s - loss: 1.4329 - k_smape: 87.2339 - val_loss: 1.3351 - val_k_smape: 90.2709
# Epoch 33/60
# 0s - loss: 1.4589 - k_smape: 87.6478 - val_loss: 1.5892 - val_k_smape: 91.1420
# Epoch 34/60
# 0s - loss: 1.4387 - k_smape: 86.5031 - val_loss: 1.3341 - val_k_smape: 89.9560
# Epoch 35/60
# 0s - loss: 1.4733 - k_smape: 85.2181 - val_loss: 1.4904 - val_k_smape: 92.2711
# Epoch 36/60
# 0s - loss: 1.4410 - k_smape: 85.8976 - val_loss: 1.4178 - val_k_smape: 89.1810
# Epoch 37/60
# 0s - loss: 1.3739 - k_smape: 84.4302 - val_loss: 1.3443 - val_k_smape: 90.3135
# Epoch 38/60
# 0s - loss: 1.3962 - k_smape: 83.7497 - val_loss: 1.4682 - val_k_smape: 91.9337
# Epoch 39/60
# 0s - loss: 1.3924 - k_smape: 84.9642 - val_loss: 1.3314 - val_k_smape: 89.0387
# Epoch 40/60
# 0s - loss: 1.3905 - k_smape: 82.1723 - val_loss: 1.3852 - val_k_smape: 88.9901
# Epoch 41/60
# 0s - loss: 1.4212 - k_smape: 82.2675 - val_loss: 1.4157 - val_k_smape: 89.0002
# Epoch 42/60
# 0s - loss: 1.4207 - k_smape: 83.4637 - val_loss: 1.2908 - val_k_smape: 88.3630
# Epoch 43/60
# 0s - loss: 1.3958 - k_smape: 84.1725 - val_loss: 1.6012 - val_k_smape: 89.8259
# Epoch 44/60
# 0s - loss: 1.3823 - k_smape: 81.9427 - val_loss: 1.2944 - val_k_smape: 87.0650
# Epoch 45/60
# 0s - loss: 1.3711 - k_smape: 84.3980 - val_loss: 1.4864 - val_k_smape: 86.7196
# Epoch 46/60
# 0s - loss: 1.3956 - k_smape: 81.8145 - val_loss: 1.5118 - val_k_smape: 89.7368
# Epoch 47/60
# 0s - loss: 1.3521 - k_smape: 84.3680 - val_loss: 1.3622 - val_k_smape: 87.1540
# Epoch 48/60
# 0s - loss: 1.3420 - k_smape: 80.3103 - val_loss: 1.5459 - val_k_smape: 92.3312
# Epoch 49/60
# 0s - loss: 1.3615 - k_smape: 83.7168 - val_loss: 1.2867 - val_k_smape: 85.6242
# Epoch 50/60
# 0s - loss: 1.3910 - k_smape: 80.7261 - val_loss: 1.4062 - val_k_smape: 88.4529
# Epoch 51/60
# 0s - loss: 1.3332 - k_smape: 81.5357 - val_loss: 1.2522 - val_k_smape: 84.3297
# Epoch 52/60
# 0s - loss: 1.3711 - k_smape: 81.3320 - val_loss: 1.2406 - val_k_smape: 84.0983
# Epoch 53/60
# 0s - loss: 1.3656 - k_smape: 80.2121 - val_loss: 1.6576 - val_k_smape: 88.2727
# Epoch 54/60
# 0s - loss: 1.4030 - k_smape: 81.4088 - val_loss: 1.2582 - val_k_smape: 82.7788
# Epoch 55/60
# 0s - loss: 1.3714 - k_smape: 80.2058 - val_loss: 1.3370 - val_k_smape: 86.2264
# Epoch 56/60
# 0s - loss: 1.2892 - k_smape: 79.8141 - val_loss: 1.2549 - val_k_smape: 83.7505
# Epoch 57/60
# 0s - loss: 1.3497 - k_smape: 80.7042 - val_loss: 1.2612 - val_k_smape: 84.6303
# Epoch 58/60
# 0s - loss: 1.3401 - k_smape: 79.8851 - val_loss: 1.3081 - val_k_smape: 83.5508
# Epoch 59/60
# 0s - loss: 1.2986 - k_smape: 79.8410 - val_loss: 1.3093 - val_k_smape: 83.5400
# Epoch 60/60
# 0s - loss: 1.2935 - k_smape: 79.0298 - val_loss: 1.4116 - val_k_smape: 84.7118
# -- Group: 5 / 6 --
# Train on 45 samples, validate on 6 samples
# Epoch 1/80
# 0s - loss: 6.8849 - k_smape: 174.0359 - val_loss: 4.7198 - val_k_smape: 166.8214
# Epoch 2/80
# 0s - loss: 6.5519 - k_smape: 165.3540 - val_loss: 4.5681 - val_k_smape: 158.2766
# Epoch 3/80
# 0s - loss: 6.3199 - k_smape: 153.9651 - val_loss: 4.3813 - val_k_smape: 150.8573
# Epoch 4/80
# 0s - loss: 6.1565 - k_smape: 144.7890 - val_loss: 4.1983 - val_k_smape: 145.5643
# Epoch 5/80
# 0s - loss: 5.9055 - k_smape: 139.7627 - val_loss: 4.0356 - val_k_smape: 140.6439
# Epoch 6/80
# 0s - loss: 5.8217 - k_smape: 134.7042 - val_loss: 3.8772 - val_k_smape: 137.5064
# Epoch 7/80
# 0s - loss: 5.6688 - k_smape: 131.9640 - val_loss: 3.7290 - val_k_smape: 134.0604
# Epoch 8/80
# 0s - loss: 5.5187 - k_smape: 132.5253 - val_loss: 3.5820 - val_k_smape: 130.1284
# Epoch 9/80
# 0s - loss: 5.3900 - k_smape: 128.8054 - val_loss: 3.4461 - val_k_smape: 127.1195
# Epoch 10/80
# 0s - loss: 5.3026 - k_smape: 130.3138 - val_loss: 3.3468 - val_k_smape: 125.3431
# Epoch 11/80
# 0s - loss: 5.4040 - k_smape: 132.0253 - val_loss: 3.2790 - val_k_smape: 125.2720
# Epoch 12/80
# 0s - loss: 5.0975 - k_smape: 127.4930 - val_loss: 3.2545 - val_k_smape: 124.9440
# Epoch 13/80
# 0s - loss: 5.1539 - k_smape: 127.3517 - val_loss: 3.2318 - val_k_smape: 123.6462
# Epoch 14/80
# 0s - loss: 4.8715 - k_smape: 124.6230 - val_loss: 3.1562 - val_k_smape: 121.6223
# Epoch 15/80
# 0s - loss: 4.9426 - k_smape: 123.3622 - val_loss: 3.0628 - val_k_smape: 119.8848
# Epoch 16/80
# 0s - loss: 4.8317 - k_smape: 120.3540 - val_loss: 2.9431 - val_k_smape: 117.7110
# Epoch 17/80
# 0s - loss: 4.5219 - k_smape: 116.6496 - val_loss: 2.8434 - val_k_smape: 115.7808
# Epoch 18/80
# 0s - loss: 4.5659 - k_smape: 118.3396 - val_loss: 2.7572 - val_k_smape: 114.1368
# Epoch 19/80
# 0s - loss: 4.4172 - k_smape: 114.0701 - val_loss: 2.6850 - val_k_smape: 112.6717
# Epoch 20/80
# 0s - loss: 4.4228 - k_smape: 115.0524 - val_loss: 2.5869 - val_k_smape: 111.3996
# Epoch 21/80
# 0s - loss: 4.3071 - k_smape: 111.7069 - val_loss: 2.5087 - val_k_smape: 110.1589
# Epoch 22/80
# 0s - loss: 4.3006 - k_smape: 113.4468 - val_loss: 2.4294 - val_k_smape: 109.0825
# Epoch 23/80
# 0s - loss: 4.1983 - k_smape: 112.3870 - val_loss: 2.3418 - val_k_smape: 107.9739
# Epoch 24/80
# 0s - loss: 4.3040 - k_smape: 113.9599 - val_loss: 2.2636 - val_k_smape: 106.4353
# Epoch 25/80
# 0s - loss: 4.1350 - k_smape: 111.7985 - val_loss: 2.1764 - val_k_smape: 104.4501
# Epoch 26/80
# 0s - loss: 3.9449 - k_smape: 108.6229 - val_loss: 2.1059 - val_k_smape: 102.4152
# Epoch 27/80
# 0s - loss: 4.1190 - k_smape: 108.8251 - val_loss: 2.0413 - val_k_smape: 100.3042
# Epoch 28/80
# 0s - loss: 3.9504 - k_smape: 103.9462 - val_loss: 1.9357 - val_k_smape: 98.4034
# Epoch 29/80
# 0s - loss: 3.8225 - k_smape: 101.4810 - val_loss: 1.8322 - val_k_smape: 96.8179
# Epoch 30/80
# 0s - loss: 3.8736 - k_smape: 100.9798 - val_loss: 1.7656 - val_k_smape: 95.9477
# Epoch 31/80
# 0s - loss: 3.7550 - k_smape: 98.7274 - val_loss: 1.7567 - val_k_smape: 95.7484
# Epoch 32/80
# 0s - loss: 3.7910 - k_smape: 100.2787 - val_loss: 1.7502 - val_k_smape: 95.8090
# Epoch 33/80
# 0s - loss: 3.8524 - k_smape: 100.8663 - val_loss: 1.7261 - val_k_smape: 96.2693
# Epoch 34/80
# 0s - loss: 3.7286 - k_smape: 97.5993 - val_loss: 1.7735 - val_k_smape: 97.1883
# Epoch 35/80
# 0s - loss: 3.6699 - k_smape: 100.8343 - val_loss: 1.7635 - val_k_smape: 97.2560
# Epoch 36/80
# 0s - loss: 3.4153 - k_smape: 95.0792 - val_loss: 1.6695 - val_k_smape: 96.6026
# Epoch 37/80
# 0s - loss: 3.7397 - k_smape: 100.1227 - val_loss: 1.5622 - val_k_smape: 96.7329
# Epoch 38/80
# 0s - loss: 3.5231 - k_smape: 95.8111 - val_loss: 1.4608 - val_k_smape: 96.8507
# Epoch 39/80
# 0s - loss: 3.5715 - k_smape: 93.4583 - val_loss: 1.3835 - val_k_smape: 96.2990
# Epoch 40/80
# 0s - loss: 3.3722 - k_smape: 93.1783 - val_loss: 1.3204 - val_k_smape: 94.7148
# Epoch 41/80
# 0s - loss: 3.3390 - k_smape: 91.7163 - val_loss: 1.3166 - val_k_smape: 92.8182
# Epoch 42/80
# 0s - loss: 3.2993 - k_smape: 88.0587 - val_loss: 1.4420 - val_k_smape: 92.6269
# Epoch 43/80
# 0s - loss: 3.4073 - k_smape: 88.5739 - val_loss: 1.6621 - val_k_smape: 93.4023
# Epoch 44/80
# 0s - loss: 3.3525 - k_smape: 87.1201 - val_loss: 1.9467 - val_k_smape: 95.5559
# Epoch 45/80
# 0s - loss: 3.4345 - k_smape: 90.2206 - val_loss: 2.0258 - val_k_smape: 97.4930
# Epoch 46/80
# 0s - loss: 3.4364 - k_smape: 88.7867 - val_loss: 1.8843 - val_k_smape: 98.5235
# Epoch 47/80
# 0s - loss: 3.1622 - k_smape: 87.8588 - val_loss: 1.6632 - val_k_smape: 98.7396
# Epoch 48/80
# 0s - loss: 3.2689 - k_smape: 90.5568 - val_loss: 1.4296 - val_k_smape: 97.2122
# Epoch 49/80
# 0s - loss: 3.2034 - k_smape: 86.1800 - val_loss: 1.3251 - val_k_smape: 95.3889
# Epoch 50/80
# 0s - loss: 3.1750 - k_smape: 83.7890 - val_loss: 1.2814 - val_k_smape: 93.4011
# Epoch 51/80
# 0s - loss: 3.0360 - k_smape: 81.9709 - val_loss: 1.2853 - val_k_smape: 91.8976
# Epoch 52/80
# 0s - loss: 3.2532 - k_smape: 87.4430 - val_loss: 1.2885 - val_k_smape: 91.1459
# Epoch 53/80
# 0s - loss: 3.1835 - k_smape: 81.4010 - val_loss: 1.3456 - val_k_smape: 91.3545
# Epoch 54/80
# 0s - loss: 3.0640 - k_smape: 80.3079 - val_loss: 1.5621 - val_k_smape: 92.8524
# Epoch 55/80
# 0s - loss: 3.0911 - k_smape: 80.2420 - val_loss: 1.7622 - val_k_smape: 94.6089
# Epoch 56/80
# 0s - loss: 3.0233 - k_smape: 81.8991 - val_loss: 1.7967 - val_k_smape: 95.2699
# Epoch 57/80
# 0s - loss: 3.2079 - k_smape: 85.4784 - val_loss: 1.6330 - val_k_smape: 93.8504
# Epoch 58/80
# 0s - loss: 2.8627 - k_smape: 80.8142 - val_loss: 1.4362 - val_k_smape: 91.8599
# Epoch 59/80
# 0s - loss: 2.9796 - k_smape: 78.6590 - val_loss: 1.3186 - val_k_smape: 89.9810
# Epoch 60/80
# 0s - loss: 3.0540 - k_smape: 79.9947 - val_loss: 1.2325 - val_k_smape: 88.7680
# Epoch 61/80
# 0s - loss: 2.8604 - k_smape: 77.6993 - val_loss: 1.1863 - val_k_smape: 88.0704
# Epoch 62/80
# 0s - loss: 2.8597 - k_smape: 76.0814 - val_loss: 1.1682 - val_k_smape: 87.7332
# Epoch 63/80
# 0s - loss: 2.9171 - k_smape: 79.7055 - val_loss: 1.1866 - val_k_smape: 87.9358
# Epoch 64/80
# 0s - loss: 3.1150 - k_smape: 79.1956 - val_loss: 1.1692 - val_k_smape: 87.6330
# Epoch 65/80
# 0s - loss: 3.0860 - k_smape: 79.2953 - val_loss: 1.1718 - val_k_smape: 87.5755
# Epoch 66/80
# 0s - loss: 2.9175 - k_smape: 77.4279 - val_loss: 1.1557 - val_k_smape: 87.2612
# Epoch 67/80
# 0s - loss: 2.9727 - k_smape: 75.9573 - val_loss: 1.1351 - val_k_smape: 87.3156
# Epoch 68/80
# 0s - loss: 3.0464 - k_smape: 76.0896 - val_loss: 1.0188 - val_k_smape: 88.1717
# Epoch 69/80
# 0s - loss: 2.8137 - k_smape: 75.8153 - val_loss: 1.0058 - val_k_smape: 87.8279
# Epoch 70/80
# 0s - loss: 3.0777 - k_smape: 78.7012 - val_loss: 0.9828 - val_k_smape: 86.3332
# Epoch 71/80
# 0s - loss: 2.7743 - k_smape: 72.5237 - val_loss: 1.0030 - val_k_smape: 85.6787
# Epoch 72/80
# 0s - loss: 2.9164 - k_smape: 74.5385 - val_loss: 1.2309 - val_k_smape: 87.5244
# Epoch 73/80
# 0s - loss: 2.8330 - k_smape: 75.4520 - val_loss: 1.4434 - val_k_smape: 87.9398
# Epoch 74/80
# 0s - loss: 3.0731 - k_smape: 73.4343 - val_loss: 1.5833 - val_k_smape: 89.4041
# Epoch 75/80
# 0s - loss: 2.9575 - k_smape: 77.5899 - val_loss: 1.5149 - val_k_smape: 89.3125
# Epoch 76/80
# 0s - loss: 3.0646 - k_smape: 79.3950 - val_loss: 1.3334 - val_k_smape: 87.3880
# Epoch 77/80
# 0s - loss: 2.8526 - k_smape: 76.7280 - val_loss: 1.1991 - val_k_smape: 86.3042
# Epoch 78/80
# 0s - loss: 2.7674 - k_smape: 74.5387 - val_loss: 1.1611 - val_k_smape: 86.1391
# Epoch 79/80
# 0s - loss: 2.8066 - k_smape: 75.4606 - val_loss: 1.0232 - val_k_smape: 85.8236
# Epoch 80/80
# 0s - loss: 2.8838 - k_smape: 71.0198 - val_loss: 1.0088 - val_k_smape: 85.6460
# === Run: 2 / 5 ===
# -- Group: 0 / 6 --
# Train on 1691 samples, validate on 188 samples
# Epoch 1/1
# 0s - loss: 0.9452 - k_smape: 197.8116 - val_loss: 0.9782 - val_k_smape: 199.8876
# -- Group: 1 / 6 --
# Train on 20776 samples, validate on 2309 samples
# Epoch 1/1
# 4s - loss: 1.1313 - k_smape: 143.3394 - val_loss: 0.9944 - val_k_smape: 137.0371
# -- Group: 2 / 6 --
# Train on 39321 samples, validate on 4370 samples
# Epoch 1/40
# 7s - loss: 1.3186 - k_smape: 126.5940 - val_loss: 1.0280 - val_k_smape: 119.5785
# Epoch 2/40
# 7s - loss: 1.2422 - k_smape: 118.1645 - val_loss: 1.0312 - val_k_smape: 119.8110
# Epoch 3/40
# 7s - loss: 1.2205 - k_smape: 116.1559 - val_loss: 1.0079 - val_k_smape: 113.3509
# Epoch 4/40
# 7s - loss: 1.2213 - k_smape: 115.5342 - val_loss: 1.0067 - val_k_smape: 115.5526
# Epoch 5/40
# 7s - loss: 1.2134 - k_smape: 114.8012 - val_loss: 1.0091 - val_k_smape: 116.3383
# Epoch 6/40
# 7s - loss: 1.2084 - k_smape: 114.3292 - val_loss: 1.0416 - val_k_smape: 117.9788
# Epoch 7/40
# 7s - loss: 1.2050 - k_smape: 114.2482 - val_loss: 1.0236 - val_k_smape: 113.9532
# Epoch 8/40
# 7s - loss: 1.1993 - k_smape: 113.8170 - val_loss: 1.0292 - val_k_smape: 119.7456
# Epoch 9/40
# 7s - loss: 1.1956 - k_smape: 113.6064 - val_loss: 1.0307 - val_k_smape: 117.1738
# Epoch 10/40
# 7s - loss: 1.1927 - k_smape: 113.4631 - val_loss: 1.0096 - val_k_smape: 116.3263
# Epoch 11/40
# 7s - loss: 1.1882 - k_smape: 113.2502 - val_loss: 1.0445 - val_k_smape: 121.8919
# Epoch 12/40
# 7s - loss: 1.1908 - k_smape: 113.0638 - val_loss: 1.0609 - val_k_smape: 124.5396
# Epoch 13/40
# 7s - loss: 1.1918 - k_smape: 113.2300 - val_loss: 1.0254 - val_k_smape: 118.7169
# Epoch 14/40
# 7s - loss: 1.1837 - k_smape: 112.8303 - val_loss: 1.0371 - val_k_smape: 118.0147
# Epoch 15/40
# 7s - loss: 1.1814 - k_smape: 112.6425 - val_loss: 1.0149 - val_k_smape: 115.2619
# Epoch 16/40
# 7s - loss: 1.1848 - k_smape: 112.9115 - val_loss: 1.0615 - val_k_smape: 119.4298
# Epoch 17/40
# 7s - loss: 1.1813 - k_smape: 112.4714 - val_loss: 1.0499 - val_k_smape: 124.4870
# Epoch 18/40
# 7s - loss: 1.1799 - k_smape: 112.5272 - val_loss: 1.0285 - val_k_smape: 119.9587
# Epoch 19/40
# 7s - loss: 1.1737 - k_smape: 112.1798 - val_loss: 1.0305 - val_k_smape: 120.7644
# Epoch 20/40
# 7s - loss: 1.1763 - k_smape: 112.1131 - val_loss: 1.0386 - val_k_smape: 119.3296
# Epoch 21/40
# 7s - loss: 1.1740 - k_smape: 111.8551 - val_loss: 1.0368 - val_k_smape: 119.0983
# Epoch 22/40
# 7s - loss: 1.1702 - k_smape: 111.8604 - val_loss: 1.0439 - val_k_smape: 118.6894
# Epoch 23/40
# 7s - loss: 1.1649 - k_smape: 111.6954 - val_loss: 1.0138 - val_k_smape: 116.8404
# Epoch 24/40
# 7s - loss: 1.1681 - k_smape: 111.7296 - val_loss: 1.0291 - val_k_smape: 116.5722
# Epoch 25/40
# 7s - loss: 1.1652 - k_smape: 111.3773 - val_loss: 1.0467 - val_k_smape: 120.4115
# Epoch 26/40
# 7s - loss: 1.1641 - k_smape: 111.4725 - val_loss: 1.0384 - val_k_smape: 116.0947
# Epoch 27/40
# 7s - loss: 1.1908 - k_smape: 112.3998 - val_loss: 1.0482 - val_k_smape: 119.4721
# Epoch 28/40
# 7s - loss: 1.1738 - k_smape: 111.4911 - val_loss: 1.0600 - val_k_smape: 121.8160
# Epoch 29/40
# 7s - loss: 1.1627 - k_smape: 111.0274 - val_loss: 1.0737 - val_k_smape: 119.9670
# Epoch 30/40
# 7s - loss: 1.1612 - k_smape: 111.1381 - val_loss: 1.0029 - val_k_smape: 115.2931
# Epoch 31/40
# 7s - loss: 1.1545 - k_smape: 110.9743 - val_loss: 1.0474 - val_k_smape: 119.5007
# Epoch 32/40
# 7s - loss: 1.1545 - k_smape: 110.9299 - val_loss: 1.0222 - val_k_smape: 115.9657
# Epoch 33/40
# 7s - loss: 1.1582 - k_smape: 111.0143 - val_loss: 1.0506 - val_k_smape: 116.9857
# Epoch 34/40
# 7s - loss: 1.1549 - k_smape: 110.9090 - val_loss: 1.0271 - val_k_smape: 117.9459
# Epoch 35/40
# 7s - loss: 1.1553 - k_smape: 110.6873 - val_loss: 1.0498 - val_k_smape: 118.6501
# Epoch 36/40
# 7s - loss: 1.1502 - k_smape: 110.3486 - val_loss: 1.0331 - val_k_smape: 116.7545
# Epoch 37/40
# 7s - loss: 1.1473 - k_smape: 110.5803 - val_loss: 1.0276 - val_k_smape: 117.4953
# Epoch 38/40
# 7s - loss: 1.1458 - k_smape: 110.4264 - val_loss: 1.0435 - val_k_smape: 119.3523
# Epoch 39/40
# 7s - loss: 1.1447 - k_smape: 110.2897 - val_loss: 1.0181 - val_k_smape: 115.7353
# Epoch 40/40
# 7s - loss: 1.1457 - k_smape: 110.1662 - val_loss: 1.0421 - val_k_smape: 120.0373
# -- Group: 3 / 6 --
# Train on 68055 samples, validate on 7562 samples
# Epoch 1/40
# 12s - loss: 1.3414 - k_smape: 108.7192 - val_loss: 1.1052 - val_k_smape: 109.3919
# Epoch 2/40
# 12s - loss: 1.2467 - k_smape: 101.0480 - val_loss: 1.0867 - val_k_smape: 107.8312
# Epoch 3/40
# 12s - loss: 1.2246 - k_smape: 99.2814 - val_loss: 1.1133 - val_k_smape: 106.1832
# Epoch 4/40
# 12s - loss: 1.2174 - k_smape: 98.6529 - val_loss: 1.1100 - val_k_smape: 106.8840
# Epoch 5/40
# 12s - loss: 1.2080 - k_smape: 98.0660 - val_loss: 1.1167 - val_k_smape: 106.6821
# Epoch 6/40
# 12s - loss: 1.2010 - k_smape: 97.6392 - val_loss: 1.1451 - val_k_smape: 106.9102
# Epoch 7/40
# 12s - loss: 1.1980 - k_smape: 97.4123 - val_loss: 1.1349 - val_k_smape: 107.3595
# Epoch 8/40
# 12s - loss: 1.1950 - k_smape: 97.1991 - val_loss: 1.1184 - val_k_smape: 105.5016
# Epoch 9/40
# 12s - loss: 1.1897 - k_smape: 96.9652 - val_loss: 1.1279 - val_k_smape: 108.1311
# Epoch 10/40
# 12s - loss: 1.1816 - k_smape: 96.7293 - val_loss: 1.1281 - val_k_smape: 108.6414
# Epoch 11/40
# 12s - loss: 1.1860 - k_smape: 96.7304 - val_loss: 1.0687 - val_k_smape: 102.2165
# Epoch 12/40
# 12s - loss: 1.1830 - k_smape: 96.4148 - val_loss: 1.1259 - val_k_smape: 105.6032
# Epoch 13/40
# 12s - loss: 1.1814 - k_smape: 96.4358 - val_loss: 1.0864 - val_k_smape: 104.4487
# Epoch 14/40
# 12s - loss: 1.1788 - k_smape: 96.2510 - val_loss: 1.1168 - val_k_smape: 104.8039
# Epoch 15/40
# 12s - loss: 1.1783 - k_smape: 96.2020 - val_loss: 1.1501 - val_k_smape: 106.3028
# Epoch 16/40
# 12s - loss: 1.1733 - k_smape: 96.1219 - val_loss: 1.1069 - val_k_smape: 105.7774
# Epoch 17/40
# 12s - loss: 1.1708 - k_smape: 96.0001 - val_loss: 1.1261 - val_k_smape: 106.3349
# Epoch 18/40
# 12s - loss: 1.1720 - k_smape: 95.9257 - val_loss: 1.1287 - val_k_smape: 105.4905
# Epoch 19/40
# 12s - loss: 1.1684 - k_smape: 95.7186 - val_loss: 1.1327 - val_k_smape: 104.8238
# Epoch 20/40
# 12s - loss: 1.1672 - k_smape: 95.4624 - val_loss: 1.1040 - val_k_smape: 105.2602
# Epoch 21/40
# 12s - loss: 1.1635 - k_smape: 95.7087 - val_loss: 1.1222 - val_k_smape: 105.4165
# Epoch 22/40
# 12s - loss: 1.1637 - k_smape: 95.5920 - val_loss: 1.1280 - val_k_smape: 106.4469
# Epoch 23/40
# 12s - loss: 1.1644 - k_smape: 95.5965 - val_loss: 1.1134 - val_k_smape: 103.8025
# Epoch 24/40
# ...
# Epoch 9/40
# 12s - loss: 1.1909 - k_smape: 96.7691 - val_loss: 1.1092 - val_k_smape: 104.8063
# Epoch 10/40
# 12s - loss: 1.1845 - k_smape: 96.3889 - val_loss: 1.0722 - val_k_smape: 104.6982
# Epoch 11/40
# 12s - loss: 1.1830 - k_smape: 96.4033 - val_loss: 1.0797 - val_k_smape: 103.6761
# Epoch 12/40
# 12s - loss: 1.1835 - k_smape: 96.1563 - val_loss: 1.1049 - val_k_smape: 104.5527
# Epoch 13/40
# 12s - loss: 1.1778 - k_smape: 96.0410 - val_loss: 1.0674 - val_k_smape: 102.6217
# Epoch 14/40
# 12s - loss: 1.1725 - k_smape: 95.8961 - val_loss: 1.1021 - val_k_smape: 105.2544
# Epoch 15/40
# 12s - loss: 1.1730 - k_smape: 95.6023 - val_loss: 1.0854 - val_k_smape: 103.6231
# Epoch 16/40
# 12s - loss: 1.1735 - k_smape: 95.6839 - val_loss: 1.1153 - val_k_smape: 105.7678
# Epoch 17/40
# 12s - loss: 1.1690 - k_smape: 95.4633 - val_loss: 1.1010 - val_k_smape: 105.5593
# Epoch 18/40
# 12s - loss: 1.1648 - k_smape: 95.3509 - val_loss: 1.0856 - val_k_smape: 103.8357
# Epoch 19/40
# 12s - loss: 1.1646 - k_smape: 95.3069 - val_loss: 1.1187 - val_k_smape: 107.1549
# Epoch 20/40
# 12s - loss: 1.1616 - k_smape: 95.0618 - val_loss: 1.1112 - val_k_smape: 105.1382
# Epoch 21/40
# 12s - loss: 1.1609 - k_smape: 95.1860 - val_loss: 1.1263 - val_k_smape: 105.3657
# Epoch 22/40
# 12s - loss: 1.1605 - k_smape: 94.9141 - val_loss: 1.0869 - val_k_smape: 103.7459
# Epoch 23/40
# 12s - loss: 1.1556 - k_smape: 94.9814 - val_loss: 1.0890 - val_k_smape: 104.7957
# Epoch 24/40
# 12s - loss: 1.1535 - k_smape: 94.8051 - val_loss: 1.1109 - val_k_smape: 103.9516
# Epoch 25/40
# 12s - loss: 1.1529 - k_smape: 94.7543 - val_loss: 1.0762 - val_k_smape: 102.4609
# Epoch 26/40
# 12s - loss: 1.1483 - k_smape: 94.5649 - val_loss: 1.1089 - val_k_smape: 103.6031
# Epoch 27/40
# 12s - loss: 1.1490 - k_smape: 94.6786 - val_loss: 1.1060 - val_k_smape: 105.7472
# Epoch 28/40
# 12s - loss: 1.1503 - k_smape: 94.5918 - val_loss: 1.1080 - val_k_smape: 105.9796
# Epoch 29/40
# 12s - loss: 1.1488 - k_smape: 94.4350 - val_loss: 1.1155 - val_k_smape: 104.8262
# Epoch 30/40
# 12s - loss: 1.1417 - k_smape: 94.4831 - val_loss: 1.0927 - val_k_smape: 104.4803
# Epoch 31/40
# 12s - loss: 1.1435 - k_smape: 94.4600 - val_loss: 1.0848 - val_k_smape: 103.2685
# Epoch 32/40
# 12s - loss: 1.1454 - k_smape: 94.4451 - val_loss: 1.0779 - val_k_smape: 103.7935
# Epoch 33/40
# 12s - loss: 1.1406 - k_smape: 94.4212 - val_loss: 1.0784 - val_k_smape: 103.2328
# Epoch 34/40
# 12s - loss: 1.1377 - k_smape: 94.1915 - val_loss: 1.0878 - val_k_smape: 104.9959
# Epoch 35/40
# 12s - loss: 1.1378 - k_smape: 94.0624 - val_loss: 1.1015 - val_k_smape: 103.6034
# Epoch 36/40
# 12s - loss: 1.1361 - k_smape: 94.1653 - val_loss: 1.0928 - val_k_smape: 103.7661
# Epoch 37/40
# 12s - loss: 1.1338 - k_smape: 93.9732 - val_loss: 1.0849 - val_k_smape: 104.4933
# Epoch 38/40
# 12s - loss: 1.1341 - k_smape: 93.9127 - val_loss: 1.1090 - val_k_smape: 105.2937
# Epoch 39/40
# 12s - loss: 1.1324 - k_smape: 93.8824 - val_loss: 1.0714 - val_k_smape: 103.9428
# Epoch 40/40
# 12s - loss: 1.1316 - k_smape: 93.9964 - val_loss: 1.0865 - val_k_smape: 103.8088
# -- Group: 4 / 6 --
# Train on 666 samples, validate on 74 samples
# Epoch 1/60
# 0s - loss: 2.9099 - k_smape: 155.7184 - val_loss: 2.8345 - val_k_smape: 139.9095
# Epoch 2/60
# 0s - loss: 2.5309 - k_smape: 136.0458 - val_loss: 2.8222 - val_k_smape: 138.6837
# Epoch 3/60
# 0s - loss: 2.3406 - k_smape: 130.3185 - val_loss: 2.2122 - val_k_smape: 122.8424
# Epoch 4/60
# 0s - loss: 2.1895 - k_smape: 124.7655 - val_loss: 2.2230 - val_k_smape: 122.9739
# Epoch 5/60
# 0s - loss: 2.1345 - k_smape: 119.5827 - val_loss: 1.9016 - val_k_smape: 118.5221
# Epoch 6/60
# 0s - loss: 1.9808 - k_smape: 117.0789 - val_loss: 2.1335 - val_k_smape: 120.1603
# Epoch 7/60
# 0s - loss: 1.9257 - k_smape: 114.4502 - val_loss: 1.7100 - val_k_smape: 113.1681
# Epoch 8/60
# 0s - loss: 1.8420 - k_smape: 110.0320 - val_loss: 1.9869 - val_k_smape: 114.5743
# Epoch 9/60
# 0s - loss: 1.8292 - k_smape: 107.9983 - val_loss: 1.8374 - val_k_smape: 111.5411
# Epoch 10/60
# 0s - loss: 1.8005 - k_smape: 106.8139 - val_loss: 1.7141 - val_k_smape: 110.2012
# Epoch 11/60
# 0s - loss: 1.7189 - k_smape: 104.0447 - val_loss: 1.7879 - val_k_smape: 111.5337
# Epoch 12/60
# 0s - loss: 1.7415 - k_smape: 103.5684 - val_loss: 1.5978 - val_k_smape: 108.5319
# Epoch 13/60
# 0s - loss: 1.6730 - k_smape: 101.7298 - val_loss: 1.7624 - val_k_smape: 107.7522
# Epoch 14/60
# 0s - loss: 1.6311 - k_smape: 99.1363 - val_loss: 1.7981 - val_k_smape: 107.7349
# Epoch 15/60
# 0s - loss: 1.6543 - k_smape: 97.8303 - val_loss: 1.6111 - val_k_smape: 105.3448
# Epoch 16/60
# 0s - loss: 1.6405 - k_smape: 99.4172 - val_loss: 1.5278 - val_k_smape: 101.2775
# Epoch 17/60
# 0s - loss: 1.6063 - k_smape: 96.2997 - val_loss: 1.6255 - val_k_smape: 104.1848
# Epoch 18/60
# 0s - loss: 1.5664 - k_smape: 94.1876 - val_loss: 1.7439 - val_k_smape: 102.2816
# Epoch 19/60
# 0s - loss: 1.5625 - k_smape: 93.1670 - val_loss: 1.7478 - val_k_smape: 102.7385
# Epoch 20/60
# 0s - loss: 1.5710 - k_smape: 93.7747 - val_loss: 1.4176 - val_k_smape: 97.6372
# Epoch 21/60
# 0s - loss: 1.5432 - k_smape: 92.1965 - val_loss: 1.5946 - val_k_smape: 102.7681
# Epoch 22/60
# 0s - loss: 1.5332 - k_smape: 91.7523 - val_loss: 1.7123 - val_k_smape: 100.0198
# Epoch 23/60
# 0s - loss: 1.5311 - k_smape: 90.1475 - val_loss: 1.7105 - val_k_smape: 101.5499
# Epoch 24/60
# 0s - loss: 1.5350 - k_smape: 91.1107 - val_loss: 1.4357 - val_k_smape: 96.9081
# Epoch 25/60
# 0s - loss: 1.6156 - k_smape: 90.1087 - val_loss: 1.5393 - val_k_smape: 96.5008
# Epoch 26/60
# 0s - loss: 1.5160 - k_smape: 88.7528 - val_loss: 1.6760 - val_k_smape: 100.3124
# Epoch 27/60
# 0s - loss: 1.5194 - k_smape: 90.2262 - val_loss: 1.3876 - val_k_smape: 96.1461
# Epoch 28/60
# 0s - loss: 1.4846 - k_smape: 88.6260 - val_loss: 1.6111 - val_k_smape: 98.5505
# Epoch 29/60
# 0s - loss: 1.4852 - k_smape: 88.4990 - val_loss: 1.3540 - val_k_smape: 94.2283
# Epoch 30/60
# 0s - loss: 1.4932 - k_smape: 88.0377 - val_loss: 1.5671 - val_k_smape: 93.9495
# Epoch 31/60
# 0s - loss: 1.5024 - k_smape: 85.3427 - val_loss: 1.8319 - val_k_smape: 97.9383
# Epoch 32/60
# 0s - loss: 1.5220 - k_smape: 89.9090 - val_loss: 1.4122 - val_k_smape: 96.2107
# Epoch 33/60
# 0s - loss: 1.4906 - k_smape: 87.8630 - val_loss: 1.8898 - val_k_smape: 102.7060
# Epoch 34/60
# 0s - loss: 1.5173 - k_smape: 90.3620 - val_loss: 1.3996 - val_k_smape: 90.5772
# Epoch 35/60
# 0s - loss: 1.4982 - k_smape: 83.3023 - val_loss: 1.6015 - val_k_smape: 96.3338
# Epoch 36/60
# 0s - loss: 1.4463 - k_smape: 86.7784 - val_loss: 1.3364 - val_k_smape: 93.7962
# Epoch 37/60
# 0s - loss: 1.4268 - k_smape: 85.8850 - val_loss: 1.6048 - val_k_smape: 94.1773
# Epoch 38/60
# 0s - loss: 1.4000 - k_smape: 83.4911 - val_loss: 1.3030 - val_k_smape: 89.2167
# Epoch 39/60
# 0s - loss: 1.4363 - k_smape: 84.8077 - val_loss: 1.5215 - val_k_smape: 97.5089
# Epoch 40/60
# 0s - loss: 1.4148 - k_smape: 86.6036 - val_loss: 1.3744 - val_k_smape: 89.8940
# Epoch 41/60
# 0s - loss: 1.3494 - k_smape: 82.1160 - val_loss: 1.4816 - val_k_smape: 88.7704
# Epoch 42/60
# 0s - loss: 1.4381 - k_smape: 82.5101 - val_loss: 1.4797 - val_k_smape: 91.9944
# Epoch 43/60
# 0s - loss: 1.3592 - k_smape: 84.6645 - val_loss: 1.3350 - val_k_smape: 88.5979
# Epoch 44/60
# 0s - loss: 1.3678 - k_smape: 80.9327 - val_loss: 1.4934 - val_k_smape: 90.8665
# Epoch 45/60
# 0s - loss: 1.3170 - k_smape: 81.9235 - val_loss: 1.3224 - val_k_smape: 86.4788
# Epoch 46/60
# 0s - loss: 1.3780 - k_smape: 81.5761 - val_loss: 1.3399 - val_k_smape: 90.2816
# Epoch 47/60
# 0s - loss: 1.3592 - k_smape: 82.1613 - val_loss: 1.2719 - val_k_smape: 86.3112
# Epoch 48/60
# 0s - loss: 1.3602 - k_smape: 81.1213 - val_loss: 1.5783 - val_k_smape: 89.6266
# Epoch 49/60
# 0s - loss: 1.3461 - k_smape: 80.8062 - val_loss: 1.3353 - val_k_smape: 89.0703
# Epoch 50/60
# 0s - loss: 1.4022 - k_smape: 82.1029 - val_loss: 1.3238 - val_k_smape: 89.5928
# Epoch 51/60
# 0s - loss: 1.3507 - k_smape: 80.9413 - val_loss: 1.5805 - val_k_smape: 91.4319
# Epoch 52/60
# 0s - loss: 1.3500 - k_smape: 82.0876 - val_loss: 1.3009 - val_k_smape: 86.3289
# Epoch 53/60
# 0s - loss: 1.3479 - k_smape: 80.2968 - val_loss: 1.4929 - val_k_smape: 91.1291
# Epoch 54/60
# 0s - loss: 1.3485 - k_smape: 82.8664 - val_loss: 1.2914 - val_k_smape: 85.3681
# Epoch 55/60
# 0s - loss: 1.3140 - k_smape: 79.0499 - val_loss: 1.2827 - val_k_smape: 84.7998
# Epoch 56/60
# 0s - loss: 1.3310 - k_smape: 79.2543 - val_loss: 1.3704 - val_k_smape: 89.3485
# Epoch 57/60
# 0s - loss: 1.3163 - k_smape: 82.2939 - val_loss: 1.2790 - val_k_smape: 86.5961
# Epoch 58/60
# 0s - loss: 1.3071 - k_smape: 79.1000 - val_loss: 1.4359 - val_k_smape: 86.4418
# Epoch 59/60
# 0s - loss: 1.3394 - k_smape: 78.9917 - val_loss: 1.4053 - val_k_smape: 88.8273
# Epoch 60/60
# 0s - loss: 1.2884 - k_smape: 79.0511 - val_loss: 1.2666 - val_k_smape: 86.3703
# -- Group: 5 / 6 --
# Train on 45 samples, validate on 6 samples
# Epoch 1/80
# 0s - loss: 6.9218 - k_smape: 176.8329 - val_loss: 4.8230 - val_k_smape: 165.6268
# Epoch 2/80
# 0s - loss: 6.6353 - k_smape: 167.5624 - val_loss: 4.6979 - val_k_smape: 158.5494
# Epoch 3/80
# 0s - loss: 6.3275 - k_smape: 155.0233 - val_loss: 4.5324 - val_k_smape: 149.7020
# Epoch 4/80
# 0s - loss: 6.1121 - k_smape: 148.4769 - val_loss: 4.3698 - val_k_smape: 143.8427
# Epoch 5/80
# 0s - loss: 5.7614 - k_smape: 140.1900 - val_loss: 4.1834 - val_k_smape: 138.3931
# Epoch 6/80
# 0s - loss: 5.9643 - k_smape: 137.6919 - val_loss: 4.0036 - val_k_smape: 135.3347
# Epoch 7/80
# 0s - loss: 5.8891 - k_smape: 132.0015 - val_loss: 3.8632 - val_k_smape: 132.5423
# Epoch 8/80
# 0s - loss: 5.7759 - k_smape: 129.6246 - val_loss: 3.7593 - val_k_smape: 129.8999
# Epoch 9/80
# 0s - loss: 5.6325 - k_smape: 131.0207 - val_loss: 3.6884 - val_k_smape: 127.8661
# Epoch 10/80
# 0s - loss: 5.4824 - k_smape: 129.3445 - val_loss: 3.6165 - val_k_smape: 127.3894
# Epoch 11/80
# 0s - loss: 5.3123 - k_smape: 131.1234 - val_loss: 3.5600 - val_k_smape: 127.1409
# Epoch 12/80
# 0s - loss: 5.2383 - k_smape: 127.3371 - val_loss: 3.5113 - val_k_smape: 126.7275
# Epoch 13/80
# 0s - loss: 5.3136 - k_smape: 130.2750 - val_loss: 3.4459 - val_k_smape: 125.4977
# Epoch 14/80
# 0s - loss: 5.1938 - k_smape: 129.3780 - val_loss: 3.3997 - val_k_smape: 124.6330
# Epoch 15/80
# 0s - loss: 5.1095 - k_smape: 127.7220 - val_loss: 3.3328 - val_k_smape: 123.7255
# Epoch 16/80
# 0s - loss: 4.8459 - k_smape: 122.7224 - val_loss: 3.2865 - val_k_smape: 123.3274
# Epoch 17/80
# 0s - loss: 4.9539 - k_smape: 123.5277 - val_loss: 3.2154 - val_k_smape: 122.0890
# Epoch 18/80
# 0s - loss: 4.7488 - k_smape: 123.1096 - val_loss: 3.1441 - val_k_smape: 120.2187
# Epoch 19/80
# 0s - loss: 4.5896 - k_smape: 119.9057 - val_loss: 3.0375 - val_k_smape: 118.3463
# Epoch 20/80
# 0s - loss: 4.5977 - k_smape: 118.3226 - val_loss: 2.8765 - val_k_smape: 115.8209
# Epoch 21/80
# 0s - loss: 4.6809 - k_smape: 117.9802 - val_loss: 2.6844 - val_k_smape: 113.0783
# Epoch 22/80
# 0s - loss: 4.5502 - k_smape: 114.7177 - val_loss: 2.5088 - val_k_smape: 110.5674
# Epoch 23/80
# 0s - loss: 4.5473 - k_smape: 113.4578 - val_loss: 2.3508 - val_k_smape: 108.5568
# Epoch 24/80
# 0s - loss: 4.4490 - k_smape: 111.1700 - val_loss: 2.2945 - val_k_smape: 108.0721
# Epoch 25/80
# 0s - loss: 4.4845 - k_smape: 113.3048 - val_loss: 2.2201 - val_k_smape: 106.9202
# Epoch 26/80
# 0s - loss: 4.3998 - k_smape: 112.3513 - val_loss: 2.1411 - val_k_smape: 106.0744
# Epoch 27/80
# 0s - loss: 4.3217 - k_smape: 109.7364 - val_loss: 2.0879 - val_k_smape: 106.1692
# Epoch 28/80
# 0s - loss: 4.4236 - k_smape: 112.4201 - val_loss: 2.0668 - val_k_smape: 107.1012
# Epoch 29/80
# 0s - loss: 4.0957 - k_smape: 108.2393 - val_loss: 2.0937 - val_k_smape: 107.8483
# Epoch 30/80
# 0s - loss: 4.4089 - k_smape: 111.1116 - val_loss: 2.1047 - val_k_smape: 107.0433
# Epoch 31/80
# 0s - loss: 4.1138 - k_smape: 109.9338 - val_loss: 2.1535 - val_k_smape: 105.2933
# Epoch 32/80
# 0s - loss: 4.0186 - k_smape: 106.3022 - val_loss: 2.1467 - val_k_smape: 103.4478
# Epoch 33/80
# 0s - loss: 3.8946 - k_smape: 105.0981 - val_loss: 2.0969 - val_k_smape: 101.5530
# Epoch 34/80
# 0s - loss: 3.8507 - k_smape: 102.0683 - val_loss: 1.9884 - val_k_smape: 99.8055
# Epoch 35/80
# 0s - loss: 3.8539 - k_smape: 99.9884 - val_loss: 1.8858 - val_k_smape: 98.6423
# Epoch 36/80
# 0s - loss: 3.8268 - k_smape: 100.8491 - val_loss: 1.7806 - val_k_smape: 98.1882
# Epoch 37/80
# 0s - loss: 3.6100 - k_smape: 96.5559 - val_loss: 1.7654 - val_k_smape: 98.4387
# Epoch 38/80
# 0s - loss: 3.7463 - k_smape: 102.0942 - val_loss: 1.7306 - val_k_smape: 98.8367
# Epoch 39/80
# 0s - loss: 3.6902 - k_smape: 98.5433 - val_loss: 1.6957 - val_k_smape: 99.2329
# Epoch 40/80
# 0s - loss: 3.6792 - k_smape: 100.8060 - val_loss: 1.6746 - val_k_smape: 99.0557
# Epoch 41/80
# 0s - loss: 3.8060 - k_smape: 97.2994 - val_loss: 1.8366 - val_k_smape: 99.6316
# Epoch 42/80
# 0s - loss: 3.8566 - k_smape: 99.0484 - val_loss: 1.9237 - val_k_smape: 98.2863
# Epoch 43/80
# 0s - loss: 3.6826 - k_smape: 95.8442 - val_loss: 1.9903 - val_k_smape: 96.7715
# Epoch 44/80
# 0s - loss: 3.6077 - k_smape: 94.2719 - val_loss: 1.9653 - val_k_smape: 95.2987
# Epoch 45/80
# 0s - loss: 3.5020 - k_smape: 93.9429 - val_loss: 1.8628 - val_k_smape: 93.9656
# Epoch 46/80
# 0s - loss: 3.5754 - k_smape: 92.7111 - val_loss: 1.7164 - val_k_smape: 92.7232
# Epoch 47/80
# 0s - loss: 3.3134 - k_smape: 89.3573 - val_loss: 1.5605 - val_k_smape: 92.0747
# Epoch 48/80
# 0s - loss: 3.3645 - k_smape: 90.1838 - val_loss: 1.3881 - val_k_smape: 91.4874
# Epoch 49/80
# 0s - loss: 3.3008 - k_smape: 87.9613 - val_loss: 1.4260 - val_k_smape: 92.0511
# Epoch 50/80
# 0s - loss: 3.2249 - k_smape: 86.3302 - val_loss: 1.4750 - val_k_smape: 92.4846
# Epoch 51/80
# 0s - loss: 3.3670 - k_smape: 86.1496 - val_loss: 1.5694 - val_k_smape: 92.6860
# Epoch 52/80
# 0s - loss: 3.3468 - k_smape: 89.8574 - val_loss: 1.5662 - val_k_smape: 92.3463
# Epoch 53/80
# 0s - loss: 3.2304 - k_smape: 85.8899 - val_loss: 1.6654 - val_k_smape: 91.8939
# Epoch 54/80
# 0s - loss: 3.5562 - k_smape: 89.5928 - val_loss: 1.6520 - val_k_smape: 90.8550
# Epoch 55/80
# 0s - loss: 3.3644 - k_smape: 86.0408 - val_loss: 1.5873 - val_k_smape: 90.2188
# Epoch 56/80
# 0s - loss: 3.1366 - k_smape: 85.3428 - val_loss: 1.4604 - val_k_smape: 89.3478
# Epoch 57/80
# 0s - loss: 3.2489 - k_smape: 82.2913 - val_loss: 1.3465 - val_k_smape: 88.5499
# Epoch 58/80
# 0s - loss: 3.1297 - k_smape: 80.3302 - val_loss: 1.3160 - val_k_smape: 88.0277
# Epoch 59/80
# 0s - loss: 3.2570 - k_smape: 82.7053 - val_loss: 1.2447 - val_k_smape: 87.0796
# Epoch 60/80
# 0s - loss: 3.0881 - k_smape: 81.7577 - val_loss: 1.1527 - val_k_smape: 86.1488
# Epoch 61/80
# 0s - loss: 3.1679 - k_smape: 82.6109 - val_loss: 1.0992 - val_k_smape: 85.9334
# Epoch 62/80
# 0s - loss: 3.1629 - k_smape: 80.7936 - val_loss: 1.2652 - val_k_smape: 87.5440
# Epoch 63/80
# 0s - loss: 3.1033 - k_smape: 84.9215 - val_loss: 1.4209 - val_k_smape: 87.7573
# Epoch 64/80
# 0s - loss: 2.9922 - k_smape: 80.7698 - val_loss: 1.4187 - val_k_smape: 87.2817
# Epoch 65/80
# 0s - loss: 3.1773 - k_smape: 80.6032 - val_loss: 1.3567 - val_k_smape: 86.6549
# Epoch 66/80
# 0s - loss: 3.3021 - k_smape: 83.6172 - val_loss: 1.1668 - val_k_smape: 86.1021
# Epoch 67/80
# 0s - loss: 3.0098 - k_smape: 78.3534 - val_loss: 1.0392 - val_k_smape: 84.5291
# Epoch 68/80
# 0s - loss: 2.8395 - k_smape: 77.5913 - val_loss: 1.0035 - val_k_smape: 83.9673
# Epoch 69/80
# 0s - loss: 3.0662 - k_smape: 78.9736 - val_loss: 0.9907 - val_k_smape: 83.8179
# Epoch 70/80
# 0s - loss: 3.1807 - k_smape: 79.5468 - val_loss: 1.1484 - val_k_smape: 85.5849
# Epoch 71/80
# 0s - loss: 2.8957 - k_smape: 76.3272 - val_loss: 1.3088 - val_k_smape: 86.6483
# Epoch 72/80
# 0s - loss: 3.1157 - k_smape: 75.1486 - val_loss: 1.3497 - val_k_smape: 86.1476
# Epoch 73/80
# 0s - loss: 2.8485 - k_smape: 75.8647 - val_loss: 1.6038 - val_k_smape: 87.9979
# Epoch 74/80
# 0s - loss: 3.0814 - k_smape: 76.2251 - val_loss: 1.8019 - val_k_smape: 89.6890
# Epoch 75/80
# 0s - loss: 3.0236 - k_smape: 78.5697 - val_loss: 1.8828 - val_k_smape: 91.0503
# Epoch 76/80
# 0s - loss: 2.8694 - k_smape: 79.6493 - val_loss: 1.7199 - val_k_smape: 88.7815
# Epoch 77/80
# 0s - loss: 3.0247 - k_smape: 75.7716 - val_loss: 1.4411 - val_k_smape: 87.9717
# Epoch 78/80
# 0s - loss: 2.9315 - k_smape: 82.1304 - val_loss: 1.1294 - val_k_smape: 85.1476
# Epoch 79/80
# 0s - loss: 2.8912 - k_smape: 75.1286 - val_loss: 1.0410 - val_k_smape: 84.7392
# Epoch 80/80
# 0s - loss: 2.8606 - k_smape: 75.5176 - val_loss: 0.9742 - val_k_smape: 83.7192
# Wall time: 1h 6min 50s

# %% [markdown]
# ### Training History

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['loss'], label=str(run))
        plt.title('Mean Squared Error (Train) - Group' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['val_loss'], label=str(run))
        plt.title('Mean Squared Error (Validation) - Group' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['k_smape'], label=str(run))
        plt.title('SMAPE (Train) - Group' + str(gp))
        plt.legend(); plt.show()

# %%
for gp, ep in zip(gp_list, epochs_list):
    if ep:
        for run in ens_list:
            hist = hists_ens[run][gp]
            plt.plot(hist.history['val_k_smape'], label=str(run))
        plt.title('SMAPE (Validation) - Group' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep:
        plt.plot(hist.history['loss'], label='train')
        plt.plot(hist.history['val_loss'], label='validation')
        plt.title('Mean Squared Error - ' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep:
        plt.plot(hist.history['k_smape'], label='train')
        plt.plot(hist.history['val_k_smape'], label='validation')
        plt.title('SMAPE - ' + str(gp))
        plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['loss'], label=gp)
plt.title('Mean Squared Error - train')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['val_loss'], label=gp)
plt.title('Mean Squared Error - validation')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['k_smape'], label=gp)
plt.title('SMAPE - train')
plt.legend(); plt.show()

# %%
for (hist, gp, ep) in zip(hists, gp_list, epochs_list):
    if ep: plt.plot(hist.history['val_k_smape'], label=gp)
plt.title('SMAPE - validation')
plt.legend(); plt.show()

# %% [markdown]
# ### More Training

# %% [markdown]
# epochs_list2 = [0,10,0,0,10]

# %% [markdown]
# hists2 = []
# for (gp, model, X_in, Y_in, epochs) in zip(gp_list, models,
#                                    X_input_list, Y_input_list,
#                                    epochs_list2):
#     hist = model.fit(X_in, Y_in, batch_size=128,
#                      epochs=epochs,
#                      validation_split=0.05)
#     #validation_data=(X_val, Y_val))
#     hists2.append(hist)

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['loss'], label='train')
#         plt.plot(hist.history['val_loss'], label='validation')
#         plt.title('Mean Squared Error - ' + str(gp))
#         plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['k_smape'], label='train')
#         plt.plot(hist.history['val_k_smape'], label='validation')
#         plt.title('SMAPE - ' + str(gp))
#         plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs:
#         plt.plot(hist.history['loss'], label=gp)
# plt.title('Mean Squared Error - train')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['val_loss'], label=gp)
# plt.title('Mean Squared Error - validation')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['k_smape'], label=gp)
# plt.title('SMAPE - train')
# plt.legend(); plt.show()

# %% [markdown]
# for (hist, gp, epochs) in zip(hists2, gp_list, epochs_list2):
#     if epochs: plt.plot(hist.history['val_k_smape'], label=gp)
# plt.title('SMAPE - validation')
# plt.legend(); plt.show()

# %% [markdown]
# ### Predict for Validation set

# %% [markdown]
# Y_val_pred = model.predict(X_val)

# %% [markdown]
# examine(Y_val_pred)

# %% [markdown]
# Y_val_pred_ori = unlog(untransform(Y_val_pred, val_center, val_scale))

# %% [markdown]
# #SMAPE of the validation set
# smape(Y_val_ori, Y_val_pred_ori)

# %% [markdown]
# def view_val(i):
#     plt.plot(Y_val_pred_ori[i])
#     plt.plot(Y_val_ori[i])
#     plt.plot(X_val_ori[i])
#     plt.show()

# %% [markdown]
# view_val(10)

# %% [markdown]
# ### Evaluation using Output Set

# %% [markdown]
# if test_length:
#     for (gp, model, X, Y) in zip(gp_list, models,
#                                  X_output_list, Y_output_list):
#         print()
#         print(model.evaluate(X,Y))

# %% [markdown]
# ### Predict for Output Set

# %%
Y_output_pred_list_ens = []
for models, run in zip(models_ens, ens_list):
    print('Run', run, end=': ')
    Y_output_pred_list = []
    for (gp, model, X, A) in zip(gp_list, models, X_output_list, A_output_list):
        print(gp, end=' ')
        Y_output_pred_list.append(model.predict([X,A]))
    Y_output_pred_list_ens.append(Y_output_pred_list)
    print('')
# Out:
# Run 0: 0 1 2 3 4 5
# Run 1: 0 1 2 3 4 5
# Run 2: 0 1 2 3 4 5
# Run 3: 0 1 2 3 4 5
# Run 4: 0 1 2 3 4 5

# %% [markdown]
# Find the original index

# %%
output_index_range = np.arange(len(output_gp)); #output_index_range

# %%
# list for original index
output_index_list = [output_index_range[output_gp == gp] 
                     for gp in gp_list]

# %%
for o in output_index_list:
    print(o.shape)
# Out:
# (1879,)
# (23085,)
# (43691,)
# (75617,)
# (740,)
# (51,)

# %%
output_index_list_comb = np.concatenate(output_index_list)
output_index_list_comb
# Out:
# array([  1475,   3412,   3467, ..., 123025, 139119, 140151])

# %%
Y_output_pred_ens = []
for Y_output_pred_list in Y_output_pred_list_ens:
    Y_output_pred_comb = np.concatenate(Y_output_pred_list)
    Y_output_pred_temp = [0]*len(output_index_list_comb)

    for index, y in zip(output_index_list_comb, Y_output_pred_comb):
        Y_output_pred_temp[index] = y

    Y_output_pred = np.array(Y_output_pred_temp)  # make it an numpy array (which will also make a copy)
    Y_output_pred_ens.append(Y_output_pred)

del Y_output_pred_temp

# %%
# Inverse transform Y of output

Y_output_pred_ori_ens = []
for Y_output_pred in Y_output_pred_ens:
    Y_output_pred_ori = unlog(untransform(Y_output_pred, 
                                          output_center, output_scale))
    Y_output_pred_ori_ens.append(Y_output_pred_ori)

# %% [markdown]
# #### Check predict output

# %% [markdown]
# Y_output_pred

# %% [markdown]
# Y_output_pred_ori

# %% [markdown]
# examine(Y_output_pred)

# %% [markdown]
# examine(Y_output_pred_ori)

# %% [markdown]
# view(X_output_ori[126420])

# %% [markdown]
# ### Model Score

# %%
# SMAPE scores for the model
if test_length:
    model_smape_ens = []
    model_smape_0_ens = []
    for Y_output_pred_ori in Y_output_pred_ori_ens:
        model_smape = smape(Y_output_raw, Y_output_pred_ori) # SMAPE score excluding nan (Correct one)
        model_smape_0 = smape(Y_output_ori, Y_output_pred_ori) # SMAPE assuming nan == 0
        print(model_smape, model_smape_0)
        
        model_smape_ens.append(model_smape)
        model_smape_0_ens.append(model_smape_0)
    model_smape_ens_mean = np.mean(model_smape_ens)
    model_smape_0_ens_mean = np.mean(model_smape_0_ens)
    print('-----------')
    print(model_smape_ens_mean, model_smape_0_ens_mean)
# Out:
# 38.7819742672 42.1048932826
# 38.7975800896 42.4873573864
# 38.8004777012 42.6563200238
# 38.7982009591 42.4478964343
# 38.8994486564 42.5470035282
# -----------
# 38.8155363347 42.4486941311

# %%
# SMAPE score for Fibonacci median
if test_length:
    fib_smape = smape(Y_output_raw, Y_output_fib)
    print(fib_smape)
# Out:
# 40.4041165988

# %% [markdown]
# ### Group Scores
# For self-testing stage only

# %%
# Prediction Y_output in group
Y_output_pred_ori_list_ens = [[Y_output_pred_ori[output_gp == gp] for gp in gp_list]
                              for Y_output_pred_ori in Y_output_pred_ori_ens]
#Y_output_pred_ori_list = [Y_output_pred_ori[output_gp == gp] for gp in gp_list]
Y_output_pred_ori_list = Y_output_pred_ori_list_ens[-1]  # in case you want to see one of them

# %%
# True Y_output in group
if test_length:
    # untransformed Y_output with nan replaced by 0
    Y_output_ori_list = [Y_output_ori[output_gp == gp] for gp in gp_list]
    
    # untransformed Y_output_ori with nan (for SMAPE estimation)
    Y_output_raw_list = [Y_output_raw[output_gp == gp] for gp in gp_list]

# %%
tot_n = len(output_gp); tot_n  # total number of pages in output set
# Out:
# 145063

# %%
def count_not_nan(data):
    return np.count_nonzero(~np.isnan(data))

# %% [markdown]
# if test_length: print(count_not_nan(Y_output_raw))

# %%
# Group SMAPE scores
if test_length:
    gp_n = [len(Y) for Y in Y_output_raw_list]
    # SMAPE assuming nan == 0
    #gp_smape_0 = [smape(Y, Y_p) for Y, Y_p 
    #              in zip(Y_output_ori_list, Y_output_pred_ori_list)]
    
    # SMAPE with nan values ignored (used by Kaggle)
    gp_smape_ens = [[smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_list)]
                    for Y_output_pred_ori_list in Y_output_pred_ori_list_ens]
    gp_smape = gp_smape_ens[-1]
    #gp_smape = [smape(Y, Y_p) for Y, Y_p 
    #            in zip(Y_output_raw_list, Y_output_pred_ori_list)]
    
    n_not_nan = count_not_nan(Y_output_raw)
    n_not_nan_gp = [count_not_nan(Y) for Y in Y_output_raw_list]
    n_not_nan_ratio_gp = [n / (len(Y) * len(Y[0])) for Y,n 
                          in zip(Y_output_raw_list, n_not_nan_gp)]
    
    # SMAPE contribution
    #gp_smape_sum = [s * n for n, s in zip(gp_smape, n_not_nan_gp)]
    #gp_smape_cont = [s / n_not_nan for s in gp_smape_sum]

# %% [markdown]
# if test_length:
#     print('[Group SMAPE]')
#     print('W/ Nan, Nan=0, Contribution, Pages, Non-nan Ratio')
#     for score, score_0, c, n, nr in zip(gp_smape, gp_smape_0,
#                                     gp_smape_cont, gp_n,
#                                     n_not_nan_ratio_gp):
#         print('%6.2f' % score, '%6.2f' % score_0, '       %6.2f' % c, '%6d' % n,
#               '        %6.3f' % nr)
#     print('-------------------------------------------------')
#     print('%6.2f' % model_smape, '%6.2f' % model_smape_0)

# %% [markdown]
# n_not_nan_gp

# %% [markdown]
# ### Individual Page Scores

# %%
if test_length:
    smape_Y_pred_ens = []
    #smape_Y_pred_na = np.array([smape(yp, y) for yp, y 
    #                            in zip(Y_output_pred_ori, Y_output_raw)])
    for Y_output_pred_ori in Y_output_pred_ori_ens:
        smape_Y_pred = np.nan_to_num(np.array([smape(yp, y) for yp, y 
                                               in zip(Y_output_pred_ori, Y_output_raw)]))
        smape_Y_pred_ens.append(smape_Y_pred)
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice
#   """

# %%
if test_length:
    for smape_Y_pred in smape_Y_pred_ens:
        plt.hist(smape_Y_pred, bins=40, alpha=0.4)
        #plt.yscale('log')
    plt.show()

# %% [markdown]
# ### SMAPE for the Model

# %%
if test_length:
    smape_Y_pred_list_ens = []
    for smape_Y_pred in smape_Y_pred_ens:
        smape_Y_pred_list = [smape_Y_pred[output_gp == gp] for gp in gp_list]
        smape_Y_pred_list_ens.append(smape_Y_pred_list)

# %%
if test_length:
    for i,s in zip(range(len(smape_Y_pred_list)),smape_Y_pred_list):
        plt.hist(s, bins=40, normed=True, alpha=0.6, label=str(i))
    #plt.yscale('log')
    plt.legend()
    plt.show()

# %% [markdown]
# if test_length:
#     for i,s in zip(range(len(smape_Y_pred_list)),smape_Y_pred_list):
#         plt.hist(s, bins=40, normed=True, alpha=0.6, label=str(i))
#     #plt.yscale('log')
#     plt.ylim([0,0.05])
#     plt.legend()
#     plt.show()

# %%
if test_length:
    for i,s in zip(range(len(smape_Y_pred_list[1:])),smape_Y_pred_list[1:]):
        plt.hist(s, bins=40, alpha=0.6, label=str(i+1))
    #plt.yscale('log')
    #plt.ylim([0,0.05])
    plt.legend()
    plt.show()

# %%
if test_length:
    for i,s in zip(range(len(smape_Y_pred_list)),smape_Y_pred_list):
        plt.hist(s, bins=40, alpha=0.6)
        plt.title('gp = '+str(i))
        plt.show()
    #plt.yscale('log')
    #plt.ylim([0,0.05])

# %% [markdown]
# ### SMAPE for Fibonacci median

# %%
Y_output_fib_list = [Y_output_fib[output_gp == gp] for gp in gp_list]

# %%
# Group SMAPE for Fib.
if test_length:
    gp_smape_fib = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_fib_list)]

# %%
# Individual SMAPE for Fib.
if test_length:
    #smape_Y_fib_na = np.array([smape(yp, y) for yp, y 
    #                           in zip(Y_output_fib, Y_output_raw)])
    smape_Y_fib = np.nan_to_num(np.array([smape(yp, y) for yp, y 
                                          in zip(Y_output_fib, Y_output_raw)]))

    smape_Y_fib_list = [smape_Y_fib[output_gp == gp] for gp in gp_list]
# The above two cells can be combined.
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: Mean of empty slice
#   """

# %% [markdown]
# #### SMAPE distribution for Fib

# %%
if test_length:
    plt.hist(smape_Y_fib, bins=40, alpha=0.6)
    plt.hist(smape_Y_pred, bins=40, alpha=0.6)
    #plt.yscale('log')
    plt.show()

# %% [markdown]
# if test_length:
#     for i,s in zip(range(len(smape_Y_fib_list)),smape_Y_fib_list):
#         plt.hist(s, bins=40, normed=True, alpha=0.6, label=str(i))
#     #plt.yscale('log')
#     #plt.ylim([0,0.05])
#     plt.legend()
#     plt.show()

# %% [markdown]
# if test_length:
#     for i,s in zip(range(len(smape_Y_fib_list[1:])),smape_Y_fib_list[1:]):
#         plt.hist(s, bins=40, alpha=0.6, label=str(i+1))
#     #plt.yscale('log')
#     #plt.ylim([0,0.05])
#     plt.legend()
#     plt.show()

# %% [markdown]
# if test_length:
#     for i in range(len(smape_Y_fib_list)):
#         plt.hist(smape_Y_pred_list[i], bins=40, alpha=0.7, label='Model')
#         plt.hist(smape_Y_fib_list[i], bins=40, alpha=0.5, label='Fib')
#         plt.title('gp = '+str(i))
#         plt.legend()
#         plt.show()
#     #plt.yscale('log')
#     #plt.ylim([0,0.05])

# %% [markdown]
# ### Models vs Fibonacci Median

# %% [markdown]
# if test_length:  # gp_score
#     print('#### ' + model_name)
#     print('', end='|')
#     print('N_pages ', 'Fibonacci', sep='|', end='|')
#     for run in ens_list: print(' Model', run, end=' |')
#     print('')
#     print('', end='|')
#     print('--------', '---------', sep='|', end='|')
#     for run in ens_list: print('---------', end='|')
#     print('')
#     for gp in gp_list:
#         print('', end='|')
#         print(' %6d ' % gp_n[gp], end='|')
#         print(' %7.3f ' % gp_smape_fib[gp], end='|')
#         for run in ens_list:
#             print(' %7.3f ' % gp_smape_ens[run][gp], end='|')
#         print('')

# %% [markdown]
# #### model_10_Modified_CNN_0_median_stdev
# |N_pages |Fibonacci| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 161.576 | 156.487 | 166.024 | 139.355 | 159.019 |
# |  23085 |  61.354 |  64.389 |  64.273 |  64.008 |  63.988 |  64.148 |
# |  43691 |  40.612 |  39.684 |  39.842 |  39.969 |  39.808 |  40.173 |
# |  75617 |  34.284 |  29.538 |  29.575 |  29.454 |  29.907 |  29.573 |
# |    740 |  35.621 |  33.564 |  33.710 |  33.397 |  33.666 |  33.965 |
# |     51 |  20.224 |  16.406 |  16.451 |  17.309 |  16.628 |  16.331 |
# #### model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3
# |N_pages |Fibonacci| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 161.230 | 166.806 | 139.008 | 152.935 | 170.833 |
# |  23085 |  61.354 |  64.048 |  63.281 |  63.966 |  63.664 |  63.569 |
# |  43691 |  40.612 |  40.004 |  39.860 |  40.201 |  39.817 |  40.143 |
# |  75617 |  34.284 |  30.201 |  29.582 |  29.611 |  29.744 |  29.618 |
# |    740 |  35.621 |  33.801 |  34.143 |  34.101 |  34.290 |  34.145 |
# |     51 |  20.224 |  16.933 |  17.094 |  16.930 |  17.424 |  16.985 |
#
# #### model_9_CNN_with_Fibonacci_4_Ensemble
# |N_pages |Fibonacci| Model 0 |
# |--------|---------|---------|
# |   1879 |  57.385 | 146.145 |
# |  23085 |  61.354 |  64.128 |
# |  43691 |  40.612 |  40.052 |
# |  75617 |  34.284 |  29.862 |
# |    740 |  35.621 |  34.607 |
# |     51 |  20.224 |  16.023 |

# %% [markdown]
# ## Prediction Combine
# Combine group 0, 1 from Fib and rest from the model

# %%
Y_output_fib.shape
# Out:
# (145063, 1)

# %%
Y_output_fib_ori = np.repeat(Y_output_fib, y_length, axis=1); Y_output_fib_ori.shape
# Out:
# (145063, 63)

# %%
# Select group 0, 1
fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape
# Out:
# (145063, 1)

# %%
# The combined result
Y_output_fmc_ori_ens = []
for Y_output_pred_ori in Y_output_pred_ori_ens:
    
    Y_output_fmc_ori = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori
    
    Y_output_fmc_ori_ens.append(Y_output_fmc_ori)

# %%
Y_output_fmc_ori
# Out:
# array([[ 28.01709045,  27.8863257 ,  28.29876437, ...,  25.76354474,
#          25.29633754,  25.94749649],
#        [ 23.29458711,  24.05617622,  24.41074557, ...,  22.20339414,
#          21.58530887,  22.52307853],
#        [  4.        ,   4.        ,   4.        , ...,   4.        ,
#           4.        ,   4.        ],
#        ...,
#        [ 29.03831963,  30.79668599,  31.41995859, ...,  29.30488701,
#          28.14239607,  29.94105893],
#        [  7.75      ,   7.75      ,   7.75      , ...,   7.75      ,
#           7.75      ,   7.75      ],
#        [ 12.77091126,  10.78378789,  11.5977682 , ...,  13.85813817,
#          13.36614969,  14.72259607]])

# %%
model_smape_ens
# Out:
# [38.781974267207353,
#  38.797580089618442,
#  38.800477701161888,
#  38.798200959063713,
#  38.899448656374084]

# %%
if test_length: 
    fmc_smape_ens = []
    for Y_output_fmc_ori in Y_output_fmc_ori_ens:
        fmc_smape = smape(Y_output_fmc_ori, Y_output_raw)
        fmc_smape_ens.append(fmc_smape)        
    fmc_smape_ens_mean = np.mean(fmc_smape_ens)

# %%
if test_length: 
    for run, fmc_smape, model_smape in zip(ens_list, fmc_smape_ens, model_smape_ens):
        print('%6.3f' % fmc_smape, '(%6.3f)' % model_smape, '-', model_name, run)
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
# Out:
# 37.583 (38.782) - model_10_Modified_CNN_0_median_stdev 0
# 37.652 (38.798) - model_10_Modified_CNN_0_median_stdev 1
# 37.626 (38.800) - model_10_Modified_CNN_0_median_stdev 2
# 37.818 (38.798) - model_10_Modified_CNN_0_median_stdev 3
# 37.754 (38.899) - model_10_Modified_CNN_0_median_stdev 4
# 37.687 (38.816) - model_10_Modified_CNN_0_median_stdev Average

# %% [markdown]
# #### Combined Scores:
# 37.687 (38.816) - model_10_Modified_CNN_0_median_stdev Average
#
# 38.734 (39.415) - Model 9.1.0 - model_9_CNN_with_Fibonacci_1_no_group 1
#
# 38.227 (39.321) - Model 9.0.0 - model_9_CNN_with_Fibonacci_0_separate_Fib_median 1
#
# 43.009 (44.180) - Model 7.8.0 - model_7_CNN_with_Fibonacci_8_mean_absolute_error 2
#
# 44.070 (45.335) - Model 7.6.3 - model_7_CNN_with_Fibonacci_6_Wider_3_conv_120_Averagepool 1
#
# 44.473 (45.652) - Model 7.6.1 - model_7_CNN_with_Fibonacci_6_Wider_1_conv_120_Maxpool 1
#
# 44.433 - Model 7.5.0 - model_7_CNN_with_Fibonacci_5_Deeper_0_Initial
#
# 44.168 - Model 7.2.0

# %% [markdown]
# ## Ensemble Learning

# %%
Y_output_pred_ori_ens

# %% [markdown]
# ### Method 1 - Mean

# %%
Y_output_pred_ori_ens_mean = np.mean(Y_output_pred_ori_ens, axis=0)

# %%
Y_output_pred_ori_ens_mean.shape
# Out:
# (145063, 63)

# %% [markdown]
# Y_output_pred_ori_ens_mean

# %%
smape(Y_output_pred_ori_ens_mean, Y_output_raw)
# Out:
# 38.869025831837448

# %% [markdown]
# ### Method 2 - Median

# %%
Y_output_pred_ori_ens_med = np.median(Y_output_pred_ori_ens, axis=0)

# %%
Y_output_pred_ori_ens_med.shape
# Out:
# (145063, 63)

# %% [markdown]
# Y_output_pred_ori_ens_med

# %%
smape(Y_output_pred_ori_ens_med, Y_output_raw)
# Out:
# 38.620586961564996

# %% [markdown]
# ### Method 3 - Mean before inverse transform and log

# %%
Y_output_pred_ens_mean = np.mean(Y_output_pred_ens, axis=0)
Y_output_pred_ens_mean_ori = unlog(untransform(Y_output_pred_ens_mean, output_center, output_scale))

# %%
smape(Y_output_pred_ens_mean_ori, Y_output_raw)
# Out:
# 38.769464925281838

# %% [markdown]
# ### Method 4 - Median before inverse transform and log

# %%
Y_output_pred_ens_med = np.median(Y_output_pred_ens, axis=0)
Y_output_pred_ens_med_ori = unlog(untransform(Y_output_pred_ens_med, output_center, output_scale))

# %%
smape(Y_output_pred_ens_med_ori, Y_output_raw)
# Out:
# 38.620586961564996

# %% [markdown]
# Best ways seem to be taking median either before or after transformation.

# %% [markdown]
# ### Ensemble Combine with Fibonacci Median

# %%
# Select group 0, 1
fib_mask = ((output_gp == 0)|(output_gp == 1)).reshape(-1,1); fib_mask.shape
# Out:
# (145063, 1)

# %%
# The combined result

Y_output_fmc_ori = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori
Y_output_pred_ens_med_ori
# Out:
# array([[ 24.31284783,  24.80548325,  25.18046906, ...,  24.27431746,
#          23.81172835,  24.4367356 ],
#        [ 26.02571694,  26.20181696,  26.77890944, ...,  23.18114653,
#          22.55339728,  23.24782331],
#        [  3.44014823,   3.68366573,   3.36283533, ...,   3.29010504,
#           3.3687697 ,   3.61722868],
#        ...,
#        [ 30.47952252,  32.15962137,  33.03829822, ...,  31.13491518,
#          30.00493242,  31.49540946],
#        [  6.95438656,   7.22314889,   6.83119515, ...,   6.8742709 ,
#           6.7118889 ,   7.21505335],
#        [  8.05731149,   7.54166947,   7.73842967, ...,   9.363081  ,
#           8.98574088,   9.92741165]])

# %%
Y_output_f_omean = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori_ens_mean
Y_output_f_omed  = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ori_ens_med
Y_output_f_meano = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ens_mean_ori
Y_output_f_medo  = fib_mask * Y_output_fib_ori + (~fib_mask) * Y_output_pred_ens_med_ori

# %%
if test_length:
    f_omean_smape = smape(Y_output_raw, Y_output_f_omean)
    f_omed_smape = smape(Y_output_raw, Y_output_f_omed)
    f_meano_smape = smape(Y_output_raw, Y_output_f_meano)
    f_medo_smape = smape(Y_output_raw, Y_output_f_medo)

# %%
if test_length: # The_score
    print('%6.3f         ' % f_omean_smape, '-', model_name, 'ori_ens_mean')
    print('%6.3f         ' % f_omed_smape, '-', model_name, 'ori_ens_med')
    print('%6.3f         ' % f_meano_smape, '-', model_name, 'ens_mean_ori')
    print('%6.3f         ' % f_medo_smape, '-', model_name, 'ens_med_ori')
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
# Out:
# 37.436          - model_10_Modified_CNN_0_median_stdev ori_ens_mean
# 37.382          - model_10_Modified_CNN_0_median_stdev ori_ens_med
# 37.394          - model_10_Modified_CNN_0_median_stdev ens_mean_ori
# 37.382          - model_10_Modified_CNN_0_median_stdev ens_med_ori
# 37.687 (38.816) - model_10_Modified_CNN_0_median_stdev Average

# %%
if test_length: 
    for run, fmc_smape, model_smape in zip(ens_list, fmc_smape_ens, model_smape_ens):
        print('%6.3f' % fmc_smape, '(%6.3f)' % model_smape, '-', model_name, run)
    print('%6.3f' % fmc_smape_ens_mean, '(%6.3f)' % model_smape_ens_mean, '-', model_name, 'Average')
# Out:
# 37.583 (38.782) - model_10_Modified_CNN_0_median_stdev 0
# 37.652 (38.798) - model_10_Modified_CNN_0_median_stdev 1
# 37.626 (38.800) - model_10_Modified_CNN_0_median_stdev 2
# 37.818 (38.798) - model_10_Modified_CNN_0_median_stdev 3
# 37.754 (38.899) - model_10_Modified_CNN_0_median_stdev 4
# 37.687 (38.816) - model_10_Modified_CNN_0_median_stdev Average

# %% [markdown]
# Ensemble of model are all better than the individual model.

# %%
fmc_smape_ens
# Out:
# [37.582776576881216,
#  37.652157945887168,
#  37.625518077549707,
#  37.81823438931761,
#  37.754247776116046]

# %%
fmc_smape_ens_mean
# Out:
# 37.686586953150353

# %% [markdown]
#  Y_output_ori_list = [Y_output_ori[output_gp == gp] for gp in gp_list]

# %% [markdown]
# ### All Group Scores

# %%
# ensemble result Y_output in each group
Y_output_pred_ori_ens_mean_list = [Y_output_pred_ori_ens_mean[output_gp == gp] for gp in gp_list]
Y_output_pred_ori_ens_med_list = [Y_output_pred_ori_ens_med[output_gp == gp] for gp in gp_list]
Y_output_pred_ens_mean_ori_list = [Y_output_pred_ens_mean_ori[output_gp == gp] for gp in gp_list]
Y_output_pred_ens_med_ori_list = [Y_output_pred_ens_med_ori[output_gp == gp] for gp in gp_list]

# %%
# Group SMAPE scores
if test_length:
    # SMAPE with nan values ignored (used by Kaggle)
    gp_omean_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_ens_mean_list)]
    gp_omed_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ori_ens_med_list)]
    gp_meano_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ens_mean_ori_list)]
    gp_medo_smape = [smape(Y, Y_p) for Y, Y_p in zip(Y_output_raw_list, Y_output_pred_ens_med_ori_list)]
    
    # SMAPE contribution
    #gp_smape_sum = [s * n for n, s in zip(gp_smape, n_not_nan_gp)]
    #gp_smape_cont = [s / n_not_nan for s in gp_smape_sum]

# %%
if test_length:  # The_gp_score
    print('#### ' + model_name)
    print('', end='|')
    print(' N_pages', 'Fibonacci', ' ori mean', 'ori media', ' mean ori', 'media ori', sep='|', end='|')
    for run in ens_list: print(' Model', run, end=' |')
    print('')
    print('', end='|')
    print('--------', '---------', '---------', '---------', '---------', '---------', sep='|', end='|')
    for run in ens_list: print('---------', end='|')
    print('')
    for gp in gp_list:
        print('', end='|')
        print(' %6d ' % gp_n[gp], end='|')
        print(' %7.3f ' % gp_smape_fib[gp], end='|')
        print(' %7.3f ' % gp_omean_smape[gp], end='|')
        print(' %7.3f ' % gp_omed_smape[gp], end='|')
        print(' %7.3f ' % gp_meano_smape[gp], end='|')
        print(' %7.3f ' % gp_medo_smape[gp], end='|')
        for run in ens_list:
            print(' %7.3f ' % gp_smape_ens[run][gp], end='|')
        print('')
# Out:
# #### model_10_Modified_CNN_0_median_stdev
# | N_pages|Fibonacci| ori mean|ori media| mean ori|media ori| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 199.741 | 172.496 | 191.624 | 172.496 | 161.576 | 156.487 | 166.024 | 139.355 | 159.019 |
# |  23085 |  61.354 |  64.110 |  64.122 |  64.116 |  64.122 |  64.389 |  64.273 |  64.008 |  63.988 |  64.148 |
# |  43691 |  40.612 |  39.620 |  39.564 |  39.574 |  39.564 |  39.684 |  39.842 |  39.969 |  39.808 |  40.173 |
# |  75617 |  34.284 |  29.300 |  29.231 |  29.248 |  29.231 |  29.538 |  29.575 |  29.454 |  29.907 |  29.573 |
# |    740 |  35.621 |  33.403 |  33.482 |  33.373 |  33.482 |  33.564 |  33.710 |  33.397 |  33.666 |  33.965 |
# |     51 |  20.224 |  16.360 |  16.338 |  16.361 |  16.338 |  16.406 |  16.451 |  17.309 |  16.628 |  16.331 |

# %% [markdown]
# #### model_9_CNN_with_Fibonacci_4_Ensemble_3_filter_3
# | N_pages|Fibonacci| ori mean|ori media| mean ori|media ori| Model 0 | Model 1 | Model 2 | Model 3 | Model 4 |
# |--------|---------|---------|---------|---------|---------|---------|---------|---------|---------|---------|
# |   1879 |  57.385 | 199.921 | 173.799 | 189.346 | 173.799 | 161.230 | 166.806 | 139.008 | 152.935 | 170.833 |
# |  23085 |  61.354 |  63.635 |  63.651 |  63.644 |  63.651 |  64.048 |  63.281 |  63.966 |  63.664 |  63.569 |
# |  43691 |  40.612 |  39.693 |  39.628 |  39.637 |  39.628 |  40.004 |  39.860 |  40.201 |  39.817 |  40.143 |
# |  75617 |  34.284 |  29.444 |  29.368 |  29.381 |  29.368 |  30.201 |  29.582 |  29.611 |  29.744 |  29.618 |
# |    740 |  35.621 |  33.858 |  33.893 |  33.837 |  33.893 |  33.801 |  34.143 |  34.101 |  34.290 |  34.145 |
# |     51 |  20.224 |  16.861 |  16.948 |  16.856 |  16.948 |  16.933 |  17.094 |  16.930 |  17.424 |  16.985 |

# %%
smape_gpm_gp_ens = []

# %%
# %%time
for run in ens_list:
    print('Run', run)
    models = models_ens[run]
    Y_output_all_ori_list = unlog(np.array([untransform(model.predict([X_output, A_output]), output_center, output_scale) 
                                            for model in models]))
    # row: model of the group; column: group of Y
    smape_gpm_gp = [[smape(Y, Y_p[output_gp == gp]) for gp, Y in zip(gp_list, Y_output_raw_list)] 
                    for Y_p in Y_output_all_ori_list]
    smape_gpm_gp_ens.append(smape_gpm_gp)
# Out:
# Run 0
# Run 1
# Run 2
# Run 3
# Run 4
# Wall time: 6min 2s

# %%
smape_gpm_gp_ens = np.array(smape_gpm_gp_ens)

# %%
smape_gpm_gp_mean = np.mean(smape_gpm_gp_ens, axis=0)

# %%
print('Ensemble avg  ', end='|')
for j in range(len(smape_gpm_gp_mean[0])): print(' group', j, end='|')
print('')
print('--------------', end='|')
for j in range(len(smape_gpm_gp_mean[0])): print('--------', end='|')
print('')
for i in range(len(smape_gpm_gp_mean)):
    print('group model', i, end=' |')
    for j in range(len(smape_gpm_gp_mean[0])):
        print(' %6.2f ' % smape_gpm_gp_mean[i][j], end='|')
    print('')
# Out:
# Ensemble avg  | group 0| group 1| group 2| group 3| group 4| group 5|
# --------------|--------|--------|--------|--------|--------|--------|
# group model 0 | 156.49 |  61.39 |  40.62 |  34.30 |  35.64 |  20.23 |
# group model 1 | 166.82 |  64.16 |  40.47 |  33.75 |  35.44 |  19.66 |
# group model 2 | 161.12 |  64.32 |  39.89 |  30.83 |  33.61 |  15.67 |
# group model 3 | 172.63 |  65.23 |  40.39 |  29.61 |  30.65 |  16.66 |
# group model 4 | 120.70 |  70.48 |  43.17 |  33.50 |  33.66 |  19.82 |
# group model 5 | 169.95 |  67.42 |  45.30 |  37.75 |  43.21 |  16.63 |

# %% [markdown]
# ### Plots

# %%
view_list=[93175, 13986, 5464, 89589, 119659, 64392, 73856, 140331, 19234, 25591]; view_list
# Out:
# [93175, 13986, 5464, 89589, 119659, 64392, 73856, 140331, 19234, 25591]

# %% [markdown]
# view_list = examine_list_gp((Y_output_ori,
#                              Y_output_pred_ori_ens_mean,
#                              Y_output_pred_ori_ens_med,
#                              Y_output_pred_ori_ens[-1],
#                              ), output_gp, view_list=view_list)

# %% [markdown]
# i = 93175
# plt.plot(Y_output_ori[i], label='true')
# plt.plot(Y_output_pred_ori_ens_mean[i], label='ens mean')
# plt.plot(Y_output_pred_ori_ens_med[i], label='ens median')
# plt.plot(Y_output_pred_ens_mean_ori[i], label='ens mean before transf')
# plt.plot(Y_output_pred_ens_med_ori[i], label='ens median before transf')
# plt.plot(Y_output_pred_ori_ens[-1][i], label='run: 4')
# plt.title('i = ' + str(i) + ' gp = ' + str(output_gp[i]))
# plt.legend()
# plt.show()

# %% [markdown]
# i = 93175
# plt.plot(Y_output_ori[i], label='true')
# for run in ens_list:
#     plt.plot(Y_output_pred_ori_ens[run][i], label='run' + str(run))
# plt.plot(Y_output_pred_ens_mean_ori[i], label='ens mean before transf')
# plt.title('i = ' + str(i) + ' gp = ' + str(output_gp[i]))
# plt.legend()
# plt.show()

# %%
view_list = examine_list_gp((Y_output_pred_ori_ens_mean, 
                             Y_output_pred_ori_ens_med,
                             Y_output_pred_ori_ens[-1], 
                             Y_output_ori), output_gp, view_list=view_list)

# %% [markdown]
# ## Case Study

# %% [markdown]
# view_list = comp_examine(X_output, Y_output_pred, view_list=view_list)

# %%
view_list
# Out:
# [93175, 13986, 5464, 89589, 119659, 64392, 73856, 140331, 19234, 25591]

# %% [markdown]
# view_list = comp_examine(X_output_ori, Y_output_pred_ori, view_list=view_list)

# %%
view_list = examine_list_gp((Y_output_pred_ori, X_output_ori, Y_input_ori), output_gp, view_list=view_list)

# %%
view_list = examine_list_gp((Y_output_pred, X_output, Y_input), output_gp, view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list((Y_output_pred, Y_output, X_output), view_list=view_list)

# %% [markdown]
# if test_length:
#     view_list = examine_list((Y_output_pred_ori, Y_output_ori, X_output_ori), view_list=view_list)

# %%
if test_length:
    view_list = examine_list_gp((Y_output_pred, Y_output, X_output), output_gp,
                             view_list=view_list)

# %%
if test_length:
    view_list = examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori), output_gp,
                             view_list=view_list)

# %%
view_list_smape = [smape(Y_output_pred_ori[i], Y_output_raw[i]) for i in view_list]; view_list_smape
# Out:
# [31.324016453516229,
#  79.476734413499045,
#  23.957087168459996,
#  47.736318643175323,
#  28.076116489024809,
#  26.874541947896319,
#  15.333611475669059,
#  42.302686848871787,
#  25.773616444585695,
#  15.716168107014544]

# %%
view_list_review = [score < model_smape for score in view_list_smape]; view_list_review
# Out:
# [True, False, True, False, True, True, True, False, True, True]

# %%
view_list_good = list(np.array(view_list)[view_list_review]); view_list_good
# Out:
# [93175, 5464, 119659, 64392, 73856, 19234, 25591]

# %%
view_list_bad = list(np.array(view_list)[~np.array(view_list_review)]); view_list_bad
# Out:
# [13986, 89589, 140331]

# %% [markdown]
# #### Good cases

# %% [markdown]
# examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori), output_gp,
#              view_list=view_list_good)

# %% [markdown]
# #### Bad cases

# %% [markdown]
# examine_list_gp((Y_output_pred_ori, Y_output_ori, X_output_ori),output_gp,
#              view_list=view_list_bad)

# %%
print(output_center[view_list_good].reshape(-1))
print(output_center[view_list_bad].reshape(-1))
# Out:
# [ 2.61225391  1.78532984  2.56555268  2.07280115  3.41796964  2.61489722
#   1.85125835]
# [ 0.30103     1.46612587  2.14921911]

# %%
print(output_scale[view_list_good].reshape(-1))
print(output_scale[view_list_bad].reshape(-1))
# Out:
# [ 0.45758495  0.13744919  0.17725717  0.12048413  0.09144428  0.18993217
#   0.07964336]
# [ 0.20849044  0.50503777  0.29619523]

# %%
output_gp[view_list_good]
# Out:
# array([3, 2, 3, 3, 3, 3, 2])

# %%
output_gp[view_list_bad]
# Out:
# array([1, 2, 3])

# %% [markdown]
# #### Case 93175

# %%
i = 93175

# %% [markdown]
# multi_view((Y_output_pred_ori[i], Y_output_ori[i], X_output_ori[i]), yscale='log')
# multi_view((Y_output_pred_ori[i], Y_output_ori[i], X_output_ori[i]))

# %% [markdown]
# smape(Y_output_pred_ori[i], Y_output_raw[i])

# %% [markdown]
# input_center[i], output_center[i], input_scale[i], output_scale[i]

# %% [markdown]
# #### Case 41896

# %% [markdown]
# i = 41896

# %% [markdown]
# multi_view((X_input[i], Y_input[i]))

# %% [markdown]
# comp_view(X_input_ori[i], Y_input_ori[i])

# %% [markdown]
# comp_view(X_output_ori[i], Y_output_pred_ori[i])

# %% [markdown]
# comp_view(X_input_ori[i], Y_input_ori[i])

# %% [markdown]
# ### Good and bad cases

# %% [markdown]
# review_Y = np.array([score < model_smape for score in smape_Y_pred])
# good_Y_index = np.arange(len(Y_output_pred))[review_Y]; #good_Y_index
# bad_Y_index = np.arange(len(Y_output_pred))[~review_Y]; #bad_Y_index

# %% [markdown]
# good_input_scale = input_scale[good_Y_index]
# good_output_scale = output_scale[good_Y_index]
# bad_input_scale = input_scale[bad_Y_index]
# bad_output_scale = output_scale[bad_Y_index]

# %% [markdown]
# good_input_center = input_center[good_Y_index]
# good_output_center = output_center[good_Y_index]
# bad_input_center = input_center[bad_Y_index]
# bad_output_center = output_center[bad_Y_index]

# %% [markdown]
# examine_list_gp((Y_output_pred_ori[good_Y_index], Y_output_ori[good_Y_index], X_output_ori[good_Y_index]), output_gp[good_Y_index])

# %% [markdown]
# examine_list_gp((Y_output_pred_ori[bad_Y_index], Y_output_ori[bad_Y_index], X_output_ori[bad_Y_index]), output_gp[bad_Y_index])

# %% [markdown]
# good_output_scale.min(), good_output_scale.max()

# %% [markdown]
# bad_output_scale.min(), bad_output_scale.max()

# %% [markdown]
# plt.hist(good_input_scale, bins=40, alpha=0.6, label='good input')
# plt.hist(bad_input_scale, bins=40, alpha=0.6, label='bad input')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_output_scale, bins=40, alpha=0.6, label='good output')
# plt.hist(bad_output_scale, bins=40, alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_input_scale, bins=40, alpha=0.6, label='good input')
# plt.hist(bad_input_scale, bins=40, alpha=0.6, label='bad input')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.hist(good_output_scale, bins=40, alpha=0.6, label='good output')
# plt.hist(bad_output_scale, bins=40, alpha=0.6, label='bad output')
# plt.yscale('log')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(good_input_scale, bins=100, range=(0,0.8), alpha=0.6, label='good input')
# plt.hist(good_output_scale, bins=100, range=(0,0.8), alpha=0.6, label='good output')
# plt.hist(bad_input_scale, bins=100, range=(0,0.8), alpha=0.6, label='bad input')
# plt.hist(bad_output_scale, bins=100, range=(0,0.8), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# Should we split the data into std > and < 1.7 ?

# %%
np.mean(good_output_scale), np.mean(good_input_scale)
# Out:
# (0.14823512183053353, 0.18748276181141144)

# %%
np.mean(bad_output_scale), np.mean(bad_input_scale)
# Out:
# (0.22998480893524639, 0.25785562296572406)

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(bad_input_scale, bins=60, range=(0,0.8), alpha=0.6, label='bad input')
# plt.hist(bad_output_scale, bins=60, range=(0,0.8), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(output_scale, bins=40, alpha=0.6, label='output')
# plt.hist(input_scale, bins=40, alpha=0.6, label='input')
# plt.legend()
# plt.show()

# %% [markdown]
# np.histogram(output_scale, bins=np.arange(0,1,0.05))

# %% [markdown]
# #### Median

# %% [markdown]
# plt.figure(figsize=(12,4))
# plt.hist(good_input_center, bins=100, range=(0,5), alpha=0.6, label='good input')
# plt.hist(good_output_center, bins=100, range=(0,5), alpha=0.6, label='good output')
# plt.hist(bad_input_center, bins=100, range=(0,5), alpha=0.6, label='bad input')
# plt.hist(bad_output_center, bins=100, range=(0,5), alpha=0.6, label='bad output')
# plt.yscale('linear')
# plt.legend()
# plt.show()

# %%
gc.collect()
# Out:
# 69660

# %% [markdown]
# ### stdev/median

# %% [markdown]
# output_factor_1 = (output_center / output_scale).reshape(-1); output_factor_1

# %% [markdown]
# output_factor_1.min(), output_factor_1.max()

# %% [markdown]
# plt.hist(output_factor_1, bins=40, range=[0,50], alpha=0.6)
# plt.show()

# %% [markdown]
# plt.scatter(smape_Y_pred, output_scale, alpha=0.1, marker='.')
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_center, alpha=0.1, marker='.')
# plt.ylim([-0.1,5])
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_scale, alpha=0.1, marker='.')
# plt.ylim([0,0.5])
# plt.show()

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(output_scale, output_center, alpha=0.1, marker='.')
# plt.ylim([0,4.5])
# plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_2 = (output_scale / output_center).reshape(-1); output_factor_2

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_2, alpha=0.1, marker='.')
# plt.ylim([0,0.8])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_3 = (output_scale / (output_center + 0.01)).reshape(-1); output_factor_3

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_3, alpha=0.1, marker='.')
# plt.ylim([0,4])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# output_factor_4 = output_scale - input_scale

# %% [markdown]
# plt.figure(figsize=(12,9))
# plt.scatter(smape_Y_pred, output_factor_4, alpha=0.1, marker='.')
# plt.ylim([-1.5,0.5])
# #plt.xlim([0,0.6])
# plt.show()

# %% [markdown]
# ## Output Prediction
# For predicting stage only

# %% [markdown]
# ### Result DataFrame

# %% [markdown]
# predict_dates_index=pd.date_range(Y_output_first_day,
#                                   periods=np.timedelta64(y_length,'D'),
#                                   freq = 'D', unit = 'D')
# predict_dates_index

# %%
Y_output_dates

# %%
if test_length == 0:
    result_df = pd.DataFrame(Y_output_f_omed, columns = Y_output_dates)  # using ensemble median combined result
result_df

# %%
result_df['Page'] = input_df['Page']  # Append 'Page' column from input_df
result_df

# %%
result_flat_df = pd.melt(result_df, id_vars='Page', var_name='date',
                         value_name='Visits')
result_flat_df

# %% [markdown]
# ### Output DataFrame

# %%
if test_length == 0:
    print('%%% Reading data key_1.csv ...', end = '', flush = True)
    output_df = pd.read_csv("../data/key_1.csv")
    print('done!')

# %%
output_df['date'] = output_df.Page.apply(lambda a: a[-10:])  # take the last 10 characters from 'Page' as date
output_df['Page'] = output_df.Page.apply(lambda a: a[:-11])  # remove the last 10 caharacters from 'Page'
#output_df['date'] = output_df['date'].astype('datetime64[ns]')  # convert 'date' string to numpy datetime format
#test['weekday'] = test.date.dt.dayofweek  # find the day of week using the 'date' column
output_df.head()

# %%
output_df.info()

# %%
output_df['date'].values[0:62]  # Make sure the range is 60 days (see if the dates resume after 60)

# %%
Y_output_dates

# %%
output_df = output_df.merge(result_flat_df, how='left')  # fill the 'Visits" from result
output_df

# %%
del result_flat_df

# %%
gc.collect()

# %%
#Check if there is null value
output_df.loc[output_df.Visits.isnull(), 'Visits']

# %%
#output_df.loc[output_df.Visits.isnull(), 'Visits'] = 0.0  # Uncommend this line to Replace NaN with 0.0

# %%
print('%%% Writing result for ' + model_name + ' ...', 
      end = '', flush = True)
#Write only the 'Id' and 'Visits' to the result file
output_df[['Id','Visits']].to_csv('../results/submit_1_' + model_name
                                  + '.csv', index = False, 
                                  float_format='%.3f')
print('done!')

# %% [markdown]
# Kaggle LB Score:
#
# [6.0.0] 46.3 [Model 6.0.0 CNN - Conv(60, 7)-FC(120)-Drop(0.25)-FC(120)-Drop(0.5)-Linear, 20 epoches]
#
# [6.1.0] 46.7 [Model 6.1.0 CNN - Conv(30, 7)-Conv(60, 7)-FC(120)-Drop(0.25)-FC(120)-Drop(0.5)-Linear, 20 epoches]
#
# [7.1.2] 47.3 [Model 7.1.2 CNN Fibonacci - range corrected :-y_length - score corrected]
#
# [7.2.0] 46.5 [Model 7.2.0 CNN Fibonacci and original combined]
